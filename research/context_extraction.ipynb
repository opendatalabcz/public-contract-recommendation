# %% [markdown]
# ### Initialization

# %%
import glob
import json
import re
import numpy
import pandas

# %%
from utils.text_extraction import *
from utils.document_processing import *
from utils.subject_extraction import *
from utils.similarity import *
from utils.context_extraction import *

# %%
import psycopg2
psycopg2_conn = psycopg2.connect(dbname='public_contracts', user='postgres', password='admin', host='localhost', port='5432')

# %% [markdown]
# ### Subject context

# %%
from utils.context_extraction import *

# %% [markdown]
# ### EvaluationMachine

# %%
class SubjectContextSelectionEvaluationMachine():
    
    _contracts = None
    _df_contracts = None
    _subj_context_extractor = None
    _func_params = None
    
    def __init__(self, contracts, subj_context_extractor=SubjectContextExtractor, func_params={}):
        self._contracts = contracts
        self._subj_context_extractor = subj_context_extractor
        self._func_params = func_params
    
    def process(self):
        for contr in self._contracts:
            contr_text = contr['text']
            contr['subj_context'] = self._subj_context_extractor(**self._func_params).get_subject_context(contr_text)
        self._df_contracts = pandas.DataFrame(self._contracts).set_index('id')
        return self._df_contracts
    
    def evaluate(self):
        return self._df_contracts['subj_context'].isna().sum()

# %%
class ComplexSubjectContextSelectionEvaluationMachine(SubjectContextSelectionEvaluationMachine):
    
    _path_to_data = None
    _validator = None
    
    def __init__(self, path_to_data, validator=validate_subj_contexts, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self._path_to_data = path_to_data
        self._validator = validator
    
    def process(self):
        super().process()
        self._df_contracts = self._validator(self._df_contracts, self._path_to_data)
        self._df_contracts['valid']=False
        df_tmp = self._df_contracts[self._df_contracts.valid_rat>0.5].copy()
        df_tmp['valid']=True
        self._df_contracts['valid']=df_tmp['valid']
        return self._df_contracts
        
    def evaluate(self):
        return self._df_contracts['valid_rat'].mean()*100

# %% [markdown]
# ### Documents

# %%
from utils.document_processing import *

# %%
loader = DatabaseDocumentLoader(psycopg2_conn)
loader.load_documents()
documents = loader.prepare_documents()
# Out:
# Running query: select * from document where processed=True
# Preparing total 998 documents
# Progress: 0.0%
# Progress: 10.0%
# Progress: 20.0%
# Progress: 30.0%
# Progress: 40.0%
# Progress: 50.0%
# Progress: 60.0%
# Progress: 70.0%
# Progress: 80.0%
# Progress: 90.0%
# Progress: 100.0%

# %%
vzdirs = '../test-data/*/*/*/*'
ignore_contracts = ['2096','sportovni-areal-zs-slatina-1-etapa_25534',
                    'revitalizace-lokality-spaliste-k-u-stare-mesto-u-uherskeho-hradiste-akceptacni-cislo-12136894-cz-1-02-4-2-00-12-16399-dodatecne-prace_9496',
                    '35226', 'kompostujeme-v-obci-sebranice-dodavka-stepkovace-a-komposteru', 'zvysovani-povedomi-verejnosti-o-biodiverzite-luk-a-pastvin',
                    'nakup-noveho-uzitkoveho-elektromobilu-typu-bev-vozidlo-s-bateriovym-pohonem']

ref_loader = ReferenceDocumentLoader(vzdirs)
# ref_loader.extract_text_from_documents(0,1024)
ref_loader.load_documents_from_extracts(ignore_contracts)
ref_documents = ref_loader.prepare_documents()
# Out:
# Loading total 316 extracts
# Preparing total 316 documents
# Progress: 0.0%
# Progress: 10.0%
# Progress: 20.0%
# Progress: 30.0%
# Progress: 40.0%
# Progress: 50.0%
# Progress: 59.0%
# Progress: 69.0%
# Progress: 79.0%
# Progress: 89.0%
# Progress: 99.0%

# %%
ignore_mask = count_occurence_vector('qwertyuiopasdfghjklzxcvbnmQWERTYUIOPASDFGHJKLZXCVBNMáčďéěíňóřšťúůýžÁČĎÉĚÍŇÓŘŠŤÚŮÝŽ0123456789')
ignore_mask[0]=0
matcher = DocumentMatcher(ref_documents, documents)
matcher.count_most_similar_documents(ignore_mask=ignore_mask)
matcher.aggregate_documents()
df_contract = matcher.filter_aggregated()
# Out:
# Collecting document matrix
# Counting most similar documents for total 316 reference documents
# Progress: 0.0%
# Progress: 10.0%
# Progress: 20.0%
# Progress: 30.0%
# Progress: 40.0%
# Progress: 50.0%
# Progress: 59.0%
# Progress: 69.0%
# Progress: 79.0%
# Progress: 89.0%
# Progress: 99.0%

# %% [markdown]
# ### Measurements

# %%
contracts = []
for contr_name, docs in df_contract.groupby('contr_name'):
    contr_text = ''
    contr_ids = []
    for index, doc in docs.iterrows():
        doc_name = doc['doc_name']
        contr_text += '======================='+doc_name+'=======================\n'
        contr_text += doc['doc_text']
        contr_ids.append(doc['contr_id'])
    contr_id = get_most_frequent(contr_ids)
    contr = {'id': contr_id, 'contr_name': contr_name, 'text': contr_text}
    contracts.append(contr)

# %%
# %%time 

vzdirs = '../test-data/*/*/*'

keywords = {
    'Předmět smlouvy':10,
    'Předmět díla':10,
    'Předmět plnění':10,
    'Předmět veřejné zakázky':10,
    'Vymezení předmětu':10,
    'Vymezení plnění': 10,
    'Název veřejné zakázky': 3,
    'Veřejná zakázka':1,
    'Veřejné zakázce':1,
    'Předmět': 1
   }
evaluator = ComplexSubjectContextSelectionEvaluationMachine(vzdirs, validator=validate_subj_contexts_v2, contracts=contracts,
                                                            subj_context_extractor=AdvancedSubjectContextExtractor,
                                                            func_params={'keywords': keywords, 'subj_range': 2000})
evaluator.process()
score = evaluator.evaluate()
print('Score: ' + str(score))
print('Improve: ' + str(score - last_score))
last_score = score
# df_last_contracts = df_contracts
df_contracts = evaluator._df_contracts
# scores3['w/o_capitals'] = score
# Out:
# C:\x\diplomka\research\researchenv\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# Score: 74.79669084074135
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <timed exec> in <module>
#
# NameError: name 'last_score' is not defined

# %%
save_valid_contexts(df_contracts, df_contract)

# %%
# %%time 

vzdirs = '../test-data/*/*/*'

keywords = {
    'Předmět smlouvy':10,
    'Předmět díla':10,
    'Předmět plnění':10,
    'Předmět veřejné zakázky':10,
    'Vymezení předmětu':10,
    'Vymezení plnění': 10,
    'Název veřejné zakázky': 3,
    'Veřejná zakázka':1,
    'Veřejné zakázce':1,
    'Předmět': 1
   }
evaluator = SubjectExtractionEvaluationMachine(vzdirs, df_contracts, subj_extractor=SubjectExtractor,
                                               func_params={'keywords': keywords, 'subj_range':4000})
evaluator.process()
score = evaluator.evaluate()
print('Score: ' + str(score))
print('Improve: ' + str(score - last_score))
last_score = score
# scores2['"Předmět"_1'] = score
# Out:
# Score: 18.89384029423359
# Improve: 0.0
# Wall time: 226 ms

# %% [markdown]
# ### Playground

# %%
df_contracts.reset_index()
# Out:
#      id                                         contr_name  \
# 0    71  e-zakazky/48a575ba-f8fe-47f2-bbb6-c6ddb26390ef...
# 1    72  e-zakazky/73b0be6b-6b49-4ab4-a6a0-508b83a305e1...
# 2    74  e-zakazky/c265fdf8-044f-44e5-b36e-df4ca53c6179...
# 3    61                    eagri/mze/contract_display_6220
# 4    64                             ezak/mpsv/P15V00000447
# 5    66                             ezak/mpsv/P16V00000187
# 6    67                             ezak/mpsv/P16V00000240
# 7   103                              nipez/mo/P18V00009525
# 8   207                              nipez/mo/P18V00012708
# 9   397                              nipez/mo/P18V00019354
# 10  488                              nipez/mo/P18V00022561
# 11  542                              nipez/mo/P19V00003599
# 12  714                            nipez/mpsv/P18V00010416
# 13  733                            nipez/mvcr/P18V00009631
# 14  755                            nipez/mvcr/P18V00015153
# 15  771                             nipez/mzv/P18V00000055
# 16  775                             nipez/mzv/P18V00016340
# 17  783                             nipez/mzv/P18V00017124
# 18  794                             nipez/mzv/P18V00026759
# 19  803                             nipez/mzv/P19V00001827
# 20  807                            stavebnionline/121/7941
# 21  806                         tenderarena/Comgate/201480
# 22  808                   tenderarena/JihoceskyKraj/255714
# 23  820                   tenderarena/Libereckykraj/219512
# 24  805                         tenderarena/agrozet/102972
# 25   52                              tenderarena/mo/171826
# 26  825                              tenderarena/msp/85449
# 27  826  vhodne-uverejneni/00254592/oprava-casti-mk-c-1...
# 28  828  vhodne-uverejneni/00291846/zdrave-mesto-ivanov...
# 29  829  vhodne-uverejneni/26272784/vzdelavani-zamestna...
# 30  830  vhodne-uverejneni/70504539/dodavka-projekcni-a...
# 31  831  vhodne-uverejneni/buly-arena-aquapark-kravare-...
# 32  832  vhodne-uverejneni/bw-naradi-s-r-o/materialove-...
# 33  833  vhodne-uverejneni/e-c-l-spol-s-r-o/kompostarna...
# 34  834  vhodne-uverejneni/flamesite-s-r-o/dodavka-novy...
# 35  835  vhodne-uverejneni/olza-spol-s-r-o/porizeni-mec...
# 36  836  vhodne-uverejneni/stavos-chlumec-n-cidl-s-r-o/...
# 37  847  vhodne-uverejneni/ustav-experimentalni-botanik...
# 38  848  vhodne-uverejneni/vrcha-a-s/technologie-na-sni...
# 39  849  vhodne-uverejneni/zakladni-skola-velke-hamry-s...
#
#                                                  text  \
# 0   =======================2017126-115451.pdf=====...
# 1   =======================Formulář - Informace o ...
# 2   =======================Dodatečné informace 01....
# 3   =======================01_výzva k podání nabíd...
# 4   =======================AKRIS_příloha-01_Kvalif...
# 5   =======================Příloha č. 1 SOD_Projek...
# 6   =======================P1_Výkaz výměr (slepý)....
# 7   =======================VZOR_smlouvy.doc=======...
# 8   =======================Oznámení o výběru dodav...
# 9   =======================PSP s přílohami.zip====...
# 10  =======================185310292 podepsaná.pdf...
# 11  =======================199310279(2).pdf=======...
# 12  =======================Kupní smlouva na dodávk...
# 13  =======================017 Oznámení o výběru A...
# 14  =======================#KS DNS ICT 11-2018-III...
# 15  =======================Plovoucí vinylová podla...
# 16  =======================VZ-096.docx============...
# 17  =======================10. Výzva a Zadávací do...
# 18  =======================VZ-161.docx============...
# 19  =======================SM1719-001.pdf=========...
# 20  =======================Smlouva o dilo.pdf=====...
# 21  =======================CG_LogIII_ZD_Priloha_c....
# 22  =======================pril._c._2_-_Kupni_smlo...
# 23  =======================06_D01_OLP_465_2019_dod...
# 24  =======================00-AGZ-Servis_CB-ZD-tex...
# 25  =======================Prilohy_2,_3,_4_k__SoD....
# 26  =======================Oprava_terminu_prohlidk...
# 27  =======================SOD - ROADFIN stavby s....
# 28  =======================Ivanovice_Rozhodnuti o ...
# 29  =======================rik-fer_Obchodní podmín...
# 30  =======================00 Dodatečné informace ...
# 31  =======================xx Písemná zpráva zadav...
# 32  =======================Dodatek KS BW nářadí.pd...
# 33  =======================Image240915212616.pdf==...
# 34  =======================Přílohy_č. 1-4.odt=====...
# 35  =======================02_P1_KrycíList.doc====...
# 36  =======================1a_zadavaci_dokumentace...
# 37  =======================rozhodnutí o přidělení ...
# 38  =======================přílohy.doc============...
# 39  =======================deklerace k dodatku č. ...
#
#                                          subj_context  valid_rat  \
# 0   PŘEDMĚT SMLOUVY\nZhotovitel se zavazuje k prov...   0.733333
# 1   PŘEDMĚT DÍLA\n\n1.1. Předmětem díla je provede...   0.985050
# 2   Předmět smlouvy\n1. Zhotovitel se touto smlouv...   0.471039
# 3   Předmět smlouvy\n\nPředmětem smlouvy je proved...   0.975272
# 4   Předmět veřejné zakázky a sjednaná cena ve sml...   0.576923
# 5   Předmět smlouvy, předmět díla\n\nPředmětem tét...   0.928721
# 6   Předmět Smlouvy\n2.1. Zhotovitel se zavazuje p...   0.769231
# 7   Předmět smlouvy\n\n2.1. \nPředmětem smlouvy je...   0.993276
# 8   Název veřejné zakázky: Sponkovače a spojovací ...   0.466667
# 9   Předmět smlouvy\n\n\n1. Poskytovatel se zavazu...   0.833333
# 10  vymezení plnění veřejné zakázky:\n\nPředmětem ...   0.859903
# 11  Předmět smlouvy\n\n2.1. \nPředmětem smlouvy je...   0.986791
# 12  předmět Smlouvy \n\n\n1. Základním účelem, pro...   0.882943
# 13   veřejné zakázce\n\n„Náboje 308 Winchester SWISS“   0.384615
# 14  Předmět plnění\n1. Předmětem této smlouvy je d...   0.829268
# 15  Název veřejné zakázky:\n\tPlovoucí vinylová po...   0.611111
# 16  Předmět veřejné zakázky\nStručný popis předmět...   0.759615
# 17  Předmět veřejné zakázky\nStručný popis předmět...   0.692913
# 18  Předmět veřejné zakázky\nStručný popis předmět...   0.816176
# 19  Předmět smlouvy\n\n1. Předmětem zakázky je opr...   0.941729
# 20  Předmět smlouvy\n\n\n1. Název díla: Rekonstruk...   0.919192
# 21  PŘEDMĚT SMLOUVY\n1.5. Zhotovitel se zavazuje p...   0.329268
# 22  Předmět smlouvy\n\n1. Předmětem smlouvy je záv...   0.950311
# 23  Vymezení předmětu veřejné zakázky \n\n\n2.1. O...   0.918605
# 24  Předmět díla \n\n2.1. Předmětem díla je zejmén...   0.987528
# 25  Předmět veřejné zakázky  \n\nPředmětem plnění ...   0.881612
# 26  PŘEDMĚT SMLOUVY \n\n \n\n1. Zhotovitel se tout...   0.986150
# 27  Předmět smlouvy\n\n1.1. Zhotovitel se touto sm...   0.421053
# 28  Předmět plnění veřejné zakázky\n2.1 Předmět pl...   0.317152
# 29  Předmět veřejné zakázky\n\n4\n\nNázev veřejné ...   0.881188
# 30  Předmět smlouvy\n(1)     Na základě této smlou...   0.989324
# 31  předmět veřejné zakázky a cena sjednaná ve sml...   0.035149
# 32  Předmět veřejné zakázky\n\nPředmětem veřejné z...   0.860294
# 33  PŘEDMĚT PLNĚNÍ\n\n1. Na základě této smlouvy s...   0.834711
# 34  Předmět smlouvy\n\tTato smlouva se uzavírá na ...   0.929204
# 35  PŘEDMĚT VEŘEJNÉ ZAKÁZKY\n\n3.1 Vyhlášení zadáv...   0.940141
# 36  vymezení předmětu zakázky a požadavků zadavate...   0.829932
# 37  Předmět veřejné zakázky\n\nPředmětem veřejné z...   0.902062
# 38  Předmět plnění\nPředmětem plnění je dodávka a ...   0.418605
# 39  Název veřejné zakázky:\nZadavatel zakázky:\n\n...   0.089286
#
#                                           ref_context valid
# 0   \nSmlouva nabývá platnosti a účinnosti dnem po...  True
# 1   \nTito uvedení zástupci jsou oprávněni jednat ...  True
# 2   3. Zhotovitel prohlašuje, že je odborně způsob...   NaN
# 3   \n(dále jen „zhotovitel “ nebo „projektant“)\n...  True
# 4   \nvyhotovil tuto písemnou zprávu.\n\n1. Předmě...  True
# 5   \nprohlášení nebo v souvislosti s ní druhé sml...  True
# 6   \nmluvní straně vznikne.\nČlánek 2\nPředmět Sm...  True
# 7   Článek 2\n\nPředmět smlouvy\n\n2.1. \nPředměte...  True
# 8   \nIdentifikace veřejné zakázky\n\nNázev veřejn...   NaN
# 9   nutného k zabezpečení činnosti rezortu Ministe...  True
# 10  \nJana Velíšková, tel. + 420 973 225 210.\n\n2...  True
# 11  Újezd u Uničova s cílem zajištění bezpečného p...  True
# 12  \ntéto Smlouvy a je odborně způsobilý ke splně...  True
# 13  \nrozhodl o výběru dodavatele k veřejné zakázc...   NaN
# 14  \nStrana 2\n\nII.\nPředmět plnění\n1. Předměte...  True
# 15  \nIdentifikace veřejné zakázky\n\n\tNázev veře...  True
# 16  \nOdůvodnění: Veřejnou zakázku malého rozsahu....  True
# 17  \nNabídku lze podat pouze elektronicky (NEN a ...  True
# 18  \nOdůvodnění: Veřejnou zakázku malého rozsahu....  True
# 19  \nkteré vyplývají z této smlouvy a nejsou v ní...  True
# 20  \n(dále jen „zhotovitel“)\n\n\nII. Předmět sml...  True
# 21  \n1.4. Účelem této Smlouvy je úprava práv a po...   NaN
# 22  \nvůči třetí osobě.\nČlánek III.\n\nPředmět sm...  True
# 23  \nv článku 21 této zadávací dokumentace (dále ...  True
# 24  \n- ve věcech řízení stavby: tel:  e-mail: \n ...  True
# 25  \n  Telefon : +420 485 226 967 \n\n     \n\n2....  True
# 26  \ncenové nabídky zhotovitele ze dne…………….. \n\...  True
# 27  \n(dále také jako „smlouva“)\n\n1. Předmět sml...   NaN
# 28  \n(dále jen „zadavatel“)\n\n2. Předmět plnění ...   NaN
# 29  \nnebude podílet na zpracování žádné nabídky.\...  True
# 30    Článek II\n\nPředmět smlouvy\n(1)     Na zák...  True
# 31  \nProfil zadavatele: https://www.vhodne-uverej...   NaN
# 32  \nVeřejná zakázka na dodávky.\n\n3. Předmět ve...  True
# 33  \n(dále jen „prodávající“)\n\nPŘEDMĚT PLNĚNÍ\n...  True
# 34  \n(dále jen „smlouva“)\n\nI.\nPředmět smlouvy\...  True
# 35  \n3z15\n\n \n\n \n\n3. DRUH DODÁVKY, PŘEDMĚT V...  True
# 36  \nzastoupená: Ing. Zdeněk Hedvičák, ředitel di...  True
# 37  \nzadavatele.info/UEB.html\n\n3, Předmět veřej...  True
# 38  následovně:\nČL I\nPředmět plnění\nPředmětem p...   NaN
# 39  \nZAKÁZKY\n\n \n\n1. Identifikační údaje o zad...   NaN

# %%
df_last_contracts.reset_index()
# Out:
#      id                                         contr_name  \
# 0    71  e-zakazky/48a575ba-f8fe-47f2-bbb6-c6ddb26390ef...
# 1    72  e-zakazky/73b0be6b-6b49-4ab4-a6a0-508b83a305e1...
# 2    74  e-zakazky/c265fdf8-044f-44e5-b36e-df4ca53c6179...
# 3    61                    eagri/mze/contract_display_6220
# 4    64                             ezak/mpsv/P15V00000447
# 5    66                             ezak/mpsv/P16V00000187
# 6    67                             ezak/mpsv/P16V00000240
# 7   103                              nipez/mo/P18V00009525
# 8   207                              nipez/mo/P18V00012708
# 9   397                              nipez/mo/P18V00019354
# 10  488                              nipez/mo/P18V00022561
# 11  542                              nipez/mo/P19V00003599
# 12  714                            nipez/mpsv/P18V00010416
# 13  733                            nipez/mvcr/P18V00009631
# 14  755                            nipez/mvcr/P18V00015153
# 15  771                             nipez/mzv/P18V00000055
# 16  775                             nipez/mzv/P18V00016340
# 17  783                             nipez/mzv/P18V00017124
# 18  794                             nipez/mzv/P18V00026759
# 19  803                             nipez/mzv/P19V00001827
# 20  807                            stavebnionline/121/7941
# 21  806                         tenderarena/Comgate/201480
# 22  808                   tenderarena/JihoceskyKraj/255714
# 23  820                   tenderarena/Libereckykraj/219512
# 24  805                         tenderarena/agrozet/102972
# 25   52                              tenderarena/mo/171826
# 26  825                              tenderarena/msp/85449
# 27  826  vhodne-uverejneni/00254592/oprava-casti-mk-c-1...
# 28  828  vhodne-uverejneni/00291846/zdrave-mesto-ivanov...
# 29  829  vhodne-uverejneni/26272784/vzdelavani-zamestna...
# 30  830  vhodne-uverejneni/70504539/dodavka-projekcni-a...
# 31  831  vhodne-uverejneni/buly-arena-aquapark-kravare-...
# 32  832  vhodne-uverejneni/bw-naradi-s-r-o/materialove-...
# 33  833  vhodne-uverejneni/e-c-l-spol-s-r-o/kompostarna...
# 34  834  vhodne-uverejneni/flamesite-s-r-o/dodavka-novy...
# 35  835  vhodne-uverejneni/olza-spol-s-r-o/porizeni-mec...
# 36  836  vhodne-uverejneni/stavos-chlumec-n-cidl-s-r-o/...
# 37  847  vhodne-uverejneni/ustav-experimentalni-botanik...
# 38  848  vhodne-uverejneni/vrcha-a-s/technologie-na-sni...
# 39  849  vhodne-uverejneni/zakladni-skola-velke-hamry-s...
#
#                                                  text  \
# 0   =======================2017126-115451.pdf=====...
# 1   =======================Formulář - Informace o ...
# 2   =======================Dodatečné informace 01....
# 3   =======================01_výzva k podání nabíd...
# 4   =======================AKRIS_příloha-01_Kvalif...
# 5   =======================Příloha č. 1 SOD_Projek...
# 6   =======================P1_Výkaz výměr (slepý)....
# 7   =======================VZOR_smlouvy.doc=======...
# 8   =======================Oznámení o výběru dodav...
# 9   =======================PSP s přílohami.zip====...
# 10  =======================185310292 podepsaná.pdf...
# 11  =======================199310279(2).pdf=======...
# 12  =======================Kupní smlouva na dodávk...
# 13  =======================017 Oznámení o výběru A...
# 14  =======================#KS DNS ICT 11-2018-III...
# 15  =======================Plovoucí vinylová podla...
# 16  =======================VZ-096.docx============...
# 17  =======================10. Výzva a Zadávací do...
# 18  =======================VZ-161.docx============...
# 19  =======================SM1719-001.pdf=========...
# 20  =======================Smlouva o dilo.pdf=====...
# 21  =======================CG_LogIII_ZD_Priloha_c....
# 22  =======================pril._c._2_-_Kupni_smlo...
# 23  =======================06_D01_OLP_465_2019_dod...
# 24  =======================00-AGZ-Servis_CB-ZD-tex...
# 25  =======================Prilohy_2,_3,_4_k__SoD....
# 26  =======================Oprava_terminu_prohlidk...
# 27  =======================SOD - ROADFIN stavby s....
# 28  =======================Ivanovice_Rozhodnuti o ...
# 29  =======================rik-fer_Obchodní podmín...
# 30  =======================00 Dodatečné informace ...
# 31  =======================xx Písemná zpráva zadav...
# 32  =======================Dodatek KS BW nářadí.pd...
# 33  =======================Image240915212616.pdf==...
# 34  =======================Přílohy_č. 1-4.odt=====...
# 35  =======================02_P1_KrycíList.doc====...
# 36  =======================1a_zadavaci_dokumentace...
# 37  =======================rozhodnutí o přidělení ...
# 38  =======================přílohy.doc============...
# 39  =======================deklerace k dodatku č. ...
#
#                                          subj_context  valid_rat  \
# 0   PŘEDMĚT SMLOUVY\nZhotovitel se zavazuje k prov...   0.733333
# 1   PŘEDMĚT DÍLA\n\n1.1. Předmětem díla je provede...   0.984219
# 2   Předmět smlouvy\n1. Zhotovitel se touto smlouv...   0.471039
# 3   Předmět smlouvy\n\nPředmětem smlouvy je proved...   0.975272
# 4   Předmět veřejné zakázky a sjednaná cena ve sml...   0.576923
# 5   Předmět smlouvy, předmět díla\n\nPředmětem tét...   0.928721
# 6   Předmět Smlouvy\n2.1. Zhotovitel se zavazuje p...   0.769231
# 7   Předmět smlouvy\n\n2.1. \nPředmětem smlouvy je...   0.993276
# 8   Název veřejné zakázky: Sponkovače a spojovací ...   0.466667
# 9   Předmět smlouvy\n\n\n1. Poskytovatel se zavazu...   0.833333
# 10  vymezení plnění veřejné zakázky:\n\nPředmětem ...   0.859903
# 11  Předmět smlouvy\n\n2.1. \nPředmětem smlouvy je...   0.986791
# 12  předmět Smlouvy \n\n\n1. Základním účelem, pro...   0.882943
# 13   veřejné zakázce\n\n„Náboje 308 Winchester SWISS“   0.384615
# 14  Předmět plnění\n1. Předmětem této smlouvy je d...   0.829268
# 15  Název veřejné zakázky:\n\tPlovoucí vinylová po...   0.611111
# 16  Předmět veřejné zakázky\nStručný popis předmět...   0.759615
# 17  Předmět veřejné zakázky\nStručný popis předmět...   0.692913
# 18  Předmět veřejné zakázky\nStručný popis předmět...   0.816176
# 19  Předmět smlouvy\n\n1. Předmětem zakázky je opr...   0.941729
# 20  Předmět smlouvy\n\n\n1. Název díla: Rekonstruk...   0.919192
# 21  PŘEDMĚT SMLOUVY\n1.5. Zhotovitel se zavazuje p...   0.329268
# 22  Předmět smlouvy\n\n1. Předmětem smlouvy je záv...   0.944099
# 23  Vymezení předmětu veřejné zakázky \n\n\n2.1. O...   0.918605
# 24  Předmět díla \n\n2.1. Předmětem díla je zejmén...   0.987528
# 25  Předmět veřejné zakázky  \n\nPředmětem plnění ...   0.881612
# 26  PŘEDMĚT SMLOUVY \n\n \n\n1. Zhotovitel se tout...   0.984765
# 27  Předmět smlouvy\n\n1.1. Zhotovitel se touto sm...   0.421053
# 28  Předmět plnění veřejné zakázky\n2.1 Předmět pl...   0.317152
# 29  Předmět veřejné zakázky\n\n4\n\nNázev veřejné ...   0.881188
# 30  Předmět smlouvy\n(1)     Na základě této smlou...   0.985765
# 31  předmět veřejné zakázky a cena sjednaná ve sml...   0.035149
# 32  Předmět veřejné zakázky\n\nPředmětem veřejné z...   0.860294
# 33  PŘEDMĚT PLNĚNÍ\n\n1. Na základě této smlouvy s...   0.834711
# 34  Předmět smlouvy\n\tTato smlouva se uzavírá na ...   0.929204
# 35  PŘEDMĚT VEŘEJNÉ ZAKÁZKY\n\n3.1 Vyhlášení zadáv...   0.940141
# 36  vymezení předmětu zakázky a požadavků zadavate...   0.829932
# 37  Předmět veřejné zakázky\n\nPředmětem veřejné z...   0.902062
# 38  Předmět plnění\nPředmětem plnění je dodávka a ...   0.418605
# 39  Název veřejné zakázky:\nZadavatel zakázky:\n\n...   0.089286
#
#                                           ref_context valid
# 0   \nSmlouva nabývá platnosti a účinnosti dnem po...  True
# 1   \nTito uvedení zástupci jsou oprávněni jednat ...  True
# 2   3. Zhotovitel prohlašuje, že je odborně způsob...   NaN
# 3   \n(dále jen „zhotovitel “ nebo „projektant“)\n...  True
# 4   \nvyhotovil tuto písemnou zprávu.\n\n1. Předmě...  True
# 5   \nprohlášení nebo v souvislosti s ní druhé sml...  True
# 6   \nmluvní straně vznikne.\nČlánek 2\nPředmět Sm...  True
# 7   Článek 2\n\nPředmět smlouvy\n\n2.1. \nPředměte...  True
# 8   \nIdentifikace veřejné zakázky\n\nNázev veřejn...   NaN
# 9   nutného k zabezpečení činnosti rezortu Ministe...  True
# 10  \nJana Velíšková, tel. + 420 973 225 210.\n\n2...  True
# 11  Újezd u Uničova s cílem zajištění bezpečného p...  True
# 12  \ntéto Smlouvy a je odborně způsobilý ke splně...  True
# 13  \nrozhodl o výběru dodavatele k veřejné zakázc...   NaN
# 14  \nStrana 2\n\nII.\nPředmět plnění\n1. Předměte...  True
# 15  \nIdentifikace veřejné zakázky\n\n\tNázev veře...  True
# 16  \nOdůvodnění: Veřejnou zakázku malého rozsahu....  True
# 17  \nNabídku lze podat pouze elektronicky (NEN a ...  True
# 18  \nOdůvodnění: Veřejnou zakázku malého rozsahu....  True
# 19  \nkteré vyplývají z této smlouvy a nejsou v ní...  True
# 20  \n(dále jen „zhotovitel“)\n\n\nII. Předmět sml...  True
# 21  \n1.4. Účelem této Smlouvy je úprava práv a po...   NaN
# 22  \nvůči třetí osobě.\nČlánek III.\n\nPředmět sm...  True
# 23  \nv článku 21 této zadávací dokumentace (dále ...  True
# 24  \n- ve věcech řízení stavby: tel:  e-mail: \n ...  True
# 25  \n  Telefon : +420 485 226 967 \n\n     \n\n2....  True
# 26  \ncenové nabídky zhotovitele ze dne…………….. \n\...  True
# 27  \n(dále také jako „smlouva“)\n\n1. Předmět sml...   NaN
# 28  \n(dále jen „zadavatel“)\n\n2. Předmět plnění ...   NaN
# 29  \nnebude podílet na zpracování žádné nabídky.\...  True
# 30    Článek II\n\nPředmět smlouvy\n(1)     Na zák...  True
# 31  \nProfil zadavatele: https://www.vhodne-uverej...   NaN
# 32  \nVeřejná zakázka na dodávky.\n\n3. Předmět ve...  True
# 33  \n(dále jen „prodávající“)\n\nPŘEDMĚT PLNĚNÍ\n...  True
# 34  \n(dále jen „smlouva“)\n\nI.\nPředmět smlouvy\...  True
# 35  \n3z15\n\n \n\n \n\n3. DRUH DODÁVKY, PŘEDMĚT V...  True
# 36  \nzastoupená: Ing. Zdeněk Hedvičák, ředitel di...  True
# 37  \nzadavatele.info/UEB.html\n\n3, Předmět veřej...  True
# 38  následovně:\nČL I\nPředmět plnění\nPředmětem p...   NaN
# 39  \nZAKÁZKY\n\n \n\n1. Identifikační údaje o zad...   NaN

# %%
index = 30
ref_context = df_contracts.iloc[index]['ref_context']
subj_context = df_contracts.iloc[index]['subj_context']
print('===========================')
print(ref_context)
print('===========================')
print(subj_context)
# Out:
# ===========================
#   Článek II
#
# Předmět smlouvy
# (1)     Na základě této smlouvy se prodávající zavazuje dodat kupujícímu zboží a převést na něj vlastnické právo ke zboží, za podmínek dohodnutých v dalších ustanoveních smlouvy. Kupující se zavazuje zboží bez vad předané převzít a zaplatit za ně prodávajícímu kupní cenu, specifikovanou v čl. IV smlouvy, na základě dohodnutých platebních podmínek.
# (2)     Předmětem smlouvy je dodávka nových školících pomůcek a zařízení, v souladu s potřebami a požadavky kupujícího. Podrobná specifikace předmětu smlouvy je obsažena v Příloze č. 1 smlouvy. Prodávající se zavazuje dodat kupujícímu zboží ve smluveném množství, jakosti, provedení, termínech a ceně. Dále je prodávající povinen předat kupujícímu doklady, které se ke zboží vztahují a umožnit kupujícímu nabýt vlastnické právo ke zboží. Součástí předmětu smlouvy je též doprava předmětu smlouvy na místo plnění, jeho montáž, uvedení do provozu a zaškolení pracovníků kupujícího.
# (3) Prodávající se zavazuje umožnit osobám oprávněným k výkonu kontroly projektu, z něhož bude zakázka hrazena, provést kontrolu dokladů souvisejících s plněním zakázky a to minimálně do 31. 12. 2025.
#
# (4) Prodávající se zavazuje uchovávat veškeré originály účetních dokladů a originály dalších dokumentů souvisejících s realizací projektu, z něhož bude zakázka hrazena, dle zákona č. 563/1991 Sb., o účetnictví, ve znění pozdějších předpisů, minimálně do 31. 12. 2025.
#
# (5) Prodávající se zavazuje řídit se v případě publicity na všech dokumentech souvisejících s projektem, z něhož bude zakázka hrazena, pravidly publicity projektů financovaných z programu OPVK a pravidly vizuální identity ESF v ČR dle příručky pro příjemce finanční podpory projektů OPVK.
#
# (6) Prodávající se zavazuje dodržovat při plnění předmětu smlouvy opatření bezpečnosti, požární ochrany a ochrany zdraví při práci.
#
# (7) Prodávající se zavazuje splnit předmět smlouvy prostřednictvím osob s potřebnou kvalifikací a odborností.
#
# Článek III
#
# ===========================
# Předmět plnění veřejné zakázky
# Předmětem plnění veřejné zakázky je dodání 1 interaktivní tabule, 14 magnetických tabulí, 23 projektorů, 18 zařízení na ozvučení třídy. Předmět plnění veřejné zakázky je podrobně vymezen a popsán v Příloze č. 1 zadávací dokumentace.
# Předmět plnění veřejné zakázky obsahuje vždy samotný produkt, jeho příslušenství a související služby. Takto tvoří celek, jemuž bude odpovídat i cena nabídnutá uchazečem. Takový celek nesmí přesáhnout 39.999,-Kč s DPH.
# Uchazeč doplní název (označení) předmětu plnění, detailní rozpis ceny v Kč dle jednotlivých položek předmětu plnění a podrobnou technickou specifikaci předmětu plnění do tabulek Přílohy č. 1 zadávací dokumentace. Takto vyplněná příloha č. 1 zadávací dokumentace bude pak součástí smlouvy, jako její příloha.
#
# 4    Klasifikace předmětu plnění dle nařízení Evropského parlamentu a Rady (ES) č. 2195/2002 a nařízení Komise č. 213/2008
# 	CPV
#
#
# 	30200000-1
# 	Počítače
#
# 	48000000-8
# 	Balíky programů a informační systémy
#
# 	30195000-2
# 	Tabule
#
#
#
#
#
# 5     Předpokládaná hodnota veřejné zakázky
# Předpokládaná hodnota veřejné zakázky je 1.125.000,- Kč bez DPH (1.350.000,- Kč vč. DPH), a je zároveň hodnotou maximální a nepřekročitelnou. Vyšší cenové nabídky nemůže a nebude veřejný zadavatel akceptovat, nabídky obsahující vyšší nabídkovou cenu budou vyřazeny a uchazeči následně vyloučeni ze zadávacího řízení.
# 6     Doba a místo plnění veřejné zakázky
# Doba plnění:	Srpen/září 2012 - uchazeč musí dodat předmět plnění nejpozději do 20 dnů od výzvy zadavatele k plnění veřejné zakázky
# Místo plnění:		Hálkova 591, 396 01 Humpolec
# 7 Dodatečné informace k zadávacím podmínkám, prohlídka místa plnění
#
# Dodavatel je oprávněn požadovat písemně po zadavateli dodatečné informace k zadávacím podmínkám dle § 49 ZVZ. Žádost musí být písemná a musí být doručena administrátorovi veřejné zakázky nejpozději 5 pracovních dnů před uplynutím lhůty pro podání nabídek. Dodatečné informace poskytne zadavatel v souladu s § 49 odst. 2 a 3 ZVZ. Zadavatel může poskytnout dodavatelům dodatečné informace k zadávacím podmínkám i bez předchozí žádosti.
#
# Písemná žádost o dodatečné informace k zadávacím podmínkám musí být doručena administrátorovi veřejné zakázky na níže uvedenou adresu nebo e-mail:
#
# Institut pro rozvoj vzdělávání, s.r.o.
# Tereza Schimmerová
# Přístavní 321/14, 170 00 Praha 7 - Holešovice
#
# Email: schimmerova@iprv.cz
#
# Prohlídka místa plnění:	Prohlídka místa plnění není pro plnění zakázky nebo pro zpracování nabídky nezbytná, a proto se nebude konat.
# 8       Požadavky na prokázání splnění kvalifikace podle § 62 ZVZ
#
# Kvalifikaci splní dodavatel, který:
#
# a) prokáže splnění zákl. kvalifikačních předpokladů dle § 53 odst. 1 písm. a) až k) ZVZ;
#
# b) prokáže splnění profesních kvalifikačních předpokladů dle § 54 písm. a) a b) ZVZ;
#
# c) prokáže splnění technických kvalifikačních předpokladů dle § 56 odst. 1 písm. a) ZVZ; a
#
# d) předloží čestné prohlášení o své ekonomické a finanční způsobilosti splnit veřejnou zakázku dle § 50 odst. 1 písm. c) ZVZ.
#
# Dodavatel je povinen prokázat splnění kvalifikace ve lhůtě pro podání nabídek a při prokazování splnění kvalifikace postupovat v souladu s ustanovením § 62 odst. 3 ZVZ. Dodavatel předloží v nabídce čestné prohlášení, z jehož obsahu bude zřejmé, že dodavatel kvalifikační předpoklady požadované zadavatelem splňuje. Toto čestné prohlášení musí být podepsáno osobou oprávněnou jednat v této věci za dodavatele nebo jeho jménem. Dodavatel může použít vzoru tohoto čestného prohlášení, který je přílohou č. 2 zadávací dokumentace.
#
# Z čestného prohlášení musí být zřejmé, že dodavatel splňuje všechny základní kvalifikační předpoklady uvedené v § 53 odst. 1 písm. a) až k) ZVZ. Dodavatel v čestném prohlášení dále prohlásí zda je či není zapsán v obchodním rejstříku, nebo v jiné obdobné evidenci ve smyslu ustanovení § 54 písm. a) ZVZ, a že vlastní potřebné oprávnění k podnikání podle zvláštních právních předpisů v rozsahu odpovídajícím předmětu veřejné zakázky ve smyslu ustanovení § 54 písm. b) ZVZ. Čestné prohlášení musí dále obsahovat prohlášení dodavatele, že v posledních 3 letech realizoval min. 5 dodávek odpovídajících předmětu veřejné zakázky, každou v hodnotě min. 300.000,- Kč bez DPH a toto své prohlášení je schopen doložit min. 3 osvědčeními objednatelů o řádné realizaci výše uvedených dodávek s náležitostmi dle § 56 odst. 1 písm. a) ZVZ. V neposlední řadě pak bude čestné prohlášení obsahovat prohlášení dodavatele, že je ekonomicky a finančně způsobilý splnit veřejnou zakázku ve smyslu ustanovení § 50 odst. 1 písm. c) ZVZ.
#
# Uchazeč, se kterým má být uzavřena smlouva podle § 82 ZVZ, je povinen před jejím uzavřením předložit zadavateli originály nebo úředně ověřené kopie dokladů prokazujících splnění kvalifikace. Nesplnění této povinnosti se považuje za neposkytnutí součinnosti k uzavření smlouvy ve smyslu ustanovení § 82 odst. 4 ZVZ.
#
#
#
#
# Splnění kvalifikačního předpokladu dle § 54 písm. a) ZVZ prokáže uchazeč, se kterým má být uzavřena smlouva podle § 82 ZVZ, předložením originálu nebo úředně ověřené kopie výpisu z obchodního rejstříku, pokud je v něm zapsán, či kopie výpisu z jiné obdobné evidence, pokud je v ní zapsán.
#
# Splnění kvalifikačního předpokladu dle § 54 písm. b) ZVZ prokáže uchazeč, se kterým má být uzavřena smlouva podle § 82 ZVZ, předložením originálu nebo úředně ověřené kopie dokladu o oprávnění k podnikání podle zvláštních právních předpisů v rozsahu odpovídajícím předmětu veřejné zakázky, zejména dokladu prokazujícího příslušné živnostenské oprávnění či licenci.
#
# Splnění kvalifikačního předpokladu dle § 56 odst. 1 písm. a) ZVZ prokáže uchazeč, se kterým má být uzavřena smlouva podle § 82 ZVZ,  předložením seznamu významných dodávek realizovaných uchazečem v posledních 3 let, v němž musí doložit, že v tomto období realizoval min. 5 dodávek odpovídajících předmětu veřejné zakázky, každou v hodnotě min. 300.000,- Kč bez DPH. V seznamu musí být uveden rozsah dodávek a doba jejich plnění. K seznamu musí být doložena min. 3 osvědčení objednatelů o řádné realizaci výše uvedených dodávek s náležitostmi dle § 56 odst. 1 písm. a) ZVZ. Tato osvědčení musí obsahovat identifikační údaje objednatele včetně kontaktů, cenu, dobu a místo realizace dodávky.
#
#
# Podmínky prokázání splnění kvalifikačních předpokladů prostřednictvím subdodavatele, v případě společné nabídky nebo v případě zahraničního dodavatele
#
# V případě prokazování splnění kvalifikačních předpokladů prostřednictvím subdodavatele, v případě společné nabídky nebo v případě zahraničního dodavatele je třeba postupovat v souladu s příslušnými ustanoveními § 51 ZVZ.
#
# Důsledek nesplnění kvalifikace
# Nesplní-li dodavatel kvalifikaci v požadovaném rozsahu, bude v souladu s ustanovením § 60 odst. 1 ZVZ veřejným zadavatelem z účasti v zadávacím řízení vyloučen.
#
#
#
# 9       Požadavky dle § 68 odst. 3 ZVZ
# Součástí nabídky musí být rovněž:
# a) seznam statutárních orgánů nebo členů statutárních orgánů, kteří v posledních 3 letech od konce lhůty pro podání nabídek byli v pracovněprávním, funkčním či obdobném poměru u zadavatele,
#
# b) má-li dodavatel formu akciové společnosti, seznam vlastníků akcií, jejichž souhrnná jmenovitá hodnota přesahuje 10 % základního kapitálu, vyhotovený ve lhůtě pro podání nabídek,
#
# c) prohlášení uchazeče o tom, že neuzavřel a neuzavře zakázanou dohodu podle zákona č. 143/2001 Sb., o ochraně hospodářské soutěže a o změně některých zákonů (zákon o ochraně hospodářské soutěže), ve znění pozdějších předpisů, v souvislosti se zadávanou veřejnou zakázkou.
#
# Dodavatel může použít vzoru čestného prohlášení, který je přílohou č. 3 zadávací dokumentace. Toto čestné prohlášení musí být podepsáno osobou oprávněnou jednat v této věci za dodavatele nebo jeho jménem.
#
# 10      Obchodní podmínky, včetně platebních podmínek
#
# Obchodní podmínky, včetně platebních podmínek, tj. závazné požadavky zadavatele na obsah návrhu smlouvy tvoří přílohu č. 4 zadávací dokumentace. Uchazeč není oprávněn činit změny či doplnění těchto závazných požadavků zadavatele, s výjimkou údajů, které je uchazeč povinen doplnit (žlutě označené pasáže) a změn či doplnění, které by zvýhodňovaly smluvní postavení objednatele. Takové změny či doplnění je třeba jasně barevně zviditelnit, aby je bylo možno snadno odlišit od původního textu (např. červenou barvou). Jiné změny, úpravy či doplnění nebude veřejný zadavatel akceptovat.
#
# 11     Technická specifikace
#
# Souhrn technických popisů, které vymezují požadované technické charakteristiky a požadavky na dodávky, jejichž prostřednictvím je předmět veřejné zakázky popsán jednoznačně a objektivně způsobem vyjadřujícím účel využití zamýšlený veřejným zadavatelem (dále jen „technická specifikace“), je obsažen v příloze č. 1 zadávací dokumentace.
#
# Materiály nebo výrobky jmenovitě uvedené v zadávacích podmínkách nejsou pro dodavatele závazné, ale jsou reprezentanty určeného kvalitativního standardu. Pokud by zadávací podmínky obsahovaly určité obchodní názvy materiálů a výrobků nebo odkazy na obchodní názvy firem nebo označení původu, uchazeč to při zpracování nabídky bude chápat jako vymezení kvalitativního standardu. Zadavatel umožňuje použití i jiných, kvalitativně a technicky vhodných řešení, pokud bude vymezený kvalitativní standard dodržen nebo bude mít dokonce lepší parametry. Toto musí dodavatel prokázat ve své nabídce, a to zejména technickou dokumentací výrobce nebo zkušebním protokolem vydaným uznaným orgánem.
#
# 12        Lhůta pro podání nabídek
#
# Nabídky musí být doručeny nejpozději dne 8. 8. 2012 do 10:00 hodin.
#
# 13      Místo pro podání nabídek
#
# Nabídky musí být doručeny v listinné podobě, a to buď osobně v pracovních dnech od 09:00 do 14:00 hod nebo poštou, administrátorovi veřejné zakázky na níže uvedenou adresu:
#
# Institut pro rozvoj vzdělávání, s.r.o.
# Tereza Schimmerová
# Přístavní 321/14, 170 00 Praha 7 - Holešovice
#
# 14    Zadávací lhůta
#
# Veřejný zadavatel stanovil délku zadávací lhůty, lhůty po kterou jsou uchazeči svými nabídkami vázáni, do 31. 10. 2012.
# 15       Var

# %%
text = df_contracts.iloc[index]['text']

# %%
print(text)
# Out:
# =======================00 Dodatečné informace č. 1.docx=======================
#
#
#
# Dodatečné informace č. 1 k zadávacím podmínkám
# pro podlimitní veřejnou zakázku na dodávky zadanou ve zjednodušeném podlimitním řízení v souladu se zákonem č. 137/2006 Sb., o veřejných zakázkách, ve znění pozdějších předpisů (dále jen „zákon o veřejných zakázkách“) a Příručkou pro základní školy – žadatele a příjemce 1.4 Operačního programu Vzdělávání pro konkurenceschopnost
#
# 	Název programu:
# 	Operační program Vzdělávání pro konkurenceschopnost
#
# 	Registrační číslo projektu
# 	CZ.1.07/1.4.00/21.0698
#
# 	Název projektu:
# 	OP VK 1.4 70504539
#
# 	Název zakázky:
# 	Dodávka projekční a interaktivní techniky
#
# 	Předmět zakázky:
# 	Dodávka
#
# 	Datum vyhlášení zakázky:
# 	23.07.2012
#
# 	Název zadavatele:
# 	Základní škola Humpolec, Hálkova 591, okres Pelhřimov
#
# 	Sídlo zadavatele:
# 	Hálkova 591, 396 01 Humpolec
#
# 	Osoba oprávněná jednat jménem zadavatele:
# 	Mgr. Václav Strnad, ředitel školy
# Telefon: +420 565 532 159
# E-mail: reditel.halkova@zshumpolec.cz
#
# 	IČ zadavatele:
# 	70504539
#
# 	DIČ zadavatele:
# 	CZ70504539
#
# 	Kontaktní osoba zadavatele:
# 	Mgr. Václav Strnad
# Telefon: +420 565 532 159
# E-mail: reditel.halkova@zshumpolec.cz
#
#
#
#
# 	Název administrátora veřejné zakázky:
# 	Institut pro rozvoj vzdělávání, s.r.o.
#
# 	Adresa sídla administrátora veřejné zakázky:
# 	Heydukova 896/11, Praha 8, Libeň
#
# 	IČ administrátora veřejné zakázky:
# 	24146005
#
#
#
# 	Kontaktní osoba administrátora veřejné zakázky:
# 	Tereza Schimmerová
#
# 	Kontaktní údaje administrátora veřejné zakázky:
# 	Tel.: +420 773 435 445
# Email: schimmerova@iprv.cz
#
#
#
# Vážení dodavatelé,
# na základě obdržené žádosti od jednoho z dodavatelů, kterou jsme obdrželi dne 30. 07. 2012, vám zasíláme tyto dodatečné informace k zadávacím podmínkám výše uvedené veřejné zakázky.
# Přesné znění žádosti:
# 1) V příloze č. 1 ZD v bodě 1.2.2 zadavatel požaduje pružinový pojezd včetně madla. Existují i jiné zvedací systémy umožňují stejný rozsah vertikálního pohybu jako pružinový pojezd, které však pracují na jiném principu. Je jiné řešení zdvihu pro zadavatele přípustné? Z jakého materiálu je stěna, do které má být systém kotven?  V tomto bodě je uveden také rozměr tabule 120x150 cm. Jde o rozměr minimální a můžeme nabídnout tabuli větší?
# 2) V příloze č. 1 ZD je v bodě 1.3.1 požaduje zadavatel 3 ks projektoru, z nichž jeden má být připevněn k tabuli specifikované v bodě 1.2.1. Projektor se instaluje do stropu nebo čelní zdi, na kterou je tabule umístěna. Upevnění k tabuli v tomto případě není opodstatněné. Zbývající počet dataprojektorů má být umístěn na teleskopický držák, pro přesnou kalkulaci je třeba znát výšku stropů a výšku a velikost projekční plochy.
#
# 3) V příloze č. 1 ZD je v bodě 1.3.2 uvedeno rozlišení dataprojektoru XGA, ovšem hodnota v závorce odpovídá WXGA.
# 4) V příloze č. 1 ZD je v bodě 1.4 je požadavek na umístění ozvučení neviditelně za tabulí. Není však specifikováno o jaké tabule se jedná ani jakým způsobem jsou umístěny (zeď, zvedací systém).
#
#
# Odpovědi na dotazy:
# 1) Ano, jiné řešení zdvihu je pro zadavatele přípustné, pokud bude zachována u nabídnutého řešení stejná funkčnost jako u pružinového pojezdu. Tabule budou kotveny do zděných příček, zadavatel předpokládá příčky z plných cihel. Uvedené rozměry v Příloze č.1 zadávací dokumentace - Specifikace předmětu plnění veřejné zakázky tabule jsou minimálními rozměry, uchazeč může nabídnout tabuli větších rozměrů.
# 2) Zadavatel požaduje připevnit jeden dataprojektor na zeď k tabuli specifikované v bodě 1.2.1 Přílohy č.1 zadávací dokumentace - Specifikace předmětu plnění veřejné zakázky. Připevněním k tabuli zadavatel myslí připevnění na zeď, na které je tabule umístěna. Výška stropů je 320 cm, u pěti místností pak 380 cm. Projekční plochou budou instalované tabule, a rozumí se jí tedy velikost tabulí.
# 3) Zadavatel požaduje rozlišení WXGA, jedná se o administrativní chybu. Zadavatel dále nově požaduje u projektoru v bodě 1.3.2 Přílohy č. 1 zadávací dokumentace - Specifikace předmětu plnění veřejné zakázky, aby měl interaktivní funkci.
# 4) Uvedený požadavek zadavatel ruší, jedná se o administrativní chybu. Ozvučení nemusí být umístěno neviditelně za tabulí.
#
# Na základě ustanovení § 49 odst. 4 zákona o veřejných zakázkách poskytuje zadavatel dodavatelům, bez jejich předchozí žádosti, ještě tyto dodatečné informace k zadávacím podmínkám.
# Dodatečné informace k zadávacím podmínkám:
# 1) Zadavatel se z technických důvodů rozhodl prodloužit lhůtu pro podání nabídek z 10:00 hod na 11:00 hod a termín otevírání obálek s nabídkami posunul z 11:00 hod na 13:00 hod. Datum a místo pro doručování nabídek a otevírání obálek s nabídkami zůstávají beze změn.
# 2) S ohledem na možný výkladový rozpor mezi ustanoveními Výzvy k podání nabídek (část „Lhůta dodání“), Zadávací dokumentace (část 6 „Doba a místo plnění veřejné zakázky“) a Přílohou č. 4 zadávací dokumentace – kupní smlouva (ustanovení čl. III odst. 2), zadavatel nahrazuje ustanovení čl. III odst. 2 Přílohy č. 4 zadávací dokumentace tímto ustanovením:
# „Prodávající se zavazuje dodat zboží nejpozději do 20 dnů od obdržení výzvy kupujícího k plnění. Datum a čas předání zboží oznámí prodávající kupujícímu nejpozději 3 pracovní dny před tímto datem.“
# 3) Vzhledem ke skutečnosti, že předmětem plnění veřejné zakázky nebude dodávka interaktivního výukového softwaru, bude ustanovení čl. V odst. 12 Přílohy č. 4 zadávací dokumentace – kupní smlouva, vypuštěno.
# 4) Zadavatel opravil administrativní chybu v bodě 1.2.1 Přílohy č.1 zadávací dokumentace - Specifikace předmětu plnění veřejné zakázky. Rozměr tabule byl uveden v nadpisu a specifikaci jinak. Zadavatel sjednotil rozměr tabule na 120x200 cm.
# Všechny dodatečné informace k zadávacím podmínkám, včetně přesného znění požadavku dodavatelů, zadavatel odešle, v souladu s ustanoveními § 49 odst. 2 a 3 zákona o veřejných zakázkách, všem dodavatelům, kteří požádali o poskytnutí zadávací dokumentace nebo kterým byla zadávací dokumentace poskytnuta. Zadavatel také uveřejní všechny dodatečné informace k zadávacím podmínkám včetně přesného znění žádosti stejným způsobem, jakým uveřejnil textovou část zadávací dokumentace.
# V zájmu právní jistoty a pro lepší přehled zadavatel vyznačil všechny výše uvedené úpravy zadávacích podmínek, tj. Výzvy k podání nabídek, Zadávací dokumentace, Přílohy č. 1 zadávací dokumentace - Specifikace předmětu plnění veřejné zakázky a Přílohy č. 4 zadávací dokumentace – kupní smlouva, v těchto dokumentech červeně a finální podobu výše uvedených dokumentů přikládá k těmto Dodatečným informacím č. 1 k zadávacím podmínkám.
#
# V Humpolci dne: 02.08.2012
#
#
# 		……………………………………………………………………………..
#                                                                                                    Mgr. Václav Strnad, ředitel školy
#
#
#
# »
# Í . 4
# |
# „0 ŠKOLSTVÍ, OP Vzdělávání
# MLÁDEŽE A TĚLOVÝCHOVY pro konkurenceschopnost
#
# evropský
# sociální
# fondv ČR EVROPSKÁ UNIE
#
# INVESTICE DO ROZVOJE VZDĚLÁVÁNÍ
#
#
#
# =======================01 Vyzva k podani nabidek.docx=======================
# Výzva k podání nabídek
# pro podlimitní veřejnou zakázku na dodávky zadanou ve zjednodušeném podlimitním řízení v souladu se zákonem č. 137/2006 Sb., o veřejných zakázkách, ve znění pozdějších předpisů a Příručkou pro základní školy – žadatele a příjemce 1.4 Operačního programu Vzdělávání pro konkurenceschopnost
#
# 	Název programu:
# 	Operační program Vzdělávání pro konkurenceschopnost
#
# 	Registrační číslo projektu
# 	CZ.1.07/1.4.00/21.0698
#
# 	Název projektu:
# 	OP VK 1.4 70504539
#
# 	Název zakázky:
# 	Dodávka projekční a interaktivní techniky
#
# 	Předmět zakázky:
# 	Dodávka
#
# 	Datum vyhlášení zakázky:
# 	23.07.2012
#
# 	Název zadavatele:
# 	Základní škola Humpolec, Hálkova 591, okres Pelhřimov
#
# 	Sídlo zadavatele:
# 	Hálkova 591, 396 01 Humpolec
#
# 	Osoba oprávněná jednat jménem zadavatele:
# 	Mgr. Václav Strnad, ředitel školy
# Telefon: +420 565 532 159
# E-mail: reditel.halkova@zshumpolec.cz
#
# 	IČ zadavatele:
# 	70504539
#
# 	DIČ zadavatele:
# 	CZ70504539
#
# 	Kontaktní osoba zadavatele:
# 	Mgr. Václav Strnad
# Telefon: +420 565 532 159
# E-mail: reditel.halkova@zshumpolec.cz
#
#
#
#
# 	Název administrátora veřejné zakázky:
# 	Institut pro rozvoj vzdělávání, s.r.o.
#
# 	Adresa sídla administrátora veřejné zakázky:
# 	Heydukova 896/11, Praha 8, Libeň
#
# 	IČ administrátora veřejné zakázky:
# 	24146005
#
#
#
# 	Kontaktní osoba administrátora veřejné zakázky:
# 	Tereza Schimmerová
#
# 	Kontaktní údaje administrátora veřejné zakázky:
# 	Tel.: +420 773 435 445
# Email: schimmerova@iprv.cz
#
#
#
# 	Lhůta pro podávání nabídek:
# 	do  8.8.2012 do 10:00 hod
#
# 	Popis předmětu zakázky:
# 	Předmětem této zakázky je dodání 1 interaktivní tabule, 14 magnetických tabulí, 23 projektorů a 18 zařízení na ozvučení třídy. Předmět veřejné zakázky je blíže specifikován v samostatné zadávací dokumentaci, která je nedílnou součástí výzvy jako její Příloha č. 1.
#
# 	Předpokládaná hodnota zakázky:
# 	1 125 000,- Kč bez DPH (1 350 000,- Kč vč. DPH)
#
# 	Typ zakázky
# 	Podlimitní veřejná zakázka zadaná ve zjednodušeném podlimitním řízení.
#
# 	Lhůta dodání
# 	Srpen/září 2012
# Uchazeč musí dodat předmět plnění nejpozději do 20 dnů od výzvy zadavatele k plnění veřejné zakázky.
#
# 	Místa dodání/převzetí nabídky:
# 	Institut pro rozvoj vzdělávání, s.r.o.
# Tereza Schimmerová
# Přístavní 321/14, 170 00 Praha 7 - Holešovice
#
#
#
#
# 	Hodnotící kritérium:
# 	Nabídková cena 100%
# Hodnotící kritérium a způsob hodnocení jsou blíže specifikovány v samostatné zadávací dokumentaci, která je nedílnou součástí výzvy jako její Příloha č. 1.
#
#
#
# 	Požadavek na uvedení kontaktní osoby uchazeče:
# 	Uchazeč ve své nabídce uvede kontaktní osobu ve věci zakázky, její telefon a e-mailovou adresu.
#
#
#
# 	Požadavek na písemnou formu nabídky:
# 	Nabídka musí být zadavateli doručena v písemné formě. Veškeré doklady musí být zpracovány v českém jazyce.
#
# 	Další podmínky pro plnění zakázky:
# 	Požadavky na prokázání splnění kvalifikace podle § 62 zákona o veřejných zakázkách, podrobná specifikace údajů uvedených ve výzvě nebo další podmínky pro plnění zakázky jsou uvedeny v samostatné zadávací dokumentaci, která je nedílnou součástí výzvy jako její Příloha č. 1.
# Výzva a zadávací dokumentace budou po celou dobu trvání lhůty pro podání nabídek uveřejněny na profilu zadavatele, tj. na internetových stránkách: https://www.vhodne-uverejneni.cz/profil/70504539
#
#
#
#
# V Humpolci dne: 23.07.2012
#
#
#
#
#
#
#
# 	Mgr. Václav Strnad, ředitel školy
#
#
#
#
# »
# Í . 4
# |
# „0 ŠKOLSTVÍ, OP Vzdělávání
# MLÁDEŽE A TĚLOVÝCHOVY pro konkurenceschopnost
#
# evropský
# sociální
# fondv ČR EVROPSKÁ UNIE
#
# INVESTICE DO ROZVOJE VZDĚLÁVÁNÍ
#
#
#
# =======================02 Zadavaci dokumentace.docx=======================
# Příloha č. 1 výzvy k podání nabídek
# Zadávací dokumentace pro podlimitní veřejnou zakázku
#
# 	„Dodávka projekční a interaktivní techniky“
#
#
#
#
# zadanou ve zjednodušeném podlimitním řízení v souladu se zákonem č. 137/2006 Sb. o veřejných zakázkách, ve znění pozdějších předpisů (dále jen „ZVZ“) a Příručkou pro základní školy – žadatele a příjemce 1.4 Operačního programu Vzdělávání pro konkurenceschopnost.
#
#
# Zadavatel:
#
# Základní škola Humpolec, Hálkova 591, okres Pelhřimov
# Hálkova 591, 396 01 Humpolec
#
#
# Obsah
#         Preambule………………………………………………………………………………str. 3
# 1	Identifikace zadavatele……………………………………………………………str. 4
# 2	Identifikace administrátora veřejné zakázky……………………………………...str. 4
# 3	Předmět plnění veřejné zakázky ………………….………………………………str. 5
# 4	Klasifikace předmětu plnění …………………………………………………….. str. 5
# 5      Předpokládaná hodnota veřejné zakázky …………………………………………str. 6
# 6      Doba a místo plnění veřejné zakázky …………………………………………….str. 6
# 7      Dodatečné informace k zadávacím podmínkám, prohlídka místa plnění ……...…str. 6
# 8      Požadavky na prokázání splnění kvalifikace podle § 62 ZVZ  …………………...str. 7
# 9      Požadavky dle § 68 odst. 3 ZVZ  …………………………………………………str. 9
# 10    Obchodní podmínky, včetně platebních podmínek …………………………….....str. 9
# 11     Technická specifikace …………………………………………………………...str. 10
# 12     Lhůta pro podání nabídek  ……………………………………………………….str. 10
# 13     Místo pro podání nabídek  ……………………………………………………….str. 10
# 14     Zadávací lhůta …………………………………………………………………...str. 10
# 15     Varianty nabídek  ………………………………………………………………..str. 11
# 16     Požadavky na způsob zpracování nabídkové ceny  ……………………………..str. 11
# 17     Jiné požadavky zadavatele na plnění veřejné zakázky a podmínky a požadavky
#          na zpracování nabídky   ………………..………………………………………...str. 11
# 18     Další podmínky a požadavky na zpracování nabídky  …………………………..str. 12
# 19     Termín a místo otevírání obálek s nabídkami  …………………………………..str. 13
# 20     Údaje o hodnotících kritériích a způsob hodnocení nabídek …………………....str. 13
# 21     Přílohy zadávací dokumentace  ………………………………………………….str. 13
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 2
#
#
#
#
#
#
#
#
#
# 13
#
#
#
#
#
# Preambule
#
# Tato zadávací dokumentace je zpracována v souladu se ZVZ a Příručkou pro základní školy – žadatele a příjemce 1.4 Operačního programu Vzdělávání pro konkurenceschopnost.                                                                                                                                          Projekt bude spolufinancován ze zdrojů EU.
# Veřejný zadavatel zpracoval tuto zadávací dokumentaci dle svých nejlepších znalostí a zkušeností z oblasti zadávání veřejných zakázek s cílem zajistit transparentní, nediskriminační a hospodárné zadání veřejné zakázky. I přes nejlepší péči nemůže však zadavatel vyloučit, že budoucí názor orgánu dohledu na skutečnosti a procesy upravené v zadávací dokumentaci, může být odlišný od jeho názoru.
# Zadavatel upozorňuje uchazeče na skutečnost, že zadávací dokumentace je souhrnem požadavků zadavatele a nikoli konečným souhrnem veškerých požadavků vyplývajících z obecně platných norem. Uchazeč se tak musí při zpracování své nabídky vždy řídit nejen požadavky obsaženými v zadávací dokumentaci, ale též ustanoveními příslušných obecně závazných norem.
# Uchazeč je povinen předložit veškeré dokumenty požadované obecně závaznými normami nebo zadavatelem ve výzvě k podání nabídek a zadávací dokumentaci. Uchazeč je dále povinen plně respektovat zadávací podmínky a není oprávněn v nich provádět žádné změny.
#
#
#
#
#
# Identifikace zadavatele
# Název zadavatele:	Základní škola Humpolec, Hálkova 591, okres Pelhřimov
# IČ zadavatele:	70504539
# Sídlo zadavatele:	Hálkova 591, 396 01 Humpolec
# Osoba oprávněná jednat za zadavatele:	Mgr. Václav Strnad, ředitel školy
# Kontaktní osoba:	Mgr. Václav Strnad
# Telefon:	+420 565532159
# E-mail:	reditel.halkova@zshumpolec.cz
#
# Identifikace administrátora veřejné zakázky
# Název:	Institut pro rozvoj vzdělávání, s.r.o.
# Adresa sídla:	Heydukova 896/11, Praha 8, Libeň
# IČ:	24146005
# Zastoupený: 	Bc. Radkem Hančem, jednatelem společnosti
# Kontaktní osoba:
# Jméno:	Tereza Schimmerová
# Telefon:	+420 773 435 445
# Email:	schimmerova@iprv.cz
# Veškeré administrativní záležitosti řeší za zadavatele administrátor veřejné zakázky.
# Předmět plnění veřejné zakázky
# Předmětem plnění veřejné zakázky je dodání 1 interaktivní tabule, 14 magnetických tabulí, 23 projektorů, 18 zařízení na ozvučení třídy. Předmět plnění veřejné zakázky je podrobně vymezen a popsán v Příloze č. 1 zadávací dokumentace.
# Předmět plnění veřejné zakázky obsahuje vždy samotný produkt, jeho příslušenství a související služby. Takto tvoří celek, jemuž bude odpovídat i cena nabídnutá uchazečem. Takový celek nesmí přesáhnout 39.999,-Kč s DPH.
# Uchazeč doplní název (označení) předmětu plnění, detailní rozpis ceny v Kč dle jednotlivých položek předmětu plnění a podrobnou technickou specifikaci předmětu plnění do tabulek Přílohy č. 1 zadávací dokumentace. Takto vyplněná příloha č. 1 zadávací dokumentace bude pak součástí smlouvy, jako její příloha.
#
# 4    Klasifikace předmětu plnění dle nařízení Evropského parlamentu a Rady (ES) č. 2195/2002 a nařízení Komise č. 213/2008
# 	CPV
#
#
# 	30200000-1
# 	Počítače
#
# 	48000000-8
# 	Balíky programů a informační systémy
#
# 	30195000-2
# 	Tabule
#
#
#
#
#
# 5     Předpokládaná hodnota veřejné zakázky
# Předpokládaná hodnota veřejné zakázky je 1.125.000,- Kč bez DPH (1.350.000,- Kč vč. DPH), a je zároveň hodnotou maximální a nepřekročitelnou. Vyšší cenové nabídky nemůže a nebude veřejný zadavatel akceptovat, nabídky obsahující vyšší nabídkovou cenu budou vyřazeny a uchazeči následně vyloučeni ze zadávacího řízení.
# 6     Doba a místo plnění veřejné zakázky
# Doba plnění:	Srpen/září 2012 - uchazeč musí dodat předmět plnění nejpozději do 20 dnů od výzvy zadavatele k plnění veřejné zakázky
# Místo plnění:		Hálkova 591, 396 01 Humpolec
# 7 Dodatečné informace k zadávacím podmínkám, prohlídka místa plnění
#
# Dodavatel je oprávněn požadovat písemně po zadavateli dodatečné informace k zadávacím podmínkám dle § 49 ZVZ. Žádost musí být písemná a musí být doručena administrátorovi veřejné zakázky nejpozději 5 pracovních dnů před uplynutím lhůty pro podání nabídek. Dodatečné informace poskytne zadavatel v souladu s § 49 odst. 2 a 3 ZVZ. Zadavatel může poskytnout dodavatelům dodatečné informace k zadávacím podmínkám i bez předchozí žádosti.
#
# Písemná žádost o dodatečné informace k zadávacím podmínkám musí být doručena administrátorovi veřejné zakázky na níže uvedenou adresu nebo e-mail:
#
# Institut pro rozvoj vzdělávání, s.r.o.
# Tereza Schimmerová
# Přístavní 321/14, 170 00 Praha 7 - Holešovice
#
# Email: schimmerova@iprv.cz
#
# Prohlídka místa plnění:	Prohlídka místa plnění není pro plnění zakázky nebo pro zpracování nabídky nezbytná, a proto se nebude konat.
# 8       Požadavky na prokázání splnění kvalifikace podle § 62 ZVZ
#
# Kvalifikaci splní dodavatel, který:
#
# a) prokáže splnění zákl. kvalifikačních předpokladů dle § 53 odst. 1 písm. a) až k) ZVZ;
#
# b) prokáže splnění profesních kvalifikačních předpokladů dle § 54 písm. a) a b) ZVZ;
#
# c) prokáže splnění technických kvalifikačních předpokladů dle § 56 odst. 1 písm. a) ZVZ; a
#
# d) předloží čestné prohlášení o své ekonomické a finanční způsobilosti splnit veřejnou zakázku dle § 50 odst. 1 písm. c) ZVZ.
#
# Dodavatel je povinen prokázat splnění kvalifikace ve lhůtě pro podání nabídek a při prokazování splnění kvalifikace postupovat v souladu s ustanovením § 62 odst. 3 ZVZ. Dodavatel předloží v nabídce čestné prohlášení, z jehož obsahu bude zřejmé, že dodavatel kvalifikační předpoklady požadované zadavatelem splňuje. Toto čestné prohlášení musí být podepsáno osobou oprávněnou jednat v této věci za dodavatele nebo jeho jménem. Dodavatel může použít vzoru tohoto čestného prohlášení, který je přílohou č. 2 zadávací dokumentace.
#
# Z čestného prohlášení musí být zřejmé, že dodavatel splňuje všechny základní kvalifikační předpoklady uvedené v § 53 odst. 1 písm. a) až k) ZVZ. Dodavatel v čestném prohlášení dále prohlásí zda je či není zapsán v obchodním rejstříku, nebo v jiné obdobné evidenci ve smyslu ustanovení § 54 písm. a) ZVZ, a že vlastní potřebné oprávnění k podnikání podle zvláštních právních předpisů v rozsahu odpovídajícím předmětu veřejné zakázky ve smyslu ustanovení § 54 písm. b) ZVZ. Čestné prohlášení musí dále obsahovat prohlášení dodavatele, že v posledních 3 letech realizoval min. 5 dodávek odpovídajících předmětu veřejné zakázky, každou v hodnotě min. 300.000,- Kč bez DPH a toto své prohlášení je schopen doložit min. 3 osvědčeními objednatelů o řádné realizaci výše uvedených dodávek s náležitostmi dle § 56 odst. 1 písm. a) ZVZ. V neposlední řadě pak bude čestné prohlášení obsahovat prohlášení dodavatele, že je ekonomicky a finančně způsobilý splnit veřejnou zakázku ve smyslu ustanovení § 50 odst. 1 písm. c) ZVZ.
#
# Uchazeč, se kterým má být uzavřena smlouva podle § 82 ZVZ, je povinen před jejím uzavřením předložit zadavateli originály nebo úředně ověřené kopie dokladů prokazujících splnění kvalifikace. Nesplnění této povinnosti se považuje za neposkytnutí součinnosti k uzavření smlouvy ve smyslu ustanovení § 82 odst. 4 ZVZ.
#
#
#
#
# Splnění kvalifikačního předpokladu dle § 54 písm. a) ZVZ prokáže uchazeč, se kterým má být uzavřena smlouva podle § 82 ZVZ, předložením originálu nebo úředně ověřené kopie výpisu z obchodního rejstříku, pokud je v něm zapsán, či kopie výpisu z jiné obdobné evidence, pokud je v ní zapsán.
#
# Splnění kvalifikačního předpokladu dle § 54 písm. b) ZVZ prokáže uchazeč, se kterým má být uzavřena smlouva podle § 82 ZVZ, předložením originálu nebo úředně ověřené kopie dokladu o oprávnění k podnikání podle zvláštních právních předpisů v rozsahu odpovídajícím předmětu veřejné zakázky, zejména dokladu prokazujícího příslušné živnostenské oprávnění či licenci.
#
# Splnění kvalifikačního předpokladu dle § 56 odst. 1 písm. a) ZVZ prokáže uchazeč, se kterým má být uzavřena smlouva podle § 82 ZVZ,  předložením seznamu významných dodávek realizovaných uchazečem v posledních 3 let, v němž musí doložit, že v tomto období realizoval min. 5 dodávek odpovídajících předmětu veřejné zakázky, každou v hodnotě min. 300.000,- Kč bez DPH. V seznamu musí být uveden rozsah dodávek a doba jejich plnění. K seznamu musí být doložena min. 3 osvědčení objednatelů o řádné realizaci výše uvedených dodávek s náležitostmi dle § 56 odst. 1 písm. a) ZVZ. Tato osvědčení musí obsahovat identifikační údaje objednatele včetně kontaktů, cenu, dobu a místo realizace dodávky.
#
#
# Podmínky prokázání splnění kvalifikačních předpokladů prostřednictvím subdodavatele, v případě společné nabídky nebo v případě zahraničního dodavatele
#
# V případě prokazování splnění kvalifikačních předpokladů prostřednictvím subdodavatele, v případě společné nabídky nebo v případě zahraničního dodavatele je třeba postupovat v souladu s příslušnými ustanoveními § 51 ZVZ.
#
# Důsledek nesplnění kvalifikace
# Nesplní-li dodavatel kvalifikaci v požadovaném rozsahu, bude v souladu s ustanovením § 60 odst. 1 ZVZ veřejným zadavatelem z účasti v zadávacím řízení vyloučen.
#
#
#
# 9       Požadavky dle § 68 odst. 3 ZVZ
# Součástí nabídky musí být rovněž:
# a) seznam statutárních orgánů nebo členů statutárních orgánů, kteří v posledních 3 letech od konce lhůty pro podání nabídek byli v pracovněprávním, funkčním či obdobném poměru u zadavatele,
#
# b) má-li dodavatel formu akciové společnosti, seznam vlastníků akcií, jejichž souhrnná jmenovitá hodnota přesahuje 10 % základního kapitálu, vyhotovený ve lhůtě pro podání nabídek,
#
# c) prohlášení uchazeče o tom, že neuzavřel a neuzavře zakázanou dohodu podle zákona č. 143/2001 Sb., o ochraně hospodářské soutěže a o změně některých zákonů (zákon o ochraně hospodářské soutěže), ve znění pozdějších předpisů, v souvislosti se zadávanou veřejnou zakázkou.
#
# Dodavatel může použít vzoru čestného prohlášení, který je přílohou č. 3 zadávací dokumentace. Toto čestné prohlášení musí být podepsáno osobou oprávněnou jednat v této věci za dodavatele nebo jeho jménem.
#
# 10      Obchodní podmínky, včetně platebních podmínek
#
# Obchodní podmínky, včetně platebních podmínek, tj. závazné požadavky zadavatele na obsah návrhu smlouvy tvoří přílohu č. 4 zadávací dokumentace. Uchazeč není oprávněn činit změny či doplnění těchto závazných požadavků zadavatele, s výjimkou údajů, které je uchazeč povinen doplnit (žlutě označené pasáže) a změn či doplnění, které by zvýhodňovaly smluvní postavení objednatele. Takové změny či doplnění je třeba jasně barevně zviditelnit, aby je bylo možno snadno odlišit od původního textu (např. červenou barvou). Jiné změny, úpravy či doplnění nebude veřejný zadavatel akceptovat.
#
# 11     Technická specifikace
#
# Souhrn technických popisů, které vymezují požadované technické charakteristiky a požadavky na dodávky, jejichž prostřednictvím je předmět veřejné zakázky popsán jednoznačně a objektivně způsobem vyjadřujícím účel využití zamýšlený veřejným zadavatelem (dále jen „technická specifikace“), je obsažen v příloze č. 1 zadávací dokumentace.
#
# Materiály nebo výrobky jmenovitě uvedené v zadávacích podmínkách nejsou pro dodavatele závazné, ale jsou reprezentanty určeného kvalitativního standardu. Pokud by zadávací podmínky obsahovaly určité obchodní názvy materiálů a výrobků nebo odkazy na obchodní názvy firem nebo označení původu, uchazeč to při zpracování nabídky bude chápat jako vymezení kvalitativního standardu. Zadavatel umožňuje použití i jiných, kvalitativně a technicky vhodných řešení, pokud bude vymezený kvalitativní standard dodržen nebo bude mít dokonce lepší parametry. Toto musí dodavatel prokázat ve své nabídce, a to zejména technickou dokumentací výrobce nebo zkušebním protokolem vydaným uznaným orgánem.
#
# 12        Lhůta pro podání nabídek
#
# Nabídky musí být doručeny nejpozději dne 8. 8. 2012 do 10:00 hodin.
#
# 13      Místo pro podání nabídek
#
# Nabídky musí být doručeny v listinné podobě, a to buď osobně v pracovních dnech od 09:00 do 14:00 hod nebo poštou, administrátorovi veřejné zakázky na níže uvedenou adresu:
#
# Institut pro rozvoj vzdělávání, s.r.o.
# Tereza Schimmerová
# Přístavní 321/14, 170 00 Praha 7 - Holešovice
#
# 14    Zadávací lhůta
#
# Veřejný zadavatel stanovil délku zadávací lhůty, lhůty po kterou jsou uchazeči svými nabídkami vázáni, do 31. 10. 2012.
# 15       Varianty nabídek
# Veřejný zadavatel nepřipouští variantní řešení nabídek.
# 16       Požadavky na způsob zpracování nabídkové ceny
# Nabídková cena bude stanovena jako cena celková a nejvýše přípustná a bude zahrnovat veškeré náklady na plnění celé veřejné zakázky, jak je popsána v zadávací dokumentaci (včetně všech jejích příloh), včetně všech poplatků a veškerých dalších nákladů spojených s plněním této veřejné zakázky. Nabídková cena nemůže překročit výši předpokládané hodnoty veřejné zakázky.
# Nabídková cena bude stanovena v Kč a bude uvedena v členění cena bez DPH, výše DPH a cena včetně DPH.
# Uchazeč doplní detailní rozpis ceny v Kč dle jednotlivých položek předmětu plnění do tabulek Přílohy č. 1 zadávací dokumentace. U každé položky uchazeč uvede cenu v Kč bez DPH, vyčíslí DPH a dále uvede celkovou cenu vč. DPH. Nabízené zboží musí být v souladu s bodem 3 zadávací dokumentace). Takto vyplněná příloha č. 1 zadávací dokumentace bude součástí smlouvy, jako její příloha.
# Zadavatel nepřipouští v průběhu plnění veřejné zakázky překročení nabídkové ceny vyjma případu, kdy dojde ke změně zákona č. 235/2004 Sb., o dani z přidané hodnoty, ve znění pozdějších předpisů, ovlivňující výši DPH.
# 17       Jiné požadavky zadavatele na plnění veřejné zakázky a          podmínky a požadavky na zpracování nabídky
# Nabídka bude obsahovat návrh smlouvy podepsaný osobou oprávněnou jednat za uchazeče nebo jeho jménem a další dokumenty požadované ZVZ či zadavatelem v zadávacích podmínkách.
# Nabídka bude obsahovat tyto samostatné části v pořadí, jak je dále uvedeno:
# 1. Krycí list nabídky - Příloha č. 5 zadávací dokumentace. Krycí list nabídky bude obsahovat zejména tyto údaje:
# - identifikační údaje uchazeče dle § 17 odst. 1 písm. d) ZVZ;
# - nabídkovou cenu v členění dle bodu 16 zadávací dokumentace.
# 2. Obsah - s uvedením jednotlivých oddílů a čísly stran, na kterých se dokumenty tvořící daný oddíl nachází.
# 3. Originál plné moci s ověřením pravosti podpisů v případě, že některé dokumenty nebudou podepsány osobou oprávněnou jednat jménem uchazeče.
# 4. Čestné prohlášení prokazující splnění kvalifikačních předpokladů – čestné prohlášení bude vyhotoveno v souladu s bodem 8 zadávací dokumentace.
#
# 5. Čestné prohlášení ve vztahu k požadavkům uvedeným v § 68 odst. 3 ZVZ – viz bod 9 zadávací dokumentace.
#
# 6. Návrh smlouvy podepsaný osobou oprávněnou jednat za uchazeče nebo jeho jménem. Návrh smlouvy musí být předložen v souladu s požadavky uvedenými v bodě 10 zadávací dokumentace.
#
# 7. Podrobná cenová kalkulace a podrobná technická specifikace předmětu plnění - bude vyhotovena v souladu s bodem 3 a 16 zadávací dokumentace v příloze č. 1 zadávací dokumentace.
#
# 8. Čestné prohlášení uchazeče, že se nepodílel na přípravě nebo zadání předmětného zadávacího řízení – příloha č. 6 zadávací dokumentace.
# Za obsahovou úplnost nabídky odpovídá výhradně uchazeč - výčet dokumentů obsažený v tomto bodě zadávací dokumentace slouží pouze pro usnadnění orientace uchazeče při kompletaci nabídky. Pokud v tomto výčtu není uveden dokument, který je uchazeč povinen doložit do nabídky dle jiných ustanovení zadávací dokumentace nebo dle ZVZ, nemůže se uchazeč zbavit odpovědnosti za obsahovou neúplnost nabídky  poukazem na tento výčet dokumentů.
# 18      Další podmínky a požadavky na zpracování nabídky
# Nabídka bude podána v listinné podobě, v jazyce českém, ve dvou vyhotoveních, z nichž jedno bude označeno „Originál“ a další vyhotovení „Kopie“. Uchazeč předloží nabídku též v elektronické podobě na CD, a to ve formátu MS Office nebo kompatibilním, případně ve formátu *.pdf.
# Nabídka v listinné podobě musí být podána v řádně uzavřené obálce, s vloženým CD, označené slovem „NEOTEVÍRAT“ a názvem veřejné zakázky, na obálce musí být také uvedena adresa, na kterou je možné zaslat oznámení podle § 71 odst. 6 ZVZ.
# Doporučení: Nabídka bude odpovídajícím způsobem zabezpečena proti možné manipulaci s jednotlivými listy včetně příloh a proti jejich vypadnutí, bude např. provázána provázkem (šňůrkou), který bude zavázán a zapečetěn nebo přelepen papírovou páskou opatřenou razítkem a podpisem osoby oprávněné jednat za uchazeče nebo jeho jménem. Všechny listy nabídky vč. příloh budou v pravém dolním rohu vzestupně a řádně očíslovány. Jednotlivé oddíly budou přehledně označeny boční popiskou nebo rozdělovníky.
# 19     Termín a místo otevírání obálek s nabídkami
#
# Otevírání obálek s nabídkami se uskuteční dne 8.8.2012 od 11:00 hod v místě sídla veřejného zadavatele: Hálkova 591, 396 01 Humpolec.
#
# Otevírání obálek se mají právo účastnit uchazeči, jejichž nabídky byly zadavateli doručeny ve lhůtě pro podání nabídek. Za každého uchazeče se bude moci otevírání obálek s nabídkami zúčastnit, z kapacitních důvodů, max. 1 zástupce. Zadavatel bude po přítomných zástupcích uchazečů požadovat, aby oprávněnost účasti při otevírání obálek s nabídkami prokázali (např. plnou mocí nebo aktuálním výpisem z obchodního rejstříku) a svoji účast stvrdili podpisem v listině přítomných uchazečů.
# 20       Údaje o hodnotících kritériích a způsob hodnocení nabídek
#
# Základním hodnotícím kritériem pro zadání veřejné zakázky je nejnižší nabídková cena. Nabídky uchazečů, které splní všechny požadavky stanovené v zadávacích podmínkách a ZVZ, a které postoupí k hodnocení nabídek, budou hodnoceny (seřazeny) podle výše celkové nabídkové ceny včetně DPH.
#
# 21       Přílohy zadávací dokumentace
# Příloha č. 1 - Specifikace předmětu plnění veřejné zakázky
# Příloha č. 2  – Čestné prohlášení prokazující splnění kvalifikačních předpokladů
# Příloha č. 3 – Čestné prohlášení dle ustanovení § 68 odst. 3 ZVZ
# Příloha č. 4 – Návrh kupní smlouvy
# Příloha č. 5 – Krycí list nabídky
# Příloha č. 6 – Čestné prohlášení uchazeče, že se nepodílel na přípravě nebo zadání předmětného zadávacího řízení.
#
# V Humpolci dne: 23. 07. 2012
#
#
# 	Mgr. Václav Strnad, ředitel školy
# »
# Í . 4
# |
# „0 ŠKOLSTVÍ, OP Vzdělávání
# MLÁDEŽE A TĚLOVÝCHOVY pro konkurenceschopnost
#
# evropský
# sociální
# fondv ČR EVROPSKÁ UNIE
#
# INVESTICE DO ROZVOJE VZDĚLÁVÁNÍ
#
#
#
# =======================03 Příloha č. 1 ZD.doc=======================
# 12
# 1
# »
# Í . 4
# |
# „0 ŠKOLSTVÍ, OP Vzdělávání
# MLÁDEŽE A TĚLOVÝCHOVY pro konkurenceschopnost
#
# evropský
# sociální
# fondv ČR EVROPSKÁ UNIE
#
# INVESTICE DO ROZVOJE VZDĚLÁVÁNÍ
#
#
#
#
#
#
# Příloha č. 1 zadávací dokumentace - Specifikace předmětu plnění veřejné zakázky
# 1.1 Interaktivní tabule
#
# 	Počet kusů
# 	1
#
# 	Specifikace
# 	· Neporézní povrch z kovo-keramické desky vysoce odolný proti mechanickému i chemickému poškození (vysoký důraz na kvalitu povrchu)
# · Tabule s popisovatelnými rozevíracími křídly pro popis fixem/křídou
#
# · Možnost popisovat tabuli fixem (snadné čištění i bez chemických přípravků)
#
# · Možnost použití magnetů, přičemž se nenaruší interaktivita tabule v žádném místě interaktivní plochy
# · Fungující bez připojení do elektrické sítě
#
# · Přenos signálu bezdrátovou technologií (např. Bluetooth)
# · Možnost práce třemi pery současně na jednom zařízení
#
# · Možnost ovládání zařízení vzdáleně
#
# · Technologie ovládání: optické odečítání souřadnic bodu dotyku pera s interaktivní plochou přímo z povrchu aktivní plochy, lze použít až tři ovládací pera
#
# · Možnost vytvoření jedné interaktivní plochy složením více zařízení vedle sebe
#
# · Jednoduchá ovladatelnost – běžný uživatel (učitel, žák) je schopen tabuli využívat bez předchozího školení
#
# · Integrované ozvučení, které je součástí tabule a nezasahuje do plochy tabule
#
# · Poměr stran 4:3
#
# · Rozměry interaktivní plochy: 1600x1200 – 1700x1300 (mm)
#
# 	Příslušenství
# 	· Pojízdný rám, integrované ozvučení do interaktivní tabule
#
# · Kvalitní a spolehlivý tablet – mini tabule, který umožňuje ovládání interaktivní tabule na dálku, pasivní (bez napájení), resp. výukovým programem na tabuli, umožňuje pracovat bez nutnosti fyzického přístupu k tabuli a ovládání stejným způsobem/perem, jako se ovládá interaktivní tabule.
#
# · Snímatelná ovládací magnetická lišta
#
# 	Související služby
# 	· Doprava a montáž tabule, implementace software, uvedení do provozu
#
# · Montáž, propojení a zalištování kabeláže ozvučení tabule
#
# · Zprovoznění tabletu, základní zaškolení obsluhy
#
#
# 	Interaktivní tabule
#
# Název (označení)
# 	Počet ks
# 	Cena za     1 ks bez DPH
# 	DPH za 1 ks
# 	Cena za 1 ks  včetně DPH
# 	Cena celkem bez DPH
# 	DPH celkem
# 	Cena celkem  včetně DPH
#
#
# 	    1
#
#
#
#
#
#
#
#
# 	Podrobná technická specifikace:
#
#
# 1.2 Magnetické tabule
#
# 1.2.1 Magnetická tabule 120x200 cm
#
# 	Počet kusů
# 	1
#
# 	Specifikace
# 	· Fixem popisovatelná kovokeramická magnetická tabule
#
# · Rozměry: 120x200 cm
#
# · Bílá barva
#
# · Pro projekci pomocí projektoru specifikovaného v bodě 1.3.1 přílohy, který bude připevněn k tabuli
#
# 	Související služby
# 	· Doprava a montáž tabule, základní zaškolení obsluhy
#
#
# 	Magnetická tabule
#
# 120x200
#
# Název (označení)
# 	Počet ks
# 	Cena za     1 ks bez DPH
# 	DPH za 1 ks
# 	Cena za 1 ks  včetně DPH
# 	Cena celkem bez DPH
# 	DPH celkem
# 	Cena celkem  včetně DPH
#
#
# 	    1
#
#
#
#
#
#
#
#
# 	Podrobná technická specifikace:
#
#
# 1.2.2 Magnetická tabule 120x150 cm
#
# 	Počet kusů
# 	13
#
# 	Specifikace
# 	· Kovokeramická magnetická fixem popisovatelná tabule s křídly
#
# · Rozměry: 120x150
#
# · 2 křídla
#
# 	Příslušenství
# 	· Pružinový pojezd včetně madla
#
# 	Související služby
# 	· Doprava a montáž tabule, základní zaškolení obsluhy
#
#
# 	Magnetická tabule
#
#  120x150
#
# Název (označení)
# 	Počet ks
# 	Cena za     1 ks bez DPH
# 	DPH za 1 ks
# 	Cena za 1 ks  včetně DPH
# 	Cena celkem bez DPH
# 	DPH celkem
# 	Cena celkem  včetně DPH
#
#
# 	    13
#
#
#
#
#
#
#
#
# 	Podrobná technická specifikace:
#
#
# 1.3 Projektory
#
# 1.3.1 Projektor I
#
# 	Počet kusů
# 	3
#
# 	Specifikace
# 	· Kvalitní dataprojektor s důrazem na jeho záruku a poskytovaný záruční servis
#
# · Svítivost: 2700 ANSI
#
# · Rozlišení XGA (1024 x 768)
#
# · Kontrastní poměr 2200:1
#
# · Mechanické přiblížení/oddálení obrazu
#
# · 2 VGA konektory (možnost připojit více zařízení současně)
#
# · Záruka: 24 měsíců NBD On-Site (Next Business Day - záruka opravy následující pracovní den od nahlášení poruchy v místě klienta
#
# · Včetně teleskopického držáku na strop, montáže, uvedení do provozu, zalištování kabeláže
#
# · 1 kus projektoru připevněn k tabuli specifikované v bodě 1.2.1 přílohy
# · 2 kusy projektoru připevněny na konzoli k přichycení na zeď/na strop
#
# 	Příslušenství
# 	· Konzole projektoru - přichycení na zeď/na strop
#
# · Kabeláž pro dataprojektor, krycí lišty
#
# 	Související služby
# 	· Montáž dataprojektoru, uvedení do provozu, základní zaškolení obsluhy
#
#
# 	Projektor I
#
# Název (označení)
# 	Počet ks
# 	Cena za     1 ks bez DPH
# 	DPH za 1 ks
# 	Cena za 1 ks  včetně DPH
# 	Cena celkem bez DPH
# 	DPH celkem
# 	Cena celkem  včetně DPH
#
#
# 	    3
#
#
#
#
#
#
#
#
# 	Podrobná technická specifikace:
#
#
# 1.3.2 Projektor II
#
# 	Počet kusů
# 	13
#
# 	Specifikace
# 	· Kvalitní dataprojektor s ultrakrátkou projekční vzdáleností a s důrazem na jeho záruku a poskytovaný záruční servis, technologie projekce 3LCD
# · Interaktivní funkce
#
# · Ochrana PIN kódem
#
# · Minimální svítivost: 2200 ANSI
#
# · Rozlišení WXGA (1280 x 800)
#
# · Kontrastní poměr 500:1
#
# · Životnost lampy minimálně 4000 hodin
#
# · Vstupy: HDMI, D-SUB, Cinch-Video, S-Video, RS232, 3,5 mm Mini Jack, RJ45
#
# · Záruka: 36 měsíců
#
# · Dálkové ovládání
#
# 	Příslušenství
# 	· Konzole projektoru - ultrakrátká projekce
#
# · Kabeláž pro dataprojektor, krycí lišty
#
# 	Související služby
# 	· Montáž dataprojektoru, uvedení do provozu, základní zaškolení obsluhy
#
#
# 	Projektor II
#
# Název (označení)
# 	Počet ks
# 	Cena za     1 ks bez DPH
# 	DPH za 1 ks
# 	Cena za 1 ks  včetně DPH
# 	Cena celkem bez DPH
# 	DPH celkem
# 	Cena celkem  včetně DPH
#
#
# 	    13
#
#
#
#
#
#
#
#
# 	Podrobná technická specifikace:
#
#
# 1.3.3 Projektor III
#
# 	Počet kusů
# 	6
#
# 	Specifikace
# 	· Kvalitní a spolehlivý dataprojektor s velmi krátkou (ultrakrátkou) projekční vzdáleností, technologie projekce 3LCD
# · Velmi krátká promítací vzdálenost (cca 0,5 m)
#
# · Interaktivní funkce
#
# · Svítivost: 3200 ANSI lumenů
#
# · Rozlišení WXGA (1280x800)
#
# · Mechanické přiblížení/oddálení obrazu
#
# · Kontrastní poměr 2300:1
#
# · 2 VGA konektory, HDMI, USB (možnost připojit více zařízení současně),
#
# · Záruka: 24 měsíců NBD On-Site (Next Business Day - záruka opravy následující pracovní den od nahlášení poruchy v místě klienta)
#
# 	Příslušenství
# 	· Konzole projektoru - ultrakrátká projekce
#
# · Kabeláž pro dataprojektor, krycí lišty
#
# · Náhradní interaktivní pero k projektoru
#
# · Dokovací stanice pro 2 interaktivní pera
#
# 	Související služby
# 	· Montáž dataprojektoru, uvedení do provozu, základní zaškolení obsluhy
#
#
# 	Projektor III
#
# Název (označení)
# 	Počet ks
# 	Cena za     1 ks bez DPH
# 	DPH za 1 ks
# 	Cena za 1 ks  včetně DPH
# 	Cena celkem bez DPH
# 	DPH celkem
# 	Cena celkem  včetně DPH
#
#
# 	    6
#
#
#
#
#
#
#
#
# 	Podrobná technická specifikace:
#
#
# 1.3.4 Projektor IV
#
# 	Počet kusů
# 	1
#
# 	Specifikace
# 	· Kvalitní a spolehlivý dataprojektor s ulktrakrátkou projekční vzdáleností
#
# · Velmi krátká promítací vzdálenost (cca 0,5 m)
#
# · Jas: 3 200 ANSI lumenů
#
# · Kontrastní poměr: 2 300 : 1
#
# · Rozlišení: WXGA (1 280 x 800)
#
# · Záruka: 24 měsíců NBD On-Site (Next business Day – záruka opravy následující pracovní den od nahlášení poruchy v místě klienta)
#
# · 2 VGA konektory, HDMI, USB (možnost připojit více zařízení současně)
#
# 	Příslušenství
# 	· Kabeláž pro dataprojektor, krycí lišty
#
# 	Související služby
# 	· Uvedení do provozu, základní zaškolení obsluhy
#
#
# 	Projektor IV
#
# Název (označení)
# 	Počet ks
# 	Cena za     1 ks bez DPH
# 	DPH za 1 ks
# 	Cena za 1 ks  včetně DPH
# 	Cena celkem bez DPH
# 	DPH celkem
# 	Cena celkem  včetně DPH
#
#
# 	    1
#
#
#
#
#
#
#
#
# 	Podrobná technická specifikace:
#
#
# 1.4 Zařízení na ozvučení třídy
#
# 	Počet kusů
# 	18
#
# 	Specifikace
# 	· Stereofonní ozvučení s dostatečným výkonem pro ozvučení celého prostoru třídy
#
# · Dálkové ovládání
#
# · Minimální výkon 15 W/kanál, umístění neviditelné, za tabulí
#
# 	Příslušenství
# 	· Konzole pro montáž reproduktorů
#
# 	Související služby
# 	· Instalace, zalištování kabeláže, uvedení do provozu, základní zaškolení obsluhy
#
#
# 	Zařízení na ozvučení třídy
#
# Název (označení)
# 	Počet ks
# 	Cena za     1 ks bez DPH
# 	DPH za 1 ks
# 	Cena za 1 ks  včetně DPH
# 	Cena celkem bez DPH
# 	DPH celkem
# 	Cena celkem  včetně DPH
#
#
# 	    18
#
#
#
#
#
#
#
#
# 	Podrobná technická specifikace:
#
#
# Součástí dodávky bude také kompletní technická specifikace dodaných produktů.
#
# Nejedná se o repasované zboží.
# PAGE
# 1
#
# =======================04 Příloha č. 4 ZD.doc=======================
#
#
#
#
#
# Příloha č. 2 Zadávací dokumentace - kupní smlouva
# K U P N Í    S M L O U V A
#
# )
# Ř P r 3
# .
# Say E =
# sociální MINISTERSTVO ŠKOLSTVÍ (OP Vzdělávání
#
# fondvČR | EVROPSKÁ UNIE © wi/oe2e A TELOVÝCHOVY © pro konkuroncosehopnost
#
# INVESTICE DO ROZVOJE VZDĚLÁVÁNÍ
#
#
#
# uzavřená podle § 409 zákona č. 513/1991 Sb., obchodní zákoník, ve znění pozdějších předpisů (dále jen „obchodní zákoník“)
# Článek I
#
# Smluvní strany
#
# Kupující:
#
# Základní škola Humpolec, Hálkova 591, okres Pelhřimov
#
#
# se sídlem: Hálkova 591, 396 01 Humpolec
# IČ: 70504539
# zastoupený: Mgr. Václavem Strnadem, ředitelem školy
#
#
#
# tel.: +420 565532159
#
#
# e-mail: reditel.halkova@zshumpolec.cz
#                                       (dále jen „kupující“)
#
#
# Prodávající:
#
# název
#
#
#
# se sídlem: ……………………………………………………………..
# IČ: ……………………….
# DIČ: ……………………….
#
# č. ú.: ……………………….
# zastoupený ……………………….
# tel.: ……………………….
# e-mail: ……………………….
# (dále jen „prodávající“)
#
#   Článek II
#
# Předmět smlouvy
# (1)     Na základě této smlouvy se prodávající zavazuje dodat kupujícímu zboží a převést na něj vlastnické právo ke zboží, za podmínek dohodnutých v dalších ustanoveních smlouvy. Kupující se zavazuje zboží bez vad předané převzít a zaplatit za ně prodávajícímu kupní cenu, specifikovanou v čl. IV smlouvy, na základě dohodnutých platebních podmínek.
# (2)     Předmětem smlouvy je dodávka nových školících pomůcek a zařízení, v souladu s potřebami a požadavky kupujícího. Podrobná specifikace předmětu smlouvy je obsažena v Příloze č. 1 smlouvy. Prodávající se zavazuje dodat kupujícímu zboží ve smluveném množství, jakosti, provedení, termínech a ceně. Dále je prodávající povinen předat kupujícímu doklady, které se ke zboží vztahují a umožnit kupujícímu nabýt vlastnické právo ke zboží. Součástí předmětu smlouvy je též doprava předmětu smlouvy na místo plnění, jeho montáž, uvedení do provozu a zaškolení pracovníků kupujícího.
# (3) Prodávající se zavazuje umožnit osobám oprávněným k výkonu kontroly projektu, z něhož bude zakázka hrazena, provést kontrolu dokladů souvisejících s plněním zakázky a to minimálně do 31. 12. 2025.
#
# (4) Prodávající se zavazuje uchovávat veškeré originály účetních dokladů a originály dalších dokumentů souvisejících s realizací projektu, z něhož bude zakázka hrazena, dle zákona č. 563/1991 Sb., o účetnictví, ve znění pozdějších předpisů, minimálně do 31. 12. 2025.
#
# (5) Prodávající se zavazuje řídit se v případě publicity na všech dokumentech souvisejících s projektem, z něhož bude zakázka hrazena, pravidly publicity projektů financovaných z programu OPVK a pravidly vizuální identity ESF v ČR dle příručky pro příjemce finanční podpory projektů OPVK.
#
# (6) Prodávající se zavazuje dodržovat při plnění předmětu smlouvy opatření bezpečnosti, požární ochrany a ochrany zdraví při práci.
#
# (7) Prodávající se zavazuje splnit předmět smlouvy prostřednictvím osob s potřebnou kvalifikací a odborností.
#
# Článek III
#
# Dodání zboží – termín a místo plnění
# (1) Prodávající je vlastníkem zboží a nese nebezpečí škody na zboží. Nebezpečí škody na zboží přechází z prodávajícího na kupujícího okamžikem, kdy kupující písemně potvrdí v místě plnění převzetí zboží. Dnem převzetí zboží nabývá kupující vlastnické právo ke zboží.
# (2) Prodávající se zavazuje dodat zboží nejpozději do 20 dnů od obdržení výzvy kupujícího k plnění. Datum a čas předání zboží oznámí prodávající kupujícímu nejpozději 3 pracovní dny před tímto datem.
#
# (3) Zboží bude protokolárně předáno v místě sídla kupujícího: Hálkova 591, 396 01 Humpolec. Kupující potvrdí svým podpisem protokol o převzetí zboží (dodací list).
# (4) Kupující je oprávněn odmítnout převzetí zboží, pokud se na něm budou vyskytovat v okamžiku předání vady. Zboží se považuje za dodané a závazek prodávajícího dodat zboží bude splněn až okamžikem převzetí zboží bez vad kupujícím.
#
# (5) Dopravu zboží zajistí prodávající na vlastní náklady. Při předání zboží provede prodávající průkazné zaškolení kupujícím určených osob na provoz a údržbu zboží, a to zdarma.
# Článek IV
#
# Cena za zboží a platební podmínky
#
# (1) Celková cena za zboží bez DPH je    ,- Kč, celková výše DPH je    ,- Kč a celková cena za zboží s DPH je    ,- Kč (slovy:       korun českých). Podrobná specifikace ceny za zboží je obsažena v Příloze č. 1 smlouvy. Cena za zboží zahrnuje veškeré náklady a poplatky potřebné k řádnému splnění předmětu smlouvy včetně povinného poplatku za recyklaci zboží, kterému podléhá.
# (2) Prodávající má právo vystavit kupujícímu daňový doklad (fakturu) až po řádném předání zboží resp. části zboží a po jeho protokolárním převzetí.
# (3) Faktura musí mít všechny náležitosti daňového dokladu dle § 28 zákona č. 235/2004 Sb., o dani z přidané hodnoty, ve znění pozdějších předpisů, a § 13a obchodního zákoníku. V případě, že faktura nebude obsahovat předepsané náležitosti, je kupující oprávněn ji zaslat ve lhůtě splatnosti zpět prodávajícímu k doplnění či opravě, aniž se dostane do prodlení se splatností. Lhůta splatnosti počíná běžet znovu od opětovného doručení náležitě doplněné či opravené faktury.
#
# (4) Faktura bude splatná do 30 dnů ode dne jejího doručení kupujícímu. Za den úhrady se považuje den, kdy byla fakturovaná částka odepsána z účtu kupujícího.
#
# (5) Kupující se zavazuje provést úhradu kupní ceny bezhotovostním převodem na účet prodávajícího. Číslo bankovního účtu bude uvedeno na faktuře.
# Článek V
#
# Záruční podmínky
# (1) Prodávající odpovídá za vady zjevné, skryté i právní, které má zboží v době jeho předání kupujícímu a dále za ty vady, které se na zboží vyskytnou v záruční době.
# (2) Prodávající se zavazuje, že předané zboží bude prosté jakýchkoli vad a bude mít vlastnosti dle této smlouvy, obecně závazných právních předpisů a norem a vlastnosti v  první jakosti kvality provedení.
# (3) Prodávající poskytuje na dodané zboží záruku v délce nejméně 24 měsíců, není-li v podrobné specifikaci předmětu smlouvy obsažené v Příloze č. 1 smlouvy uvedeno jinak.
#
# (4) Záruční doba počíná běžet od dne následujícího po dni převzetí zboží kupujícím, které je uvedeno v předávacím protokolu podepsaném oběma smluvními stranami.
# (5) Kupující je oprávněn reklamovat v záruční době vady zboží u prodávajícího, a to písemnou formou. V reklamaci musí být popsána vada zboží nebo alespoň způsob, jakým se projevuje a určen nárok kupujícího z vady zboží, případně požadavek na způsob odstranění vady zboží, a to včetně návrhu termínu pro odstranění vady zboží prodávajícím.
# (6) Záruční servis se prodávající zavazuje provádět u kupujícího, a to formou opravy zboží na místě či dodáním náhradního zboží zdarma. Toto náhradní zboží musí být totožných či obdobných technických parametrů jako zboží vadné a kupující bude oprávněn je bezplatně užívat obvyklým způsobem až do doby převzetí opraveného zboží. Náklady spojené s dopravou, montáží a demontáží vadného i náhradního zboží nese prodávající v plné výši.
# (7) Prodávající nastoupí k odstranění reklamovaných vad u kupujícího nejpozději do 5 (slovy pěti) kalendářních dnů od nahlášení vady zboží, není-li v podrobné specifikaci předmětu smlouvy obsažené v Příloze č. 1 smlouvy uvedeno jinak.
# (8) V případě nemožnosti odstranění reklamované vady dodá prodávající kupujícímu náhradní plnění (zboží), přičemž pro toto náhradní plnění (zboží) běží nová záruční lhůta, a to ode dne řádného protokolárního převzetí náhradního plnění (zboží) kupujícím. Záruční lhůta je shodná jako v čl. V odst. 3 smlouvy.
# (9) Po dobu od nahlášení vady zboží kupujícím prodávajícímu až do řádného odstranění vady zboží prodávajícím neběží záruční doba s tím, že doba přerušení běhu záruční lhůty bude počítána na celé dny a bude brán v úvahu každý započatý kalendářní den.
# (10) Pozáruční servis zboží garantuje prodávající kupujícímu v délce 5 let po uplynutí řádné záruční doby jednotlivě určeného zboží dle čl. V odst. 3 smlouvy, a to za cenu v místě a čase obvyklou.
# (11) Prodávající se zavazuje zřídit a po celou záruční a pozáruční dobu udržovat v provozu telefonické a e-mailové kontaktní místo pro hlášení závad:
#
# Telefon: XXX
#
#
# GSM: XXX
#
#
# E-mail: XXX
# Kontaktní osoba: XXX
# ...
# V           dne:
#                                          ……………………………………………
#
# Jméno
#  a podpis osoby oprávněné jednat v této                                                                              věci za dodavatele nebo jeho jménem
# � Není-li nikdo takový, řádky proškrtněte.
#
# � Vyplňuje se pouze v případě, má-li dodavatel formu akciové společnosti.
#
# � Čitelně vepsat jméno a příjmení osoby či osob, které čestné prohlášení podepisují.
#
#
#
#
# =======================Příloha č. 4 ZD.doc=======================
#
#
#
#
#
# Příloha č. 2 Zadávací dokumentace - kupní smlouva
# K U P N Í    S M L O U V A
#
# )
# Ř P r 3
# .
# Say E =
# sociální MINISTERSTVO ŠKOLSTVÍ (OP Vzdělávání
#
# fondvČR | EVROPSKÁ UNIE © wi/oe2e A TELOVÝCHOVY © pro konkuroncosehopnost
#
# INVESTICE DO ROZVOJE VZDĚLÁVÁNÍ
#
#
#
# uzavřená podle § 409 zákona č. 513/1991 Sb., obchodní zákoník, ve znění pozdějších předpisů (dále jen „obchodní zákoník“)
# Článek I
#
# Smluvní strany
#
# Kupující:
#
# Základní škola Humpolec, Hálkova 591, okres Pelhřimov
#
#
# se sídlem: Hálkova 591, 396 01 Humpolec
# IČ: 70504539
# zastoupený: Mgr. Václavem Strnadem, ředitelem školy
#
#
#
# tel.: +420 565532159
#
#
# e-mail: reditel.halkova@zshumpolec.cz
#                                       (dále jen „kupující“)
#
#
# Prodávající:
#
# název
#
#
#
# se sídlem: ……………………………………………………………..
# IČ: ……………………….
# DIČ: ……………………….
#
# č. ú.: ……………………….
# zastoupený ……………………….
# tel.: ……………………….
# e-mail: ……………………….
# (dále jen „prodávající“)
#
#   Článek II
#
# Předmět smlouvy
# (1)     Na základě této smlouvy se prodávající zavazuje dodat kupujícímu zboží a převést na něj vlastnické právo ke zboží, za podmínek dohodnutých v dalších ustanoveních smlouvy. Kupující se zavazuje zboží bez vad předané převzít a zaplatit za ně prodávajícímu kupní cenu, specifikovanou v čl. IV smlouvy, na základě dohodnutých platebních podmínek.
# (2)     Předmětem smlouvy je dodávka nových školících pomůcek a zařízení, v souladu s potřebami a požadavky kupujícího. Podrobná specifikace předmětu smlouvy je obsažena v Příloze č. 1 smlouvy. Prodávající se zavazuje dodat kupujícímu zboží ve smluveném množství, jakosti, provedení, termínech a ceně. Dále je prodávající povinen předat kupujícímu doklady, které se ke zboží vztahují a umožnit kupujícímu nabýt vlastnické právo ke zboží. Součástí předmětu smlouvy je též doprava předmětu smlouvy na místo plnění, jeho montáž, uvedení do provozu a zaškolení pracovníků kupujícího.
# (3) Prodávající se zavazuje umožnit osobám oprávněným k výkonu kontroly projektu, z něhož bude zakázka hrazena, provést kontrolu dokladů souvisejících s plněním zakázky a to minimálně do 31. 12. 2025.
#
# (4) Prodávající se zavazuje uchovávat veškeré originály účetních dokladů a originály dalších dokumentů souvisejících s realizací projektu, z něhož bude zakázka hrazena, dle zákona č. 563/1991 Sb., o účetnictví, ve znění pozdějších předpisů, minimálně do 31. 12. 2025.
#
# (5) Prodávající se zavazuje řídit se v případě publicity na všech dokumentech souvisejících s projektem, z něhož bude zakázka hrazena, pravidly publicity projektů financovaných z programu OPVK a pravidly vizuální identity ESF v ČR dle příručky pro příjemce finanční podpory projektů OPVK.
#
# (6) Prodávající se zavazuje dodržovat při plnění předmětu smlouvy opatření bezpečnosti, požární ochrany a ochrany zdraví při práci.
#
# (7) Prodávající se zavazuje splnit předmět smlouvy prostřednictvím osob s potřebnou kvalifikací a odborností.
#
# Článek III
#
# Dodání zboží – termín a místo plnění
# (1) Prodávající je vlastníkem zboží a nese nebezpečí škody na zboží. Nebezpečí škody na zboží přechází z prodávajícího na kupujícího okamžikem, kdy kupující písemně potvrdí v místě plnění převzetí zboží. Dnem převzetí zboží nabývá kupující vlastnické právo ke zboží.
#
# (2) Prodávající se zavazuje dodat zboží nejpozději do 30.9.2012. Datum a čas předání zboží oznámí prodávající kupujícímu nejpozději 3 pracovní dny před tímto datem.
#
# (3) Zboží bude protokolárně předáno v místě sídla kupujícího: Hálkova 591, 396 01 Humpolec. Kupující potvrdí svým podpisem protokol o převzetí zboží (dodací list).
# (4) Kupující je oprávněn odmítnout převzetí zboží, pokud se na něm budou vyskytovat v okamžiku předání vady. Zboží se považuje za dodané a závazek prodávajícího dodat zboží bude splněn až okamžikem převzetí zboží bez vad kupujícím.
#
# (5) Dopravu zboží zajistí prodávající na vlastní náklady. Při předání zboží provede prodávající průkazné zaškolení kupujícím určených osob na provoz a údržbu zboží, a to zdarma.
# Článek IV
#
# Cena za zboží a platební podmínky
#
# (1) Celková cena za zboží bez DPH je    ,- Kč, celková výše DPH je    ,- Kč a celková cena za zboží s DPH je    ,- Kč (slovy:       korun českých). Podrobná specifikace ceny za zboží je obsažena v Příloze č. 1 smlouvy. Cena za zboží zahrnuje veškeré náklady a poplatky potřebné k řádnému splnění předmětu smlouvy včetně povinného poplatku za recyklaci zboží, kterému podléhá.
# (2) Prodávající má právo vystavit kupujícímu daňový doklad (fakturu) až po řádném předání zboží resp. části zboží a po jeho protokolárním převzetí.
# (3) Faktura musí mít všechny náležitosti daňového dokladu dle § 28 zákona č. 235/2004 Sb., o dani z přidané hodnoty, ve znění pozdějších předpisů, a § 13a obchodního zákoníku. V případě, že faktura nebude obsahovat předepsané náležitosti, je kupující oprávněn ji zaslat ve lhůtě splatnosti zpět prodávajícímu k doplnění či opravě, aniž se dostane do prodlení se splatností. Lhůta splatnosti počíná běžet znovu od opětovného doručení náležitě doplněné či opravené faktury.
#
# (4) Faktura bude splatná do 30 dnů ode dne jejího doručení kupujícímu. Za den úhrady se považuje den, kdy byla fakturovaná částka odepsána z účtu kupujícího.
#
# (5) Kupující se zavazuje provést úhradu kupní ceny bezhotovostním převodem na účet prodávajícího. Číslo bankovního účtu bude uvedeno na faktuře.
# Článek V
#
# Záruční podmínky
# (1) Prodávající odpovídá za vady zjevné, skryté i právní, které má zboží v době jeho předání kupujícímu a dále za ty vady, které se na zboží vyskytnou v záruční době.
# (2) Prodávající se zavazuje, že předané zboží bude prosté jakýchkoli vad a bude mít vlastnosti dle této smlouvy, obecně závazných právních předpisů a norem a vlastnosti v  první jakosti kvality provedení.
# (3) Prodávající poskytuje na dodané zboží záruku v délce nejméně 24 měsíců, není-li v podrobné specifikaci předmětu smlouvy obsažené v Příloze č. 1 smlouvy uvedeno jinak.
#
# (4) Záruční doba počíná běžet od dne následujícího po dni převzetí zboží kupujícím, které je uvedeno v předávacím protokolu podepsaném oběma smluvními stranami.
# (5) Kupující je oprávněn reklamovat v záruční době vady zboží u prodávajícího, a to písemnou formou. V reklamaci musí být popsána vada zboží nebo alespoň způsob, jakým se projevuje a určen nárok kupujícího z vady zboží, případně požadavek na způsob odstranění vady zboží, a to včetně návrhu termínu pro odstranění vady zboží prodávajícím.
# (6) Záruční servis se prodávající zavazuje provádět u kupujícího, a to formou opravy zboží na místě či dodáním náhradního zboží zdarma. Toto náhradní zboží musí být totožných či obdobných technických parametrů jako zboží vadné a kupující bude oprávněn je bezplatně užívat obvyklým způsobem až do doby převzetí opraveného zboží. Náklady spojené s dopravou, montáží a demontáží vadného i náhradního zboží nese prodávající v plné výši.
# (7) Prodávající nastoupí k odstranění reklamovaných vad u kupujícího nejpozději do 5 (slovy pěti) kalendářních dnů od nahlášení vady zboží, není-li v podrobné specifikaci předmětu smlouvy obsažené v Příloze č. 1 smlouvy uvedeno jinak.
# (8) V případě nemožnosti odstranění reklamované vady dodá prodávající kupujícímu náhradní plnění (zboží), přičemž pro toto náhradní plnění (zboží) běží nová záruční lhůta, a to ode dne řádného protokolárního převzetí náhradního plnění (zboží) kupujícím. Záruční lhůta je shodná jako v čl. V odst. 3 smlouvy.
# (9) Po dobu od nahlášení vady zboží kupujícím prodávajícímu až do řádného odstranění vady zboží prodávajícím neběží záruční doba s tím, že doba přerušení běhu záruční lhůty bude počítána na celé dny a bude brán v úvahu každý započatý kalendářní den.
# (10) Pozáruční servis zboží garantuje prodávající kupujícímu v délce 5 let po uplynutí řádné záruční doby jednotlivě určeného zboží dle čl. V odst. 3 smlouvy, a to za cenu v místě a čase obvyklou.
# (11) Prodávající se zavazuje zřídit a po celou záruční a pozáruční dobu udržovat v provozu telefonické a e-mailové kontaktní místo pro hlášení závad:
#
# Telefon: XXX
#
#
# GSM: XXX
#
#
# E-mail: XXX
# Kontaktní osoba: XXX
# (12) Prodávající se zavazuje zřídit a po celou záruční a pozáruční dobu udržovat v provozu telefonické a e-mailové kontaktní místo pro řešení problémů a dotazů spojených s interaktivním výukovým softwarem:
#
# Telefon: XXX
#
#
# GSM: XXX
#
#
# E-mail: XXX
# Kontaktní osoba: XXX
# Článek VI
#
# Sankční ustanovení
#
# (1) Pro případ porušení níže uvedených smluvních povinností dohodly smluvní strany, ve smyslu ustanovení § 300 a násl. obchodního zákoníku, níže uvedené smluvní pokuty, jejichž sjednáním není dotčen nárok kupujícího na náhradu škody způsobenou porušením povinnosti, zajištěnou smluvní pokutou. Pohledávka kupujícího na zaplacení smluvní pokuty může být započítána s pohledávkou prodávajícího na zaplacení ceny za zboží.
#
# (2) Kupující má právo požadovat na prodávajícím při nedodržení termínu předání zboží dle čl. III odst. 2 smlouvy smluvní pokutu ve výši 0,5 % z ceny za zboží, s jehož dodáním je prodávající v prodlení, a to za každý započatý den prodlení. Při nedodržení stanoveného termínu předání zboží je kupující oprávněn také od smlouvy odstoupit.
#
# (3) Při nedodržení termínu nástupu prodávajícího k odstranění reklamovaných vad u kupujícího dle č. V. odst. 7 smlouvy je kupující oprávněn požadovat na prodávajícím smluvní pokutu ve výši 500,- Kč za každý započatý den prodlení.
# (4) Prodávající má právo požadovat na kupujícím při nedodržení termínu splatnosti faktury zákonný úrok z prodlení.
#
# Článek VII
#
# Závěrečná ustanovení
#
# 1) V případě, že součástí dodaného zboží bude jakékoli autorské dílo ve smyslu ustanovení zákona č. 121/2000 Sb., o právu autorském, o právech souvisejících s právem autorským a o změně některých zákonů (autorský zákon), ve znění pozdějších předpisů, poskytuje tímto prodávající kupujícímu potřebnou licenci ke všem možným způsobům užití těchto autorských děl, jež budou potřebné pro řádné užívání zboží kupujícím, a to v potřebném rozsahu a na neomezenou dobu. Odměna za poskytnutí této licence je zahrnuta v celkové ceně za zboží.
# 2) Tuto smlouvu lze měnit pouze oboustranně odsouhlasenými, písemnými a průběžně číslovanými dodatky, podepsanými oprávněnými zástupci obou smluvních stran.
# 3) Případné spory vzniklé z této smlouvy budou řešeny podle platné právní úpravy věcně a místně příslušnými soudy České republiky.
# 4) Smluvní strany se dohodly, že právní vztahy založené touto smlouvou se budou řídit příslušnými ustanoveními obchodního zákoníku.
# 5) Smluvní strany prohlašují, že předem souhlasí, v souladu se zněním zákona č.106/1999 Sb., o svobodném přístupu k informacím, ve znění pozdějších předpisů, s možným zpřístupněním, či zveřejněním celé této smlouvy v jejím plném znění, jakož i všech úkonů a okolností s touto smlouvou souvisejících, ke kterému může kdykoli v budoucnu dojít.
# 6) Pokud kterékoli ustanovení této smlouvy nebo jeho část bude neplatné či nevynutitelné, nebo se stane neplatným či nevynutitelným, nebo bude shledáno neplatným či nevynutitelným soudem či jiným příslušným orgánem, pak tato neplatnost či nevynutitelnost nebude mít vliv na platnost či vynutitelnost ostatních ustanovení smlouvy nebo jejich částí.
# 7) Smluvní strany se dohodly, že v případě zániku právního vztahu založeného touto smlouvou zůstávají v platnosti a účinnosti i nadále ustanovení, z jejichž povahy vyplývá, že mají zůstat nedotčena zánikem právního vztahu založeného touto smlouvou.
# 8) Nedílnou součást této smlouvy tvoří jako příloha této smlouvy:
#              Příloha č. 1 – Specifikace předmětu smlouvy a ceny za zboží.
# 9) Tato smlouva nabývá platnosti a účinnosti v den jejího podpisu oběma smluvními stranami.
# 10) Smluvní strany konstatují, že tato smlouva byla vyhotovena ve 3 stejnopisech, z nichž kupující obdrží 2 vyhotovení a prodávající 1 vyhotovení. Každý stejnopis má právní sílu originálu.
#
# 11) Obě smluvní strany potvrzují autentičnost této smlouvy a prohlašují, že si smlouvu přečetly, s jejím obsahem souhlasí, že smlouva byla sepsána na základě pravdivých údajů, z jejich pravé a svobodné vůle a bez jednostranně nevýhodných podmínek, což stvrzují svým podpisem, resp. podpisem svého oprávněného zástupce.
#
# V Humpolci dne:
#
#
#
#
#
#
# V             dne:
# ……………………………………
#
#
#
#
# ……….
# ………………………………….
# za kupujícího
#
#
#
#
#
#
#
#
#         za prodávajícího
# Mgr. Václav Strnad, ředitel školy
# PAGE
# 1
#
# =======================Příloha č. 5 ZD.doc=======================
# »
# Í . 4
# |
# „0 ŠKOLSTVÍ, OP Vzdělávání
# MLÁDEŽE A TĚLOVÝCHOVY pro konkurenceschopnost
#
# evropský
# sociální
# fondv ČR EVROPSKÁ UNIE
#
# INVESTICE DO ROZVOJE VZDĚLÁVÁNÍ
#
#
#
#
#
#
# Příloha č. 5 zadávací dokumentace – Krycí list nabídky
#
# Krycí list nabídky
#
# Název veřejné zakázky: „Dodávka projekční a interaktivní techniky“
# Veřejný zadavatel: Základní škola Humpolec, Hálkova 591, okres Pelhřimov
#                                  IČ:
# 70504539
#
#                                  Sídlo:
# Hálkova 591, 396 01 Humpolec
#
# Osoba oprávněná jednat za zadavatele: Mgr. Václav Strnad, ředitel školy
#
# Kontaktní osoba:
# Mgr. Václav Strnad
#
# Telefon:
# +420 565532159
#
# E-mail:
# reditel.halkova@zshumpolec.cz
# Uchazeč:
#
#
#
#
# Obchodní firma/název:
# ……………………………………………………………..
#
# sídlo:
#
#
#
# ……………………………………………………………..
#
# právní forma:
#
#             ……………………………………………………………..
#
# IČ:
#
#
#
# ……………………………………………………………..
#
# DIČ:
#
#
#
# ……………………………………………………………..
#
# bankovní spojení:
#
# ……………………………………………………………..
# osoba oprávněná jednat za uchazeče: ……..……………………………………………..
#
# kontaktní osoba  ve věci zakázky:     ……..…………………………….………………...
#
# telefon a e-mail:                    ……………………………………………………………..
# Celková nabídková cena:
#
#
# 	Cena v Kč bez DPH
# 	Výše DPH v Kč
# 	Cena v Kč včetně DPH
#
# 	Celková nabídková cena
#
#
#
#
#
# V       dne:
#                                          ……………………………………………
#
# Jméno
#  a podpis osoby oprávněné jednat v této                                                                              věci za dodavatele nebo jeho jménem
# � Čitelně vepsat jméno a příjmení osoby či osob, které čestné prohlášení podepisují.
#
#
#
#
# =======================Příloha č. 6 ZD.doc=======================
# »
# Í . 4
# |
# „0 ŠKOLSTVÍ, OP Vzdělávání
# MLÁDEŽE A TĚLOVÝCHOVY pro konkurenceschopnost
#
# evropský
# sociální
# fondv ČR EVROPSKÁ UNIE
#
# INVESTICE DO ROZVOJE VZDĚLÁVÁNÍ
#
#
#
#
#
#
# Příloha č. 6 zadávací dokumentace – Čestné prohlášení uchazeče, že se nepodílel na přípravě nebo zadání předmětného zadávacího řízení
# Čestné prohlášení uchazeče
# Tímto jako uchazeč o podlimitní veřejnou zakázku s názvem „Dodávka projekční a interaktivní techniky“ čestně prohlašuji, že:
# a) na zpracování naší nabídky se nepodílel zaměstnanec zadavatele či člen realizačního týmu projektu či osoba, která se na základě smluvního vztahu podílela na přípravě nebo zadání předmětného výběrového řízení;
#
# b) nejsem uchazečem ve sdružení, kde je zaměstnanec zadavatele či člen realizačního týmu či osoba, která se na základě smluvního vztahu podílela na přípravě nebo zadání předmětného výběrového řízení;
#
# c) naším subdodavatelem není zaměstnanec zadavatele, člen realizačního týmu či osoba, která se na základě smluvního vztahu podílela na přípravě nebo zadání předmětného výběrového řízení.
#
# V           dne:
#                                          ……………………………………………
#
# Jméno
#  a podpis osoby oprávněné jednat v této                                                                              věci za dodavatele nebo jeho jménem
# � Čitelně vepsat jméno a příjmení osoby či osob, které čestné prohlášení podepisují.

# %%
extractor = AdvancedSubjectContextExtractor(keywords=keywords)

# %%
extractor.show_occurrence_distribution(text)

# %%
extractor.get_subject_context_start(text)
# Out:
# 66362

# %%
extractor.get_subject_context_end(text, 66362)
# Out:
# 76362

# %%
df_contracts.at[index, 'subj_context2']
# Out:
# '  Článek II\n\nPředmět smlouvy\n(1)     Na základě této smlouvy se prodávající zavazuje dodat kupujícímu zboží a převést na něj vlastnické právo ke zboží, za podmínek dohodnutých v dalších ustanoveních smlouvy. Kupující se zavazuje zboží bez vad předané převzít a zaplatit za ně prodávajícímu kupní cenu, specifikovanou v čl. IV smlouvy, na základě dohodnutých platebních podmínek.\n(2)     Předmětem smlouvy je dodávka nových školících pomůcek a zařízení, v souladu s potřebami a požadavky kupujícího. Podrobná specifikace předmětu smlouvy je obsažena v Příloze č. 1 smlouvy. Prodávající se zavazuje dodat kupujícímu zboží ve smluveném množství, jakosti, provedení, termínech a ceně. Dále je prodávající povinen předat kupujícímu doklady, které se ke zboží vztahují a umožnit kupujícímu nabýt vlastnické právo ke zboží. Součástí předmětu smlouvy je též doprava předmětu smlouvy na místo plnění, jeho montáž, uvedení do provozu a zaškolení pracovníků kupujícího.\n(3) Prodávající se zavazuje umožnit osobám oprávněným k výkonu kontroly projektu, z něhož bude zakázka hrazena, provést kontrolu dokladů souvisejících s plněním zakázky a to minimálně do 31. 12. 2025.\n\n(4) Prodávající se zavazuje uchovávat veškeré originály účetních dokladů a originály dalších dokumentů souvisejících s realizací projektu, z něhož bude zakázka hrazena, dle zákona č. 563/1991 Sb., o účetnictví, ve znění pozdějších předpisů, minimálně do 31. 12. 2025. \n\n(5) Prodávající se zavazuje řídit se v případě publicity na všech dokumentech souvisejících s projektem, z něhož bude zakázka hrazena, pravidly publicity projektů financovaných z programu OPVK a pravidly vizuální identity ESF v ČR dle příručky pro příjemce finanční podpory projektů OPVK.\n\n(6) Prodávající se zavazuje dodržovat při plnění předmětu smlouvy opatření bezpečnosti, požární ochrany a ochrany zdraví při práci.\n\n(7) Prodávající se zavazuje splnit předmět smlouvy prostřednictvím osob s potřebnou kvalifikací a odborností.\n\nČlánek III\n'

# %%
df_contracts.at[index, 'subj_context2'] = """  Článek II

Předmět smlouvy
(1)     Na základě této smlouvy se prodávající zavazuje dodat kupujícímu zboží a převést na něj vlastnické právo ke zboží, za podmínek dohodnutých v dalších ustanoveních smlouvy. Kupující se zavazuje zboží bez vad předané převzít a zaplatit za ně prodávajícímu kupní cenu, specifikovanou v čl. IV smlouvy, na základě dohodnutých platebních podmínek.
(2)     Předmětem smlouvy je dodávka nových školících pomůcek a zařízení, v souladu s potřebami a požadavky kupujícího. Podrobná specifikace předmětu smlouvy je obsažena v Příloze č. 1 smlouvy. Prodávající se zavazuje dodat kupujícímu zboží ve smluveném množství, jakosti, provedení, termínech a ceně. Dále je prodávající povinen předat kupujícímu doklady, které se ke zboží vztahují a umožnit kupujícímu nabýt vlastnické právo ke zboží. Součástí předmětu smlouvy je též doprava předmětu smlouvy na místo plnění, jeho montáž, uvedení do provozu a zaškolení pracovníků kupujícího.
(3) Prodávající se zavazuje umožnit osobám oprávněným k výkonu kontroly projektu, z něhož bude zakázka hrazena, provést kontrolu dokladů souvisejících s plněním zakázky a to minimálně do 31. 12. 2025.

(4) Prodávající se zavazuje uchovávat veškeré originály účetních dokladů a originály dalších dokumentů souvisejících s realizací projektu, z něhož bude zakázka hrazena, dle zákona č. 563/1991 Sb., o účetnictví, ve znění pozdějších předpisů, minimálně do 31. 12. 2025. 

(5) Prodávající se zavazuje řídit se v případě publicity na všech dokumentech souvisejících s projektem, z něhož bude zakázka hrazena, pravidly publicity projektů financovaných z programu OPVK a pravidly vizuální identity ESF v ČR dle příručky pro příjemce finanční podpory projektů OPVK.

(6) Prodávající se zavazuje dodržovat při plnění předmětu smlouvy opatření bezpečnosti, požární ochrany a ochrany zdraví při práci.

(7) Prodávající se zavazuje splnit předmět smlouvy prostřednictvím osob s potřebnou kvalifikací a odborností.

Článek III
"""

# %%
df_subj_context2 = df_contracts.loc[0:39]['subj_context2']
df_subj_context2
# Out:
# id
# 0     \nSmlouva nabývá platnosti a účinnosti dnem po...
# 1     \nTito uvedení zástupci jsou oprávněni jednat ...
# 2     \njménem zadavatele\n\n \n\n2. Předmět veřejné...
# 3     \n(dále jen „zhotovitel “ nebo „projektant“)\n...
# 4     \nvyhotovil tuto písemnou zprávu.\n\n1. Předmě...
# 5     \nprohlášení nebo v souvislosti s ní druhé sml...
# 6     \nmluvní straně vznikne.\nČlánek 2\nPředmět Sm...
# 7     \nOdůvodnění: Veřejnou zakázku malého rozsahu....
# 8     \nIdentifikace veřejné zakázky\n\nNázev veřejn...
# 9     \nvěstníku EU, na veřejnou zakázku „Programové...
# 10    \nJana Velíšková, tel. + 420 973 225 210.\n\n2...
# 11    \npovinen dodržet zásady podle $ 6 ZZVZ.\n\n2....
# 12    \ntéto Smlouvy a je odborně způsobilý ke splně...
# 13    \nrozhodl o výběru dodavatele k veřejné zakázc...
# 14    \nStrana 2\n\nII.\nPředmět plnění\n1. Předměte...
# 15    \nIdentifikace veřejné zakázky\n\n\tNázev veře...
# 16    \nOdůvodnění: Veřejnou zakázku malého rozsahu....
# 17    \nNabídku lze podat pouze elektronicky (NEN a ...
# 18    \nOdůvodnění: Veřejnou zakázku malého rozsahu....
# 19    \nkteré vyplývají z této smlouvy a nejsou v ní...
# 20    \n(dále jen „zhotovitel“)\n\n\nII. Předmět sml...
# 21    \n1.4. Účelem této Smlouvy je úprava práv a po...
# 22    \nvůči třetí osobě.\nČlánek III.\n\nPředmět sm...
# 23    \nv článku 21 této zadávací dokumentace (dále ...
# 24    \n- ve věcech řízení stavby: tel:  e-mail: \n ...
# 25    \n  Telefon : +420 485 226 967 \n\n     \n\n2....
# 26    \ncenové nabídky zhotovitele ze dne…………….. \n\...
# 27    \n(dále také jako „smlouva“)\n\n1. Předmět sml...
# 28    \n(dále jen „zadavatel“)\n\n2. Předmět plnění ...
# 29    \nnebude podílet na zpracování žádné nabídky.\...
# 30    \n(dále jen „prodávající“)\n\n  Článek II\n\nP...
# 31    \nProfil zadavatele: https://www.vhodne-uverej...
# 32    \nVeřejná zakázka na dodávky.\n\n3. Předmět ve...
# 33    \n(dále jen „prodávající“)\n\nPŘEDMĚT PLNĚNÍ\n...
# 34    \n(dále jen „smlouva“)\n\nI.\nPředmět smlouvy\...
# 35    \n3z15\n\n \n\n \n\n3. DRUH DODÁVKY, PŘEDMĚT V...
# 36    \nzastoupená: Ing. Zdeněk Hedvičák, ředitel di...
# 37    \nzadavatele.info/UEB.html\n\n3, Předmět veřej...
# 38    \nnásledovně:\n\nl. I\nPředmět plnění\n\nPředm...
# 39    \nZAKÁZKY\n\n \n\n1. Identifikační údaje o zad...
# Name: subj_context2, dtype: object
