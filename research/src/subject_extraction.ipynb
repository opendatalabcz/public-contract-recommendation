# %% [markdown]
# ### Initialization

# %%
import glob
import json
import re
from nltk import tokenize
import textdistance
import random
import string
import os
import numpy
import pandas
import fasttext
import gensim
import conllu
import editdistance
import udapi
import time

# %%
from utils.text_extraction import *
from utils.document_processing import *
from utils.subject_extraction import *
from utils.similarity import *
from utils.context_extraction import *

# %%
import psycopg2
psycopg2_conn = psycopg2.connect(dbname='public_contracts', user='postgres', password='admin', host='localhost', port='5432')

# %%
from udapi.core.document import Document
from ufal.udpipe import *
# load model from the given file;
# if the file does not exist, expect a Segmentation fault
udpipe_model = Model.load("../model/udpipe/udpipe-ud-2.4-190531/czech-pdt-ud-2.4-190531.udpipe")

# %%
# create a UDPipe processing pipeline with the loaded model,
# with "horizontal" input (a sentence with space-separated tokens),
# default setting for tagger and parser,
# and CoNLL-U output
udp_pipeline = Pipeline(udpipe_model, "tokenize", Pipeline.DEFAULT, Pipeline.DEFAULT, "conllu")

# %% [markdown]
# ### Documents

# %%
from utils.document_processing import *

# %%
loader = DatabaseDocumentLoader(psycopg2_conn)
loader.load_documents()
documents = loader.prepare_documents()
# Out:
# Running query: select * from document where processed=True
# Preparing total 1008 documents
# Progress: 0.0%
# Progress: 10.0%
# Progress: 20.0%
# Progress: 30.0%
# Progress: 40.0%
# Progress: 50.0%
# Progress: 60.0%
# Progress: 70.0%
# Progress: 80.0%
# Progress: 90.0%
# Progress: 100.0%

# %%
vzdirs = '../../test-data/*/*/*/*'
ignore_contracts = ['2096','sportovni-areal-zs-slatina-1-etapa_25534',
                    'revitalizace-lokality-spaliste-k-u-stare-mesto-u-uherskeho-hradiste-akceptacni-cislo-12136894-cz-1-02-4-2-00-12-16399-dodatecne-prace_9496',
                    '35226', 'kompostujeme-v-obci-sebranice-dodavka-stepkovace-a-komposteru', 'zvysovani-povedomi-verejnosti-o-biodiverzite-luk-a-pastvin',
                    'nakup-noveho-uzitkoveho-elektromobilu-typu-bev-vozidlo-s-bateriovym-pohonem']

ref_loader = ReferenceDocumentLoader(vzdirs)
# ref_loader.extract_text_from_documents(0,1024)
ref_loader.load_documents_from_extracts(ignore_contracts)
ref_documents = ref_loader.prepare_documents()
# Out:
# Loading total 340 extracts
# Preparing total 340 documents
# Progress: 0.0%
# Progress: 10.0%
# Progress: 20.0%
# Progress: 30.0%
# Progress: 40.0%
# Progress: 50.0%
# Progress: 60.0%
# Progress: 70.0%
# Progress: 80.0%
# Progress: 90.0%

# %%
ignore_mask = count_occurence_vector('qwertyuiopasdfghjklzxcvbnmQWERTYUIOPASDFGHJKLZXCVBNMáčďéěíňóřšťúůýžÁČĎÉĚÍŇÓŘŠŤÚŮÝŽ0123456789')
ignore_mask[0]=0
matcher = DocumentMatcher(ref_documents, documents)
matcher.count_most_similar_documents(ignore_mask=ignore_mask)
matcher.aggregate_documents()
df_contract = matcher.filter_aggregated()
# Out:
# Collecting document matrix
# Counting most similar documents for total 340 reference documents
# Progress: 0.0%
# Progress: 10.0%
# Progress: 20.0%
# Progress: 30.0%
# Progress: 40.0%
# Progress: 50.0%
# Progress: 60.0%
# Progress: 70.0%
# Progress: 80.0%
# Progress: 90.0%

# %% [markdown]
# ### Subject context

# %%
from utils.context_extraction import *

# %%
contracts = []
for contr_name, docs in df_contract.groupby('contr_name'):
    contr_text = ''
    contr_ids = []
    for index, doc in docs.iterrows():
        doc_name = doc['doc_name']
        contr_text += '======================='+doc_name+'=======================\n'
        contr_text += doc['doc_text']
        contr_ids.append(doc['contr_id'])
    contr_id = get_most_frequent(contr_ids)
    contr = {'id': contr_id, 'contr_name': contr_name, 'text': contr_text}
    contracts.append(contr)

# %%
DEF_KEYWORDS = {
    'Předmět smlouvy': 10,
    'Předmět díla': 10,
    'Předmět plnění': 10,
    'Předmět veřejné zakázky': 10,
    'Vymezení předmětu': 10,
    'Vymezení plnění': 10,
    'Popis předmětu': 10,
    'Název veřejné zakázky': 3,
    'Veřejná zakázka': 1,
    'Veřejné zakázce': 1,
    'Předmět': 1,
    'Popis': 1
}

extractor = AdvancedSubjectContextExtractor(keywords=DEF_KEYWORDS, subj_range=2040)
for contr in contracts:
    contr_text = contr['text']
    contr['subj_context'] = extractor.get_subject_contexts(contr_text)

# %%
df_contracts = pandas.DataFrame(contracts)
# df_contracts

# %% [markdown]
# ### Subject extraction

# %%
from utils.subject_extraction import *

# %%
from utils.subject_context_preprocessing import *

# %%
from utils.conllu_preprocessing import *

# %% [markdown]
# ### EvaluationMachine

# %%
class EvaluationMachine:
    
    _core = None
    _subjects = None
    _ref_subjects = None
    _similarity_matrix = None
    
    def __init__(self, core=None):
        self._core = core
    
    def evaluateSubjects(self, subjects, ref_subjects):
        self._subjects = [' '.join(s) if isinstance(s, list) else s for s in subjects]
        self._ref_subjects = [' '.join(s) if isinstance(s, list) else s for s in ref_subjects]
        return self.evaluate()
    
    def evaluate(self):
        self.compute_matrix()
        return self._similarity_matrix
        
    def compute_matrix(self):
        sl = len(self._subjects)
        rl = len(self._ref_subjects)
        result_matrix = numpy.zeros((sl, rl))
        for i in range(sl):
            for j in range(rl):
                d = self._core.compute(self._subjects[i], self._ref_subjects[j])
                result_matrix[i][j] = d
        self._similarity_matrix = result_matrix
        
    def display(self, with_headers=False):
        if with_headers:
            df = pandas.DataFrame(self._similarity_matrix, columns=self._ref_subjects, index=self._subjects)
        else:
            df = pandas.DataFrame(self._similarity_matrix)
        display(df)
        
    
class RandomEvaluationMachine(EvaluationMachine):
    
    def __init__(self, core=None):
        super().__init__(RandomSimilarityMachine())
        
class JaccardEvaluationMachine(EvaluationMachine):

    def __init__(self, core=None):
        super().__init__(JaccardSimilarityMachine())
        
class FastTextEvaluationMachine(EvaluationMachine):
    
    def __init__(self, core=None):
        super().__init__(FastTextSimilarityMachine(core))
        
class GensimFastTextEvaluationMachine(EvaluationMachine):
    
    def __init__(self, core=None):
        super().__init__(GensimFastTextSimilarityMachine(core))

# %%
class SubjectContextCopyExtractor(SubjectExtractor):
    
    def __init__(self, param=None):
        pass
        
    def extract(self, text):
        return text

# %% [markdown]
# ### Similarity functions

# %%
from utils.similarity import *

# %% [markdown]
# ### Measurements

# %%
from utils.evaluation import *

# %%
from udapi.core.document import Document

def apply_transformation(data, transformation):
    if isinstance(data, list):
        return [transformation(text) for text in data]
    return transformation(data)

def create_conllu_document(decomposition):
    doc = Document()
    doc.from_conllu_string(decomposition)
    return doc

def create_conllu_sentence_list(decomposition):
    doc = create_conllu_document(decomposition)
    return [b.trees[0] for b in doc.bundles]

def tag_text(text):
    return udp_pipeline.process(text)

class SubjectSentenceEvaluationMachine:
    
    _df_contracts = None
    _subj_context_preprocessor = None
    
    def __init__(self, df_contracts, subj_context_preprocessor=SubjectContextPreprocessor()):
        self._df_contracts = df_contracts
        self._subj_context_extractor = subj_context_preprocessor
        
    def preprocess(self):
        self._df_contracts['filtered_context'] = self._df_contracts['subj_context'].apply(\
            lambda text: self._subj_context_extractor.process(text))
#         self._df_contracts['subj_context_decomposition'] = self._df_contracts['filtered_context'].apply(tag_data)
#             return self._df_contracts
    
    def process(self):
        self._df_contracts = validate_subjects(self._df_contracts, 'filtered_context')
        return self._df_contracts

    def evaluate(self):
        return self._df_contracts['valid_score'].mean()*100
    
    def evaluateSentenceNum(self):
        self._df_contracts['sent_cnt_diff'] = \
            self._df_contracts['subj_context_decomposition'].apply(lambda decomposition: len(create_conllu_sentence_list(decomposition))) \
            - self._df_contracts['subj_context_decomposition_ref'].apply(lambda decomposition: len(create_conllu_sentence_list(decomposition)))
        return self._df_contracts['sent_cnt_diff'].abs().mean()

# %%
scores = {}
last_score = 0

# %%
# %%time

transformers = [
]

evaluator = SubjectSentenceEvaluationMachine(df_contracts, subj_context_preprocessor=SubjectContextPreprocessor())

start = time.time()
evaluator.preprocess()
evaluator.process()
end = time.time()
elapsed_time = end - start
score = evaluator.evaluate()
print('Score: ' + str(score))
print('Time: ' + str(elapsed_time))
print('Improve: ' + str(score - last_score))
last_score = score
df_last_contracts = df_contracts
df_contracts = evaluator._df_contracts
# scores['all'] = {'score': score, 'time': elapsed_time}
# Out:
# Score: 99.2387840112235
# Time: 0.6100409030914307
# Improve: 99.2387840112235
# Wall time: 610 ms

# %%
class SubjectItemsEvaluationMachine:
    
    def __init__(self, df_contracts,\
                 subj_context_preprocessor=SubjectContextPreprocessor(),\
                 conllu_context_preprocessor=ConlluSubjectContextPreprocessor()):
        self._df_contracts = df_contracts
        self._subj_context_extractor = subj_context_preprocessor
        self._conllu_context_extractor = conllu_context_preprocessor
        
    def preprocess(self):
        self._df_contracts['filtered_context'] = self._df_contracts['subj_context'].apply(\
            lambda text: self._subj_context_extractor.process(text))
        self._df_contracts['subj_context_decomposition'] = self._df_contracts['filtered_context'].apply(
            lambda data: apply_transformation(data, tag_text))
        self._df_contracts['subj_items'] = self._df_contracts['subj_context_decomposition'].apply(\
            lambda data: apply_transformation(self._conllu_context_extractor.process(
                            apply_transformation(data, create_conllu_document)), str))
        return self._df_contracts
    
    def process(self):
        self._df_contracts = validate_subjects(self._df_contracts, 'subj_items')
        return self._df_contracts

    def evaluate(self):
        return self._df_contracts['valid_score'].mean()*100

# %%
# %%time

transformers = [
    NumeralLinesFilter(too_many_numerals_ratio_threshold=0.5),
    TooShortLinesFilter(too_short_line_threshold=5),
    IrrelevantLinesFilter(keywords=['strana', 'stránka', 'e-mail'], max_line_length=75, lower=True),
    IrrelevantLinesFilter(keywords=['Tel:', 'Fax:', 'IČ:', 'IČO:', 'DIČ:'], max_line_length=75,
                          lower=False),
    IrrelevantLinesRegexFilter(patterns=[r'www', r'[\w\-\.]+\s*@\s*([\w\-]+\.)+[\w\-]{2,4}']),  # email
    IrrelevantLinesRegexFilter(patterns=[r'(\+\d{2,3}){0,1}(\s{0,1}\d{3}){3}']),  # phone
    RegexReplaceTransformer(pattern_to_transform=r',([\s]+[A-Z][a-z ])', result_pattern='.\g<1>'),  # . vs , correction
    RegexReplaceTransformer(pattern_to_transform=r'\n[ \t]*([^\d]{0,1}[\d]{1,2}[^\d])+[ \t]*',  # paragraph numbers
                            result_pattern='\n'),
    BlankLinesFilter(replacement='\n', top_n_frequency=200, top_n_var_threshold=5,
                     full_line_threshold=0.85, min_max_line_length=0),
    ReplaceMarksTransformer(marks_to_transform='„“', result_mark='"'),
    TooLongLinesTransformer(forbidden_delimiters='aábcčdďeéěfghiíjklmnňoópqrřsštťuúůvwxyýzž0123456789',
                            special_delimiters={'-': (r'[\s,\.](-)[\s]+[^(Kč)]', 1)},
                            too_long_line_treshold=200),
    RegexReplaceTransformer(pattern_to_transform=r'([^\n])[ ]*\n', result_pattern='\g<1>.\n'),  # . filling
    RegexReplaceTransformer(pattern_to_transform=r'(([Nn]ázev|[Pp]opis)[^\n,.:"()]{5,})(\s[A-Z][^\n:]{10})',
                            result_pattern='\g<1>:\g<3>'),  # : filling
    ReplaceMarksTransformer(marks_to_transform=[':'], result_mark=':.'),
    ReplaceMarksTransformer(marks_to_transform=['..'], result_mark='.'),
    RegexReplaceTransformer(pattern_to_transform=r'\([^\n()]*\)', result_pattern=''),  # bracket erasing
]

preprocessor = SubjectContextPreprocessor(transformers)

conllu_eval_transformers = [
    UdapiWordOccurrencePartSentenceFilter(keywords=['cena', 'hodnota', 'DPH']),
    UdapiWordOccurrencePartSentenceFilter(keywords=['příloha', 'dále', 'jen']),
    NonSubjectPartSentenceFilter(),
    EmptyBundlesFilter(),
]

conllu_eval_preprocessor = ConlluSubjectContextPreprocessor(transformers=conllu_eval_transformers)
conllu_evaluator = SubjectItemsEvaluationMachine(df_contracts, subj_context_preprocessor=preprocessor,
                                                 conllu_context_preprocessor=conllu_eval_preprocessor)
conllu_evaluator.preprocess()
conllu_evaluator.process()
conllu_evaluator.evaluate()
# Out:
# Wall time: 30.4 s
# 98.52368047489998

# %%
df_contracts = conllu_evaluator._df_contracts
df_contracts
# Out:
#      id                                         contr_name  \
# 0    71  e-zakazky/48a575ba-f8fe-47f2-bbb6-c6ddb26390ef...
# 1    72  e-zakazky/73b0be6b-6b49-4ab4-a6a0-508b83a305e1...
# 2    74  e-zakazky/c265fdf8-044f-44e5-b36e-df4ca53c6179...
# 3    61                    eagri/mze/contract_display_6220
# 4    64                             ezak/mpsv/P15V00000447
# 5    66                             ezak/mpsv/P16V00000187
# 6    67                             ezak/mpsv/P16V00000240
# 7   103                              nipez/mo/P18V00009525
# 8   207                              nipez/mo/P18V00012708
# 9   397                              nipez/mo/P18V00019354
# 10  488                              nipez/mo/P18V00022561
# 11  542                              nipez/mo/P19V00003599
# 12  714                            nipez/mpsv/P18V00010416
# 13  733                            nipez/mvcr/P18V00009631
# 14  755                            nipez/mvcr/P18V00015153
# 15  771                             nipez/mzv/P18V00000055
# 16  775                             nipez/mzv/P18V00016340
# 17  783                             nipez/mzv/P18V00017124
# 18  794                             nipez/mzv/P18V00026759
# 19  803                             nipez/mzv/P19V00001827
# 20  807                            stavebnionline/121/7941
# 21  806                         tenderarena/Comgate/201480
# 22  808                   tenderarena/JihoceskyKraj/255714
# 23  820                   tenderarena/Libereckykraj/219512
# 24  805                         tenderarena/agrozet/102972
# 25  822                              tenderarena/mo/171826
# 26  825                              tenderarena/msp/85449
# 27   59                   test_contracts/test_sub/contr_59
# 28  826  vhodne-uverejneni/00254592/oprava-casti-mk-c-1...
# 29  828  vhodne-uverejneni/00291846/zdrave-mesto-ivanov...
# 30  829  vhodne-uverejneni/26272784/vzdelavani-zamestna...
# 31  830  vhodne-uverejneni/70504539/dodavka-projekcni-a...
# 32  831  vhodne-uverejneni/buly-arena-aquapark-kravare-...
# 33  832  vhodne-uverejneni/bw-naradi-s-r-o/materialove-...
# 34  833  vhodne-uverejneni/e-c-l-spol-s-r-o/kompostarna...
# 35  834  vhodne-uverejneni/flamesite-s-r-o/dodavka-novy...
# 36  835  vhodne-uverejneni/olza-spol-s-r-o/porizeni-mec...
# 37  836  vhodne-uverejneni/stavos-chlumec-n-cidl-s-r-o/...
# 38  846  vhodne-uverejneni/ustav-experimentalni-botanik...
# 39  848  vhodne-uverejneni/vrcha-a-s/technologie-na-sni...
# 40  849  vhodne-uverejneni/zakladni-skola-velke-hamry-s...
#
#                                                  text  \
# 0   =======================2017126-115451.pdf=====...
# 1   =======================Formulář - Informace o ...
# 2   =======================Dodatečné informace 01....
# 3   =======================01_výzva k podání nabíd...
# 4   =======================AKRIS_příloha-01_Kvalif...
# 5   =======================Příloha č. 1 SOD_Projek...
# 6   =======================P1_Výkaz výměr (slepý)....
# 7   =======================VZOR_smlouvy.doc=======...
# 8   =======================Oznámení o výběru dodav...
# 9   =======================PSP s přílohami.zip====...
# 10  =======================185310292 podepsaná.pdf...
# 11  =======================199310279(2).pdf=======...
# 12  =======================Kupní smlouva na dodávk...
# 13  =======================017 Oznámení o výběru A...
# 14  =======================#KS DNS ICT 11-2018-III...
# 15  =======================Plovoucí vinylová podla...
# 16  =======================VZ-096.docx============...
# 17  =======================10. Výzva a Zadávací do...
# 18  =======================VZ-161.docx============...
# 19  =======================SM1719-001.pdf=========...
# 20  =======================Smlouva o dilo.pdf=====...
# 21  =======================CG_LogIII_ZD_Priloha_c....
# 22  =======================pril._c._2_-_Kupni_smlo...
# 23  =======================06_D01_OLP_465_2019_dod...
# 24  =======================00-AGZ-Servis_CB-ZD-tex...
# 25  =======================D.3.4.3-04_-_Vykaz_vyme...
# 26  =======================Oprava_terminu_prohlidk...
# 27  =======================426====================...
# 28  =======================SOD - ROADFIN stavby s....
# 29  =======================Ivanovice_Rozhodnuti o ...
# 30  =======================rik-fer_Obchodní podmín...
# 31  =======================00 Dodatečné informace ...
# 32  =======================xx Písemná zpráva zadav...
# 33  =======================Dodatek KS BW nářadí.pd...
# 34  =======================Image240915212616.pdf==...
# 35  =======================Přílohy_č. 1-4.odt=====...
# 36  =======================02_P1_KrycíList.doc====...
# 37  =======================1a_zadavaci_dokumentace...
# 38  =======================rozhodnutí o přidělení ...
# 39  =======================přílohy.doc============...
# 40  =======================deklerace k dodatku č. ...
#
#                                          subj_context  \
# 0   [PŘEDMĚT SMLOUVY\nZhotovitel se zavazuje k pro...
# 1   [PŘEDMĚT DÍLA\n\n1.1. Předmětem díla je proved...
# 2   [Předmět smlouvy\n1. Zhotovitel se touto smlou...
# 3   [Předmět smlouvy\n\nPředmětem smlouvy je prove...
# 4   [Předmět veřejné zakázky a sjednaná cena ve sm...
# 5   [Předmět smlouvy, předmět díla\n\nPředmětem té...
# 6   [Předmět Smlouvy\n2.1. Zhotovitel se zavazuje ...
# 7   [Předmět smlouvy\n\n2.1. \nPředmětem smlouvy j...
# 8   [Název veřejné zakázky: Sponkovače a spojovací...
# 9   [Předmět smlouvy\n\n\n1. Poskytovatel se zavaz...
# 10  [vymezení plnění veřejné zakázky:\n\nPředmětem...
# 11  [Předmět smlouvy\n\n2.1. \nPředmětem smlouvy j...
# 12  [předmět Smlouvy \n\n\n1. Základním účelem, pr...
# 13  [veřejné zakázce\n\n„Náboje 308 Winchester SWI...
# 14  [Předmět plnění\n1. Předmětem této smlouvy je ...
# 15  [Název veřejné zakázky:\n\tPlovoucí vinylová p...
# 16  [Předmět veřejné zakázky\nStručný popis předmě...
# 17  [Předmět veřejné zakázky\nStručný popis předmě...
# 18  [Předmět veřejné zakázky\nStručný popis předmě...
# 19  [Předmět smlouvy\n\n1. Předmětem zakázky je op...
# 20  [Předmět smlouvy\n\n\n1. Název díla: Rekonstru...
# 21  [PŘEDMĚT SMLOUVY\n1.5. Zhotovitel se zavazuje ...
# 22  [Předmět smlouvy\n\n1. Předmětem smlouvy je zá...
# 23  [Vymezení předmětu veřejné zakázky \n\n\n2.1. ...
# 24  [vymezení předmětu zakázky \n \nPředmětem této...
# 25  [Předmět smlouvy\n1.1st Předmětem smlouvy je z...
# 26  [PŘEDMĚT SMLOUVY \n\n \n\n1. Zhotovitel se tou...
# 27  [Popis předmětu veřejné zakázky\nPředmětem zad...
# 28  [Předmět smlouvy\n\n1.1. Zhotovitel se touto s...
# 29  [Předmět plnění veřejné zakázky\n2.1 Předmět p...
# 30  [Předmět Smlouvy\n\n1. Předmětem Smlouvy je zá...
# 31  [Předmět veřejné zakázky je blíže specifikován...
# 32  [předmět veřejné zakázky a cena sjednaná ve sm...
# 33  [Předmět smlouvy\n\n1) Předmětem smlouvy je do...
# 34  [PŘEDMĚT PLNĚNÍ\n\n1. Na základě této smlouvy ...
# 35  [Předmět smlouvy\n\tTato smlouva se uzavírá na...
# 36  [PŘEDMĚT VEŘEJNÉ ZAKÁZKY ............oooooeeoe...
# 37  [vymezení předmětu zakázky a požadavků zadavat...
# 38  [Předmět veřejné zakázky\n\nPředmětem veřejné ...
# 39  [Předmět plnění\n\nPředmětem plnění je dodávka...
# 40  [Název veřejné zakázky:\nZadavatel zakázky:\n\...
#
#                                      filtered_context  valid_score  \
# 0   [PŘEDMĚT SMLOUVY.\nZhotovitel se zavazuje k pr...     1.000000
# 1   [PŘEDMĚT DÍLA.\nPředmětem díla je provedení st...     1.000000
# 2   [Předmět smlouvy.\nZhotovitel se touto smlouvo...     1.000000
# 3   [Předmět smlouvy.\n\nPředmětem smlouvy je prov...     1.000000
# 4   [Předmět veřejné zakázky a sjednaná cena ve sm...     1.000000
# 5   [Předmět smlouvy, předmět díla.\n\nPředmětem t...     1.000000
# 6   [Předmět Smlouvy.\nZhotovitel se zavazuje prov...     1.000000
# 7   [Předmět smlouvy.\n\nPředmětem smlouvy je záva...     1.000000
# 8   [Název veřejné zakázky:. Sponkovače a spojovac...     1.000000
# 9   [Předmět smlouvy.\n\nPoskytovatel se zavazuje ...     1.000000
# 10  [vymezení plnění veřejné zakázky:.\n\nPředměte...     1.000000
# 11  [Předmět smlouvy.\n\nPředmětem smlouvy je záva...     1.000000
# 12  [předmět Smlouvy.\n\nZákladním účelem, pro kte...     1.000000
# 13  [veřejné zakázce.\n\n"Náboje 308 Winchester SW...     1.000000
# 14  [Předmět plnění.\nPředmětem této smlouvy je do...     1.000000
# 15  [Název veřejné zakázky:.\n\tPlovoucí vinylová ...     1.000000
# 16  [Předmět veřejné zakázky.\nStručný popis předm...     1.000000
# 17  [Předmět veřejné zakázky.\nStručný popis předm...     1.000000
# 18  [Předmět veřejné zakázky.\nStručný popis předm...     1.000000
# 19  [Předmět smlouvy.\nPředmětem zakázky je oprava...     1.000000
# 20  [Předmět smlouvy.\n\nNázev díla:. Rekonstrukce...     1.000000
# 21  [PŘEDMĚT SMLOUVY.\nZhotovitel se zavazuje prov...     1.000000
# 22  [Předmět smlouvy.\nPředmětem smlouvy je závaze...     1.000000
# 23  [Vymezení předmětu veřejné zakázky.\n\nObecné ...     1.000000
# 24  [vymezení předmětu zakázky.\nPředmětem této za...     0.994709
# 25  [Předmět smlouvy.\nt Předmětem smlouvy je záva...     1.000000
# 26  [PŘEDMĚT SMLOUVY.\n\nZhotovitel se touto Smlou...     1.000000
# 27  [Popis předmětu veřejné zakázky.\nPředmětem za...     1.000000
# 28  [Předmět smlouvy.\nZhotovitel se touto smlouvo...     1.000000
# 29  [Předmět plnění veřejné zakázky.\nPředmět plně...     1.000000
# 30  [Předmět Smlouvy.\nPředmětem Smlouvy je závaze...     1.000000
# 31  [Předmět veřejné zakázky je blíže specifikován...     1.000000
# 32  [předmět veřejné zakázky a cena sjednaná ve sm...     1.000000
# 33  [Předmět smlouvy.\nPředmětem smlouvy je dodávk...     1.000000
# 34  [PŘEDMĚT PLNĚNÍ.\nNa základě této smlouvy se p...     1.000000
# 35  [Předmět smlouvy.\n\tTato smlouva se uzavírá n...     1.000000
# 36  [PŘEDMĚT VEŘEJNÉ ZAKÁZKY ......oooooeeoenooeoo...     1.000000
# 37  [vymezení předmětu zakázky a požadavků zadavat...     0.400000
# 38  [Předmět veřejné zakázky.\n\nPředmětem veřejné...     1.000000
# 39  [Předmět plnění.\n\nPředmětem plnění je dodávk...     1.000000
# 40  [Název veřejné zakázky:.\nZadavatel zakázky:.\...     1.000000
#
#                                  filtered_context_ref  \
# 0   PŘEDMĚT SMLOUVY.\nZhotovitel se zavazuje k pro...
# 1   PŘEDMĚT DÍLA.\nPředmětem díla je provedení sta...
# 2   Předmět smlouvy.\nZhotovitel se touto smlouvou...
# 3   Předmět smlouvy.\n\nPředmětem smlouvy je prove...
# 4   Předmět veřejné zakázky a sjednaná cena ve sml...
# 5   Předmět smlouvy, předmět díla.\n\nPředmětem té...
# 6   Předmět Smlouvy.\nZhotovitel se zavazuje prové...
# 7   Předmět smlouvy.\n\nPředmětem smlouvy je závaz...
# 8   Název veřejné zakázky:. Sponkovače a spojovací...
# 9   Předmět smlouvy.\n\nPoskytovatel se zavazuje d...
# 10  vymezení plnění veřejné zakázky:.\n\nPředmětem...
# 11  Předmět smlouvy.\n\nPředmětem smlouvy je závaz...
# 12  předmět Smlouvy.\n\nZákladním účelem, pro kter...
# 13  veřejné zakázce.\n\n"Náboje 308 Winchester SWI...
# 14  Předmět plnění.\nPředmětem této smlouvy je dod...
# 15  Název veřejné zakázky:.\n\tPlovoucí vinylová p...
# 16  Předmět veřejné zakázky.\nStručný popis předmě...
# 17  Předmět veřejné zakázky.\nStručný popis předmě...
# 18  Předmět veřejné zakázky.\nStručný popis předmě...
# 19  Předmět smlouvy.\nPředmětem zakázky je oprava ...
# 20  Předmět smlouvy.\n\nNázev díla:. Rekonstrukce ...
# 21  PŘEDMĚT SMLOUVY.\nZhotovitel se zavazuje prové...
# 22  Předmět smlouvy.\nPředmětem smlouvy je závazek...
# 23  Vymezení předmětu veřejné zakázky.\n\nObecné v...
# 24  vymezení předmětu zakázky.\nPředmětem této zak...
# 25  Předmět smlouvy.\n1.1st Předmětem smlouvy je z...
# 26  PŘEDMĚT SMLOUVY.\n\nZhotovitel se touto Smlouv...
# 27  Popis předmětu veřejné zakázky.\nPředmětem zad...
# 28  Předmět smlouvy.\nZhotovitel se touto smlouvou...
# 29  Předmět plnění veřejné zakázky.\nPředmět plněn...
# 30  Předmět Smlouvy.\nPředmětem Smlouvy je závazek...
# 31  Předmět veřejné zakázky je blíže specifikován ...
# 32  předmět veřejné zakázky a cena sjednaná ve sml...
# 33  Předmět smlouvy.\nPředmětem smlouvy je dodávka...
# 34  PŘEDMĚT PLNĚNÍ.\nNa základě této smlouvy se pr...
# 35  Předmět smlouvy.\n\tTato smlouva se uzavírá na...
# 36  PŘEDMĚT VEŘEJNÉ ZAKÁZKY ......oooooeeoenooeooe...
# 37  vymezení předmětu zakázky a požadavků zadavate...
# 38  Předmět veřejné zakázky.\n\nPředmětem veřejné ...
# 39  Předmět plnění.\n\nPředmětem plnění je dodávka...
# 40  Název veřejné zakázky:.\nZadavatel zakázky:.\n...
#
#                            subj_context_decomposition  \
# 0   [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 1   [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 2   [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 3   [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 4   [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 5   [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 6   [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 7   [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 8   [# newdoc\n# newpar\n# sent_id = 1\n# text = N...
# 9   [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 10  [# newdoc\n# newpar\n# sent_id = 1\n# text = v...
# 11  [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 12  [# newdoc\n# newpar\n# sent_id = 1\n# text = p...
# 13  [# newdoc\n# newpar\n# sent_id = 1\n# text = v...
# 14  [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 15  [# newdoc\n# newpar\n# sent_id = 1\n# text = N...
# 16  [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 17  [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 18  [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 19  [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 20  [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 21  [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 22  [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 23  [# newdoc\n# newpar\n# sent_id = 1\n# text = V...
# 24  [# newdoc\n# newpar\n# sent_id = 1\n# text = v...
# 25  [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 26  [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 27  [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 28  [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 29  [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 30  [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 31  [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 32  [# newdoc\n# newpar\n# sent_id = 1\n# text = p...
# 33  [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 34  [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 35  [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 36  [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 37  [# newdoc\n# newpar\n# sent_id = 1\n# text = v...
# 38  [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 39  [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 40  [# newdoc\n# newpar\n# sent_id = 1\n# text = N...
#
#                                            subj_items  \
# 0   [k provedení stavebních prací v rámci projektu...
# 1   [provedení stavby pro objednatele\ni geodetick...
# 2   [dobudování kanalizace v obci Žádovice a výsta...
# 3   [stavebně technických průzkumů, zpracování pro...
# 4   [vytvoření, údržba, uživatelská podpora a rozv...
# 5                                                  []
# 6                                                [, ]
# 7                                                [, ]
# 8                                                  []
# 9   [SW včetně dokumentace v českém nebo anglickém...
# 10  [na dodávky CD a DVD o různých kapacitách ve p...
# 11  ["Cenová kalkulace zakázky – výkaz výměr", kte...
# 12  [zajištění dodávek bílého a dalšího zboží pro ...
# 13                                                 []
# 14                         [dodávka zboží vymezeného]
# 15                                                 []
# 16                                                 []
# 17                                               [, ]
# 18                                                 []
# 19  [oprava a revize systémů PZTS, CCTV, VDT a MZP...
# 20         [zejména práce na rekonstrukci chodníku, ]
# 21  [v přípravě komplexních podkladů pro uživatels...
# 22                               [zařízení, zařízení]
# 23  [velkoplošná oprava silnice III/26322 mezi Čes...
# 24  [stavební práce příslušné projektu, které se p...
# 25  [stavby "Olomouc – Hejčínská kasárna Olomouc,\...
# 26  [provedení stavebně technického průzkumu, prov...
# 27  [dodávka počítačů a monitorů\ndodávka tiskáren...
# 28  ["Oprava části místní komunikace III. třídy č....
# 29  [zametacího stroje vhodného pro údržbu komunik...
# 30  [školení pro oddělení účetnictví a managementu...
# 31  [, dodání 1 interaktivní tabule, 14 magnetický...
# 32                     [o dodávce elektrické energie]
# 33  [dodávka tj. realizace projektu "Materiálové v...
# 34  [mininakladač se lžící, překopávač, síto a kry...
# 35                                               [, ]
# 36  [mechanického lisu vč\ndle Pravidel, mechanick...
# 37  [na zpracování tenkostěnných potravinářských o...
# 38  [dodávka chemikálií pro účely zajištění aktivi...
# 39  [dodávka a nákup zemědělských strojů včetně př...
# 40                                                 []
#
#                                        subj_items_ref
# 0   k provedení stavebních prací v rámci projektu ...
# 1   provedení stavby pro objednatele\ni geodetické...
# 2   dobudování kanalizace v obci Žádovice a výstav...
# 3   stavebně technických průzkumů, zpracování proj...
# 4   vytvoření, údržba, uživatelská podpora a rozvo...
# 5
# 6                                      \n==========\n
# 7                                      \n==========\n
# 8
# 9   SW včetně dokumentace v českém nebo anglickém ...
# 10  na dodávky CD a DVD o různých kapacitách ve pr...
# 11  "Cenová kalkulace zakázky – výkaz výměr", kter...
# 12  zajištění dodávek bílého a dalšího zboží pro v...
# 13
# 14                           dodávka zboží vymezeného
# 15
# 16
# 17                                     \n==========\n
# 18
# 19  oprava a revize systémů PZTS, CCTV, VDT a MZP ...
# 20  zejména práce na rekonstrukci chodníku\n======...
# 21  v přípravě komplexních podkladů pro uživatelsk...
# 22                     zařízení\n==========\nzařízení
# 23  velkoplošná oprava silnice III/26322 mezi Česk...
# 24  stavební práce příslušné projektu, které se po...
# 25  stavby "Olomouc – Hejčínská kasárna Olomouc,\n...
# 26  provedení stavebně technického průzkumu\n=====...
# 27  dodávka počítačů a monitorů\ndodávka tiskáren ...
# 28  "Oprava části místní komunikace III. třídy č. 14c
# 29   zametacího stroje vhodného pro údržbu komunikací
# 30  školení pro oddělení účetnictví a managementu\...
# 31  \n==========\ndodání 1 interaktivní tabule, 14...
# 32                       o dodávce elektrické energie
# 33  dodávka tj. realizace projektu "Materiálové vy...
# 34  mininakladač se lžící, překopávač, síto a kryc...
# 35                                     \n==========\n
# 36  mechanického lisu vč\ndle Pravidel\n==========...
# 37  na zpracování tenkostěnných potravinářských ob...
# 38  dodávka chemikálií pro účely zajištění aktivit...
# 39  dodávka a nákup zemědělských strojů včetně pří...
# 40

# %% [markdown]
# ### Playground

# %%
# 21 neextrahuje prvni kontext
# 24 extrakce vice ruznych enumerace
# 27 extrakce ?
# 37 castecna extrakce

# %%
df_contracts
# Out:
#      id                                         contr_name  \
# 0    71  e-zakazky/48a575ba-f8fe-47f2-bbb6-c6ddb26390ef...
# 1    72  e-zakazky/73b0be6b-6b49-4ab4-a6a0-508b83a305e1...
# 2    74  e-zakazky/c265fdf8-044f-44e5-b36e-df4ca53c6179...
# 3    61                    eagri/mze/contract_display_6220
# 4    64                             ezak/mpsv/P15V00000447
# 5    66                             ezak/mpsv/P16V00000187
# 6    67                             ezak/mpsv/P16V00000240
# 7   103                              nipez/mo/P18V00009525
# 8   207                              nipez/mo/P18V00012708
# 9   397                              nipez/mo/P18V00019354
# 10  488                              nipez/mo/P18V00022561
# 11  542                              nipez/mo/P19V00003599
# 12  714                            nipez/mpsv/P18V00010416
# 13  733                            nipez/mvcr/P18V00009631
# 14  755                            nipez/mvcr/P18V00015153
# 15  771                             nipez/mzv/P18V00000055
# 16  775                             nipez/mzv/P18V00016340
# 17  783                             nipez/mzv/P18V00017124
# 18  794                             nipez/mzv/P18V00026759
# 19  803                             nipez/mzv/P19V00001827
# 20  807                            stavebnionline/121/7941
# 21  806                         tenderarena/Comgate/201480
# 22  808                   tenderarena/JihoceskyKraj/255714
# 23  820                   tenderarena/Libereckykraj/219512
# 24  805                         tenderarena/agrozet/102972
# 25  822                              tenderarena/mo/171826
# 26  825                              tenderarena/msp/85449
# 27   59                   test_contracts/test_sub/contr_59
# 28  826  vhodne-uverejneni/00254592/oprava-casti-mk-c-1...
# 29  828  vhodne-uverejneni/00291846/zdrave-mesto-ivanov...
# 30  829  vhodne-uverejneni/26272784/vzdelavani-zamestna...
# 31  830  vhodne-uverejneni/70504539/dodavka-projekcni-a...
# 32  831  vhodne-uverejneni/buly-arena-aquapark-kravare-...
# 33  832  vhodne-uverejneni/bw-naradi-s-r-o/materialove-...
# 34  833  vhodne-uverejneni/e-c-l-spol-s-r-o/kompostarna...
# 35  834  vhodne-uverejneni/flamesite-s-r-o/dodavka-novy...
# 36  835  vhodne-uverejneni/olza-spol-s-r-o/porizeni-mec...
# 37  836  vhodne-uverejneni/stavos-chlumec-n-cidl-s-r-o/...
# 38  846  vhodne-uverejneni/ustav-experimentalni-botanik...
# 39  848  vhodne-uverejneni/vrcha-a-s/technologie-na-sni...
# 40  849  vhodne-uverejneni/zakladni-skola-velke-hamry-s...
#
#                                                  text  \
# 0   =======================2017126-115451.pdf=====...
# 1   =======================Formulář - Informace o ...
# 2   =======================Dodatečné informace 01....
# 3   =======================01_výzva k podání nabíd...
# 4   =======================AKRIS_příloha-01_Kvalif...
# 5   =======================Příloha č. 1 SOD_Projek...
# 6   =======================P1_Výkaz výměr (slepý)....
# 7   =======================VZOR_smlouvy.doc=======...
# 8   =======================Oznámení o výběru dodav...
# 9   =======================PSP s přílohami.zip====...
# 10  =======================185310292 podepsaná.pdf...
# 11  =======================199310279(2).pdf=======...
# 12  =======================Kupní smlouva na dodávk...
# 13  =======================017 Oznámení o výběru A...
# 14  =======================#KS DNS ICT 11-2018-III...
# 15  =======================Plovoucí vinylová podla...
# 16  =======================VZ-096.docx============...
# 17  =======================10. Výzva a Zadávací do...
# 18  =======================VZ-161.docx============...
# 19  =======================SM1719-001.pdf=========...
# 20  =======================Smlouva o dilo.pdf=====...
# 21  =======================CG_LogIII_ZD_Priloha_c....
# 22  =======================pril._c._2_-_Kupni_smlo...
# 23  =======================06_D01_OLP_465_2019_dod...
# 24  =======================00-AGZ-Servis_CB-ZD-tex...
# 25  =======================D.3.4.3-04_-_Vykaz_vyme...
# 26  =======================Oprava_terminu_prohlidk...
# 27  =======================426====================...
# 28  =======================SOD - ROADFIN stavby s....
# 29  =======================Ivanovice_Rozhodnuti o ...
# 30  =======================rik-fer_Obchodní podmín...
# 31  =======================00 Dodatečné informace ...
# 32  =======================xx Písemná zpráva zadav...
# 33  =======================Dodatek KS BW nářadí.pd...
# 34  =======================Image240915212616.pdf==...
# 35  =======================Přílohy_č. 1-4.odt=====...
# 36  =======================02_P1_KrycíList.doc====...
# 37  =======================1a_zadavaci_dokumentace...
# 38  =======================rozhodnutí o přidělení ...
# 39  =======================přílohy.doc============...
# 40  =======================deklerace k dodatku č. ...
#
#                                          subj_context  \
# 0   [PŘEDMĚT SMLOUVY\nZhotovitel se zavazuje k pro...
# 1   [PŘEDMĚT DÍLA\n\n1.1. Předmětem díla je proved...
# 2   [Předmět smlouvy\n1. Zhotovitel se touto smlou...
# 3   [Předmět smlouvy\n\nPředmětem smlouvy je prove...
# 4   [Předmět veřejné zakázky a sjednaná cena ve sm...
# 5   [Předmět smlouvy, předmět díla\n\nPředmětem té...
# 6   [Předmět Smlouvy\n2.1. Zhotovitel se zavazuje ...
# 7   [Předmět smlouvy\n\n2.1. \nPředmětem smlouvy j...
# 8   [Název veřejné zakázky: Sponkovače a spojovací...
# 9   [Předmět smlouvy\n\n\n1. Poskytovatel se zavaz...
# 10  [vymezení plnění veřejné zakázky:\n\nPředmětem...
# 11  [Předmět smlouvy\n\n2.1. \nPředmětem smlouvy j...
# 12  [předmět Smlouvy \n\n\n1. Základním účelem, pr...
# 13  [veřejné zakázce\n\n„Náboje 308 Winchester SWI...
# 14  [Předmět plnění\n1. Předmětem této smlouvy je ...
# 15  [Název veřejné zakázky:\n\tPlovoucí vinylová p...
# 16  [Předmět veřejné zakázky\nStručný popis předmě...
# 17  [Předmět veřejné zakázky\nStručný popis předmě...
# 18  [Předmět veřejné zakázky\nStručný popis předmě...
# 19  [Předmět smlouvy\n\n1. Předmětem zakázky je op...
# 20  [Předmět smlouvy\n\n\n1. Název díla: Rekonstru...
# 21  [PŘEDMĚT SMLOUVY\n1.5. Zhotovitel se zavazuje ...
# 22  [Předmět smlouvy\n\n1. Předmětem smlouvy je zá...
# 23  [Vymezení předmětu veřejné zakázky \n\n\n2.1. ...
# 24  [vymezení předmětu zakázky \n \nPředmětem této...
# 25  [Předmět smlouvy\n1.1st Předmětem smlouvy je z...
# 26  [PŘEDMĚT SMLOUVY \n\n \n\n1. Zhotovitel se tou...
# 27  [Popis předmětu veřejné zakázky\nPředmětem zad...
# 28  [Předmět smlouvy\n\n1.1. Zhotovitel se touto s...
# 29  [Předmět plnění veřejné zakázky\n2.1 Předmět p...
# 30  [Předmět Smlouvy\n\n1. Předmětem Smlouvy je zá...
# 31  [Předmět veřejné zakázky je blíže specifikován...
# 32  [předmět veřejné zakázky a cena sjednaná ve sm...
# 33  [Předmět smlouvy\n\n1) Předmětem smlouvy je do...
# 34  [PŘEDMĚT PLNĚNÍ\n\n1. Na základě této smlouvy ...
# 35  [Předmět smlouvy\n\tTato smlouva se uzavírá na...
# 36  [PŘEDMĚT VEŘEJNÉ ZAKÁZKY ............oooooeeoe...
# 37  [vymezení předmětu zakázky a požadavků zadavat...
# 38  [Předmět veřejné zakázky\n\nPředmětem veřejné ...
# 39  [Předmět plnění\n\nPředmětem plnění je dodávka...
# 40  [Název veřejné zakázky:\nZadavatel zakázky:\n\...
#
#                                      filtered_context  valid_score  \
# 0   [PŘEDMĚT SMLOUVY.\nZhotovitel se zavazuje k pr...     1.000000
# 1   [PŘEDMĚT DÍLA.\nPředmětem díla je provedení st...     0.404762
# 2   [Předmět smlouvy.\nZhotovitel se touto smlouvo...     0.614679
# 3   [Předmět smlouvy.\n\nPředmětem smlouvy je prov...     0.623932
# 4   [Předmět veřejné zakázky a sjednaná cena ve sm...     0.968254
# 5   [Předmět smlouvy, předmět díla.\n\nPředmětem t...     1.000000
# 6   [Předmět Smlouvy.\nZhotovitel se zavazuje prov...     1.000000
# 7   [Předmět smlouvy.\n\nPředmětem smlouvy je záva...     0.032258
# 8   [Název veřejné zakázky:. Sponkovače a spojovac...     1.000000
# 9   [Předmět smlouvy.\n\nPoskytovatel se zavazuje ...     1.000000
# 10  [vymezení plnění veřejné zakázky:.\n\nPředměte...     1.000000
# 11  [Předmět smlouvy.\n\nPředmětem smlouvy je záva...     0.047619
# 12  [předmět Smlouvy.\n\nZákladním účelem, pro kte...     0.541667
# 13  [veřejné zakázce.\n\n"Náboje 308 Winchester SW...     1.000000
# 14  [Předmět plnění.\nPředmětem této smlouvy je do...     0.750000
# 15  [Název veřejné zakázky:.\n\tPlovoucí vinylová ...     1.000000
# 16  [Předmět veřejné zakázky.\nStručný popis předm...     1.000000
# 17  [Předmět veřejné zakázky.\nStručný popis předm...     1.000000
# 18  [Předmět veřejné zakázky.\nStručný popis předm...     1.000000
# 19  [Předmět smlouvy.\nPředmětem zakázky je oprava...     1.000000
# 20  [Předmět smlouvy.\n\nNázev díla:. Rekonstrukce...     0.666667
# 21  [PŘEDMĚT SMLOUVY.\nZhotovitel se zavazuje prov...     1.000000
# 22  [Předmět smlouvy.\nPředmětem smlouvy je závaze...     1.000000
# 23  [Vymezení předmětu veřejné zakázky.\n\nObecné ...     1.000000
# 24  [vymezení předmětu zakázky.\nPředmětem této za...     0.486880
# 25  [Předmět smlouvy.\nt Předmětem smlouvy je záva...     0.392157
# 26  [PŘEDMĚT SMLOUVY.\n\nZhotovitel se touto Smlou...     0.111111
# 27  [Popis předmětu veřejné zakázky.\nPředmětem za...     1.000000
# 28  [Předmět smlouvy.\nZhotovitel se touto smlouvo...     1.000000
# 29  [Předmět plnění veřejné zakázky.\nPředmět plně...     1.000000
# 30  [Předmět Smlouvy.\nPředmětem Smlouvy je závaze...     0.526786
# 31  [Předmět veřejné zakázky je blíže specifikován...     0.726316
# 32  [předmět veřejné zakázky a cena sjednaná ve sm...     1.000000
# 33  [Předmět smlouvy.\nPředmětem smlouvy je dodávk...     0.858639
# 34  [PŘEDMĚT PLNĚNÍ.\nNa základě této smlouvy se p...     1.000000
# 35  [Předmět smlouvy.\n\tTato smlouva se uzavírá n...     1.000000
# 36  [PŘEDMĚT VEŘEJNÉ ZAKÁZKY ......oooooeeoenooeoo...     0.680000
# 37  [vymezení předmětu zakázky a požadavků zadavat...     0.750000
# 38  [Předmět veřejné zakázky.\n\nPředmětem veřejné...     0.947368
# 39  [Předmět plnění.\n\nPředmětem plnění je dodávk...     1.000000
# 40  [Název veřejné zakázky:.\nZadavatel zakázky:.\...     1.000000
#
#                                  filtered_context_ref  \
# 0   PŘEDMĚT SMLOUVY.\nZhotovitel se zavazuje k pro...
# 1   PŘEDMĚT DÍLA.\nPředmětem díla je provedení sta...
# 2   Předmět smlouvy.\nZhotovitel se touto smlouvou...
# 3   Předmět smlouvy.\n\nPředmětem smlouvy je prove...
# 4   Předmět veřejné zakázky a sjednaná cena ve sml...
# 5   Předmět smlouvy, předmět díla.\n\nPředmětem té...
# 6   Předmět Smlouvy.\nZhotovitel se zavazuje prové...
# 7   Předmět smlouvy.\n\nPředmětem smlouvy je závaz...
# 8   Název veřejné zakázky:. Sponkovače a spojovací...
# 9   Předmět smlouvy.\n\nPoskytovatel se zavazuje d...
# 10  vymezení plnění veřejné zakázky:.\n\nPředmětem...
# 11  Předmět smlouvy.\n\nPředmětem smlouvy je závaz...
# 12  předmět Smlouvy.\n\nZákladním účelem, pro kter...
# 13  veřejné zakázce.\n\n"Náboje 308 Winchester SWI...
# 14  Předmět plnění.\nPředmětem této smlouvy je dod...
# 15  Název veřejné zakázky:.\n\tPlovoucí vinylová p...
# 16  Předmět veřejné zakázky.\nStručný popis předmě...
# 17  Předmět veřejné zakázky.\nStručný popis předmě...
# 18  Předmět veřejné zakázky.\nStručný popis předmě...
# 19  Předmět smlouvy.\nPředmětem zakázky je oprava ...
# 20  Předmět smlouvy.\n\nNázev díla:. Rekonstrukce ...
# 21  PŘEDMĚT SMLOUVY.\nZhotovitel se zavazuje prové...
# 22  Předmět smlouvy.\nPředmětem smlouvy je závazek...
# 23  Vymezení předmětu veřejné zakázky.\n\nObecné v...
# 24  vymezení předmětu zakázky.\nPředmětem této zak...
# 25  Předmět smlouvy.\n1.1st Předmětem smlouvy je z...
# 26  PŘEDMĚT SMLOUVY.\n\nZhotovitel se touto Smlouv...
# 27  Popis předmětu veřejné zakázky.\nPředmětem zad...
# 28  Předmět smlouvy.\nZhotovitel se touto smlouvou...
# 29  Předmět plnění veřejné zakázky.\nPředmět plněn...
# 30  Předmět Smlouvy.\nPředmětem Smlouvy je závazek...
# 31  Předmět veřejné zakázky je blíže specifikován ...
# 32  předmět veřejné zakázky a cena sjednaná ve sml...
# 33  Předmět smlouvy.\nPředmětem smlouvy je dodávka...
# 34  PŘEDMĚT PLNĚNÍ.\nNa základě této smlouvy se pr...
# 35  Předmět smlouvy.\n\tTato smlouva se uzavírá na...
# 36  PŘEDMĚT VEŘEJNÉ ZAKÁZKY ......oooooeeoenooeooe...
# 37  vymezení předmětu zakázky a požadavků zadavate...
# 38  Předmět veřejné zakázky.\n\nPředmětem veřejné ...
# 39  Předmět plnění.\n\nPředmětem plnění je dodávka...
# 40  Název veřejné zakázky:.\nZadavatel zakázky:.\n...
#
#                            subj_context_decomposition  \
# 0   [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 1   [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 2   [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 3   [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 4   [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 5   [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 6   [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 7   [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 8   [# newdoc\n# newpar\n# sent_id = 1\n# text = N...
# 9   [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 10  [# newdoc\n# newpar\n# sent_id = 1\n# text = v...
# 11  [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 12  [# newdoc\n# newpar\n# sent_id = 1\n# text = p...
# 13  [# newdoc\n# newpar\n# sent_id = 1\n# text = v...
# 14  [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 15  [# newdoc\n# newpar\n# sent_id = 1\n# text = N...
# 16  [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 17  [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 18  [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 19  [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 20  [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 21  [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 22  [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 23  [# newdoc\n# newpar\n# sent_id = 1\n# text = V...
# 24  [# newdoc\n# newpar\n# sent_id = 1\n# text = v...
# 25  [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 26  [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 27  [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 28  [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 29  [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 30  [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 31  [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 32  [# newdoc\n# newpar\n# sent_id = 1\n# text = p...
# 33  [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 34  [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 35  [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 36  [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 37  [# newdoc\n# newpar\n# sent_id = 1\n# text = v...
# 38  [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 39  [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 40  [# newdoc\n# newpar\n# sent_id = 1\n# text = N...
#
#                                            subj_items  \
# 0   [k provedení stavebních prací v rámci projektu...
# 1   [provedení stavby pro objednatele\ni geodetick...
# 2   [vybudování nové kanalizace v obci Žádovice v ...
# 3   [provedení stavebně technických průzkumů, zpra...
# 4   [vytvoření, údržba, uživatelská podpora a rozv...
# 5                                                  []
# 6                                                [, ]
# 7   [jejich nevhodnost, která by překážela řádnému...
# 8                                                  []
# 9   [SW včetně dokumentace v českém nebo anglickém...
# 10  [na dodávky CD a DVD o různých kapacitách ve p...
# 11                                             [, , ]
# 12  [zajištění dodávek bílého a dalšího zboží pro ...
# 13                                                 []
# 14                    [dodávka zboží vymezeného -IIl]
# 15                                                 []
# 16                                                 []
# 17                                               [, ]
# 18                                                 []
# 19  [oprava a revize systémů PZTS, CCTV, VDT a MZP...
# 20  [zejména práce na rekonstrukci chodníku v násl...
# 21  [v přípravě komplexních podkladů pro uživatels...
# 22                               [zařízení, zařízení]
# 23  [velkoplošná oprava silnice III/26322 mezi Čes...
# 24  [stavební práce příslušné projektu, které se p...
# 25  [stavby "Olomouc\nna straně zhotovitele\njejic...
# 26                                               [, ]
# 27  [dodávka počítačů a monitorů\ndodávka tiskáren...
# 28  ["Oprava části místní komunikace III. třídy č....
# 29  [zametacího stroje vhodného pro údržbu komunik...
# 30  [Zadavateli\n16 hodin . vi) školení pro zaměst...
# 31  [, dodání 1 interaktivní tabule, 14 magnetický...
# 32                     [o dodávce elektrické energie]
# 33  [dodávka v dodávce lisovací linky, která lisuj...
# 34  [mininakladač se lžící, překopávač, síto a kry...
# 35                                               [, ]
# 36  [mechanického lisu dle Pravidel, mechanického ...
# 37  [na zpracování tenkostěnných potravinářských o...
# 38  [dodávka chemikálií pro účely zajištění aktivi...
# 39  [dodávka a nákup zemědělských strojů včetně př...
# 40                                                 []
#
#                                        subj_items_ref
# 0   k provedení stavebních prací v rámci projektu ...
# 1   provedení stavby pro objednatele\ni geodetické...
# 2   dobudování kanalizace v obci Žádovice a výstav...
# 3   stavebně technických průzkumů, zpracování proj...
# 4   vytvoření, údržba, uživatelská podpora a rozvo...
# 5
# 6                                      \n==========\n
# 7                                      \n==========\n
# 8
# 9   SW včetně dokumentace v českém nebo anglickém ...
# 10  na dodávky CD a DVD o různých kapacitách ve pr...
# 11  "Cenová kalkulace zakázky – výkaz výměr", kter...
# 12  zajištění dodávek bílého a dalšího zboží pro v...
# 13
# 14                           dodávka zboží vymezeného
# 15
# 16
# 17                                     \n==========\n
# 18
# 19  oprava a revize systémů PZTS, CCTV, VDT a MZP ...
# 20  zejména práce na rekonstrukci chodníku\n======...
# 21  v přípravě komplexních podkladů pro uživatelsk...
# 22                     zařízení\n==========\nzařízení
# 23  velkoplošná oprava silnice III/26322 mezi Česk...
# 24  stavební práce příslušné projektu, které se po...
# 25  stavby "Olomouc – Hejčínská kasárna Olomouc,\n...
# 26  provedení stavebně technického průzkumu\n=====...
# 27  dodávka počítačů a monitorů\ndodávka tiskáren ...
# 28  "Oprava části místní komunikace III. třídy č. 14c
# 29   zametacího stroje vhodného pro údržbu komunikací
# 30  školení pro oddělení účetnictví a managementu\...
# 31  \n==========\ndodání 1 interaktivní tabule, 14...
# 32                       o dodávce elektrické energie
# 33  dodávka tj. realizace projektu "Materiálové vy...
# 34  mininakladač se lžící, překopávač, síto a kryc...
# 35                                     \n==========\n
# 36  mechanického lisu vč\ndle Pravidel\n==========...
# 37  na zpracování tenkostěnných potravinářských ob...
# 38  dodávka chemikálií pro účely zajištění aktivit...
# 39  dodávka a nákup zemědělských strojů včetně pří...
# 40

# %%
index = 24
for data in df_contracts.loc[index, 'subj_items']:
    print(data)
    print('==========')
# Out:
# stavební práce příslušné projektu, které se požadují zajistit uchazečem o zakázku
# pro řádné dokončení a zprovoznění díla
# v souladu
# účast stavbyvedoucího
# revizí a vypracování revizních zpráv dle příslušných právních předpisů a norem ČSN, doložení atestů, certifikátů, prohlášení o shodě dle zákona č. 1997 Sb. ve znění pozdějších předpisů a prováděcích předpisů
# ==========
# zejména dodávka stavebních prací s materiálem příslušných projektu "Budovy pro technický servis AGROZET České Budějovice
# vybudování stavebních základů montážní jámy a stavební dokončení instalace jámy podle instalační dokumentace dodavatele jámy a jeho oprávněných pokynů,
# vybudování nosných prvků pro jeřábovou dráhu
# veškeré předepsané atesty, zkoušky a revize dle norem a dalších obecně platných předpisů a nařízení
# předání dokumentů k jednotlivým součástem díla s jejich technickou specifikací a s uvedením podmínek jejich užívání a případně dalších dokumentů potřebných pro protokolární přejímací řízení
# zajištění trvale bezplatného užívání díla objednatelem ve vztahu k případným nárokům držitelů licencí
# dodání všech předepsaných ochranných, bezpečnostních a protipožárních pomůcek pro pracovníky zhotovitele
# zajištění bezpečnosti při provádění stavby ve smyslu bezpečnosti práce i ochrany životního prostředí
# péče o nepředané objekty a konstrukce a jejich ošetřování
# pro zhotovitele nutné, včetně získání nezbytných povolení k výstavbě dočasných obj
# ==========

# %%
print(df_contracts.loc[index, 'subj_items_ref'])
# Out:
# stavební práce příslušné projektu, které se požadují zajistit uchazečem o zakázku
# pro řádné dokončení a zprovoznění díla
# v souladu
# účast stavbyvedoucího
# revizí a vypracování revizních zpráv dle příslušných právních předpisů a norem ČSN, doložení atestů, certifikátů, prohlášení o shodě dle zákona č. Sb. ve znění pozdějších předpisů a prováděcích předpisů
# ==========
# zejména dodávka stavebních prací s materiálem příslušných projektu "Budovy pro technický servis AGROZET České Budějovice
# vybudování stavebních základů montážní jámy a stavební dokončení instalace jámy podle instalační dokumentace dodavatele jámy a jeho oprávněných pokynů,
# vybudování nosných prvků pro jeřábovou dráhu
# veškeré předepsané atesty, zkoušky a revize dle norem a dalších obecně platných předpisů a nařízení
# předání dokumentů k jednotlivým součástem díla s jejich technickou specifikací a s uvedením podmínek jejich užívání a případně dalších dokumentů potřebných pro protokolární přejímací řízení
# zajištění trvale bezplatného užívání díla objednatelem ve vztahu k případným nárokům držitelů licencí
# dodání všech předepsaných ochranných, bezpečnostních a protipožárních pomůcek pro pracovníky zhotovitele
# zajištění bezpečnosti při provádění stavby ve smyslu bezpečnosti práce i ochrany životního prostředí
# péče o nepředané objekty a konstrukce a jejich ošetřování
# pro zhotovitele nutné, včetně získání nezbytných povolení k výstavbě dočasných obj

# %%
for data in df_contracts.loc[index, 'filtered_context']:
    print(data)
    print('==========')
# Out:
# vymezení předmětu zakázky a požadavků zadavatele.
#
# Předmětem zakázky je:.
# Nákup výrobní linky na zpracování plastů formou vstřikování. Výrobní linka je určena na zpracování tenkostěnných potravinářských obalů.
# Pořízení FVE na střechu výrobní haly.
#
# Požadavky na parametry výrobní linky jsou následovné:.
#
# (Vstřikovací stroj — uzavírací síla (200 — 250 tun.
#
# Komora vstřikovacího stroje 35 mm.
#
# Integrované topení formy 8 — 12 okruhů .
#
# Sfuky pro formu 8 — 12 sfuků .
#
# Pneumatická uzavírací jehla 1—2 okruhy.
#
# Pneumatický tahač jader 1-2 okruhy.
#
# Manipulátor | óti osý.
#
# (Dopravník (Šíře min. 600 mm.
#
# (Způsob instalace Výrobní linku včetně automatizace uvede do.
#
# (provozu dodavatel.
#
# Požadavky na parametry FVE jsou uvedeny v projektové dokumentaci, která je k dispozici na vyžádání na adrese Sovova 153. Chlumec nad Cidlinou.
# ==========
# předmět smlouvy.
#
# se musí shodovat s předmětem nabídky daného uchazeče;.
#  c) cena vč. DPH a uvedení samotného DPH, příp. uvést, že dodavatel není pláteem DPH, d) platební podmínky; e) doba a místo plnění;.
#
# f) další obligatorní náležitosti nezbytné pro platnost smlouvy.
#
# V návrhu smlouvy musí být uvedeno že dodavatel je osobu povinnou dle $ 2e zákona č. 320/2001 Sb., o finanční kontrole ve veřejné správě ve znění pozdějších předpisů spolupůsobit při výkonu finanční kontroly.
#
# Veškeré náklady spojené s účastí na výběrovém řízení  jsou na vrub uchazeče.
# | Požadavky na varianty nabídek.
# Zadavatel nepřipouští variantní zpracování nabídek ani dodatečné plnění nad rámec požadavků stanovených v ZD.
# Poskytování dodatečných informací.
#  - | Uchazeči jsou oprávněni požadovat dodatečné informace k zadávacím podmínkám. Písemná žádost musí být zadavateli doručena nejpozději 4 pracovní dny před uplynutím lhůty pro podání nabídek.
#  - © Zadavatel odešle dodatečné informace k zadávacím podmínkám nejpozději do 2 pracovních dnů po doručení žádosti.
#  .
# - © Dodatečné informace může zadavatel poskytnout i bez předchozí žádosti.
# - © Dodatečné informace, včetně přesného znění požadavku, zveřejní zadavatel na profilu zadavatele a zároveň je neprodleně písemně oznámí všem dosud známým uchazečům. Ostatní podmínky -Dle $ 2e zákona č. 320/2001 Sb., o finanční kontrole ve veřejné správě je vybraný dodavatel osobou povinnou spolupůsobit při výkonu finanční kontroly.
#
# INVESTICE DO VAŠÍ BUDOUCNOSTI.
#
# " " EVROPSKÁ UNIE .
# ZADÁVACÍ DOKUMENTACE — = 3zz.
#
# a inovace pro konkurenceschopnost.
#  -Společnost prohlašuje, že toto výběrové řízení není veřejnou obchodní soutěží ani veřejným příslibem a nejedná se o veřejnou zakázku realizovanou dle zákona č. 134/2016 Sb. o veřejných zakázkách.
# -Zadavatel si vyhrazuje právo zrušit výběrové řízení.
#
# V Chlumci nad Cidlinou dne 1.6.2017.
#
# C / ode.
# hora.
#
# Ing. Martina Hedvičáková PhD. MBA.
#
# INVESTICE DO VAŠÍ BUDOUCNOSTI.
#  =======================2_Kryci list nabidky vzor.doc=======================.
# KRYCÍ LIST NABÍDKY                                                                         - DÉS DI JVS.pdf - Adobe Acrobat Reader DC Soubor Úpravy Zobrazení Okna Nápověda x.
#
# Hledat 5.
# © Pozmámka.
#
# Česká verze x=3,5a.
#
# EVROPSKÁ UNIE.
# Evropský fond pro regionální rozvoj.
# Operační program Podnikání.
# etl al :.
# a inovace pro konkurenceschopnost.
#
# Česká verze - zkrácený text x=3,5a.
#
# EVROPSKÁ UNIE.
#
# a :. "i Evropský fond pro regionální rozvoj.
# U * OP Podnikání a inovace o omeumne om.
# POE L 0.4 m Il L 1 A".
# S ES TE = ase:. EDS.
#
# KRYCÍ LIST NABÍDKY.
# Identifikační údaje uchazeče.
# Uchazeč vyplní níže uvedenou tabulku údaji platnými ke dni podání nabídky. 	POLOŽKA 	ÚDAJE VYPLNĚNÉ UCHAZEČEM.
#
# 	Sídlo – adresa.
#
# 	Adresa pro doručování korespondence.
#
# .
#
# 	Identifikační číslo.
#
# 	Daňové identifikační číslo.
#
# 	Telefon, fax.
#
# Parametry Nabídky.
# 	Parametr.
# 	Hodnota.
#
# 	Vstřikovací stroj – uzavírací síla.
#
# 	Komora vstřikovacího stroje.
#
# 	Integrované topení formy.
#
# 	Sfuky pro formu.
#
# 	Pneumatická uzavírací jehla.
#
# 	Pneumatický tahač jader.
#
# 	Manipulátor.
#
# 	Dopravník.
#
# 	Způsob instalace.
#
# 	Integrace 6ti osého robota do řízení stroje.
#
# 	Vstřikovací rychlost v ccm / s.
#
# 	Servoelektrické pohony všech os.
#
#
# ==========

# %%
for data in df_contracts.loc[index, 'subj_context']:
    print(data)
    print('==========')
# Out:
# Předmět smlouvy
# 1. Zhotovitel se touto smlouvou zavazuje realizovat předmět veřejné zakázky „Žádovice – odkanalizování obce“, kterým je dobudování kanalizace v obci Žádovice a výstavba čistírny odpadních vod včetně příslušných stavebních objektů a provozních souborů nutných pro provoz ČOV. Dále je předmětem zakázky vybudování nové kanalizace v obci Žádovice v části zvané Horní újezd, z důvodu odvedení dešťových a splaškových vod z jednotlivých rodinných domů. Navrhuje se jednotná kanalizace, která bude odvádět splaškové a dešťové vody na plánovanou ČOV. Do doby, než bude vybudována obecní ČOV, bude kanalizace odvádět jen vody dešťové. Splaškové vody budou jako doposud akumulovány v žumpách (jímkách na vyvážení) a pravidelně vyváženy k ekologické likvidaci. Dešťové vody z rodinných domů i do budoucna ale doporučujeme využívat k zalévání nebo vsakovat na vlastních pozemcích. Předmět stavebního díla, jakož i druhy, kvalita a množství výrobků a prací nezbytných k jeho realizaci, jsou vymezeny zadávací projektovou dokumentací objednatele, kterou zpracovala firma Artesia, spol. s r. o., Ratíškovice 241, 696 02 Ratíškovice, IČ: 45475199, vč. podmínek a požadavků objednatele dle podmínek zadávacího řízení. Zhotovitel před podpisem této smlouvy o dílo prověřil s odbornou péčí uvedené dokumenty a prohlašuje, že nemají vady, zřejmé nedostatky ani nejsou v rozporu se stanovenými technickými ukazateli. Zhotoviteli je známý objem zadaných prací i místní podmínky pro provedení díla.
# 2. Předmět díla (plnění zhotovitele) je vymezen touto smlouvou včetně všech jejích příloh.
# 3. Součástí realizace díla je i zajištění zkušebního provozu ČOV po dobu 12 měsíců včetně následného vyhodnocení tohoto zkušebního provozu.  Zhotovitel pro zahájení zkušebního provozu zajistí všechny provozní náplně do technologických a strojních zařízení.
# 4. V rozsahu plnění zhotovitele za sjednanou pevnou cenu jsou tedy takto zejména, nikoli však výlučně:
# · všechny dodávky specifikované v podrobném soupisu stavebních prací, dodávek a služeb s výkazy výměr, v rozsahu pro provedení stavby;
# · protokol o vytýčení stavby, případně i vlastnických hranic dotčených pozemků ověřený úředně oprávněným zeměměřickým inženýrem zpracování projektové dokumentace skutečného provedení stavby v listinné podobě v počtu 6 ks i digitální podobě na CD nosiči v počtu 2 ks (výkresová část bude zpracována ve formátu *.dwg, textové části budou zpracovány ve formátu *.doc pro MS Word, tabulky ve formátu *.xls pro MS Excel);
# · zabezpečení a předání geodetického zaměření stavby v šesti vyhotoveních v grafické podobě, a jedenkrát v podobě digitální, zaměření objektů pro vklad do katastru nemovitostí včetně vyhotovení geometrického plánu (geometrické plány pro služebnosti) ověřeného Katastrálním úřadem;
# · zpracování a předání Provozního a Kanalizačního řádu splaškové kanalizace dle TNV 75 6911 a vyhlášky MŽP č. 195/2002 Sb. vč. projednání na příslušném odboru životního prostředí;
# · příprava a provedení komplexních zkoušek, uvedení ČOV do provozu včetně zaškolení obsluhy;
# · provozní předpisy;
# · návrh provozního řádu ČOV pro zkušební provoz;
# · návrh provozního řádu ČOV pro trvalý provoz;
# · spolupráce při řízení a vyhodnocení zkušebního provozu, účast na kontrolních provozních dnech během zkušebního provozu;
# · veškerá opatření k zajištění bezpečnosti lidí a majetku, požární ochrany a ochrany životního prostředí zajištění všech nezbytných průzkumů nutných pro řádné provedení a dokončení díla;
# · zajištění a provedení všech opatření organizačního a stavebně technologického charakteru k řádnému provedení díla;
# · zápis o předání a převzetí staveniště;
# · účast na pravidelných měsíčních kontrolních dnech stavby, a týdenních výrobních výborech;
# · veškeré práce a dodávky související s bezpečnostními opatřeními na ochranu lidí a majetku;
# · zřízení provozu, odstranění a zajištění zařízení staveniště včetně napojení na inženýrské sítě;
# · zdokumentování stavu nemovitostí, např. budovy, studny, komunikace, v blízkosti stavby před zahájením stavebních prací;
# · po dobu realizace díla musí být v pracovní době, zajištěny prostory a pracovní místo se stolem a židlí pro kontrolní orgány stavby k provádění zápisů ve stavebním deníku a k dalším nutným úkonům;
# · likvidace, odvoz a uložení vybouraných hmot a stavební suti na skládku včetně poplatku za uskladnění v souladu s ustanoveními zákona č. 185/2001 Sb., o odpadech;
# · uvedení všech povrchů dotčených stavbou do původního stavu;
# · zajištění bezpečnosti práce a ochrany životního prostředí;
# · zápis o předání a převzetí díla;
# · protokoly o řádném předání dotčených povrchů do původního stavu (silnice, místní komunikace, chodníky, zeleň) jejich vlastníkům a správcům;
# · protokoly o řádném předání dočasných záborů jejich vlastníků;
# · předání návodů na údržbu a obsluhu zařízení, zaškolení obsluhy a zpracování potřebných provozních manuálů a písemných seznamů všech těchto podkladů
# · vedení stavebního deníku;
# · dopravně – inženýrská opatření – projednání a zajištění případného zvláštního užívání komunikací a veřejných ploch včetně úhrady vyměřených poplatků a nájemného, zajištění dopravního značení k dopravním omezením, jejich údržba a přemisťování a následné odstranění dle uzavřených smluv s provozovatelem krajských komunikací případně vyjádření správce obsažených v dokladové části DSP a podmínek v těchto dokumentech uvedených;
# · zajištění přístupů a příjezdů k nemovitostem po dohodě s vlastníky (veškeré případné škody na nemovitostech a porostech při provádění stavby hradí zhotovitel);
# · v případě omezení přístupu nebo příjezdu do okolních nemovitostí budou konkrétní podmínky a termíny projednány s uživateli nemovitostí. Výsledek jednání bude zapsán do stavebního deníku a podepsán uživatelem nemovitosti a odpovědným zástupcem zhotovitele;
# · zabezpečení staveniště proti vstupu neoprávněných osob;
# · stavba musí být prováděna při trvalém zachování minimálních průjezdných šířek na komunikacích tak, aby nedošlo k omezení příjezdu vozidel HZS a zdravotní služby k jednotlivým objektům;
# ·  výkopy budou zabezpečeny tak, aby nemohlo dojít k případnému pádu osob a
# ==========
# Předmět veřejné zakázky
#
# Předmětem zakázky je dobudování kanalizace v obci Žádovice a výstavba čistírny
# odpadních vod včetně příslušných stavebních objektů a provozních souborů nutných pro
# provoz ČOV.
#
# Bližší specifikace předmětu plnění veřejné zakázky je uvedena v příslušné zadávací
# dokumentaci.
#
# ==========

# %%
save_subjects(df_contracts, 'filtered_context')
# Out:
# saving e-zakazky/48a575ba-f8fe-47f2-bbb6-c6ddb26390ef/P17V00000001
# saving e-zakazky/73b0be6b-6b49-4ab4-a6a0-508b83a305e1/P12V00000002
# saving e-zakazky/c265fdf8-044f-44e5-b36e-df4ca53c6179/P17V00000001
# saving eagri/mze/contract_display_6220
# saving ezak/mpsv/P15V00000447
# saving ezak/mpsv/P16V00000187
# saving ezak/mpsv/P16V00000240
# saving nipez/mo/P18V00009525
# saving nipez/mo/P18V00012708
# saving nipez/mo/P18V00019354
# saving nipez/mo/P18V00022561
# saving nipez/mo/P19V00003599
# saving nipez/mpsv/P18V00010416
# saving nipez/mvcr/P18V00009631
# saving nipez/mvcr/P18V00015153
# saving nipez/mzv/P18V00000055
# saving nipez/mzv/P18V00016340
# saving nipez/mzv/P18V00017124
# saving nipez/mzv/P18V00026759
# saving nipez/mzv/P19V00001827
# saving stavebnionline/121/7941
# saving tenderarena/agrozet/102972
# saving tenderarena/Comgate/201480
# saving tenderarena/JihoceskyKraj/255714
# saving tenderarena/Libereckykraj/219512
# saving tenderarena/mo/171826
# saving tenderarena/msp/85449
# saving test_contracts/test_sub/contr_59
# saving vhodne-uverejneni/00254592/oprava-casti-mk-c-14c-velky-rybnik-sever
# saving vhodne-uverejneni/00291846/zdrave-mesto-ivanovice-na-hane
# saving vhodne-uverejneni/26272784/vzdelavani-zamestnancu-spolecnosti-rik-fer-cz-s-r-o
# saving vhodne-uverejneni/70504539/dodavka-projekcni-a-interaktivni-techniky
# saving vhodne-uverejneni/buly-arena-aquapark-kravare-prispevkova-organizace/dodavka-elektricke-energie-27
# saving vhodne-uverejneni/bw-naradi-s-r-o/materialove-vyuziti-drcenych-napojovych-kartonu
# saving vhodne-uverejneni/e-c-l-spol-s-r-o/kompostarna-sobehrdy-dodavka-technickeho-vybaveni
# saving vhodne-uverejneni/flamesite-s-r-o/dodavka-novych-technologii-pro-postprodukcni-studio
# saving vhodne-uverejneni/olza-spol-s-r-o/porizeni-mechanickeho-lisu-500-t-vcetne-prislusenstvi
# saving vhodne-uverejneni/stavos-chlumec-n-cidl-s-r-o/nakup-vyrobni-linky-a-fve
# saving vhodne-uverejneni/ustav-experimentalni-botaniky-av-cr-v-v-i/chemikalie-pro-molekularni-biologii-ii-1
# saving vhodne-uverejneni/vrcha-a-s/technologie-na-snizeni-emisi-amoniaku-vrcha-a-s
# saving vhodne-uverejneni/zakladni-skola-velke-hamry-skolni-541-prispevkova-organizace/odborne-ucebny-v-zs-velke-hamry-stavebni-prace-ucebny-a-remeslna-dilna

# %%
class NonSubjectPartSentenceFilter(UdapiTransformer):

    def __init__(self,
                 target_dep_relations=['nsubj', 'obj', 'obl', 'obl:arg', 'nmod'],
                 target_verb_lemmas=['zavazovat', 'doda(t|ný)', 'zajistit', 'prov(edený|ést)',
                                     'zahrnovat', 'spočíva(t|jící)', 'rozumět'],
                 banned_upos_tags=['PUNCT', 'SYM', 'NUM', 'DET'],
                 banned_node_lemmas=['smlouva', 'předmět', 'uzavření', 'náklad', 'nebezpečí', 'specifikace',
                                     'dodavatel', 'závazek', 'dokumentace', 'rozsah', 'plnění', 'zakázka',
                                     'dohoda', 'poplatek', 'požádání', 'záměr', 'dodatek', 'podmínka', 'standard',
                                     'norma', 'kvalita', 'prohlášení', 'jiný'],
                 banned_submitter_lemmas=['objednatel', 'kupující', 'zadavate[lt]', 'projektant'],
                 banned_loctime_lemmas=['místo', 'doba'],
                 previous_banned_lemmas=['zbytný', 'pokud', 'dodatečný', 'dokumentace', 'nutný'],
                 preceding_banned_lemmas=['specifikovaný', 'povinný', 'oprávněný', 'možný', 'uvedený']):

        self._target_dep_relations = target_dep_relations
        self._target_verb_lemmas = target_verb_lemmas
        self._banned_upos_tags = banned_upos_tags
        self._banned_node_lemmas = banned_node_lemmas

        self._banned_submitter_lemmas = banned_submitter_lemmas
        self._banned_loctime_lemmas = banned_loctime_lemmas
        self._previous_banned_lemmas = previous_banned_lemmas
        self._preceding_banned_lemmas = preceding_banned_lemmas

        self._target_deprel_checker = NodeFinder(('deprel', self._target_dep_relations))
        self._banned_upos_checker = NodeFinder([('upos', self._banned_upos_tags), ('feats[Case]', 'Ins')])
        self._banned_lemmas_checker = NodeFinder(('lemma', self._banned_node_lemmas))

        self._banned_submitter_lemma_finder = PreviousNodeFinder(('lemma', self._banned_submitter_lemmas), 10, True)
        self._banned_loctime_lemma_finder = PreviousNodeFinder(('lemma', self._banned_loctime_lemmas), 10, True)
        self._previous_banned_lemma_finder = PreviousNodeFinder(('lemma', self._previous_banned_lemmas), 5)
        self._preceding_banned_lemma_finder = PrecedingNodeFinder(('lemma', self._preceding_banned_lemmas), 4)
        self._previous_target_verb_finder = PreviousNodeFinder([('lemma', self._target_verb_lemmas),
                                                                [('lemma', 'být'), ('deprel', ['cop','root']), ('feats[Polarity]', 'Pos')],
                                                               ], 5)

    def _get_candidate_nodes(self, tree):
        candidates = []
        for n in tree.descendants:

            if n.lemma == 'být' and n.deprel != 'cop':
                CNT.append((n.form, n.deprel, n.xpos))
#                 print(n.form + ': ' + n.xpos)

            if not self._target_deprel_checker.check_node_attributes(n):
                continue
                
            if self._banned_upos_checker.check_node_attributes(n):
                continue

            if self._banned_lemmas_checker.check_node_attributes(n):
                continue

            n2 = self._banned_submitter_lemma_finder.find(n)
            if n2 and (n2 == n or not PreviousNodeFinder(('lemma', 'pro'), 2).find(n2)):
                continue

            n2 = PreviousNodeFinder(('lemma', ['dílo']), 5, True).find(n)
            if n2 and (n2 == n or not (NextNodeFinder(('upos', 'DET'), 5).find(n2) or
                                       PreviousNodeFinder(('lemma', 'předmět'), 2).find(n2))):
                continue

            if self._banned_loctime_lemma_finder.find(n):
                continue

            if self._previous_banned_lemma_finder.find(n):
                continue

            if self._preceding_banned_lemma_finder.find(n):
                continue

            n2 = PreviousNodeFinder(('lemma', ['proveden(í|ý)']), 5).find(n)
            if n2 and PreviousNodeFinder([('lemma', 'předmět'), ('upos', 'DET')], 3).find(n2):
                candidates.append(n)
                continue

            if NodeFinder(('deprel', ['nmod'])).check_node_attributes(n):
                if PrecedingNodeFinder(('lemma', ['pořízení', 'uzavřen(í|ý)', 'zabezpečení'])).find(n):
                    candidates.append(n)
                continue

            if not self._previous_target_verb_finder.find(n):
                continue

            if NodeFinder(('deprel', ['obl', 'obl:arg'])).check_node_attributes(n):
                if not NodeFinder(('lemma', ['realizace'])).check_node_attributes(n):
                    if not PreviousNodeFinder(('lemma', ['předmět']), 5).find(n):
                        candidates.append(n)
                continue

            # deprel: nsubj, obj
            candidates.append(n)

        return candidates

    def _extend_candidates(self, candidates):
        # doplnim konjunkce
        extended_candidates = []
        i = 0
        while True:
            if not len(candidates) > i:
                break
            n = candidates[i]
            i += 1
            extended_candidates.append(n)
            # if not (extended_candidates and n.is_descendant_of(extended_candidates[-1])):
            #     extended_candidates.append(n)
            # else:
            #     n = extended_candidates[-1]
            if n.descendants and n.descendants[-1].next_node != n:
                n = n.descendants[-1]
            while True:
                n = NextNodeFinder(('deprel', ['conj', 'nsubj', 'obj']), 7).find(n)
                if not n or (len(candidates) > i and n.is_descendant_of(candidates[i])):
                    break
                extended_candidates.append(n)
        return extended_candidates

    def _get_all_node_candidates(self, node):
        tmp_candidates = []
        # ponecham jen slova za pripadnym nasledujicim slovesem
        n = DescendingNodeFinder([('upos', 'VERB'), ('deprel', 'cop')]).find(node)
        if n and abs(n.ord - node.ord) < 10 \
                and NodeFinder(('form', '(je|.{3,})')).check_node_attributes(n) \
                and not PreviousNodeFinder(('upos', 'DET'), 2).find(n):
            # abs(n2.ord - n.ord) < 10 kvuli bugu s nespravne tokenizovanzmi vetami
            # (je|.{3,}) kvuli bugu s identifikaci slovesa na nerelevantnich tokenech
            n = n.next_node
            while n and (n.is_descendant_of(node) or n == node):
                tmp_candidates.append(n)
                n = n.next_node
        else:
            tmp_candidates.append(node)
            tmp_candidates.extend(node.descendants)
            # odříznu příliš dlouhé řetězce
        keep_node_candidates = []
        for n in tmp_candidates:
            subj_node = PrecedingNodeFinder(('lemma', 'předmět')).find(n)
            if not (subj_node and subj_node.is_descendant_of(node)):
                if abs(n.ord - node.ord) > 10 and n.upos == 'PUNCT':
                    break
                keep_node_candidates.append(n)
        return keep_node_candidates

    def process(self, document):
        for i2, tree in enumerate(self._iter_sentences(document)):
            if not tree.children:
                continue

            candidates = self._get_candidate_nodes(tree)
            candidates = self._extend_candidates(candidates)

            keep_nodes = []
            for n in candidates:
                node_candidates = self._get_all_node_candidates(n)
                keep_nodes.extend(node_candidates)
            keep_nodes = [n for n in keep_nodes
                          if not NodeFinder(('lemma', ['smlouva', 'uzavření', 'předmět', 'plnění']))
                    .check_node_attributes(n)]

            to_remove = [n for n in tree.descendants if not n in keep_nodes]

            for n in keep_nodes:
                n.parent = tree
            for n in to_remove:
                n.remove()

            tree.text = tree.compute_text()
        return document

# %%
class StringFinder:
    
    _pattern = None
    _lower = None
    _show_prec_range = None
    _show_next_range = None
    
    def __init__(self, keyword, lower=True, show_range=30):
        self._pattern = keyword
        self._lower = lower
        self._show_prec_range = show_range[0] if isinstance(show_range, tuple) else show_range
        self._show_next_range = show_range[1] if isinstance(show_range, tuple) else show_range
    
    def process(self, text):
        occurrences = find_all_occurrences_in_string(self._pattern, text, self._lower)
        findings = {}
        for occ in occurrences:
            findings[occ] = text[max(0, occ-self._show_prec_range): min(occ+self._show_next_range, len(text))]
        return findings

class SearchEngine:
    
    _finders = None
    _findings = None

    def __init__(self, by_string=None, by_regex=None, by_conllu=None, match='exact', show_range=30):
        self._finders = []
        self._findings = {}
        for keyword in by_string:
            lower = False
            if match=='lower':
                lower = True
            self._finders.append(StringFinder(keyword, lower, show_range))
    
    def preprocess(self, data):
        data_collection = []
        if isinstance(data, str):
            data_collection.append(data)
        if isinstance(data, list) or \
           isinstance(data, pandas.core.series.Series):
            data_collection.extend([str(x) for x in data])
        return data_collection
    
    def process(self, data):
        texts = self.preprocess(data)
        for i, text in enumerate(texts):
            findings = {}
            for finder in self._finders:
                finding = finder.process(text)
                if finding:
                    findings[finder._pattern] = finding
            if findings:
                self._findings[i] = findings
        return self._findings

# %%
# validate_subjects(df_contracts, 'subj_context_decomposition')

# %%
df_sorted_contracts = df_contracts.copy()
df_sorted_contracts['context_len'] = df_sorted_contracts.subj_context.str.len()
df_sorted_contracts = df_sorted_contracts.sort_values('context_len').reset_index()
df_sorted_contracts
# Out:
#     index   id                                         contr_name  \
# 0       0   71  e-zakazky/48a575ba-f8fe-47f2-bbb6-c6ddb26390ef...
# 1      38  846  vhodne-uverejneni/ustav-experimentalni-botanik...
# 2      34  833  vhodne-uverejneni/e-c-l-spol-s-r-o/kompostarna...
# 3      32  831  vhodne-uverejneni/buly-arena-aquapark-kravare-...
# 4      29  828  vhodne-uverejneni/00291846/zdrave-mesto-ivanov...
# 5      28  826  vhodne-uverejneni/00254592/oprava-casti-mk-c-1...
# 6      23  820                   tenderarena/Libereckykraj/219512
# 7      19  803                             nipez/mzv/P19V00001827
# 8      18  794                             nipez/mzv/P18V00026759
# 9      16  775                             nipez/mzv/P18V00016340
# 10     15  771                             nipez/mzv/P18V00000055
# 11     14  755                            nipez/mvcr/P18V00015153
# 12     13  733                            nipez/mvcr/P18V00009631
# 13     40  849  vhodne-uverejneni/zakladni-skola-velke-hamry-s...
# 14      4   64                             ezak/mpsv/P15V00000447
# 15      8  207                              nipez/mo/P18V00012708
# 16      5   66                             ezak/mpsv/P16V00000187
# 17     12  714                            nipez/mpsv/P18V00010416
# 18     20  807                            stavebnionline/121/7941
# 19     35  834  vhodne-uverejneni/flamesite-s-r-o/dodavka-novy...
# 20     36  835  vhodne-uverejneni/olza-spol-s-r-o/porizeni-mec...
# 21     26  825                              tenderarena/msp/85449
# 22     25  822                              tenderarena/mo/171826
# 23     24  805                         tenderarena/agrozet/102972
# 24      6   67                             ezak/mpsv/P16V00000240
# 25     22  808                   tenderarena/JihoceskyKraj/255714
# 26     37  836  vhodne-uverejneni/stavos-chlumec-n-cidl-s-r-o/...
# 27     39  848  vhodne-uverejneni/vrcha-a-s/technologie-na-sni...
# 28      7  103                              nipez/mo/P18V00009525
# 29     17  783                             nipez/mzv/P18V00017124
# 30     10  488                              nipez/mo/P18V00022561
# 31      3   61                    eagri/mze/contract_display_6220
# 32      2   74  e-zakazky/c265fdf8-044f-44e5-b36e-df4ca53c6179...
# 33      1   72  e-zakazky/73b0be6b-6b49-4ab4-a6a0-508b83a305e1...
# 34     11  542                              nipez/mo/P19V00003599
# 35     30  829  vhodne-uverejneni/26272784/vzdelavani-zamestna...
# 36      9  397                              nipez/mo/P18V00019354
# 37     27   59                   test_contracts/test_sub/contr_59
# 38     31  830  vhodne-uverejneni/70504539/dodavka-projekcni-a...
# 39     21  806                         tenderarena/Comgate/201480
# 40     33  832  vhodne-uverejneni/bw-naradi-s-r-o/materialove-...
#
#                                                  text  \
# 0   =======================2017126-115451.pdf=====...
# 1   =======================rozhodnutí o přidělení ...
# 2   =======================Image240915212616.pdf==...
# 3   =======================xx Písemná zpráva zadav...
# 4   =======================Ivanovice_Rozhodnuti o ...
# 5   =======================SOD - ROADFIN stavby s....
# 6   =======================06_D01_OLP_465_2019_dod...
# 7   =======================SM1719-001.pdf=========...
# 8   =======================VZ-161.docx============...
# 9   =======================VZ-096.docx============...
# 10  =======================Plovoucí vinylová podla...
# 11  =======================#KS DNS ICT 11-2018-III...
# 12  =======================017 Oznámení o výběru A...
# 13  =======================deklerace k dodatku č. ...
# 14  =======================AKRIS_příloha-01_Kvalif...
# 15  =======================Oznámení o výběru dodav...
# 16  =======================Příloha č. 1 SOD_Projek...
# 17  =======================Kupní smlouva na dodávk...
# 18  =======================Smlouva o dilo.pdf=====...
# 19  =======================Přílohy_č. 1-4.odt=====...
# 20  =======================02_P1_KrycíList.doc====...
# 21  =======================Oprava_terminu_prohlidk...
# 22  =======================D.3.4.3-04_-_Vykaz_vyme...
# 23  =======================00-AGZ-Servis_CB-ZD-tex...
# 24  =======================P1_Výkaz výměr (slepý)....
# 25  =======================pril._c._2_-_Kupni_smlo...
# 26  =======================1a_zadavaci_dokumentace...
# 27  =======================přílohy.doc============...
# 28  =======================VZOR_smlouvy.doc=======...
# 29  =======================10. Výzva a Zadávací do...
# 30  =======================185310292 podepsaná.pdf...
# 31  =======================01_výzva k podání nabíd...
# 32  =======================Dodatečné informace 01....
# 33  =======================Formulář - Informace o ...
# 34  =======================199310279(2).pdf=======...
# 35  =======================rik-fer_Obchodní podmín...
# 36  =======================PSP s přílohami.zip====...
# 37  =======================426====================...
# 38  =======================00 Dodatečné informace ...
# 39  =======================CG_LogIII_ZD_Priloha_c....
# 40  =======================Dodatek KS BW nářadí.pd...
#
#                                          subj_context  \
# 0   [PŘEDMĚT SMLOUVY\nZhotovitel se zavazuje k pro...
# 1   [Předmět veřejné zakázky\n\nPředmětem veřejné ...
# 2   [PŘEDMĚT PLNĚNÍ\n\n1. Na základě této smlouvy ...
# 3   [předmět veřejné zakázky a cena sjednaná ve sm...
# 4   [Předmět plnění veřejné zakázky\n2.1 Předmět p...
# 5   [Předmět smlouvy\n\n1.1. Zhotovitel se touto s...
# 6   [Vymezení předmětu veřejné zakázky \n\n\n2.1. ...
# 7   [Předmět smlouvy\n\n1. Předmětem zakázky je op...
# 8   [Předmět veřejné zakázky\nStručný popis předmě...
# 9   [Předmět veřejné zakázky\nStručný popis předmě...
# 10  [Název veřejné zakázky:\n\tPlovoucí vinylová p...
# 11  [Předmět plnění\n1. Předmětem této smlouvy je ...
# 12  [veřejné zakázce\n\n„Náboje 308 Winchester SWI...
# 13  [Název veřejné zakázky:\nZadavatel zakázky:\n\...
# 14  [Předmět veřejné zakázky a sjednaná cena ve sm...
# 15  [Název veřejné zakázky: Sponkovače a spojovací...
# 16  [Předmět smlouvy, předmět díla\n\nPředmětem té...
# 17  [předmět Smlouvy \n\n\n1. Základním účelem, pr...
# 18  [Předmět smlouvy\n\n\n1. Název díla: Rekonstru...
# 19  [Předmět smlouvy\n\tTato smlouva se uzavírá na...
# 20  [PŘEDMĚT VEŘEJNÉ ZAKÁZKY ............oooooeeoe...
# 21  [PŘEDMĚT SMLOUVY \n\n \n\n1. Zhotovitel se tou...
# 22  [Předmět smlouvy\n1.1st Předmětem smlouvy je z...
# 23  [vymezení předmětu zakázky \n \nPředmětem této...
# 24  [Předmět Smlouvy\n2.1. Zhotovitel se zavazuje ...
# 25  [Předmět smlouvy\n\n1. Předmětem smlouvy je zá...
# 26  [vymezení předmětu zakázky a požadavků zadavat...
# 27  [Předmět plnění\n\nPředmětem plnění je dodávka...
# 28  [Předmět smlouvy\n\n2.1. \nPředmětem smlouvy j...
# 29  [Předmět veřejné zakázky\nStručný popis předmě...
# 30  [vymezení plnění veřejné zakázky:\n\nPředmětem...
# 31  [Předmět smlouvy\n\nPředmětem smlouvy je prove...
# 32  [Předmět smlouvy\n1. Zhotovitel se touto smlou...
# 33  [PŘEDMĚT DÍLA\n\n1.1. Předmětem díla je proved...
# 34  [Předmět smlouvy\n\n2.1. \nPředmětem smlouvy j...
# 35  [Předmět Smlouvy\n\n1. Předmětem Smlouvy je zá...
# 36  [Předmět smlouvy\n\n\n1. Poskytovatel se zavaz...
# 37  [Popis předmětu veřejné zakázky\nPředmětem zad...
# 38  [Předmět veřejné zakázky je blíže specifikován...
# 39  [PŘEDMĚT SMLOUVY\n1.5. Zhotovitel se zavazuje ...
# 40  [Předmět smlouvy\n\n1) Předmětem smlouvy je do...
#
#                                      filtered_context  valid_score  \
# 0   [PŘEDMĚT SMLOUVY.\nZhotovitel se zavazuje k pr...            1
# 1   [Předmět veřejné zakázky.\n\nPředmětem veřejné...            1
# 2   [PŘEDMĚT PLNĚNÍ.\n\nNa základě této smlouvy se...            1
# 3   [předmět veřejné zakázky a cena sjednaná ve sm...            1
# 4   [Předmět plnění veřejné zakázky.\nPředmět plně...            1
# 5   [Předmět smlouvy.\n\nZhotovitel se touto smlou...            1
# 6   [Vymezení předmětu veřejné zakázky.\n\nObecné ...            1
# 7   [Předmět smlouvy.\n\nPředmětem zakázky je opra...            1
# 8   [Předmět veřejné zakázky.\nStručný popis předm...            1
# 9   [Předmět veřejné zakázky.\nStručný popis předm...            1
# 10  [Název veřejné zakázky:.\n\tPlovoucí vinylová ...            1
# 11  [Předmět plnění.\nPředmětem této smlouvy je do...            1
# 12  [veřejné zakázce.\n\n"Náboje 308 Winchester SW...            1
# 13  [Název veřejné zakázky:.\nZadavatel zakázky:.\...            1
# 14  [Předmět veřejné zakázky a sjednaná cena ve sm...            1
# 15  [Název veřejné zakázky:. Sponkovače a spojovac...            1
# 16  [Předmět smlouvy, předmět díla.\n\nPředmětem t...            1
# 17  [předmět Smlouvy.\n\nZákladním účelem, pro kte...            1
# 18  [Předmět smlouvy.\n\nNázev díla:. Rekonstrukce...            1
# 19  [Předmět smlouvy.\n\tTato smlouva se uzavírá n...            1
# 20  [PŘEDMĚT VEŘEJNÉ ZAKÁZKY ......oooooeeoenooeoo...            1
# 21  [PŘEDMĚT SMLOUVY.\n\nZhotovitel se touto Smlou...            1
# 22  [Předmět smlouvy.\nt Předmětem smlouvy je záva...            1
# 23  [vymezení předmětu zakázky.\nPředmětem této za...            1
# 24  [Předmět Smlouvy.\nZhotovitel se zavazuje prov...            1
# 25  [Předmět smlouvy.\n\nPředmětem smlouvy je záva...            1
# 26  [vymezení předmětu zakázky a požadavků zadavat...            1
# 27  [Předmět plnění.\n\nPředmětem plnění je dodávk...            1
# 28  [Předmět smlouvy.\n\nPředmětem smlouvy je záva...            1
# 29  [Předmět veřejné zakázky.\nStručný popis předm...            1
# 30  [vymezení plnění veřejné zakázky:.\n\nPředměte...            1
# 31  [Předmět smlouvy.\n\nPředmětem smlouvy je prov...            1
# 32  [Předmět smlouvy.\nZhotovitel se touto smlouvo...            1
# 33  [PŘEDMĚT DÍLA.\n\nPředmětem díla je provedení ...            1
# 34  [Předmět smlouvy.\n\nPředmětem smlouvy je záva...            1
# 35  [Předmět Smlouvy.\n\nPředmětem Smlouvy je záva...            1
# 36  [Předmět smlouvy.\n\nPoskytovatel se zavazuje ...            1
# 37  [Popis předmětu veřejné zakázky.\nPředmětem za...            1
# 38  [Předmět veřejné zakázky je blíže specifikován...            1
# 39  [PŘEDMĚT SMLOUVY.\nZhotovitel se zavazuje prov...            1
# 40  [Předmět smlouvy.\n\nPředmětem smlouvy je dodá...            1
#
#                                  filtered_context_ref  \
# 0   PŘEDMĚT SMLOUVY.\nZhotovitel se zavazuje k pro...
# 1   Předmět veřejné zakázky.\n\nPředmětem veřejné ...
# 2   PŘEDMĚT PLNĚNÍ.\n\nNa základě této smlouvy se ...
# 3   předmět veřejné zakázky a cena sjednaná ve sml...
# 4   Předmět plnění veřejné zakázky.\nPředmět plněn...
# 5   Předmět smlouvy.\n\nZhotovitel se touto smlouv...
# 6   Vymezení předmětu veřejné zakázky.\n\nObecné v...
# 7   Předmět smlouvy.\n\nPředmětem zakázky je oprav...
# 8   Předmět veřejné zakázky.\nStručný popis předmě...
# 9   Předmět veřejné zakázky.\nStručný popis předmě...
# 10  Název veřejné zakázky:.\n\tPlovoucí vinylová p...
# 11  Předmět plnění.\nPředmětem této smlouvy je dod...
# 12  veřejné zakázce.\n\n"Náboje 308 Winchester SWI...
# 13  Název veřejné zakázky:.\nZadavatel zakázky:.\n...
# 14  Předmět veřejné zakázky a sjednaná cena ve sml...
# 15  Název veřejné zakázky:. Sponkovače a spojovací...
# 16  Předmět smlouvy, předmět díla.\n\nPředmětem té...
# 17  předmět Smlouvy.\n\nZákladním účelem, pro kter...
# 18  Předmět smlouvy.\n\nNázev díla:. Rekonstrukce ...
# 19  Předmět smlouvy.\n\tTato smlouva se uzavírá na...
# 20  PŘEDMĚT VEŘEJNÉ ZAKÁZKY ......oooooeeoenooeooe...
# 21  PŘEDMĚT SMLOUVY.\n\nZhotovitel se touto Smlouv...
# 22  Předmět smlouvy.\nt Předmětem smlouvy je závaz...
# 23  vymezení předmětu zakázky.\nPředmětem této zak...
# 24  Předmět Smlouvy.\nZhotovitel se zavazuje prové...
# 25  Předmět smlouvy.\n\nPředmětem smlouvy je závaz...
# 26  vymezení předmětu zakázky a požadavků zadavate...
# 27  Předmět plnění.\n\nPředmětem plnění je dodávka...
# 28  Předmět smlouvy.\n\nPředmětem smlouvy je závaz...
# 29  Předmět veřejné zakázky.\nStručný popis předmě...
# 30  vymezení plnění veřejné zakázky:.\n\nPředmětem...
# 31  Předmět smlouvy.\n\nPředmětem smlouvy je prove...
# 32  Předmět smlouvy.\nZhotovitel se touto smlouvou...
# 33  PŘEDMĚT DÍLA.\n\nPředmětem díla je provedení s...
# 34  Předmět smlouvy.\n\nPředmětem smlouvy je závaz...
# 35  Předmět Smlouvy.\n\nPředmětem Smlouvy je závaz...
# 36  Předmět smlouvy.\n\nPoskytovatel se zavazuje d...
# 37  Popis předmětu veřejné zakázky.\nPředmětem zad...
# 38  Předmět veřejné zakázky je blíže specifikován ...
# 39  PŘEDMĚT SMLOUVY.\nZhotovitel se zavazuje prové...
# 40  Předmět smlouvy.\n\nPředmětem smlouvy je dodáv...
#
#                            subj_context_decomposition  \
# 0   [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 1   [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 2   [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 3   [# newdoc\n# newpar\n# sent_id = 1\n# text = p...
# 4   [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 5   [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 6   [# newdoc\n# newpar\n# sent_id = 1\n# text = V...
# 7   [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 8   [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 9   [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 10  [# newdoc\n# newpar\n# sent_id = 1\n# text = N...
# 11  [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 12  [# newdoc\n# newpar\n# sent_id = 1\n# text = v...
# 13  [# newdoc\n# newpar\n# sent_id = 1\n# text = N...
# 14  [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 15  [# newdoc\n# newpar\n# sent_id = 1\n# text = N...
# 16  [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 17  [# newdoc\n# newpar\n# sent_id = 1\n# text = p...
# 18  [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 19  [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 20  [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 21  [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 22  [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 23  [# newdoc\n# newpar\n# sent_id = 1\n# text = v...
# 24  [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 25  [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 26  [# newdoc\n# newpar\n# sent_id = 1\n# text = v...
# 27  [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 28  [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 29  [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 30  [# newdoc\n# newpar\n# sent_id = 1\n# text = v...
# 31  [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 32  [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 33  [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 34  [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 35  [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 36  [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 37  [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 38  [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 39  [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
# 40  [# newdoc\n# newpar\n# sent_id = 1\n# text = P...
#
#                                            subj_items  \
# 0   [k provedení stavebních prací v rámci projektu...
# 1   [dodávka chemikálií pro účely zajištění aktivi...
# 2   [mininakladač se lžící, překopávač, síto a kry...
# 3                      [o dodávce elektrické energie]
# 4   [zametacího stroje vhodného pro údržbu komunik...
# 5   ["Oprava části místní komunikace III. třídy č....
# 6   [velkoplošná oprava silnice III/26322 mezi Čes...
# 7   [oprava a revize systémů PZTS, CCTV, VDT a MZP...
# 8                                                  []
# 9                                                  []
# 10                                                 []
# 11                         [dodávka zboží vymezeného]
# 12                                                 []
# 13                                                 []
# 14  [vytvoření, údržba, uživatelská podpora a rozv...
# 15                                                 []
# 16                                                 []
# 17  [zajištění dodávek bílého a dalšího zboží pro ...
# 18         [zejména práce na rekonstrukci chodníku, ]
# 19                                               [, ]
# 20  [mechanického lisu vč\ndle Pravidel, mechanick...
# 21  [provedení stavebně technického průzkumu, prov...
# 22  [stavby "Olomouc – Hejčínská kasárna Olomouc,\...
# 23  [stavební práce příslušné projektu, které se p...
# 24                                               [, ]
# 25                               [zařízení, zařízení]
# 26  [na zpracování tenkostěnných potravinářských o...
# 27  [dodávka a nákup zemědělských strojů včetně př...
# 28                                               [, ]
# 29                                               [, ]
# 30  [na dodávky CD a DVD o různých kapacitách ve p...
# 31  [stavebně technických průzkumů, zpracování pro...
# 32  [dobudování kanalizace v obci Žádovice a výsta...
# 33  [provedení stavby pro objednatele\ni geodetick...
# 34  ["Cenová kalkulace zakázky – výkaz výměr", kte...
# 35  [školení pro oddělení účetnictví a managementu...
# 36  [SW včetně dokumentace v českém nebo anglickém...
# 37  [dodávka počítačů a monitorů\ndodávka tiskáren...
# 38  [, dodání 1 interaktivní tabule, 14 magnetický...
# 39  [v přípravě komplexních podkladů pro uživatels...
# 40  [dodávka tj. realizace projektu "Materiálové v...
#
#                                        subj_items_ref  context_len
# 0   k provedení stavebních prací v rámci projektu ...            1
# 1   dodávka chemikálií pro účely zajištění aktivit...            1
# 2   mininakladač se lžící, překopávač, síto a kryc...            1
# 3                        o dodávce elektrické energie            1
# 4    zametacího stroje vhodného pro údržbu komunikací            1
# 5   "Oprava části místní komunikace III. třídy č. 14c            1
# 6   velkoplošná oprava silnice III/26322 mezi Česk...            1
# 7   oprava a revize systémů PZTS, CCTV, VDT a MZP ...            1
# 8                                                                1
# 9                                                                1
# 10                                                               1
# 11                           dodávka zboží vymezeného            1
# 12                                                               1
# 13                                                               1
# 14  vytvoření, údržba, uživatelská podpora a rozvo...            1
# 15                                                               1
# 16                                                               1
# 17  zajištění dodávek bílého a dalšího zboží pro v...            1
# 18  zejména práce na rekonstrukci chodníku\n======...            2
# 19                                     \n==========\n            2
# 20  mechanického lisu vč\ndle Pravidel\n==========...            2
# 21  provedení stavebně technického průzkumu\n=====...            2
# 22  stavby "Olomouc – Hejčínská kasárna Olomouc,\n...            2
# 23  stavební práce příslušné projektu, které se po...            2
# 24                                     \n==========\n            2
# 25                     zařízení\n==========\nzařízení            2
# 26  na zpracování tenkostěnných potravinářských ob...            2
# 27  dodávka a nákup zemědělských strojů včetně pří...            2
# 28                                     \n==========\n            2
# 29                                     \n==========\n            2
# 30  na dodávky CD a DVD o různých kapacitách ve pr...            2
# 31  stavebně technických průzkumů, zpracování proj...            2
# 32  dobudování kanalizace v obci Žádovice a výstav...            2
# 33  provedení stavby pro objednatele\ni geodetické...            3
# 34  "Cenová kalkulace zakázky – výkaz výměr", kter...            3
# 35  školení pro oddělení účetnictví a managementu\...            3
# 36  SW včetně dokumentace v českém nebo anglickém ...            3
# 37  dodávka počítačů a monitorů\ndodávka tiskáren ...            3
# 38  \n==========\ndodání 1 interaktivní tabule, 14...            5
# 39  v přípravě komplexních podkladů pro uživatelsk...            6
# 40  dodávka tj. realizace projektu "Materiálové vy...            6

# %%
class SubjectItemsEvaluationMachineDBG:
    
    def __init__(self, df_contracts,\
                 subj_context_preprocessor=SubjectContextPreprocessor(),\
                 conllu_context_preprocessor=ConlluSubjectContextPreprocessor()):
        self._df_contracts = df_contracts
        self._subj_context_extractor = subj_context_preprocessor
        self._conllu_context_extractor = conllu_context_preprocessor
        self._log_file = '../../test-data/debug.log'
        self._old_stdout = sys.stdout

        
    def preprocess(self):
        sys.stdout = open(self._log_file, 'w', encoding='utf8')
        self._df_contracts['filtered_context'] = self._df_contracts['subj_context'].apply(\
            lambda text: self._subj_context_extractor.process(text))
        self._df_contracts['subj_context_decomposition'] = self._df_contracts['filtered_context'].apply(\
            lambda text: udp_pipeline.process(text))
        self._df_contracts['subj_items'] = self._df_contracts['subj_context_decomposition'].apply(\
            lambda text: str(self._conllu_context_extractor.process(create_conllu_document(text))))
        sys.stdout.close()
        sys.stdout = self._old_stdout
        return self._df_contracts
    
    def process(self):
        self._df_contracts = validate_subjects(self._df_contracts, 'subj_items')
        return self._df_contracts

    def evaluate(self):
        return self._df_contracts['valid_score'].mean()*100

# %%
class NonSubjectPartSentenceFilterDBG(NonSubjectPartSentenceFilter):
    
    def _log(self, mark, node):
        msg = '<'+mark+'>'+ node.lemma if node is not None else ''
        print(msg)

    def _get_candidate_nodes(self, tree):
        candidates = []
        for n in tree.descendants:
            self._log('-',n)

            if not NodeFinder(('deprel', ['nsubj', 'obj', 'obl', 'nmod'])).check_node_attributes(n):
                self._log('21',n)
                continue
            self._log('51',n)

            if NodeFinder([('upos', ['PUNCT', 'SYM', 'NUM', 'DET']), \
                           ('feats[Case]', 'Ins')]).check_node_attributes(n):
                self._log('01',n)
                continue
            self._log('31',n)

            if NodeFinder([[('lemma', ['smlouva', 'předmět', 'uzavření', 'náklad', 'nebezpečí', 'specifikace',
                                      'dodavatel', 'závazek',
                                     'dokumentace', 'rozsah', 'plnění', 
                                      'zakázka','dohoda', 
                                       'poplatek','požádání','záměr', 'dodatek',]),\
                            ]]).check_node_attributes(n):
                self._log('055',n)
                continue
            self._log('355', n)
            
            n2 = PreviousNodeFinder(('lemma', ['objednatel', 'kupující', 'zadavate[lt]', 'projektant']), 10, True).find(n)
            if n2 and (n2 == n or not PreviousNodeFinder(('lemma', 'pro'), 2).find(n2)):
                self._log('03',n)
                continue
            self._log('33',n)

            n2 = PreviousNodeFinder(('lemma', ['dílo']), 5, True).find(n)
            if n2 and (n2 == n or not (NextNodeFinder(('upos', 'DET'), 5).find(n2) or \
                                       PreviousNodeFinder(('lemma', 'předmět'), 2).find(n2))):
                self._log('02',n)
                continue
            self._log('32',n)

            if PreviousNodeFinder(('lemma', ['místo', 'doba']), 10, True).find(n):
                self._log('04',n)
                continue
            self._log('34',n)

            if PreviousNodeFinder(('lemma', ['zbytný', 'pokud', 'dodatečný', 'dokumentace']), 5).find(n):
                self._log('057',n)
                continue
            self._log('357', n)
            
            if PrecedingNodeFinder(('lemma', ['specifikovaný', 'povinný', 'oprávněný', 'možný', 'uvedený',
                                             ]), 4).find(n):
                self._log('058',n)
                continue
            self._log('358', n)
                

            if NodeFinder(('deprel', ['nmod'])).check_node_attributes(n):
                self._log('17',n)
                if PrecedingNodeFinder(('lemma', ['pořízení', 'uzavřen(í|ý)'])).find(n):
                    self._log('18',n)
                    candidates.append(n)
                    continue
            self._log('46',n)

            n2 = PreviousNodeFinder(('lemma', ['proveden(í|ý)']), 5).find(n)
            if n2 and PreviousNodeFinder([('lemma', 'předmět'), ('upos', 'DET')], 3).find(n2):
                self._log('20',n)
                candidates.append(n)
                continue
            self._log('50', n)
                
            if not PreviousNodeFinder([('lemma', ['zavazovat', 'doda(t|ný)', 'zajistit', 'prov(edený|ést)',
                                                  'zahrnovat', 'spočíva(t|jící)', 'rozumět']),
                                        [('deprel', ['cop']), ('feats[Polarity]', 'Pos')]], 5).find(n):
                self._log('056', n)
                continue
            self._log('356',n)

            if NodeFinder(('deprel', ['obl'])).check_node_attributes(n) and \
                    not NodeFinder(('lemma', ['realizace'])).check_node_attributes(n):
                self._log('10',n)
                if not PreviousNodeFinder(('lemma', ['předmět']), 5).find(n):
                    self._log('11',n)
                    candidates.append(n)
                    continue
            self._log('40',n)            

            if NodeFinder(('deprel', ['nsubj'])).check_node_attributes(n):
                self._log('06',n)
                candidates.append(n)
                continue
            self._log('36',n)

            if NodeFinder(('deprel', ['obj'])).check_node_attributes(n):
                self._log('15',n)
                candidates.append(n)
                continue
            self._log('45',n)                       

        return candidates
    
    def _extend_candidates(self, candidates):
        # doplnim konjunkce
        extended_candidates = []
        i = 0
        while True:
            if not len(candidates) > i:
                break
            n = candidates[i]
            i += 1
            if not (extended_candidates and n.is_descendant_of(extended_candidates[-1])):
                extended_candidates.append(n)
            else:
                n = extended_candidates[-1]
            if n.descendants and n.descendants[-1].next_node != n:
                n = n.descendants[-1]
            while True:
                n = NextNodeFinder(('deprel', ['conj', 'nsubj', 'obj']), 7).find(n)
                if not n or (len(candidates) > i and n.is_descendant_of(candidates[i])):
                    break
                extended_candidates.append(n)
        return extended_candidates

    def _get_all_node_candidates(self, node):
        tmp_candidates = []
        # ponecham jen slova za pripadnym nasledujicim slovesem
        n = DescendingNodeFinder([('upos', 'VERB'), ('deprel', 'cop')]).find(node)
        if n and abs(n.ord - node.ord) < 10 \
                and NodeFinder(('form', '(je|.{3,})')).check_node_attributes(n) \
                and not PreviousNodeFinder(('upos', 'DET'), 2).find(n):
            # abs(n2.ord - n.ord) < 10 kvuli bugu s nespravne tokenizovanzmi vetami
            # (je|.{3,}) kvuli bugu s identifikaci slovesa na nerelevantnich tokenech
            n = n.next_node
            while n and (n.is_descendant_of(node) or n == node):
                tmp_candidates.append(n)
                n = n.next_node
        else:
            tmp_candidates.append(node)
            tmp_candidates.extend(node.descendants)
            # odříznu příliš dlouhé řetězce
        keep_node_candidates = []
        for n in tmp_candidates:
            subj_node = PrecedingNodeFinder(('lemma', 'předmět')).find(n)
            if not (subj_node and subj_node.is_descendant_of(node)):
                if abs(n.ord - node.ord) > 10 and n.upos == 'PUNCT':
                    break
                keep_node_candidates.append(n)
        return keep_node_candidates

    def process(self, document):
        for i2, tree in enumerate(self._iter_sentences(document)):
            if not tree.children:
                continue

            candidates = self._get_candidate_nodes(tree)
            candidates = self._extend_candidates(candidates)

            keep_nodes = []
            for n in candidates:
                node_candidates = self._get_all_node_candidates(n)
                keep_nodes.extend(node_candidates)
            keep_nodes = [n for n in keep_nodes
                          if not NodeFinder(('lemma', ['smlouva', 'uzavření', 'předmět', 'plnění']))
                    .check_node_attributes(n)]

            to_remove = [n for n in tree.descendants if not n in keep_nodes]

            for n in keep_nodes:
                n.parent = tree
            for n in to_remove:
                n.remove()

            tree.text = tree.compute_text()
        return document

# %%
# %%time

preprocessor = SubjectContextPreprocessor()

conllu_eval_transformers = [
    UdapiWordOccurrencePartSentenceFilter(keywords=['cena', 'hodnota', 'DPH']),
#     SubmitterPartSentenceFilter(submitter_keywords=['objednatel', 'zadavatel', 'kupující'],
#                                 suplier_keywords=['dodavatel', 'prodávající', 'zhotovitel', 'uchazeč']),
    UdapiWordOccurrencePartSentenceFilter(keywords=['příloha', 'dále', 'jen']),
#     UdapiWordOccurrencePartSentenceFilter(keywords=['náklad', 'nebezpečí','odpovědnost']),
#     UdapiWordOccurrencePartSentenceFilter(keywords=['místo', 'doba']),
    NonSubjectPartSentenceFilter(
                target_dep_relations = ['nsubj', 'obj', 'obl', 'nmod'],
                target_verb_lemmas = ['zavazovat', 'doda(t|ný)', 'zajistit', 'prov(edený|ést)',
                                      'zahrnovat', 'spočíva(t|jící)', 'rozumět'],
                banned_upos_tags = ['PUNCT', 'SYM', 'NUM', 'DET'],
                banned_node_lemmas = ['smlouva', 'předmět', 'uzavření', 'náklad', 'nebezpečí', 'specifikace',
                                    'dodavatel', 'závazek', 'dokumentace', 'rozsah', 'plnění', 'zakázka',
                                    'dohoda', 'poplatek', 'požádání', 'záměr', 'dodatek'],
                banned_submitter_lemmas = ['objednatel', 'kupující', 'zadavate[lt]', 'projektant'],
                banned_loctime_lemmas = ['místo', 'doba'],
                previous_banned_lemmas = ['zbytný', 'pokud', 'dodatečný', 'dokumentace'], 
                preceding_banned_lemmas = ['specifikovaný', 'povinný', 'oprávněný', 'možný', 'uvedený']),
    EmptyBundlesFilter(),
]
df_slice = df_sorted_contracts[30:].copy()
conllu_eval_preprocessor = ConlluSubjectContextPreprocessor(transformers=conllu_eval_transformers)
conllu_evaluator = SubjectItemsEvaluationMachine(df_sorted_contracts, subj_context_preprocessor=preprocessor, conllu_context_preprocessor=conllu_eval_preprocessor)
conllu_evaluator.preprocess()
conllu_evaluator.process()
conllu_evaluator.evaluate()
# Out:
# Wall time: 31.8 s
# 100.0

# %%
df_conllu_contracts = conllu_evaluator._df_contracts
df_conllu_contracts[df_conllu_contracts.valid_score < 1]
# Out:
#     index  id                                         contr_name  \
# 37      1  72  e-zakazky/73b0be6b-6b49-4ab4-a6a0-508b83a305e1...
#
#                                                  text  \
# 37  =======================Formulář - Informace o ...
#
#                                          subj_context  \
# 37  PŘEDMĚT DÍLA\n\n1.1. Předmětem díla je provede...
#
#                                      filtered_context  \
# 37  PŘEDMĚT DÍLA.\n\nPředmětem díla je provedení s...
#
#                            subj_context_decomposition  valid_score  \
# 37  # newdoc\n# newpar\n# sent_id = 1\n# text = PŘ...     0.611111
#
#                        subj_context_decomposition_ref  sent_cnt_diff  \
# 37  # newdoc\n# newpar\n# sent_id = 1\n# text = PŘ...              0
#
#     context_len                                         subj_items  \
# 37         8293  provedení stavby pro objednatele\ni geodetické...
#
#                                        subj_items_ref
# 37  provedení stavby pro objednatele\ni geodetické...

# %%
for neco in df_conllu_contracts.loc[37, ['subj_items', 'subj_items_ref']]:
    print('----------------')
    print(neco)
# Out:
# ----------------
# provedení stavby pro objednatele
# i geodetické zaměření dokončeného díla
# realizace výše
# ----------------
# provedení stavby pro objednatele
# i geodetické zaměření dokončeného díla
# realizace výše

# %%
default_stdout = sys.stdout

# %%
sys.stdout = default_stdout

# %%
transformed_texts = [preprocessor.process(t) for t in df_sorted_contracts.subj_context]

# %%
se = SearchEngine(by_string=['uzavření'], match='exact', show_range=(50,50))
se.process(transformed_texts)
# Out:
# {7: {'uzavření': {285: 'organizace « Předmět Předmětem veřejné zakázky je uzavření smlouvy o dodávce elektrické energie. \n\n'}},
#  11: {'uzavření': {106: 'akázky a jeho specifikace.\n\nZáměrem zadavatele je uzavření smlouvy, na základě které vybraný uchazeč',
#    212: 'ou odpovědnost a náklady dodá zadavateli po jejím uzavření předmět plnění této zakázky (zboží), kter'}},
#  17: {'uzavření': {532: 'zahájení plnění předmětu veřejné zakázky ihned po uzavření smlouvy a ukončení dodávky nejpozději do ',
#    596: 'vy a ukončení dodávky nejpozději do 60 dnů od dne uzavření smlouvy. Místem plnění je areál firmy ZDA'}},
#  20: {'uzavření': {98: 'ejné zakázky je ve smyslu ustanovení $ 134 zákona uzavření rámcové dohody s jedním dodavatelem na do',
#    529: 'emné výzvy k poskytnutí plnění, jež je návrhem na uzavření smlouvy, a písemného potvrzení této výzvy'}},
#  30: {'uzavření': {986: '. Zhotovitel prohlašuje, že nejpozději k okamžiku uzavření této smlouvy se s přílohou č. 1 a č. 2 té',
#    1648: 'vést zaměření jednotlivých detailů bezodkladně po uzavření této smlouvy. Na základě zaměření zahájí ',
#    3045: 'veniště nejpozději do 14 kalendářních dní ode dne uzavření této smlouvy a ukončit realizaci plnění n'}},
#  31: {'uzavření': {3004: 'měny zhotovitelem a zaplacení objednatelem vzniká uzavřením dodatku ke smlouvě, který vždy musí obsa'}},
#  34: {'uzavření': {4189: 'y a jiné jejich nedostatky;.\n\nb) neshledal ke dni uzavření smlouvy jejich nevhodnost, která by překá',
#    5716: 'možné při vynaložení náležité péče předvídat před uzavřením smlouvy (dále také jen "vícepráce").\nSml'}},
#  36: {'uzavření': {5773: 'y a jiné jejich nedostatky;.\n\nb) neshledal ke dni uzavření smlouvy jejich nevhodnost, která by překá',
#    5905: ' a dokončení plnění smlouvy;.\nc) neshledal ke dni uzavření smlouvy žádné nedostatky či rozpory v\xa0pře',
#    7289: 'možné při vynaložení náležité péče předvídat před uzavřením smlouvy (dále jen "vícepráce").\nh Smluvn'}},
#  37: {'uzavření': {4809: 'Dodatku ke smlouvě. Teprve po jeho odsouhlasení a uzavření má právo na realizaci těchto změn a na je'}},
#  38: {'uzavření': {5774: 'y a jiné jejich nedostatky;.\n\nb) neshledal ke dni uzavření smlouvy jejich nevhodnost, která by překá',
#    7197: 'možné při vynaložení náležité péče předvídat před uzavřením smlouvy (dále také jen "vícepráce").\nSml',
#    7484: 'le také jen "méněpráce"), nebudou zhotovitelem po uzavření dodatku této smlouvy provedeny a fakturov'}}}

# %%
# %%time
# 26, 29
conllu_transformers = [
    UdapiWordOccurrencePartSentenceFilter(keywords=['cena', 'hodnota', 'DPH']),
#     SubmitterPartSentenceFilter(submitter_keywords=['objednatel', 'zadavatel', 'kupující'],
#                                 suplier_keywords=['dodavatel', 'prodávající', 'zhotovitel', 'uchazeč']),
    UdapiWordOccurrencePartSentenceFilter(keywords=['příloha', 'dále', 'jen']),
#     UdapiWordOccurrencePartSentenceFilter(keywords=['náklad', 'nebezpečí','odpovědnost']),
#     UdapiWordOccurrencePartSentenceFilter(keywords=['místo', 'doba']),
]
conllu_preprocessor = ConlluSubjectContextPreprocessor(transformers=conllu_transformers)

conllu_transformers2 = [
    NonSubjectPartSentenceFilter(),
    EmptyBundlesFilter(),
]
conllu_preprocessor2 = ConlluSubjectContextPreprocessor(transformers=conllu_transformers2)

index = 24
text = df_sorted_contracts.subj_context.iloc[index]
print(text)
print('------------------')
transformed_text = preprocessor.process(text)
print(transformed_text)
print('------------------')
decomposition = udp_pipeline.process(transformed_text)
doc = Document()
doc.from_conllu_string(decomposition)
doc = conllu_preprocessor.process(doc)
display(doc)
print('------------------')
doc = conllu_preprocessor2.process(doc)
display(doc)
# Out:
# Předmět smlouvy
#
#
# 1. Název díla: Rekonstrukce vytápění v objektu SPV Pod Kamenem 179 – vybrané části.
#
# 2. Specifikace díla:
#
#
# Rozsah díla je dán Soupisem stavebních prací, dodávek a služeb s výkazem výměr, který byl součástí zadávací dokumentace veřejné zakázky malého rozsahu „Rekonstrukce vytápění v objektu SPV Pod Kamenem 179“, který tvoří přílohu č. 1 této smlouvy.
#
# V rámci realizace budou provedeny zejména práce na rekonstrukci chodníku v následujícím rozsahu:
#
# 		PS01
#
#
#
# 		STL plynová přípojka
#
#
#
#
#
#
#
# 		PS01
#
# 		57
#
# 		Kryty štěrkových a živičných pozemních komunikací a zpevněných ploch
#
#
#
#
#
#
#
# 		PS01
#
# 		573211111R00
#
# 		Postřik živičný spojovací z asfaltu 0,5-0,7 kg/m2
#
# 		m2
#
# 		450,66
#
#
#
#
#
#
#
# 		429,2*1,05
#
#
#
# 		450,66
#
#
#
# 		PS01
#
# 		572713111R00
#
# 		Vyrovnání povrch krytů živ. směsí, koberec otevřený
#
# 		t
#
# 		2,58
#
#
#
#
#
#
#
# 		429,2*0,05*0,05*2,4
#
#
#
# 		2,58
#
#
#
# 		PS01
#
# 		577131311R00
#
# 		Beton asfaltový ACO 8 CH, š. do 3 m, tl. 4 cm
#
# 		m2
#
# 		450,66
#
#
#
#
#
#
#
# 		429,2*1,05
#
#
#
# 		450,66
#
#
#
# 		PS01
#
# 		998225311R00
#
# 		Přesun hmot, oprava komunikací, kryt živič. a bet.
#
# 		t
#
# 		45,84
#
#
#
# 		PS01
#
# 		998225394R00
#
# 		Přesun hmot, oprava komunikací, příplatek do 5 km
#
# 		t
#
# 		45,84
#
#
#
#
#
#
#
# 		1
#
#
#
# 		1,00
#
#
#
# 		PS02
#
# 		93
#
# 		Různé dokončovací konstrukce a práce inženýrských staveb
#
#
#
#
#
#
#
# 		PS02
#
# 		938908411R00
#
# 		Očištění povrchu krytu saponátovým roztokem
#
# 		m2
#
# 		450,66
#
#
#
#
#
#
#
# 		429,2*1,05
#
#
#
# 		450,66
#
#
#
#
#
# 3. Místo plnění:
#
# Ul. Pod Kamenem, Český Krumlov.
#
# ------------------
# Předmět smlouvy.
#
# Název díla:. Rekonstrukce vytápění v objektu SPV Pod Kamenem 179 – vybrané části.
#
# Specifikace díla:.
#
# Rozsah díla je dán Soupisem stavebních prací, dodávek a služeb s výkazem výměr, který byl součástí zadávací dokumentace veřejné zakázky malého rozsahu "Rekonstrukce vytápění v objektu SPV Pod Kamenem 179", který tvoří přílohu č. 1 této smlouvy.
#
# V rámci realizace budou provedeny zejména práce na rekonstrukci chodníku v následujícím rozsahu:.
#
# 		STL plynová přípojka.
#
# 		Kryty štěrkových a živičných pozemních komunikací a zpevněných ploch.
#
# 		Postřik živičný spojovací z asfaltu 0,5-0,7 kg/m2.
#
# 		Vyrovnání povrch krytů živ. směsí, koberec otevřený.
#
# 		Beton asfaltový ACO 8 CH, š. do 3 m, tl. 4 cm.
#
# 		Přesun hmot, oprava komunikací, kryt živič. a bet.
#
# 		Přesun hmot, oprava komunikací, příplatek do 5 km.
#
# 		Různé dokončovací konstrukce a práce inženýrských staveb.
#
# 		Očištění povrchu krytu saponátovým roztokem.
#
# Místo plnění:.
#
# Ul. Pod Kamenem, Český Krumlov.
#
#
#
# <ITEM>STL plynová přípojka<ITEM/>
# <ITEM>Kryty štěrkových a živičných pozemních komunikací a zpevněných ploch<ITEM/>
# <ITEM>Postřik živičný spojovací z asfaltu 0,5-0,7 kg/m2<ITEM/>
# <ITEM>Vyrovnání povrch krytů živ. směsí, koberec otevřený<ITEM/>
# <ITEM>Beton asfaltový ACO 8 CH, š. do 3 m, tl. 4 cm<ITEM/>
# <ITEM>Přesun hmot, oprava komunikací, kryt živič. a bet<ITEM/>
# <ITEM>Přesun hmot, oprava komunikací, příplatek do 5 km<ITEM/>
# <ITEM>Různé dokončovací konstrukce a práce inženýrských staveb<ITEM/>
# <ITEM>Očištění povrchu krytu saponátovým roztokem<ITEM/>
# <CONTRACT_NAME>Rekonstrukce vytápění v objektu SPV Pod Kamenem 179 – vybrané části<CONTRACT_NAME/>
# <CONTRACT_NAME>Rekonstrukce vytápění v objektu SPV Pod Kamenem 179<CONTRACT_NAME/>
# ------------------
# Předmět smlouvy.
# Název díla:.
# Rekonstrukce vytápění v objektu SPV Pod Kamenem 179 – vybrané části.
# Specifikace díla:.
# Rozsah díla je dán Soupisem stavebních prací, dodávek a služeb s výkazem výměr, který byl součástí zadávací dokumentace veřejné zakázky malého rozsahu "Rekonstrukce vytápění v objektu SPV Pod Kamenem 179", který tvoří .
# V rámci realizace budou provedeny zejména práce na rekonstrukci chodníku v následujícím rozsahu:.
# STL plynová přípojka.
# Kryty štěrkových a živičných pozemních komunikací a zpevněných ploch.
# Postřik živičný spojovací z asfaltu 0,5-0,7 kg/m2.
# Vyrovnání povrch krytů živ. směsí, koberec otevřený.
# Beton asfaltový ACO 8 CH, š. do 3 m, tl. 4 cm.
# Přesun hmot, oprava komunikací, kryt živič. a bet.
# Přesun hmot, oprava komunikací, příplatek do 5 km.
# Různé dokončovací konstrukce a práce inženýrských staveb.
# Očištění povrchu krytu saponátovým roztokem.
# Místo plnění:.
# Ul. Pod Kamenem, Český Krumlov.
# <ITEM>STL plynová přípojka<ITEM/> <ITEM>Kryty štěrkových a živičných pozemních komunikací a zpevněných ploch<ITEM/> <ITEM>Postřik živičný spojovací z asfaltu 0,5-0,7 kg/m2<ITEM/> <ITEM>Vyrovnání povrch krytů živ. směsí, koberec otevřený<ITEM/> <ITEM>Beton asfaltový ACO 8 CH, š. do 3 m, tl. 4 cm<ITEM/> <ITEM>Přesun hmot, oprava komunikací, kryt živič. a bet<ITEM/> <ITEM>Přesun hmot, oprava komunikací, příplatek do 5 km<ITEM/> <ITEM>Různé dokončovací konstrukce a práce inženýrských staveb<ITEM/> <ITEM>Očištění povrchu krytu saponátovým roztokem<ITEM/> <CONTRACT_NAME>Rekonstrukce vytápění v objektu SPV Pod Kamenem 179 – vybrané části<CONTRACT_NAME/> <CONTRACT_NAME>Rekonstrukce vytápění v objektu SPV Pod Kamenem 179<CONTRACT_NAME/>
# ------------------
# zejména práce na rekonstrukci chodníku
# Wall time: 639 ms

# %%
text = '''
Předmětem plnění této veřejné zakázky je dodávka zemědělských strojů.
Předmětem jsou zemědělské stroje.
Dodavatel dodá zemědělské stroje.
Dodavatel se zavazuje k dodání zemědělských strojů.
Předmět spočívá v dodání zemědělských strojů.
Předmětem je uzavření smlouvy na dodání zemědělských strojů.
'''
decomposition = udp_pipeline.process(text)
tmp_doc = Document()
tmp_doc.from_conllu_string(decomposition)
tmp_doc
# Out:
# Předmětem plnění této veřejné zakázky je dodávka zemědělských strojů.
# Předmětem jsou zemědělské stroje.
# Dodavatel dodá zemědělské stroje.
# Dodavatel se zavazuje k dodání zemědělských strojů.
# Předmět spočívá v dodání zemědělských strojů.
# Předmětem je uzavření smlouvy na dodání zemědělských strojů.

# %%
tree = tmp_doc.bundles[1].trees[0]
tree.print_subtree()
# Out:
# # sent_id = 2
# # text = Předmětem plnění je dodávka a nákup zemědělských strojů včetně příslušenství a služeb s touto činností souvisejících , Prodávající se zavazuje kupujícímu dodat následující zboží:. kus Nakladač kolový kloubový JCB 436 c HT AGRI HL.
# ─┮
#  ╰─┮ Předmětem NOUN root
#    ┡─╼ plnění NOUN nmod
#    ┡─╼ je AUX cop
#    ┡─┮ dodávka NOUN nsubj
#    │ │ ╭─╼ a CCONJ cc
#    │ ┡─┶ nákup NOUN conj
#    │ │ ╭─╼ zemědělských ADJ amod
#    │ ┡─┾ strojů NOUN nmod
#    │ │ │ ╭─╼ včetně ADP case
#    │ │ ╰─┾ příslušenství NOUN nmod
#    │ │   │ ╭─╼ a CCONJ cc
#    │ │   ╰─┶ služeb NOUN conj
#    │ │   ╭─╼ s ADP case
#    │ │   ┢─╼ touto DET det
#    │ │ ╭─┶ činností NOUN obl:arg
#    │ ┡─┶ souvisejících ADJ amod
#    │ │ ╭─╼ , PUNCT punct
#    │ │ ┢─╼ Prodávající ADJ nsubj:pass
#    │ │ ┢─╼ se PRON expl:pass
#    │ ╰─┾ zavazuje VERB appos
#    │   ╰─┮ kupujícímu ADJ obj
#    │     ╰─┮ dodat VERB advcl
#    │       │ ╭─╼ následující ADJ amod
#    │       ┡─┶ zboží NOUN obj
#    │       │ ╭─┮ : PUNCT punct
#    │       │ │ ╰─╼ . PUNCT punct
#    │       │ ┢─╼ kus NOUN nmod
#    │       ╰─┾ Nakladač PROPN appos
#    │         │ ╭─╼ kolový ADJ amod
#    │         │ ┢─╼ kloubový ADJ amod
#    │         ┡─┶ JCB PROPN flat
#    │         │   ╭─╼ 436 NUM nummod
#    │         │ ╭─┶ c NOUN nmod
#    │         ╰─┾ HT NOUN flat
#    │           ┡─╼ AGRI PROPN flat
#    │           ╰─╼ HL PROPN flat
#    ╰─╼ . PUNCT punct

# %%
tmp_doc.store_conllu('../../test-data/test_src/conllu_temp_'+str(index)+'.txt')

# %%
tmp_doc.store_conllu('../../test-data/test_src/conllu_tmp.txt')

# %%
def save_connlu_to_file(conllu_data, path='../../test-data/test_src/conllu_temp.txt'):
    if isinstance(conllu_data, list):
        conllu_data = '\n'.join([sentence.serialize() for sentence in conllu_data])
    if isinstance(conllu_data, conllu.models.TokenList):
        conllu_data = conllu_data.serialize()
    with open(path, 'w', encoding='utf-8') as f:
        f.write(conllu_data)

def save_text_as_connlu(text, udp_pipeline, path='../../test-data/test_src/conllu_temp.txt'):
    decomposition = udp_pipeline.process(text)
    save_connlu_to_file(decomposition, path)

# %%
save_connlu_to_file(doc, path='../../test-data/conllu_temp_'+str(index)+'.txt')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-13d39bd133d3> in <module>
# ----> 1 save_connlu_to_file(doc, path='../../test-data/conllu_temp_'+str(index)+'.txt')
#
# C:\x\diplomka\research\src\utils\subject_extraction.py in save_connlu_to_file(connlu_data, path)
#      22         connlu_data = connlu_data.serialize()
#      23     with open(path, 'w', encoding='utf-8') as f:
# ---> 24         f.write(connlu_data)
#      25
#      26 class SubjectExtractor:
#
# TypeError: write() argument must be str, not Document
