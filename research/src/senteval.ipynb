# %%
from __future__ import absolute_import, division, unicode_literals
import sys
import io
import numpy as np
import os.path
from os import path
import logging
import hashlib
import json
import pandas as pd

# %%
import tensorflow as tf
import torch
from transformers import BertTokenizer, BertModel, TFBertModel

# %%
# Set PATHs
PATH_TO_SENTEVAL = './senteval/SentEval'
PATH_TO_DATA = PATH_TO_SENTEVAL + '/data'
STS_path = PATH_TO_SENTEVAL + '/data/downstream/STS'
EMBEDDINGS_path = PATH_TO_SENTEVAL + '/examples/embeddings'

# %%
# import SentEval
sys.path.insert(0, PATH_TO_SENTEVAL)
import senteval

# %%
dictionaries = {}
results = {}

# %%
# Get word vectors from vocabulary (glove, word2vec, fasttext ..)
def get_wordvec(path_to_vec, word2id): #TODO hierarchizace slov podle vet
    word_vec = {}

    with io.open(path_to_vec, 'r', encoding='utf-8') as f:
        # if word2vec or fasttext file : skip first line "next(f)"
        for line in f:
            word, vec = line.split(' ', 1)
            if word in word2id:
                word_vec[word] = np.fromstring(vec, sep=' ')

    logging.info('Found {0} words with word vectors, out of \
        {1} words'.format(len(word_vec), len(word2id)))
    return word_vec


# SentEval prepare and batcher
class Prepare:

    def __init__(self, path_to_vec, wvec_dim=768):
        self.path_to_vec = path_to_vec
        self.wvec_dim = wvec_dim

    def run(self, params, sentences):
        params.sent2id = sentences
        params.word_vec = get_wordvec(self.path_to_vec, params.sent2id)
        params.wvec_dim = self.wvec_dim
        return

def batcher(params, batch):
    batch = [sent if sent != [] else ['.'] for sent in batch]
    embeddings = []

    for sent in batch:
        sentvec = []
        if sent in params.word_vec:
            sentvec.append(params.word_vec[sent]) #TODO vyber podle vety, ne jen podle slowa
        if not sentvec:
            vec = np.zeros(params.wvec_dim)
            sentvec.append(vec)
        sentvec = np.mean(sentvec, 0)
        embeddings.append(sentvec)

    embeddings = np.vstack(embeddings)
    return embeddings


# Set params for SentEval
params_senteval = {'task_path': PATH_TO_DATA, 'usepytorch': True, 'kfold': 5}
params_senteval['classifier'] = {'nhid': 0, 'optim': 'rmsprop', 'batch_size': 128,
                                 'tenacity': 3, 'epoch_size': 2}

# %%
def torch_embedding(token, model, tokenizer):
    input_ids = torch.tensor(tokenizer.encode(token)).unsqueeze(0)  # Batch size 1
    outputs = model(input_ids)
    last_hidden_states = outputs[0]  # The last hidden-state is the first element of the output tuple
    return last_hidden_states.detach().numpy()


def tf_embedding(token, model, tokenizer):
    input_ids = tf.constant(tokenizer.encode(token))[None, :]  # Batch size 1
    outputs = model(input_ids)
    last_hidden_states = outputs[0]  # The last hidden-state is the first element of the output tuple
    return last_hidden_states.numpy()

# %%
def torch_mean_pooling_embedding(token, model, tokenizer):
    input_ids = torch.tensor(tokenizer.encode(token)).unsqueeze(0)  # Batch size 1
    outputs = model(input_ids)
    last_hidden_states = outputs[0]  # The last hidden-state is the first element of the output tuple
    arr = last_hidden_states.detach().numpy()
    return np.mean(arr[0], axis=0)

# %%
class Job():

    def __init__(self,
                 test='STSCZ2',
                 model_spec='bert-base-multilingual-cased',
                 technology='torch',
                 name=None,
                 sentences=None,
                 lang='CZ',
                 datasets=['headlines', 'images'],
                 embed_with=None,
                 embeddings=None,
                 path_to_embeddings=None,
                 tokenizer=None,
                 model=None,
                 wvec_dim=768):
        self.test = test
        self.model_spec = model_spec
        self.technology = technology
        self.name = \
            name \
                if name is not None else \
                '_'.join([test, model_spec, technology])
        self.sentences = sentences
        self.lang = lang
        self.datasets = datasets
        self.embeddings = embeddings
        self.path_to_embeddings = \
            path_to_embeddings \
                if path_to_embeddings is not None else \
                EMBEDDINGS_path + '/' + self.name
        if embed_with is None:
            self.embed = \
                torch_embedding \
                    if technology == 'torch' else \
                    tf_embedding
        else:
            self.embed = embed_with
        self.tokenizer = tokenizer
        self.model = model
        self.wvec_dim = wvec_dim
        self.results = None

    def get_sentences(self):
        if self.sentences is not None:
            return self.sentences

        print('Getting sentences for ' + self.name)
        sentences = []

        fpath = STS_path + '/' + self.test + ('-cz-test' if self.lang == 'CZ' else '-en-test')
        for dataset in self.datasets:
            sent1, sent2 = zip(*[l.split("\t") for l in
                                 io.open(fpath + '/STS.input.%s.txt' % dataset,
                                         encoding='utf8').read().splitlines()])
            sentences += sent1 + sent2

        self.sentences = sentences
        return self.sentences

    def get_embeddings(self):
        if self.embeddings is not None:
            return self.embeddings
        if path.exists(self.path_to_embeddings):
            self.embeddings = self.load_embeddings()
            return self.embeddings

        if self.tokenizer is None:
            print('Loading tokenizer for ' + self.name)
            self.tokenizer = BertTokenizer.from_pretrained(self.model_spec)
        if self.model is None:
            print('Loading model for ' + self.name)
            self.model = \
                BertModel.from_pretrained(self.model_spec) \
                    if self.technology == 'torch' else \
                    TFBertModel.from_pretrained(self.model_spec)
        print('Processing embeddings for ' + self.name)
        embeddings = {}
        for i, sent in enumerate(list(self.get_sentences())):
            hashed = hashlib.md5(sent.encode('utf-8')).hexdigest()
            embeddings[hashed] = self.embed(sent, self.model, self.tokenizer)
            print("%i/%i:%s" % (i, len(self.get_sentences()), sent))
        self.embeddings = embeddings
        self.save_embeddings()
        return self.embeddings

    def load_embeddings(self):
        print('Loading embeddings for ' + self.name)
        embeddings = {}
        with io.open(EMBEDDINGS_path + '/' + self.name, 'r', encoding='utf-8') as f:
            for line in f:
                word, vec = line.split(' ', 1)
                embeddings[word] = np.fromstring(vec, sep=' ')
        return embeddings

    def save_embeddings(self):
        embeddings = self.get_embeddings()
        print('Saving embeddings for ' + self.name)
        with io.open(self.path_to_embeddings, 'w', encoding='utf-8') as f:
            for token in embeddings:
                tokens = [token] + [str(x) for x in embeddings[token]]
                f.write(' '.join(tokens) + '\n')

    def run_evaluation(self):
        if not path.exists(self.path_to_embeddings):
            self.save_embeddings()
        print('Running evaluation for ' + self.name)
        se = senteval.engine.SE(params_senteval, batcher, Prepare(self.path_to_embeddings, wvec_dim=self.wvec_dim))
        transfer_tasks = [self.test]
        self.results = se.eval(transfer_tasks)
        return self.results

    def get_results(self):
        if self.results is not None:
            return self.results
        return self.run_evaluation()

    def save_results(self):
        results = self.get_results()
        print('Saving results for ' + self.name)
        with io.open(EMBEDDINGS_path + '/results.json', 'a', encoding='utf-8') as f:
            data = {self.name: results}
            json_data = json.dumps(data)
            f.write(json_data + '\n')
            return json_data

# %%
STSCZ_bert_base_multilingual_cased_torch_job = Job()

# %%
STSCZ_dictionary = STSCZ_bert_base_multilingual_cased_torch_job.get_dictionary()
# Out:
# Getting dictionary for STSCZ_bert-base-multilingual-cased_torch

# %%
STSCZ_bert_base_multilingual_cased_torch_job.get_embeddings()

# %%
STSCZ_bert_base_multilingual_cased_torch_job.get_results()
# Out:
# Running evaluation for STSCZ_bert-base-multilingual-cased_torch
# {'STSCZ': {'headlines': {'pearson': (0.0017701255986185087,
#     0.9662166676605177),
#    'spearman': SpearmanrResult(correlation=-0.020812356817649466, pvalue=0.61846238688042),
#    'nsamples': 575},
#   'images': {'pearson': (0.043712113796052915, 0.20296506069815348),
#    'spearman': SpearmanrResult(correlation=0.06488102600778692, pvalue=0.05865110464755204),
#    'nsamples': 850},
#   'all': {'pearson': {'mean': 0.02274111969733571,
#     'wmean': 0.02678815364621096},
#    'spearman': {'mean': 0.022034334595068726, 'wmean': 0.030302994341382766}}}}

# %%
dictionaries['STSCZ'] = STSCZ_dictionary
results[STSCZ_bert_base_multilingual_cased_torch_job.name] = STSCZ_bert_base_multilingual_cased_torch_job.get_results()

# %%
raw_results = []
with io.open(EMBEDDINGS_path + '/results.json', 'r') as f:
    for line in f:
        raw_results.append(json.loads(line))
raw_results
# Out:
# [{'STSCZ_bert-base-multilingual-cased_torch': {'STSCZ': {'headlines': {'pearson': [0.45181167547936035,
#       2.854290863573569e-30],
#      'spearman': [0.509163722179652, 2.9853923460035995e-39],
#      'nsamples': 575},
#     'images': {'pearson': [0.43734476852886184, 5.049647454736709e-41],
#      'spearman': [0.539174813744424, 2.845041547860588e-65],
#      'nsamples': 850},
#     'all': {'pearson': {'mean': 0.4445782220041111,
#       'wmean': 0.44318229238608053},
#      'spearman': {'mean': 0.524169267962038, 'wmean': 0.5270650750428493}}}}},
#  {'STSCZ2_bert-base-multilingual-cased_torch': {'STSCZ2': {'headlines': {'pearson': [0.38382098407064996,
#       1.272624384364285e-21],
#      'spearman': [0.4257876270230112, 1.0026060356177619e-26],
#      'nsamples': 575},
#     'images': {'pearson': [0.3982399674501556, 1.088782977184562e-33],
#      'spearman': [0.4543518361367437, 1.5890018878238387e-44],
#      'nsamples': 850},
#     'all': {'pearson': {'mean': 0.3910304757604028,
#       'wmean': 0.39242178117421467},
#      'spearman': {'mean': 0.44006973157987744,
#       'wmean': 0.4428259271961148}}}}},
#  {'STSCZ_multi_cased_L-12_H-768_A-12_torch': {'STSCZ': {'headlines': {'pearson': [0.5101076658989366,
#       2.0534831136245208e-39],
#      'spearman': [0.5523454236645796, 3.105297653554739e-47],
#      'nsamples': 575},
#     'images': {'pearson': [0.5300776517070618, 9.322986813324278e-63],
#      'spearman': [0.5925229440467971, 1.076577551080529e-81],
#      'nsamples': 850},
#     'all': {'pearson': {'mean': 0.5200926588029993,
#       'wmean': 0.5220195872581692},
#      'spearman': {'mean': 0.5724341838556883, 'wmean': 0.576310962138183}}}}},
#  {'STSCZ2_multi_cased_L-12_H-768_A-12_torch': {'STSCZ2': {'headlines': {'pearson': [0.5544278878699856,
#       1.1943206070235641e-47],
#      'spearman': [0.5624157871569156, 2.8700587859568032e-49],
#      'nsamples': 575},
#     'images': {'pearson': [0.6128901535718398, 8.232390899028563e-89],
#      'spearman': [0.635210520451141, 3.1269343430443696e-97],
#      'nsamples': 850},
#     'all': {'pearson': {'mean': 0.5836590207209127,
#       'wmean': 0.5893001165342495},
#      'spearman': {'mean': 0.5988131538040283, 'wmean': 0.605837207016629}}}}},
#  {'STSCZ_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_torch': {'STSCZ': {'headlines': {'pearson': [0.5250992742990885,
#       4.59294727664545e-42],
#      'spearman': [0.5596413291539634, 1.0599526893408327e-48],
#      'nsamples': 575},
#     'images': {'pearson': [0.5180317559416066, 1.5302798780388756e-59],
#      'spearman': [0.5788123364431161, 3.498461796319507e-77],
#      'nsamples': 850},
#     'all': {'pearson': {'mean': 0.5215655151203475,
#       'wmean': 0.5208835615946257},
#      'spearman': {'mean': 0.5692268327985397, 'wmean': 0.5710766668352124}}}}},
#  {'STSCZ2_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_torch': {'STSCZ2': {'headlines': {'pearson': [0.5340470627349253,
#       1.0375334885774865e-43],
#      'spearman': [0.541701348093774, 3.7004423685046276e-45],
#      'nsamples': 575},
#     'images': {'pearson': [0.5726332037719152, 3.2230052479298675e-75],
#      'spearman': [0.6011994950572622, 1.156065681677813e-84],
#      'nsamples': 850},
#     'all': {'pearson': {'mean': 0.5533401332534202,
#       'wmean': 0.5570633573885684},
#      'spearman': {'mean': 0.5714504215755181, 'wmean': 0.5771914708439249}}}}},
#  {'STSCZ2_multi_cased_L-12_H-768_A-12_mean_pooled_torch': {'STSCZ2': {'headlines': {'pearson': [0.558530011585776,
#       1.7826338167991827e-48],
#      'spearman': [0.563151152736174, 2.0258318063795265e-49],
#      'nsamples': 575},
#     'images': {'pearson': [0.6273688052337666, 3.4021270359198095e-94],
#      'spearman': [0.6455169235005342, 2.3317744424249662e-101],
#      'nsamples': 850},
#     'all': {'pearson': {'mean': 0.5929494084097713,
#       'wmean': 0.5995917481477353},
#      'spearman': {'mean': 0.6043340381183542, 'wmean': 0.6122816124903538}}}}},
#  {'STSCZ_multi_cased_L-12_H-768_A-12_mean_pooled_torch': {'STSCZ': {'headlines': {'pearson': [0.5020967154907711,
#       4.738714900955174e-38],
#      'spearman': [0.5593170350255514, 1.2338383169105442e-48],
#      'nsamples': 575},
#     'images': {'pearson': [0.5589500586797128, 5.161686863097684e-71],
#      'spearman': [0.6097894674102017, 1.077548093424233e-87],
#      'nsamples': 850},
#     'all': {'pearson': {'mean': 0.5305233870852419,
#       'wmean': 0.5360092359894381},
#      'spearman': {'mean': 0.5845532512178766, 'wmean': 0.5894233982023603}}}}},
#  {'STS16_bert-base-cased_mean_pooled_torch': {'STS16': {'answer-answer': {'pearson': [0.32110346404764606,
#       1.6814153533209378e-07],
#      'spearman': [0.3751744218750229, 6.537125413890069e-10],
#      'nsamples': 254},
#     'headlines': {'pearson': [0.5421631916919518, 1.9897402815149126e-20],
#      'spearman': [0.6168922308032694, 1.6764839523992787e-27],
#      'nsamples': 249},
#     'plagiarism': {'pearson': [0.4900225542310833, 2.6995446608184965e-15],
#      'spearman': [0.5088572683951347, 1.4935642762647775e-16],
#      'nsamples': 230},
#     'postediting': {'pearson': [0.3969384066508668, 1.236012143298513e-10],
#      'spearman': [0.7322140978055455, 2.995860983837213e-42],
#      'nsamples': 244},
#     'question-question': {'pearson': [0.24207225186486922,
#       0.0004135599851528423],
#      'spearman': [0.30169321607902844, 9.027432895757852e-06],
#      'nsamples': 209},
#     'all': {'pearson': {'mean': 0.3984599736972834,
#       'wmean': 0.40194787009706273},
#      'spearman': {'mean': 0.5069662469916002, 'wmean': 0.5123539311823111}}}}},
#  {'STS16_bert-base-cased_torch': {'STS16': {'answer-answer': {'pearson': [0.3531108035612372,
#       7.148159624073278e-09],
#      'spearman': [0.3948697595833895, 6.602986415547235e-11],
#      'nsamples': 254},
#     'headlines': {'pearson': [0.5892013636320054, 1.149333186897537e-24],
#      'spearman': [0.6284451736039791, 9.037828181712479e-29],
#      'nsamples': 249},
#     'plagiarism': {'pearson': [0.4357427632627837, 4.473836994859913e-12],
#      'spearman': [0.5561956360797917, 4.4494555238689656e-20],
#      'nsamples': 230},
#     'postediting': {'pearson': [0.4218221282547021, 6.0297624278997545e-12],
#      'spearman': [0.7468032838634672, 9.224173490233604e-45],
#      'nsamples': 244},
#     'question-question': {'pearson': [0.24391960688286882,
#       0.00037217708397526073],
#      'spearman': [0.2798099966097731, 4.0753309555780803e-05],
#      'nsamples': 209},
#     'all': {'pearson': {'mean': 0.4087593331187194,
#       'wmean': 0.4135968940404981},
#      'spearman': {'mean': 0.5212247699480801, 'wmean': 0.5273229797757608}}}}},
#  {'STS162_bert-base-cased_torch': {'STS162': {'answer-answer': {'pearson': [0.3760310146895078,
#       5.935410067050635e-10],
#      'spearman': [0.40001297415205916, 3.5374629184793124e-11],
#      'nsamples': 254},
#     'headlines': {'pearson': [0.5036459855635268, 2.0219645721518128e-17],
#      'spearman': [0.5056978395823368, 1.428961297341267e-17],
#      'nsamples': 249},
#     'plagiarism': {'pearson': [0.6131590669704027, 3.852471282985387e-25],
#      'spearman': [0.6668246664170382, 5.974643730124522e-31],
#      'nsamples': 230},
#     'postediting': {'pearson': [0.7019757556504326, 1.5532772728688603e-37],
#      'spearman': [0.7637626994830876, 6.603689616359677e-48],
#      'nsamples': 244},
#     'question-question': {'pearson': [0.06937425637682093, 0.318221115521911],
#      'spearman': [0.116497183169029, 0.09299546063963784],
#      'nsamples': 209},
#     'all': {'pearson': {'mean': 0.4528372158501381,
#       'wmean': 0.4618276707429232},
#      'spearman': {'mean': 0.4905590725607102,
#       'wmean': 0.49881765659590555}}}}},
#  {'STS162_bert-base-cased_mean_pooled_torch': {'STS162': {'answer-answer': {'pearson': [0.5550939755708896,
#       6.249200759095932e-22],
#      'spearman': [0.569130625791919, 3.331910569319697e-23],
#      'nsamples': 254},
#     'headlines': {'pearson': [0.6334819915268047, 2.4335892711056615e-29],
#      'spearman': [0.6396281950965452, 4.748092819529793e-30],
#      'nsamples': 249},
#     'plagiarism': {'pearson': [0.7655284968786941, 1.4831953871553005e-45],
#      'spearman': [0.7828603033522973, 6.970649011429045e-49],
#      'nsamples': 230},
#     'postediting': {'pearson': [0.8022864710063166, 3.7962941045441648e-56],
#      'spearman': [0.8300453439104866, 2.6173818814507954e-63],
#      'nsamples': 244},
#     'question-question': {'pearson': [0.45670528209797157,
#       3.642326627461808e-12],
#      'spearman': [0.43585629590739194, 4.221429214501767e-11],
#      'nsamples': 209},
#     'all': {'pearson': {'mean': 0.6426192434161353,
#       'wmean': 0.6458783666537076},
#      'spearman': {'mean': 0.651504152811728, 'wmean': 0.6555729334401511}}}}},
#  {'STSCZ_bert-base-multilingual-cased_torch_headlines': {'STSCZ': {'headlines': {'pearson': [0.45181167547936035,
#       2.854290863573569e-30],
#      'spearman': [0.509163722179652, 2.9853923460035995e-39],
#      'nsamples': 575},
#     'images': {'pearson': [0.016953513009774122, 0.6216002154410325],
#      'spearman': [0.2976376987095722, 7.54796561832515e-19],
#      'nsamples': 850},
#     'all': {'pearson': {'mean': 0.23438259424456723,
#       'wmean': 0.19242259611153698},
#      'spearman': {'mean': 0.4034007104446121,
#       'wmean': 0.38299030467118333}}}}},
#  {'STSCZ_bert-base-multilingual-cased_torch_all': {'STSCZ': {'headlines': {'pearson': [0.45181167547936035,
#       2.854290863573569e-30],
#      'spearman': [0.509163722179652, 2.9853923460035995e-39],
#      'nsamples': 575},
#     'headlines2013-2015CZ_Lemma': {'pearson': [0.4150248298334991,
#       2.397838092073334e-25],
#      'spearman': [0.4703661077927978, 5.420967380805618e-33],
#      'nsamples': 575},
#     'headlines2013-2015CZ_POSTag': {'pearson': [0.24801205708553467,
#       1.6536787475919304e-09],
#      'spearman': [0.3215429541505239, 2.691886726587671e-15],
#      'nsamples': 575},
#     'headlines2013-2015CZ_Stem': {'pearson': [0.4073203804950766,
#       2.1703777979810177e-24],
#      'spearman': [0.5018061103883155, 5.301940251759242e-38],
#      'nsamples': 575},
#     'images': {'pearson': [0.43734476852886184, 5.049647454736709e-41],
#      'spearman': [0.539174813744424, 2.845041547860588e-65],
#      'nsamples': 850},
#     'imagesCZ2014-2015shuffled': {'pearson': [0.4373447685288619,
#       5.049647454736709e-41],
#      'spearman': [0.539174813744424, 2.845041547860588e-65],
#      'nsamples': 850},
#     'imagesCZ2014-2015shuffled_Lemma': {'pearson': [0.48246330212387195,
#       9.135343935005096e-51],
#      'spearman': [0.552713600961128, 3.6730690900003224e-69],
#      'nsamples': 850},
#     'imagesCZ2014-2015shuffled_POSTag': {'pearson': [0.36082666389871754,
#       1.5547674376319544e-27],
#      'spearman': [0.4141248800287106, 1.4934946611193519e-36],
#      'nsamples': 850},
#     'imagesCZ2014-2015shuffled_Stem': {'pearson': [0.5266408527353151,
#       7.94517592272987e-62],
#      'spearman': [0.6054160139089552, 3.863218562393235e-86],
#      'nsamples': 850},
#     'all': {'pearson': {'mean': 0.418532144301011,
#       'wmean': 0.42491212894763813},
#      'spearman': {'mean': 0.4948314463221034, 'wmean': 0.5022395218890819}}}}},
#  {'STSCZ2_bert-base-multilingual-cased_torch_all': {'STSCZ2': {'headlines': {'pearson': [0.38382098407064996,
#       1.272624384364285e-21],
#      'spearman': [0.4257876270230112, 1.0026060356177619e-26],
#      'nsamples': 575},
#     'headlines2013-2015CZ_Lemma': {'pearson': [0.37420771967025546,
#       1.4938262952177982e-20],
#      'spearman': [0.40877152913396725, 1.4395697398347397e-24],
#      'nsamples': 575},
#     'headlines2013-2015CZ_POSTag': {'pearson': [0.24717603885372336,
#       1.8824264666906744e-09],
#      'spearman': [0.2812520375355312, 6.481817053923247e-12],
#      'nsamples': 575},
#     'headlines2013-2015CZ_Stem': {'pearson': [0.3962545288842209,
#       4.652956897964154e-23],
#      'spearman': [0.41891927731572953, 7.703530735021434e-26],
#      'nsamples': 575},
#     'images': {'pearson': [0.3982399674501556, 1.088782977184562e-33],
#      'spearman': [0.4543518361367437, 1.5890018878238387e-44],
#      'nsamples': 850},
#     'imagesCZ2014-2015shuffled': {'pearson': [0.39823996745015566,
#       1.0887829771845003e-33],
#      'spearman': [0.4543518361367437, 1.5890018878238387e-44],
#      'nsamples': 850},
#     'imagesCZ2014-2015shuffled_Lemma': {'pearson': [0.3919903739226422,
#       1.3224031526731955e-32],
#      'spearman': [0.43818568579934736, 3.425491335068501e-41],
#      'nsamples': 850},
#     'imagesCZ2014-2015shuffled_POSTag': {'pearson': [0.32399976126609514,
#       3.167770357374969e-22],
#      'spearman': [0.3858731918134056, 1.447016556735035e-31],
#      'nsamples': 850},
#     'imagesCZ2014-2015shuffled_Stem': {'pearson': [0.45132659947990533,
#       6.897157487274878e-44],
#      'spearman': [0.505983061731143, 1.8804546301508516e-56],
#      'nsamples': 850},
#     'all': {'pearson': {'mean': 0.3739173267830893,
#       'wmean': 0.37787270995938155},
#      'spearman': {'mean': 0.4192751202917358, 'wmean': 0.4252524871304601}}}}},
#  {'STSCZ_multi_cased_L-12_H-768_A-12_mean_pooled_torch_all': {'STSCZ': {'headlines': {'pearson': [0.5020967154907711,
#       4.738714900955174e-38],
#      'spearman': [0.5593170350255514, 1.2338383169105442e-48],
#      'nsamples': 575},
#     'headlines2013-2015CZ_Lemma': {'pearson': [0.4829875732788488,
#       6.098424442828543e-35],
#      'spearman': [0.5440374515295321, 1.3150499898806454e-45],
#      'nsamples': 575},
#     'headlines2013-2015CZ_POSTag': {'pearson': [0.2794474827397236,
#       8.933337395835672e-12],
#      'spearman': [0.33097565989096955, 3.637367809442198e-16],
#      'nsamples': 575},
#     'headlines2013-2015CZ_Stem': {'pearson': [0.5033665476237332,
#       2.897243878712131e-38],
#      'spearman': [0.5548195074622949, 9.971349100510309e-48],
#      'nsamples': 575},
#     'images': {'pearson': [0.5589500586797128, 5.161686863097684e-71],
#      'spearman': [0.6097894674102017, 1.077548093424233e-87],
#      'nsamples': 850},
#     'imagesCZ2014-2015shuffled': {'pearson': [0.558950058679713,
#       5.161686863096951e-71],
#      'spearman': [0.6097894674102017, 1.077548093424233e-87],
#      'nsamples': 850},
#     'imagesCZ2014-2015shuffled_Lemma': {'pearson': [0.6342237892143996,
#       7.621792209406906e-97],
#      'spearman': [0.6718201002450108, 1.1846413289124497e-112],
#      'nsamples': 850},
#     'imagesCZ2014-2015shuffled_POSTag': {'pearson': [0.4314614024130017,
#       7.400400081866647e-40],
#      'spearman': [0.4675910136479867, 2.1603259054104817e-47],
#      'nsamples': 850},
#     'imagesCZ2014-2015shuffled_Stem': {'pearson': [0.6133111200183127,
#       5.793347872366065e-89],
#      'spearman': [0.6609216962734804, 7.799229763547072e-108],
#      'nsamples': 850},
#     'all': {'pearson': {'mean': 0.5071994164598018,
#       'wmean': 0.5181532058253263},
#      'spearman': {'mean': 0.5565623776550255, 'wmean': 0.5665169517917784}}}}},
#  {'STSCZ2_multi_cased_L-12_H-768_A-12_mean_pooled_torch_all': {'STSCZ2': {'headlines': {'pearson': [0.558530011585776,
#       1.7826338167991827e-48],
#      'spearman': [0.563151152736174, 2.0258318063795265e-49],
#      'nsamples': 575},
#     'headlines2013-2015CZ_Lemma': {'pearson': [0.5677451062309433,
#       2.253462932704996e-50],
#      'spearman': [0.5775390247654023, 1.856768354571934e-52],
#      'nsamples': 575},
#     'headlines2013-2015CZ_POSTag': {'pearson': [0.31613694740319875,
#       8.216017919732669e-15],
#      'spearman': [0.3340121509463883, 1.881333777401849e-16],
#      'nsamples': 575},
#     'headlines2013-2015CZ_Stem': {'pearson': [0.5500609215232368,
#       8.790217089249806e-47],
#      'spearman': [0.5576246811887364, 2.7186974099362865e-48],
#      'nsamples': 575},
#     'images': {'pearson': [0.6273688052337666, 3.4021270359198095e-94],
#      'spearman': [0.6455169235005342, 2.3317744424249662e-101],
#      'nsamples': 850},
#     'imagesCZ2014-2015shuffled': {'pearson': [0.6273688052337667,
#       3.4021270359198095e-94],
#      'spearman': [0.6455169235005342, 2.3317744424249662e-101],
#      'nsamples': 850},
#     'imagesCZ2014-2015shuffled_Lemma': {'pearson': [0.6195819994859347,
#       2.898911951647063e-91],
#      'spearman': [0.635206888091879, 3.137225589731125e-97],
#      'nsamples': 850},
#     'imagesCZ2014-2015shuffled_POSTag': {'pearson': [0.4558206945539104,
#       7.749172160365418e-45],
#      'spearman': [0.4817060592450098, 1.3694590407236705e-50],
#      'nsamples': 850},
#     'imagesCZ2014-2015shuffled_Stem': {'pearson': [0.607900498018535,
#       5.091309025872096e-87],
#      'spearman': [0.6339542548596686, 9.716456709198145e-97],
#      'nsamples': 850},
#     'all': {'pearson': {'mean': 0.5478348654743409,
#       'wmean': 0.556184221301426},
#      'spearman': {'mean': 0.5638031176482585, 'wmean': 0.5731609041769595}}}}},
#  {'STSCZ_cc_cs_300_fasttext_sentence': {'STSCZ': {'headlines': {'pearson': [0.5820461373692433,
#       1.9311198812527916e-53],
#      'spearman': [0.5769693605652192, 2.4655284689135243e-52],
#      'nsamples': 575},
#     'headlines2013-2015CZ_Lemma': {'pearson': [0.587485564515748,
#       1.1992911458213011e-54],
#      'spearman': [0.5845739257518789, 5.34297855637833e-54],
#      'nsamples': 575},
#     'headlines2013-2015CZ_POSTag': {'pearson': [0.36263788030530675,
#       2.6002107537234417e-19],
#      'spearman': [0.38619654319028396, 6.837057428838524e-22],
#      'nsamples': 575},
#     'headlines2013-2015CZ_Stem': {'pearson': [0.5735760151895442,
#       1.3198189808421834e-51],
#      'spearman': [0.5614208503802359, 4.591749203002682e-49],
#      'nsamples': 575},
#     'images': {'pearson': [0.704812580513345, 1.3848618673576658e-128],
#      'spearman': [0.7081043087726708, 2.6893604314281973e-130],
#      'nsamples': 850},
#     'imagesCZ2014-2015shuffled': {'pearson': [0.7048125805133452,
#       1.3848618673576658e-128],
#      'spearman': [0.7081043087726708, 2.6893604314281973e-130],
#      'nsamples': 850},
#     'imagesCZ2014-2015shuffled_Lemma': {'pearson': [0.7393735872345127,
#       7.704023662501198e-148],
#      'spearman': [0.7443437789863141, 7.306868277557645e-151],
#      'nsamples': 850},
#     'imagesCZ2014-2015shuffled_POSTag': {'pearson': [0.4423134703370569,
#       5.0179840622483297e-42],
#      'spearman': [0.4804254743436288, 2.7094865799245444e-50],
#      'nsamples': 850},
#     'imagesCZ2014-2015shuffled_Stem': {'pearson': [0.7353753514470425,
#       1.8566456468222726e-145],
#      'spearman': [0.742213429849822, 1.4723375793843887e-149],
#      'nsamples': 850},
#     'all': {'pearson': {'mean': 0.6036036852694605,
#       'wmean': 0.6165630767987659},
#      'spearman': {'mean': 0.6102613311791916, 'wmean': 0.6241954193208734}}}}},
#  {'STSCZ_cc_cs_300_fasttext_word': {'STSCZ': {'headlines': {'pearson': [0.45243410576300863,
#       2.3274827666070004e-30],
#      'spearman': [0.4626670241236353, 7.649139808893686e-32],
#      'nsamples': 575},
#     'headlines2013-2015CZ_Lemma': {'pearson': [0.43930747947377846,
#       1.5756052978792167e-28],
#      'spearman': [0.44202836394592754, 6.676272507672774e-29],
#      'nsamples': 575},
#     'headlines2013-2015CZ_POSTag': {'pearson': [0.23938439723774907,
#       6.155990654999399e-09],
#      'spearman': [0.27689362131245493, 1.4010409884995993e-11],
#      'nsamples': 575},
#     'headlines2013-2015CZ_Stem': {'pearson': [0.41848623090201237,
#       8.746681245770348e-26],
#      'spearman': [0.42283792031852685, 2.4207190230962004e-26],
#      'nsamples': 575},
#     'images': {'pearson': [0.5523616913911996, 4.659975317289405e-69],
#      'spearman': [0.5695330701307794, 3.0073856401921574e-74],
#      'nsamples': 850},
#     'imagesCZ2014-2015shuffled': {'pearson': [0.5523616913911996,
#       4.659975317289405e-69],
#      'spearman': [0.5695330701307794, 3.0073856401921574e-74],
#      'nsamples': 850},
#     'imagesCZ2014-2015shuffled_Lemma': {'pearson': [0.6368556939138795,
#       7.027997924638165e-98],
#      'spearman': [0.6466839561186869, 7.766512106239325e-102],
#      'nsamples': 850},
#     'imagesCZ2014-2015shuffled_POSTag': {'pearson': [0.17169138733392075,
#       4.761225170002821e-07],
#      'spearman': [0.2304541957896072, 1.0411711069945414e-11],
#      'nsamples': 850},
#     'imagesCZ2014-2015shuffled_Stem': {'pearson': [0.6428495593758667,
#       2.8258709682104704e-100],
#      'spearman': [0.6460894261357044, 1.360579221641065e-101],
#      'nsamples': 850},
#     'all': {'pearson': {'mean': 0.45619247075362385,
#       'wmean': 0.46774489199796515},
#      'spearman': {'mean': 0.4740800720006779, 'wmean': 0.4863351366622194}}}}},
#  {'STSCZ2_cc_cs_300_fasttext_sentence': {'STSCZ2': {'headlines': {'pearson': [0.5820461378683905,
#       1.931119393427596e-53],
#      'spearman': [0.5769693059362351, 2.4655954499659657e-52],
#      'nsamples': 575},
#     'headlines2013-2015CZ_Lemma': {'pearson': [0.5874855657237583,
#       1.1992903986512135e-54],
#      'spearman': [0.5845812407435088, 5.323061605156563e-54],
#      'nsamples': 575},
#     'headlines2013-2015CZ_POSTag': {'pearson': [0.3626378777881063,
#       2.6002123373050687e-19],
#      'spearman': [0.3862466529911947, 6.747667061647054e-22],
#      'nsamples': 575},
#     'headlines2013-2015CZ_Stem': {'pearson': [0.5735760143821316,
#       1.3198195046275271e-51],
#      'spearman': [0.5614396649125397, 4.55119260887321e-49],
#      'nsamples': 575},
#     'images': {'pearson': [0.7048125806765313, 1.384861598637031e-128],
#      'spearman': [0.7081043087726708, 2.6893604314281973e-130],
#      'nsamples': 850},
#     'imagesCZ2014-2015shuffled': {'pearson': [0.7048125806765313,
#       1.384861598637031e-128],
#      'spearman': [0.7081043087726708, 2.6893604314281973e-130],
#      'nsamples': 850},
#     'imagesCZ2014-2015shuffled_Lemma': {'pearson': [0.7393735882155084,
#       7.704013199517808e-148],
#      'spearman': [0.7443441885904576, 7.302629298374185e-151],
#      'nsamples': 850},
#     'imagesCZ2014-2015shuffled_POSTag': {'pearson': [0.4423134693402556,
#       5.0179864058840023e-42],
#      'spearman': [0.48081309756277546, 2.204551748562595e-50],
#      'nsamples': 850},
#     'imagesCZ2014-2015shuffled_Stem': {'pearson': [0.7353753528254581,
#       1.85664216807523e-145],
#      'spearman': [0.7422130456360874, 1.473131314342989e-149],
#      'nsamples': 850},
#     'all': {'pearson': {'mean': 0.6036036852774079,
#       'wmean': 0.6165630768759564},
#      'spearman': {'mean': 0.6103128682131267, 'wmean': 0.6242524128351089}}}}},
#  {'STSCZ2_cc_cs_300_fasttext_word': {'STSCZ2': {'headlines': {'pearson': [0.5767938496545317,
#       2.6903203175692284e-52],
#      'spearman': [0.5662250131539256, 4.678368863918498e-50],
#      'nsamples': 575},
#     'headlines2013-2015CZ_Lemma': {'pearson': [0.620097854441282,
#       2.1803935972729474e-62],
#      'spearman': [0.619538975718204, 3.012327944916386e-62],
#      'nsamples': 575},
#     'headlines2013-2015CZ_POSTag': {'pearson': [0.4048563616752499,
#       4.33801867824397e-24],
#      'spearman': [0.4242567089902576, 1.5859346416108124e-26],
#      'nsamples': 575},
#     'headlines2013-2015CZ_Stem': {'pearson': [0.5913218463807428,
#       1.636467714491527e-55],
#      'spearman': [0.5878736844979819, 9.816007703252722e-55],
#      'nsamples': 575},
#     'images': {'pearson': [0.5548804656126964, 8.431523860026883e-70],
#      'spearman': [0.5844975628031199, 5.001224394665181e-79],
#      'nsamples': 850},
#     'imagesCZ2014-2015shuffled': {'pearson': [0.5548659451588897,
#       8.515390503799146e-70],
#      'spearman': [0.5844968976025093, 5.003735297977067e-79],
#      'nsamples': 850},
#     'imagesCZ2014-2015shuffled_Lemma': {'pearson': [0.6074012081481969,
#       7.661724106364479e-87],
#      'spearman': [0.6275360863325707, 2.9368373907941145e-94],
#      'nsamples': 850},
#     'imagesCZ2014-2015shuffled_POSTag': {'pearson': [0.48461036950239644,
#       2.882668780105476e-51],
#      'spearman': [0.5096284296100534, 2.2518755727202835e-57],
#      'nsamples': 850},
#     'imagesCZ2014-2015shuffled_Stem': {'pearson': [0.6028325790730802,
#       3.1183208471869164e-85],
#      'spearman': [0.6184371153239391, 7.694236018979995e-91],
#      'nsamples': 850},
#     'all': {'pearson': {'mean': 0.555295608849674,
#       'wmean': 0.5564759056272152},
#      'spearman': {'mean': 0.5691656082258402, 'wmean': 0.5724726637829888}}}}},
#  {'STS16_cc_en_300_fasttext_sentence': {'STS16': {'answer-answer': {'pearson': [0.3489388038056709,
#       1.1011975021318023e-08],
#      'spearman': [0.4000999456948449, 3.500001868869484e-11],
#      'nsamples': 254},
#     'headlines': {'pearson': [0.6401576283447556, 4.117441200833762e-30],
#      'spearman': [0.6458778887368579, 8.67168824588698e-31],
#      'nsamples': 249},
#     'plagiarism': {'pearson': [0.5665088977043184, 6.360182761365652e-21],
#      'spearman': [0.580781868974906, 3.8407620252615156e-22],
#      'nsamples': 230},
#     'postediting': {'pearson': [0.5887341559442562, 3.736026717110978e-24],
#      'spearman': [0.7292372771506441, 9.307228992240356e-42],
#      'nsamples': 244},
#     'question-question': {'pearson': [0.30097857472393397,
#       9.501628652486875e-06],
#      'spearman': [0.3344035750923563, 7.473758041967051e-07],
#      'nsamples': 209},
#     'all': {'pearson': {'mean': 0.489063612104587,
#       'wmean': 0.4931554875751927},
#      'spearman': {'mean': 0.5380801111299218, 'wmean': 0.5428777851477707}}}}},
#  {'STS16_cc_en_300_fasttext_word': {'STS16': {'answer-answer': {'pearson': [0.18434807394519095,
#       0.003189607186792924],
#      'spearman': [0.25070476391131463, 5.3317975010263185e-05],
#      'nsamples': 254},
#     'headlines': {'pearson': [0.4406466314596257, 2.9867596389026083e-13],
#      'spearman': [0.440220184351843, 3.166659005556519e-13],
#      'nsamples': 249},
#     'plagiarism': {'pearson': [0.28751150543021686, 9.402574508260559e-06],
#      'spearman': [0.3629615524141609, 1.4354400734699763e-08],
#      'nsamples': 230},
#     'postediting': {'pearson': [0.4252609518666171, 3.893884338763317e-12],
#      'spearman': [0.6200986368552872, 2.564532364877301e-27],
#      'nsamples': 244},
#     'question-question': {'pearson': [-0.007292283345907742,
#       0.9165405046070281],
#      'spearman': [0.010006435136935696, 0.8856604843739284],
#      'nsamples': 209},
#     'all': {'pearson': {'mean': 0.26609497587114855,
#       'wmean': 0.27395670598704475},
#      'spearman': {'mean': 0.3367983145339083, 'wmean': 0.345843512081492}}}}},
#  {'STS162_cc_en_300_fasttext_sentence': {'STS162': {'answer-answer': {'pearson': [0.3489387982476427,
#       1.1011981314753832e-08],
#      'spearman': [0.4000999456948449, 3.500001868869484e-11],
#      'nsamples': 254},
#     'headlines': {'pearson': [0.6401576283205536, 4.117441227683796e-30],
#      'spearman': [0.6458783907801084, 8.67049008312231e-31],
#      'nsamples': 249},
#     'plagiarism': {'pearson': [0.566508899062466, 6.36018110348505e-21],
#      'spearman': [0.580781868974906, 3.8407620252615156e-22],
#      'nsamples': 230},
#     'postediting': {'pearson': [0.5887341575324284, 3.736025413459128e-24],
#      'spearman': [0.7292372771506441, 9.307228992240356e-42],
#      'nsamples': 244},
#     'question-question': {'pearson': [0.30097856413038576,
#       9.501635853723448e-06],
#      'spearman': [0.3344035750923563, 7.473758041967051e-07],
#      'nsamples': 209},
#     'all': {'pearson': {'mean': 0.4890636094586953,
#       'wmean': 0.49315548510307705},
#      'spearman': {'mean': 0.538080211538572, 'wmean': 0.542877890551455}}}}},
#  {'STS162_cc_en_300_fasttext_word': {'STS162': {'answer-answer': {'pearson': [0.3603717373295795,
#       3.3190225191758626e-09],
#      'spearman': [0.3770480267775135, 5.290565259287277e-10],
#      'nsamples': 254},
#     'headlines': {'pearson': [0.5480804829777879, 6.33698708617134e-21],
#      'spearman': [0.5444451323168672, 1.2833014349853117e-20],
#      'nsamples': 249},
#     'plagiarism': {'pearson': [0.6431740251760772, 3.016433554005771e-28],
#      'spearman': [0.6489936858725174, 6.863813748491504e-29],
#      'nsamples': 230},
#     'postediting': {'pearson': [0.740355557939472, 1.2466569078097058e-43],
#      'spearman': [0.790012845258126, 2.464893509685889e-53],
#      'nsamples': 244},
#     'question-question': {'pearson': [0.08615934376826677,
#       0.21481680710414694],
#      'spearman': [0.0868219577462059, 0.2112978929850528],
#      'nsamples': 209},
#     'all': {'pearson': {'mean': 0.4756282294382366,
#       'wmean': 0.4844776950408762},
#      'spearman': {'mean': 0.489464329594246, 'wmean': 0.4987474771593651}}}}},
#  {'STSCZ_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_mean_pooled_torch_all': {'STSCZ': {'headlines': {'pearson': [0.5125391564169962,
#       7.78994290633095e-40],
#      'spearman': [0.5566681996597297, 4.2403864449027674e-48],
#      'nsamples': 575},
#     'headlines2013-2015CZ_Lemma': {'pearson': [0.5167208035265121,
#       1.444077918028924e-40],
#      'spearman': [0.5629857433174792, 2.1911203934133332e-49],
#      'nsamples': 575},
#     'headlines2013-2015CZ_POSTag': {'pearson': [0.2517572533014806,
#       9.20156501253324e-10],
#      'spearman': [0.3146208887132803, 1.1189398957422662e-14],
#      'nsamples': 575},
#     'headlines2013-2015CZ_Stem': {'pearson': [0.49729705576546285,
#       2.987074366347959e-37],
#      'spearman': [0.5576539742725513, 2.6818768187955295e-48],
#      'nsamples': 575},
#     'images': {'pearson': [0.5151341479034207, 8.691788400825761e-59],
#      'spearman': [0.5796676963996854, 1.856253429442304e-77],
#      'nsamples': 850},
#     'imagesCZ2014-2015shuffled': {'pearson': [0.5151341479034207,
#       8.691788400825761e-59],
#      'spearman': [0.5796676963996854, 1.856253429442304e-77],
#      'nsamples': 850},
#     'imagesCZ2014-2015shuffled_Lemma': {'pearson': [0.5829819924080402,
#       1.564675722772472e-78],
#      'spearman': [0.6433637065049739, 1.7504517558897638e-100],
#      'nsamples': 850},
#     'imagesCZ2014-2015shuffled_POSTag': {'pearson': [0.40898305843998134,
#       1.3116519333726825e-35],
#      'spearman': [0.45214546186241705, 4.64230030734386e-44],
#      'nsamples': 850},
#     'imagesCZ2014-2015shuffled_Stem': {'pearson': [0.5997914463768859,
#       3.5562942033305096e-84],
#      'spearman': [0.6649743152309233, 1.3306970086487442e-109],
#      'nsamples': 850},
#     'all': {'pearson': {'mean': 0.48892656244913346,
#       'wmean': 0.49637431736763304},
#      'spearman': {'mean': 0.545749742484525, 'wmean': 0.5537717722697375}}}}},
#  {'STSCZ2_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_mean_pooled_torch_all': {'STSCZ2': {'headlines': {'pearson': [0.5373962151229553,
#       2.4383861237528887e-44],
#      'spearman': [0.545934972798684, 5.641292571756747e-46],
#      'nsamples': 575},
#     'headlines2013-2015CZ_Lemma': {'pearson': [0.5712144670660695,
#       4.193587511132753e-51],
#      'spearman': [0.5805305905511879, 4.1499390046457424e-53],
#      'nsamples': 575},
#     'headlines2013-2015CZ_POSTag': {'pearson': [0.2864644682129161,
#       2.532606723187987e-12],
#      'spearman': [0.3163042209186031, 7.939872867353916e-15],
#      'nsamples': 575},
#     'headlines2013-2015CZ_Stem': {'pearson': [0.5538488560579653,
#       1.558837462357503e-47],
#      'spearman': [0.5620640682644243, 3.389350177575842e-49],
#      'nsamples': 575},
#     'images': {'pearson': [0.5812975521934144, 5.519731388515483e-78],
#      'spearman': [0.6066048496797043, 1.4681787976389586e-86],
#      'nsamples': 850},
#     'imagesCZ2014-2015shuffled': {'pearson': [0.5812975521934146,
#       5.519731388514228e-78],
#      'spearman': [0.6066048496797043, 1.4681787976389586e-86],
#      'nsamples': 850},
#     'imagesCZ2014-2015shuffled_Lemma': {'pearson': [0.592106116799881,
#       1.4873580332657153e-81],
#      'spearman': [0.6083225101535554, 3.6021196498727563e-87],
#      'nsamples': 850},
#     'imagesCZ2014-2015shuffled_POSTag': {'pearson': [0.4511146843189074,
#       7.639938983537043e-44],
#      'spearman': [0.47125912619517135, 3.2943796183918465e-48],
#      'nsamples': 850},
#     'imagesCZ2014-2015shuffled_Stem': {'pearson': [0.6078138271687633,
#       5.46592297385187e-87],
#      'spearman': [0.6359881497473486, 1.5459040724569876e-97],
#      'nsamples': 850},
#     'all': {'pearson': {'mean': 0.5291726376815874,
#       'wmean': 0.5362162712194914},
#      'spearman': {'mean': 0.5481792597764872, 'wmean': 0.5560674851669586}}}}},
#  {'STSCZ_wiki_cs_300_fasttext_sentence': {'STSCZ': {'headlines': {'pearson': [0.6458306696096886,
#       3.587471181759894e-69],
#      'spearman': [0.6407838171352014, 8.640990226803496e-68],
#      'nsamples': 575},
#     'headlines2013-2015CZ_Lemma': {'pearson': [0.612050388203227,
#       2.1514748062402092e-60],
#      'spearman': [0.6181317050819604, 6.777963186032025e-62],
#      'nsamples': 575},
#     'headlines2013-2015CZ_POSTag': {'pearson': [0.3868785145953727,
#       5.714762759102055e-22],
#      'spearman': [0.41057500953931547, 8.618212494184426e-25],
#      'nsamples': 575},
#     'headlines2013-2015CZ_Stem': {'pearson': [0.6306228536559314,
#       4.377368749861743e-65],
#      'spearman': [0.6313618452104776, 2.804821185695657e-65],
#      'nsamples': 575},
#     'images': {'pearson': [0.7018580923853577, 4.5467488544723494e-127],
#      'spearman': [0.7091848845708458, 7.286236004064457e-131],
#      'nsamples': 850},
#     'imagesCZ2014-2015shuffled': {'pearson': [0.7018580923853578,
#       4.546748854471315e-127],
#      'spearman': [0.7091848845708458, 7.286236004064457e-131],
#      'nsamples': 850},
#     'imagesCZ2014-2015shuffled_Lemma': {'pearson': [0.735999712847127,
#       7.936366299283808e-146],
#      'spearman': [0.7415265221680057, 3.8530774602972414e-149],
#      'nsamples': 850},
#     'imagesCZ2014-2015shuffled_POSTag': {'pearson': [0.45349860383880175,
#       2.4076090432006873e-44],
#      'spearman': [0.4917289446750187, 5.932883171056722e-53],
#      'nsamples': 850},
#     'imagesCZ2014-2015shuffled_Stem': {'pearson': [0.7577233822197231,
#       2.316471265275101e-159],
#      'spearman': [0.7636159369930806, 2.7783739214591352e-163],
#      'nsamples': 850},
#     'all': {'pearson': {'mean': 0.6251467010822874,
#       'wmean': 0.6346018467346318},
#      'spearman': {'mean': 0.6351215055494168, 'wmean': 0.645182460120172}}}}},
#  {'STSCZ_wiki_cs_300_fasttext_word': {'STSCZ': {'headlines': {'pearson': [0.6286271983412663,
#       1.4475576019259406e-64],
#      'spearman': [0.6145092474484171, 5.364427220120675e-61],
#      'nsamples': 575},
#     'headlines2013-2015CZ_Lemma': {'pearson': [0.6280712234124126,
#       2.0168292310796724e-64],
#      'spearman': [0.6182545296990112, 6.315839602746647e-62],
#      'nsamples': 575},
#     'headlines2013-2015CZ_POSTag': {'pearson': [0.2755796463719494,
#       1.7628597442195736e-11],
#      'spearman': [0.2951501241780452, 5.063394326043467e-13],
#      'nsamples': 575},
#     'headlines2013-2015CZ_Stem': {'pearson': [0.6716863548568717,
#       1.1097406785991446e-76],
#      'spearman': [0.6556696563401583, 6.086625995132441e-72],
#      'nsamples': 575},
#     'images': {'pearson': [0.7296737182595723, 3.903729994608591e-142],
#      'spearman': [0.7338931190817919, 1.382923042414908e-144],
#      'nsamples': 850},
#     'imagesCZ2014-2015shuffled': {'pearson': [0.7296737182595725,
#       3.903729994608591e-142],
#      'spearman': [0.7338931190817919, 1.382923042414908e-144],
#      'nsamples': 850},
#     'imagesCZ2014-2015shuffled_Lemma': {'pearson': [0.7802867430497888,
#       5.00990447806585e-175],
#      'spearman': [0.7844706105819272, 3.88561320803869e-178],
#      'nsamples': 850},
#     'imagesCZ2014-2015shuffled_POSTag': {'pearson': [0.25065664033570695,
#       1.2090909704956186e-13],
#      'spearman': [0.29213306049049287, 3.47120042438679e-18],
#      'nsamples': 850},
#     'imagesCZ2014-2015shuffled_Stem': {'pearson': [0.7909716516639285,
#       4.128210674722358e-183],
#      'spearman': [0.7963959543990607, 2.128642950321615e-187],
#      'nsamples': 850},
#     'all': {'pearson': {'mean': 0.6094696549501187,
#       'wmean': 0.6192904800073621},
#      'spearman': {'mean': 0.6138188245889662, 'wmean': 0.6252257297324494}}}}},
#  {'STSCZ2_wiki_cs_300_fasttext_sentence': {'STSCZ2': {'headlines': {'pearson': [0.6458306696175045,
#       3.587471163915819e-69],
#      'spearman': [0.6407837867996465, 8.641153929550116e-68],
#      'nsamples': 575},
#     'headlines2013-2015CZ_Lemma': {'pearson': [0.6120503889054463,
#       2.1514739565731116e-60],
#      'spearman': [0.6181544233544137, 6.690024327727067e-62],
#      'nsamples': 575},
#     'headlines2013-2015CZ_POSTag': {'pearson': [0.3868785144176036,
#       5.714763026518505e-22],
#      'spearman': [0.41038312114653325, 9.103095197254672e-25],
#      'nsamples': 575},
#     'headlines2013-2015CZ_Stem': {'pearson': [0.6306228522020187,
#       4.3773725780115575e-65],
#      'spearman': [0.6313921752646786, 2.7539759127873423e-65],
#      'nsamples': 575},
#     'images': {'pearson': [0.7018580923878125, 4.546748841363884e-127],
#      'spearman': [0.7091848845708458, 7.286236004064457e-131],
#      'nsamples': 850},
#     'imagesCZ2014-2015shuffled': {'pearson': [0.7018580923878122,
#       4.5467488413654345e-127],
#      'spearman': [0.7091848845708458, 7.286236004064457e-131],
#      'nsamples': 850},
#     'imagesCZ2014-2015shuffled_Lemma': {'pearson': [0.7359997150144314,
#       7.936342852046774e-146],
#      'spearman': [0.7415273196145958, 3.8487834629323504e-149],
#      'nsamples': 850},
#     'imagesCZ2014-2015shuffled_POSTag': {'pearson': [0.45349860410064413,
#       2.407608736621139e-44],
#      'spearman': [0.4916190156637625, 6.303959698974724e-53],
#      'nsamples': 850},
#     'imagesCZ2014-2015shuffled_Stem': {'pearson': [0.7577233817099545,
#       2.316473048568603e-159],
#      'spearman': [0.7636134899941573, 2.788963075961417e-163],
#      'nsamples': 850},
#     'all': {'pearson': {'mean': 0.625146701193692,
#       'wmean': 0.6346018469034407},
#      'spearman': {'mean': 0.6350936778866089, 'wmean': 0.6451557895461233}}}}},
#  {'STSCZ2_wiki_cs_300_fasttext_word': {'STSCZ2': {'headlines': {'pearson': [0.60420279620433,
#       1.6707134277662287e-58],
#      'spearman': [0.6000934740648913, 1.5555146586825057e-57],
#      'nsamples': 575},
#     'headlines2013-2015CZ_Lemma': {'pearson': [0.6113611444434196,
#       3.168638989449942e-60],
#      'spearman': [0.6066767435352322, 4.292535202737262e-59],
#      'nsamples': 575},
#     'headlines2013-2015CZ_POSTag': {'pearson': [0.3908428108187229,
#       1.9985047758088178e-22],
#      'spearman': [0.3923237445488398, 1.3447810335327034e-22],
#      'nsamples': 575},
#     'headlines2013-2015CZ_Stem': {'pearson': [0.6108134445641521,
#       4.307106317054289e-60],
#      'spearman': [0.6094717055010657, 9.113227599234875e-60],
#      'nsamples': 575},
#     'images': {'pearson': [0.6772680683392207, 3.860869842382178e-115],
#      'spearman': [0.6839821259051817, 2.7978146625360314e-118],
#      'nsamples': 850},
#     'imagesCZ2014-2015shuffled': {'pearson': [0.6772901914415662,
#       3.7711746976929466e-115],
#      'spearman': [0.6839990298264992, 2.7466709864076103e-118],
#      'nsamples': 850},
#     'imagesCZ2014-2015shuffled_Lemma': {'pearson': [0.6750581923847843,
#       3.998647005989418e-114],
#      'spearman': [0.6830525847607746, 7.701496660613658e-118],
#      'nsamples': 850},
#     'imagesCZ2014-2015shuffled_POSTag': {'pearson': [0.4833751116265437,
#       5.603073733291127e-51],
#      'spearman': [0.49793198446976517, 1.8658605219501352e-54],
#      'nsamples': 850},
#     'imagesCZ2014-2015shuffled_Stem': {'pearson': [0.7113914392947454,
#       4.9686619923375874e-132],
#      'spearman': [0.7196827416897724, 1.635395105461824e-136],
#      'nsamples': 850},
#     'all': {'pearson': {'mean': 0.6046225776797205,
#       'wmean': 0.613072849670449},
#      'spearman': {'mean': 0.6085793482557801, 'wmean': 0.618057474130223}}}}},
#  {'STS16_wiki_cs_300_fasttext_sentence': {'STS16': {'answer-answer': {'pearson': [0.23995709280797442,
#       0.00011246310711919195],
#      'spearman': [0.2719313954499254, 1.1046214842047455e-05],
#      'nsamples': 254},
#     'headlines': {'pearson': [0.5991475800587382, 1.1840756619927356e-25],
#      'spearman': [0.6446634747087941, 1.2104216786371427e-30],
#      'nsamples': 249},
#     'plagiarism': {'pearson': [0.4886277422714877, 3.321580335825171e-15],
#      'spearman': [0.5187306378200451, 3.045298624050369e-17],
#      'nsamples': 230},
#     'postediting': {'pearson': [0.5348062727605822, 1.8759821365809316e-19],
#      'spearman': [0.7374128515808515, 3.987937219184984e-43],
#      'nsamples': 244},
#     'question-question': {'pearson': [0.18455880540218667,
#       0.00746949566148706],
#      'spearman': [0.20476508016435058, 0.002938701693513246],
#      'nsamples': 209},
#     'all': {'pearson': {'mean': 0.4094194986601939,
#       'wmean': 0.4144913580210224},
#      'spearman': {'mean': 0.4755006879447933, 'wmean': 0.4819767823654791}}}}},
#  {'STS16_wiki_cs_300_fasttext_word': {'STS16': {'answer-answer': {'pearson': [0.2099749872211533,
#       0.0007583532209409944],
#      'spearman': [0.2605533619486473, 2.6118389179583894e-05],
#      'nsamples': 254},
#     'headlines': {'pearson': [0.6120752842758558, 5.4686442419782505e-27],
#      'spearman': [0.6405073921520866, 3.746905552141949e-30],
#      'nsamples': 249},
#     'plagiarism': {'pearson': [0.5045992871412172, 2.9188982065753e-16],
#      'spearman': [0.5193969449712086, 2.7303188819245816e-17],
#      'nsamples': 230},
#     'postediting': {'pearson': [0.5499744224242898, 1.0869205703329944e-20],
#      'spearman': [0.7471426062291399, 8.025427879417118e-45],
#      'nsamples': 244},
#     'question-question': {'pearson': [0.21050625631782952,
#       0.002218127569281186],
#      'spearman': [0.23436131446152753, 0.0006366620769744242],
#      'nsamples': 209},
#     'all': {'pearson': {'mean': 0.41742604747606915,
#       'wmean': 0.4215748694968753},
#      'spearman': {'mean': 0.480392323952522, 'wmean': 0.48601391447434505}}}}},
#  {'STS162_wiki_cs_300_fasttext_sentence': {'STS162': {'answer-answer': {'pearson': [0.23995708982819816,
#       0.0001124631298695971],
#      'spearman': [0.2719313954499254, 1.1046214842047455e-05],
#      'nsamples': 254},
#     'headlines': {'pearson': [0.5991475806915812, 1.1840754877743174e-25],
#      'spearman': [0.6446634747087941, 1.2104216786371427e-30],
#      'nsamples': 249},
#     'plagiarism': {'pearson': [0.48862774500418377, 3.321578989492972e-15],
#      'spearman': [0.5187306378200451, 3.045298624050369e-17],
#      'nsamples': 230},
#     'postediting': {'pearson': [0.5348062734239757, 1.8759819087250393e-19],
#      'spearman': [0.7374128515808515, 3.987937219184984e-43],
#      'nsamples': 244},
#     'question-question': {'pearson': [0.18455880077678855,
#       0.007469497181510661],
#      'spearman': [0.20476508016435058, 0.002938701693513246],
#      'nsamples': 209},
#     'all': {'pearson': {'mean': 0.4094194979449455,
#       'wmean': 0.414491357367055},
#      'spearman': {'mean': 0.4755006879447933, 'wmean': 0.4819767823654791}}}}},
#  {'STS162_wiki_cs_300_fasttext_word': {'STS162': {'answer-answer': {'pearson': [0.32601016305496777,
#       1.0603495661903907e-07],
#      'spearman': [0.3565669717979974, 4.973316461156873e-09],
#      'nsamples': 254},
#     'headlines': {'pearson': [0.6269840730630858, 1.3164719638344547e-28],
#      'spearman': [0.6370108112663807, 9.565863215816966e-30],
#      'nsamples': 249},
#     'plagiarism': {'pearson': [0.6623034175641477, 2.0514890279924012e-30],
#      'spearman': [0.6864922499812324, 2.149251654294826e-33],
#      'nsamples': 230},
#     'postediting': {'pearson': [0.766695343904831, 1.7742513748154504e-48],
#      'spearman': [0.8256500719837734, 4.320332385032603e-62],
#      'nsamples': 244},
#     'question-question': {'pearson': [0.4290110963614181,
#       9.106210221564432e-11],
#      'spearman': [0.43785584245234965, 3.361346402191228e-11],
#      'nsamples': 209},
#     'all': {'pearson': {'mean': 0.56220081878969, 'wmean': 0.5632313530360366},
#      'spearman': {'mean': 0.5887151894963466, 'wmean': 0.5902591981233434}}}}},
#  {'STSCZ_elmo_139': {'STSCZ': {'headlines': {'pearson': [0.5147392972800048,
#       3.218800784076569e-40],
#      'spearman': [0.510899959567052, 1.49863590015424e-39],
#      'nsamples': 575},
#     'headlines2013-2015CZ_Lemma': {'pearson': [0.5311890238284899,
#       3.5248293381898782e-43],
#      'spearman': [0.5271051406162605, 1.9830854644388062e-42],
#      'nsamples': 575},
#     'headlines2013-2015CZ_POSTag': {'pearson': [0.1385821411229395,
#       0.0008624221189713498],
#      'spearman': [0.23191813234545391, 1.8445455983267526e-08],
#      'nsamples': 575},
#     'headlines2013-2015CZ_Stem': {'pearson': [0.5119110928299921,
#       1.0013694707212308e-39],
#      'spearman': [0.5106890709388854, 1.6298311219833357e-39],
#      'nsamples': 575},
#     'images': {'pearson': [0.6239431237201327, 6.779461294938793e-93],
#      'spearman': [0.6288396172249616, 9.30743830031751e-95],
#      'nsamples': 850},
#     'imagesCZ2014-2015shuffled': {'pearson': [0.6239431237201327,
#       6.779461294938793e-93],
#      'spearman': [0.6288396172249616, 9.30743830031751e-95],
#      'nsamples': 850},
#     'imagesCZ2014-2015shuffled_Lemma': {'pearson': [0.6804584567497891,
#       1.2740548368548437e-116],
#      'spearman': [0.6917255877107253, 5.229995440413782e-122],
#      'nsamples': 850},
#     'imagesCZ2014-2015shuffled_POSTag': {'pearson': [0.2600290534664051,
#       1.3310293522698567e-14],
#      'spearman': [0.3065667596093388, 5.916574919818481e-20],
#      'nsamples': 850},
#     'imagesCZ2014-2015shuffled_Stem': {'pearson': [0.6236893057858786,
#       8.449499844281885e-93],
#      'spearman': [0.6366849469352678, 8.209162599041034e-98],
#      'nsamples': 850},
#     'all': {'pearson': {'mean': 0.5009427353893072,
#       'wmean': 0.5138467172650851},
#      'spearman': {'mean': 0.5192520924636563, 'wmean': 0.5316962021211247}}}}},
#  {'STSCZ2_elmo_139': {'STSCZ2': {'headlines': {'pearson': [0.27255224235255404,
#       2.9788995283906296e-11],
#      'spearman': [0.28305565593236776, 4.6928600008687685e-12],
#      'nsamples': 575},
#     'headlines2013-2015CZ_Lemma': {'pearson': [0.2840609945925119,
#       3.915754931545367e-12],
#      'spearman': [0.278292326664657, 1.0956297140176624e-11],
#      'nsamples': 575},
#     'headlines2013-2015CZ_POSTag': {'pearson': [0.2329903804685388,
#       1.5791748168036417e-08],
#      'spearman': [0.2590260466174676, 2.8700177513725345e-10],
#      'nsamples': 575},
#     'headlines2013-2015CZ_Stem': {'pearson': [0.1703655048219196,
#       4.0189339480149935e-05],
#      'spearman': [0.1767846846786471, 2.0120556603020266e-05],
#      'nsamples': 575},
#     'images': {'pearson': [0.42321391691747406, 2.9212182211320895e-38],
#      'spearman': [0.42737035817447455, 4.640919313824928e-39],
#      'nsamples': 850},
#     'imagesCZ2014-2015shuffled': {'pearson': [0.4232190622846947,
#       2.914619268636632e-38],
#      'spearman': [0.4273675506366168, 4.646730252733158e-39],
#      'nsamples': 850},
#     'imagesCZ2014-2015shuffled_Lemma': {'pearson': [0.4202086138310282,
#       1.0872574107652364e-37],
#      'spearman': [0.4303735237049103, 1.2087940897535205e-39],
#      'nsamples': 850},
#     'imagesCZ2014-2015shuffled_POSTag': {'pearson': [0.30262663318267763,
#       1.8397141127193628e-19],
#      'spearman': [0.3180284779814953, 1.9756877171941047e-21],
#      'nsamples': 850},
#     'imagesCZ2014-2015shuffled_Stem': {'pearson': [0.36643309026823806,
#       2.088664583648101e-28],
#      'spearman': [0.39780398134790557, 1.2982228593714966e-33],
#      'nsamples': 850},
#     'all': {'pearson': {'mean': 0.32174115985773744,
#       'wmean': 0.33546997928197286},
#      'spearman': {'mean': 0.3331225117487269, 'wmean': 0.3472013081766637}}}}}]

# %%
results = {}
for res in raw_results:
    for x in res:
        results[x] = res[x]
results
# Out:
# {'STSCZ_bert-base-multilingual-cased_torch': {'STSCZ': {'headlines': {'pearson': [0.45181167547936035,
#      2.854290863573569e-30],
#     'spearman': [0.509163722179652, 2.9853923460035995e-39],
#     'nsamples': 575},
#    'images': {'pearson': [0.43734476852886184, 5.049647454736709e-41],
#     'spearman': [0.539174813744424, 2.845041547860588e-65],
#     'nsamples': 850},
#    'all': {'pearson': {'mean': 0.4445782220041111,
#      'wmean': 0.44318229238608053},
#     'spearman': {'mean': 0.524169267962038, 'wmean': 0.5270650750428493}}}},
#  'STSCZ2_bert-base-multilingual-cased_torch': {'STSCZ2': {'headlines': {'pearson': [0.38382098407064996,
#      1.272624384364285e-21],
#     'spearman': [0.4257876270230112, 1.0026060356177619e-26],
#     'nsamples': 575},
#    'images': {'pearson': [0.3982399674501556, 1.088782977184562e-33],
#     'spearman': [0.4543518361367437, 1.5890018878238387e-44],
#     'nsamples': 850},
#    'all': {'pearson': {'mean': 0.3910304757604028,
#      'wmean': 0.39242178117421467},
#     'spearman': {'mean': 0.44006973157987744, 'wmean': 0.4428259271961148}}}},
#  'STSCZ_multi_cased_L-12_H-768_A-12_torch': {'STSCZ': {'headlines': {'pearson': [0.5101076658989366,
#      2.0534831136245208e-39],
#     'spearman': [0.5523454236645796, 3.105297653554739e-47],
#     'nsamples': 575},
#    'images': {'pearson': [0.5300776517070618, 9.322986813324278e-63],
#     'spearman': [0.5925229440467971, 1.076577551080529e-81],
#     'nsamples': 850},
#    'all': {'pearson': {'mean': 0.5200926588029993,
#      'wmean': 0.5220195872581692},
#     'spearman': {'mean': 0.5724341838556883, 'wmean': 0.576310962138183}}}},
#  'STSCZ2_multi_cased_L-12_H-768_A-12_torch': {'STSCZ2': {'headlines': {'pearson': [0.5544278878699856,
#      1.1943206070235641e-47],
#     'spearman': [0.5624157871569156, 2.8700587859568032e-49],
#     'nsamples': 575},
#    'images': {'pearson': [0.6128901535718398, 8.232390899028563e-89],
#     'spearman': [0.635210520451141, 3.1269343430443696e-97],
#     'nsamples': 850},
#    'all': {'pearson': {'mean': 0.5836590207209127,
#      'wmean': 0.5893001165342495},
#     'spearman': {'mean': 0.5988131538040283, 'wmean': 0.605837207016629}}}},
#  'STSCZ_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_torch': {'STSCZ': {'headlines': {'pearson': [0.5250992742990885,
#      4.59294727664545e-42],
#     'spearman': [0.5596413291539634, 1.0599526893408327e-48],
#     'nsamples': 575},
#    'images': {'pearson': [0.5180317559416066, 1.5302798780388756e-59],
#     'spearman': [0.5788123364431161, 3.498461796319507e-77],
#     'nsamples': 850},
#    'all': {'pearson': {'mean': 0.5215655151203475,
#      'wmean': 0.5208835615946257},
#     'spearman': {'mean': 0.5692268327985397, 'wmean': 0.5710766668352124}}}},
#  'STSCZ2_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_torch': {'STSCZ2': {'headlines': {'pearson': [0.5340470627349253,
#      1.0375334885774865e-43],
#     'spearman': [0.541701348093774, 3.7004423685046276e-45],
#     'nsamples': 575},
#    'images': {'pearson': [0.5726332037719152, 3.2230052479298675e-75],
#     'spearman': [0.6011994950572622, 1.156065681677813e-84],
#     'nsamples': 850},
#    'all': {'pearson': {'mean': 0.5533401332534202,
#      'wmean': 0.5570633573885684},
#     'spearman': {'mean': 0.5714504215755181, 'wmean': 0.5771914708439249}}}},
#  'STSCZ2_multi_cased_L-12_H-768_A-12_mean_pooled_torch': {'STSCZ2': {'headlines': {'pearson': [0.558530011585776,
#      1.7826338167991827e-48],
#     'spearman': [0.563151152736174, 2.0258318063795265e-49],
#     'nsamples': 575},
#    'images': {'pearson': [0.6273688052337666, 3.4021270359198095e-94],
#     'spearman': [0.6455169235005342, 2.3317744424249662e-101],
#     'nsamples': 850},
#    'all': {'pearson': {'mean': 0.5929494084097713,
#      'wmean': 0.5995917481477353},
#     'spearman': {'mean': 0.6043340381183542, 'wmean': 0.6122816124903538}}}},
#  'STSCZ_multi_cased_L-12_H-768_A-12_mean_pooled_torch': {'STSCZ': {'headlines': {'pearson': [0.5020967154907711,
#      4.738714900955174e-38],
#     'spearman': [0.5593170350255514, 1.2338383169105442e-48],
#     'nsamples': 575},
#    'images': {'pearson': [0.5589500586797128, 5.161686863097684e-71],
#     'spearman': [0.6097894674102017, 1.077548093424233e-87],
#     'nsamples': 850},
#    'all': {'pearson': {'mean': 0.5305233870852419,
#      'wmean': 0.5360092359894381},
#     'spearman': {'mean': 0.5845532512178766, 'wmean': 0.5894233982023603}}}},
#  'STS16_bert-base-cased_mean_pooled_torch': {'STS16': {'answer-answer': {'pearson': [0.32110346404764606,
#      1.6814153533209378e-07],
#     'spearman': [0.3751744218750229, 6.537125413890069e-10],
#     'nsamples': 254},
#    'headlines': {'pearson': [0.5421631916919518, 1.9897402815149126e-20],
#     'spearman': [0.6168922308032694, 1.6764839523992787e-27],
#     'nsamples': 249},
#    'plagiarism': {'pearson': [0.4900225542310833, 2.6995446608184965e-15],
#     'spearman': [0.5088572683951347, 1.4935642762647775e-16],
#     'nsamples': 230},
#    'postediting': {'pearson': [0.3969384066508668, 1.236012143298513e-10],
#     'spearman': [0.7322140978055455, 2.995860983837213e-42],
#     'nsamples': 244},
#    'question-question': {'pearson': [0.24207225186486922,
#      0.0004135599851528423],
#     'spearman': [0.30169321607902844, 9.027432895757852e-06],
#     'nsamples': 209},
#    'all': {'pearson': {'mean': 0.3984599736972834,
#      'wmean': 0.40194787009706273},
#     'spearman': {'mean': 0.5069662469916002, 'wmean': 0.5123539311823111}}}},
#  'STS16_bert-base-cased_torch': {'STS16': {'answer-answer': {'pearson': [0.3531108035612372,
#      7.148159624073278e-09],
#     'spearman': [0.3948697595833895, 6.602986415547235e-11],
#     'nsamples': 254},
#    'headlines': {'pearson': [0.5892013636320054, 1.149333186897537e-24],
#     'spearman': [0.6284451736039791, 9.037828181712479e-29],
#     'nsamples': 249},
#    'plagiarism': {'pearson': [0.4357427632627837, 4.473836994859913e-12],
#     'spearman': [0.5561956360797917, 4.4494555238689656e-20],
#     'nsamples': 230},
#    'postediting': {'pearson': [0.4218221282547021, 6.0297624278997545e-12],
#     'spearman': [0.7468032838634672, 9.224173490233604e-45],
#     'nsamples': 244},
#    'question-question': {'pearson': [0.24391960688286882,
#      0.00037217708397526073],
#     'spearman': [0.2798099966097731, 4.0753309555780803e-05],
#     'nsamples': 209},
#    'all': {'pearson': {'mean': 0.4087593331187194,
#      'wmean': 0.4135968940404981},
#     'spearman': {'mean': 0.5212247699480801, 'wmean': 0.5273229797757608}}}},
#  'STS162_bert-base-cased_torch': {'STS162': {'answer-answer': {'pearson': [0.3760310146895078,
#      5.935410067050635e-10],
#     'spearman': [0.40001297415205916, 3.5374629184793124e-11],
#     'nsamples': 254},
#    'headlines': {'pearson': [0.5036459855635268, 2.0219645721518128e-17],
#     'spearman': [0.5056978395823368, 1.428961297341267e-17],
#     'nsamples': 249},
#    'plagiarism': {'pearson': [0.6131590669704027, 3.852471282985387e-25],
#     'spearman': [0.6668246664170382, 5.974643730124522e-31],
#     'nsamples': 230},
#    'postediting': {'pearson': [0.7019757556504326, 1.5532772728688603e-37],
#     'spearman': [0.7637626994830876, 6.603689616359677e-48],
#     'nsamples': 244},
#    'question-question': {'pearson': [0.06937425637682093, 0.318221115521911],
#     'spearman': [0.116497183169029, 0.09299546063963784],
#     'nsamples': 209},
#    'all': {'pearson': {'mean': 0.4528372158501381,
#      'wmean': 0.4618276707429232},
#     'spearman': {'mean': 0.4905590725607102, 'wmean': 0.49881765659590555}}}},
#  'STS162_bert-base-cased_mean_pooled_torch': {'STS162': {'answer-answer': {'pearson': [0.5550939755708896,
#      6.249200759095932e-22],
#     'spearman': [0.569130625791919, 3.331910569319697e-23],
#     'nsamples': 254},
#    'headlines': {'pearson': [0.6334819915268047, 2.4335892711056615e-29],
#     'spearman': [0.6396281950965452, 4.748092819529793e-30],
#     'nsamples': 249},
#    'plagiarism': {'pearson': [0.7655284968786941, 1.4831953871553005e-45],
#     'spearman': [0.7828603033522973, 6.970649011429045e-49],
#     'nsamples': 230},
#    'postediting': {'pearson': [0.8022864710063166, 3.7962941045441648e-56],
#     'spearman': [0.8300453439104866, 2.6173818814507954e-63],
#     'nsamples': 244},
#    'question-question': {'pearson': [0.45670528209797157,
#      3.642326627461808e-12],
#     'spearman': [0.43585629590739194, 4.221429214501767e-11],
#     'nsamples': 209},
#    'all': {'pearson': {'mean': 0.6426192434161353,
#      'wmean': 0.6458783666537076},
#     'spearman': {'mean': 0.651504152811728, 'wmean': 0.6555729334401511}}}},
#  'STSCZ_bert-base-multilingual-cased_torch_headlines': {'STSCZ': {'headlines': {'pearson': [0.45181167547936035,
#      2.854290863573569e-30],
#     'spearman': [0.509163722179652, 2.9853923460035995e-39],
#     'nsamples': 575},
#    'images': {'pearson': [0.016953513009774122, 0.6216002154410325],
#     'spearman': [0.2976376987095722, 7.54796561832515e-19],
#     'nsamples': 850},
#    'all': {'pearson': {'mean': 0.23438259424456723,
#      'wmean': 0.19242259611153698},
#     'spearman': {'mean': 0.4034007104446121, 'wmean': 0.38299030467118333}}}},
#  'STSCZ_bert-base-multilingual-cased_torch_all': {'STSCZ': {'headlines': {'pearson': [0.45181167547936035,
#      2.854290863573569e-30],
#     'spearman': [0.509163722179652, 2.9853923460035995e-39],
#     'nsamples': 575},
#    'headlines2013-2015CZ_Lemma': {'pearson': [0.4150248298334991,
#      2.397838092073334e-25],
#     'spearman': [0.4703661077927978, 5.420967380805618e-33],
#     'nsamples': 575},
#    'headlines2013-2015CZ_POSTag': {'pearson': [0.24801205708553467,
#      1.6536787475919304e-09],
#     'spearman': [0.3215429541505239, 2.691886726587671e-15],
#     'nsamples': 575},
#    'headlines2013-2015CZ_Stem': {'pearson': [0.4073203804950766,
#      2.1703777979810177e-24],
#     'spearman': [0.5018061103883155, 5.301940251759242e-38],
#     'nsamples': 575},
#    'images': {'pearson': [0.43734476852886184, 5.049647454736709e-41],
#     'spearman': [0.539174813744424, 2.845041547860588e-65],
#     'nsamples': 850},
#    'imagesCZ2014-2015shuffled': {'pearson': [0.4373447685288619,
#      5.049647454736709e-41],
#     'spearman': [0.539174813744424, 2.845041547860588e-65],
#     'nsamples': 850},
#    'imagesCZ2014-2015shuffled_Lemma': {'pearson': [0.48246330212387195,
#      9.135343935005096e-51],
#     'spearman': [0.552713600961128, 3.6730690900003224e-69],
#     'nsamples': 850},
#    'imagesCZ2014-2015shuffled_POSTag': {'pearson': [0.36082666389871754,
#      1.5547674376319544e-27],
#     'spearman': [0.4141248800287106, 1.4934946611193519e-36],
#     'nsamples': 850},
#    'imagesCZ2014-2015shuffled_Stem': {'pearson': [0.5266408527353151,
#      7.94517592272987e-62],
#     'spearman': [0.6054160139089552, 3.863218562393235e-86],
#     'nsamples': 850},
#    'all': {'pearson': {'mean': 0.418532144301011,
#      'wmean': 0.42491212894763813},
#     'spearman': {'mean': 0.4948314463221034, 'wmean': 0.5022395218890819}}}},
#  'STSCZ2_bert-base-multilingual-cased_torch_all': {'STSCZ2': {'headlines': {'pearson': [0.38382098407064996,
#      1.272624384364285e-21],
#     'spearman': [0.4257876270230112, 1.0026060356177619e-26],
#     'nsamples': 575},
#    'headlines2013-2015CZ_Lemma': {'pearson': [0.37420771967025546,
#      1.4938262952177982e-20],
#     'spearman': [0.40877152913396725, 1.4395697398347397e-24],
#     'nsamples': 575},
#    'headlines2013-2015CZ_POSTag': {'pearson': [0.24717603885372336,
#      1.8824264666906744e-09],
#     'spearman': [0.2812520375355312, 6.481817053923247e-12],
#     'nsamples': 575},
#    'headlines2013-2015CZ_Stem': {'pearson': [0.3962545288842209,
#      4.652956897964154e-23],
#     'spearman': [0.41891927731572953, 7.703530735021434e-26],
#     'nsamples': 575},
#    'images': {'pearson': [0.3982399674501556, 1.088782977184562e-33],
#     'spearman': [0.4543518361367437, 1.5890018878238387e-44],
#     'nsamples': 850},
#    'imagesCZ2014-2015shuffled': {'pearson': [0.39823996745015566,
#      1.0887829771845003e-33],
#     'spearman': [0.4543518361367437, 1.5890018878238387e-44],
#     'nsamples': 850},
#    'imagesCZ2014-2015shuffled_Lemma': {'pearson': [0.3919903739226422,
#      1.3224031526731955e-32],
#     'spearman': [0.43818568579934736, 3.425491335068501e-41],
#     'nsamples': 850},
#    'imagesCZ2014-2015shuffled_POSTag': {'pearson': [0.32399976126609514,
#      3.167770357374969e-22],
#     'spearman': [0.3858731918134056, 1.447016556735035e-31],
#     'nsamples': 850},
#    'imagesCZ2014-2015shuffled_Stem': {'pearson': [0.45132659947990533,
#      6.897157487274878e-44],
#     'spearman': [0.505983061731143, 1.8804546301508516e-56],
#     'nsamples': 850},
#    'all': {'pearson': {'mean': 0.3739173267830893,
#      'wmean': 0.37787270995938155},
#     'spearman': {'mean': 0.4192751202917358, 'wmean': 0.4252524871304601}}}},
#  'STSCZ_multi_cased_L-12_H-768_A-12_mean_pooled_torch_all': {'STSCZ': {'headlines': {'pearson': [0.5020967154907711,
#      4.738714900955174e-38],
#     'spearman': [0.5593170350255514, 1.2338383169105442e-48],
#     'nsamples': 575},
#    'headlines2013-2015CZ_Lemma': {'pearson': [0.4829875732788488,
#      6.098424442828543e-35],
#     'spearman': [0.5440374515295321, 1.3150499898806454e-45],
#     'nsamples': 575},
#    'headlines2013-2015CZ_POSTag': {'pearson': [0.2794474827397236,
#      8.933337395835672e-12],
#     'spearman': [0.33097565989096955, 3.637367809442198e-16],
#     'nsamples': 575},
#    'headlines2013-2015CZ_Stem': {'pearson': [0.5033665476237332,
#      2.897243878712131e-38],
#     'spearman': [0.5548195074622949, 9.971349100510309e-48],
#     'nsamples': 575},
#    'images': {'pearson': [0.5589500586797128, 5.161686863097684e-71],
#     'spearman': [0.6097894674102017, 1.077548093424233e-87],
#     'nsamples': 850},
#    'imagesCZ2014-2015shuffled': {'pearson': [0.558950058679713,
#      5.161686863096951e-71],
#     'spearman': [0.6097894674102017, 1.077548093424233e-87],
#     'nsamples': 850},
#    'imagesCZ2014-2015shuffled_Lemma': {'pearson': [0.6342237892143996,
#      7.621792209406906e-97],
#     'spearman': [0.6718201002450108, 1.1846413289124497e-112],
#     'nsamples': 850},
#    'imagesCZ2014-2015shuffled_POSTag': {'pearson': [0.4314614024130017,
#      7.400400081866647e-40],
#     'spearman': [0.4675910136479867, 2.1603259054104817e-47],
#     'nsamples': 850},
#    'imagesCZ2014-2015shuffled_Stem': {'pearson': [0.6133111200183127,
#      5.793347872366065e-89],
#     'spearman': [0.6609216962734804, 7.799229763547072e-108],
#     'nsamples': 850},
#    'all': {'pearson': {'mean': 0.5071994164598018,
#      'wmean': 0.5181532058253263},
#     'spearman': {'mean': 0.5565623776550255, 'wmean': 0.5665169517917784}}}},
#  'STSCZ2_multi_cased_L-12_H-768_A-12_mean_pooled_torch_all': {'STSCZ2': {'headlines': {'pearson': [0.558530011585776,
#      1.7826338167991827e-48],
#     'spearman': [0.563151152736174, 2.0258318063795265e-49],
#     'nsamples': 575},
#    'headlines2013-2015CZ_Lemma': {'pearson': [0.5677451062309433,
#      2.253462932704996e-50],
#     'spearman': [0.5775390247654023, 1.856768354571934e-52],
#     'nsamples': 575},
#    'headlines2013-2015CZ_POSTag': {'pearson': [0.31613694740319875,
#      8.216017919732669e-15],
#     'spearman': [0.3340121509463883, 1.881333777401849e-16],
#     'nsamples': 575},
#    'headlines2013-2015CZ_Stem': {'pearson': [0.5500609215232368,
#      8.790217089249806e-47],
#     'spearman': [0.5576246811887364, 2.7186974099362865e-48],
#     'nsamples': 575},
#    'images': {'pearson': [0.6273688052337666, 3.4021270359198095e-94],
#     'spearman': [0.6455169235005342, 2.3317744424249662e-101],
#     'nsamples': 850},
#    'imagesCZ2014-2015shuffled': {'pearson': [0.6273688052337667,
#      3.4021270359198095e-94],
#     'spearman': [0.6455169235005342, 2.3317744424249662e-101],
#     'nsamples': 850},
#    'imagesCZ2014-2015shuffled_Lemma': {'pearson': [0.6195819994859347,
#      2.898911951647063e-91],
#     'spearman': [0.635206888091879, 3.137225589731125e-97],
#     'nsamples': 850},
#    'imagesCZ2014-2015shuffled_POSTag': {'pearson': [0.4558206945539104,
#      7.749172160365418e-45],
#     'spearman': [0.4817060592450098, 1.3694590407236705e-50],
#     'nsamples': 850},
#    'imagesCZ2014-2015shuffled_Stem': {'pearson': [0.607900498018535,
#      5.091309025872096e-87],
#     'spearman': [0.6339542548596686, 9.716456709198145e-97],
#     'nsamples': 850},
#    'all': {'pearson': {'mean': 0.5478348654743409, 'wmean': 0.556184221301426},
#     'spearman': {'mean': 0.5638031176482585, 'wmean': 0.5731609041769595}}}},
#  'STSCZ_cc_cs_300_fasttext_sentence': {'STSCZ': {'headlines': {'pearson': [0.5820461373692433,
#      1.9311198812527916e-53],
#     'spearman': [0.5769693605652192, 2.4655284689135243e-52],
#     'nsamples': 575},
#    'headlines2013-2015CZ_Lemma': {'pearson': [0.587485564515748,
#      1.1992911458213011e-54],
#     'spearman': [0.5845739257518789, 5.34297855637833e-54],
#     'nsamples': 575},
#    'headlines2013-2015CZ_POSTag': {'pearson': [0.36263788030530675,
#      2.6002107537234417e-19],
#     'spearman': [0.38619654319028396, 6.837057428838524e-22],
#     'nsamples': 575},
#    'headlines2013-2015CZ_Stem': {'pearson': [0.5735760151895442,
#      1.3198189808421834e-51],
#     'spearman': [0.5614208503802359, 4.591749203002682e-49],
#     'nsamples': 575},
#    'images': {'pearson': [0.704812580513345, 1.3848618673576658e-128],
#     'spearman': [0.7081043087726708, 2.6893604314281973e-130],
#     'nsamples': 850},
#    'imagesCZ2014-2015shuffled': {'pearson': [0.7048125805133452,
#      1.3848618673576658e-128],
#     'spearman': [0.7081043087726708, 2.6893604314281973e-130],
#     'nsamples': 850},
#    'imagesCZ2014-2015shuffled_Lemma': {'pearson': [0.7393735872345127,
#      7.704023662501198e-148],
#     'spearman': [0.7443437789863141, 7.306868277557645e-151],
#     'nsamples': 850},
#    'imagesCZ2014-2015shuffled_POSTag': {'pearson': [0.4423134703370569,
#      5.0179840622483297e-42],
#     'spearman': [0.4804254743436288, 2.7094865799245444e-50],
#     'nsamples': 850},
#    'imagesCZ2014-2015shuffled_Stem': {'pearson': [0.7353753514470425,
#      1.8566456468222726e-145],
#     'spearman': [0.742213429849822, 1.4723375793843887e-149],
#     'nsamples': 850},
#    'all': {'pearson': {'mean': 0.6036036852694605,
#      'wmean': 0.6165630767987659},
#     'spearman': {'mean': 0.6102613311791916, 'wmean': 0.6241954193208734}}}},
#  'STSCZ_cc_cs_300_fasttext_word': {'STSCZ': {'headlines': {'pearson': [0.45243410576300863,
#      2.3274827666070004e-30],
#     'spearman': [0.4626670241236353, 7.649139808893686e-32],
#     'nsamples': 575},
#    'headlines2013-2015CZ_Lemma': {'pearson': [0.43930747947377846,
#      1.5756052978792167e-28],
#     'spearman': [0.44202836394592754, 6.676272507672774e-29],
#     'nsamples': 575},
#    'headlines2013-2015CZ_POSTag': {'pearson': [0.23938439723774907,
#      6.155990654999399e-09],
#     'spearman': [0.27689362131245493, 1.4010409884995993e-11],
#     'nsamples': 575},
#    'headlines2013-2015CZ_Stem': {'pearson': [0.41848623090201237,
#      8.746681245770348e-26],
#     'spearman': [0.42283792031852685, 2.4207190230962004e-26],
#     'nsamples': 575},
#    'images': {'pearson': [0.5523616913911996, 4.659975317289405e-69],
#     'spearman': [0.5695330701307794, 3.0073856401921574e-74],
#     'nsamples': 850},
#    'imagesCZ2014-2015shuffled': {'pearson': [0.5523616913911996,
#      4.659975317289405e-69],
#     'spearman': [0.5695330701307794, 3.0073856401921574e-74],
#     'nsamples': 850},
#    'imagesCZ2014-2015shuffled_Lemma': {'pearson': [0.6368556939138795,
#      7.027997924638165e-98],
#     'spearman': [0.6466839561186869, 7.766512106239325e-102],
#     'nsamples': 850},
#    'imagesCZ2014-2015shuffled_POSTag': {'pearson': [0.17169138733392075,
#      4.761225170002821e-07],
#     'spearman': [0.2304541957896072, 1.0411711069945414e-11],
#     'nsamples': 850},
#    'imagesCZ2014-2015shuffled_Stem': {'pearson': [0.6428495593758667,
#      2.8258709682104704e-100],
#     'spearman': [0.6460894261357044, 1.360579221641065e-101],
#     'nsamples': 850},
#    'all': {'pearson': {'mean': 0.45619247075362385,
#      'wmean': 0.46774489199796515},
#     'spearman': {'mean': 0.4740800720006779, 'wmean': 0.4863351366622194}}}},
#  'STSCZ2_cc_cs_300_fasttext_sentence': {'STSCZ2': {'headlines': {'pearson': [0.5820461378683905,
#      1.931119393427596e-53],
#     'spearman': [0.5769693059362351, 2.4655954499659657e-52],
#     'nsamples': 575},
#    'headlines2013-2015CZ_Lemma': {'pearson': [0.5874855657237583,
#      1.1992903986512135e-54],
#     'spearman': [0.5845812407435088, 5.323061605156563e-54],
#     'nsamples': 575},
#    'headlines2013-2015CZ_POSTag': {'pearson': [0.3626378777881063,
#      2.6002123373050687e-19],
#     'spearman': [0.3862466529911947, 6.747667061647054e-22],
#     'nsamples': 575},
#    'headlines2013-2015CZ_Stem': {'pearson': [0.5735760143821316,
#      1.3198195046275271e-51],
#     'spearman': [0.5614396649125397, 4.55119260887321e-49],
#     'nsamples': 575},
#    'images': {'pearson': [0.7048125806765313, 1.384861598637031e-128],
#     'spearman': [0.7081043087726708, 2.6893604314281973e-130],
#     'nsamples': 850},
#    'imagesCZ2014-2015shuffled': {'pearson': [0.7048125806765313,
#      1.384861598637031e-128],
#     'spearman': [0.7081043087726708, 2.6893604314281973e-130],
#     'nsamples': 850},
#    'imagesCZ2014-2015shuffled_Lemma': {'pearson': [0.7393735882155084,
#      7.704013199517808e-148],
#     'spearman': [0.7443441885904576, 7.302629298374185e-151],
#     'nsamples': 850},
#    'imagesCZ2014-2015shuffled_POSTag': {'pearson': [0.4423134693402556,
#      5.0179864058840023e-42],
#     'spearman': [0.48081309756277546, 2.204551748562595e-50],
#     'nsamples': 850},
#    'imagesCZ2014-2015shuffled_Stem': {'pearson': [0.7353753528254581,
#      1.85664216807523e-145],
#     'spearman': [0.7422130456360874, 1.473131314342989e-149],
#     'nsamples': 850},
#    'all': {'pearson': {'mean': 0.6036036852774079,
#      'wmean': 0.6165630768759564},
#     'spearman': {'mean': 0.6103128682131267, 'wmean': 0.6242524128351089}}}},
#  'STSCZ2_cc_cs_300_fasttext_word': {'STSCZ2': {'headlines': {'pearson': [0.5767938496545317,
#      2.6903203175692284e-52],
#     'spearman': [0.5662250131539256, 4.678368863918498e-50],
#     'nsamples': 575},
#    'headlines2013-2015CZ_Lemma': {'pearson': [0.620097854441282,
#      2.1803935972729474e-62],
#     'spearman': [0.619538975718204, 3.012327944916386e-62],
#     'nsamples': 575},
#    'headlines2013-2015CZ_POSTag': {'pearson': [0.4048563616752499,
#      4.33801867824397e-24],
#     'spearman': [0.4242567089902576, 1.5859346416108124e-26],
#     'nsamples': 575},
#    'headlines2013-2015CZ_Stem': {'pearson': [0.5913218463807428,
#      1.636467714491527e-55],
#     'spearman': [0.5878736844979819, 9.816007703252722e-55],
#     'nsamples': 575},
#    'images': {'pearson': [0.5548804656126964, 8.431523860026883e-70],
#     'spearman': [0.5844975628031199, 5.001224394665181e-79],
#     'nsamples': 850},
#    'imagesCZ2014-2015shuffled': {'pearson': [0.5548659451588897,
#      8.515390503799146e-70],
#     'spearman': [0.5844968976025093, 5.003735297977067e-79],
#     'nsamples': 850},
#    'imagesCZ2014-2015shuffled_Lemma': {'pearson': [0.6074012081481969,
#      7.661724106364479e-87],
#     'spearman': [0.6275360863325707, 2.9368373907941145e-94],
#     'nsamples': 850},
#    'imagesCZ2014-2015shuffled_POSTag': {'pearson': [0.48461036950239644,
#      2.882668780105476e-51],
#     'spearman': [0.5096284296100534, 2.2518755727202835e-57],
#     'nsamples': 850},
#    'imagesCZ2014-2015shuffled_Stem': {'pearson': [0.6028325790730802,
#      3.1183208471869164e-85],
#     'spearman': [0.6184371153239391, 7.694236018979995e-91],
#     'nsamples': 850},
#    'all': {'pearson': {'mean': 0.555295608849674, 'wmean': 0.5564759056272152},
#     'spearman': {'mean': 0.5691656082258402, 'wmean': 0.5724726637829888}}}},
#  'STS16_cc_en_300_fasttext_sentence': {'STS16': {'answer-answer': {'pearson': [0.3489388038056709,
#      1.1011975021318023e-08],
#     'spearman': [0.4000999456948449, 3.500001868869484e-11],
#     'nsamples': 254},
#    'headlines': {'pearson': [0.6401576283447556, 4.117441200833762e-30],
#     'spearman': [0.6458778887368579, 8.67168824588698e-31],
#     'nsamples': 249},
#    'plagiarism': {'pearson': [0.5665088977043184, 6.360182761365652e-21],
#     'spearman': [0.580781868974906, 3.8407620252615156e-22],
#     'nsamples': 230},
#    'postediting': {'pearson': [0.5887341559442562, 3.736026717110978e-24],
#     'spearman': [0.7292372771506441, 9.307228992240356e-42],
#     'nsamples': 244},
#    'question-question': {'pearson': [0.30097857472393397,
#      9.501628652486875e-06],
#     'spearman': [0.3344035750923563, 7.473758041967051e-07],
#     'nsamples': 209},
#    'all': {'pearson': {'mean': 0.489063612104587, 'wmean': 0.4931554875751927},
#     'spearman': {'mean': 0.5380801111299218, 'wmean': 0.5428777851477707}}}},
#  'STS16_cc_en_300_fasttext_word': {'STS16': {'answer-answer': {'pearson': [0.18434807394519095,
#      0.003189607186792924],
#     'spearman': [0.25070476391131463, 5.3317975010263185e-05],
#     'nsamples': 254},
#    'headlines': {'pearson': [0.4406466314596257, 2.9867596389026083e-13],
#     'spearman': [0.440220184351843, 3.166659005556519e-13],
#     'nsamples': 249},
#    'plagiarism': {'pearson': [0.28751150543021686, 9.402574508260559e-06],
#     'spearman': [0.3629615524141609, 1.4354400734699763e-08],
#     'nsamples': 230},
#    'postediting': {'pearson': [0.4252609518666171, 3.893884338763317e-12],
#     'spearman': [0.6200986368552872, 2.564532364877301e-27],
#     'nsamples': 244},
#    'question-question': {'pearson': [-0.007292283345907742,
#      0.9165405046070281],
#     'spearman': [0.010006435136935696, 0.8856604843739284],
#     'nsamples': 209},
#    'all': {'pearson': {'mean': 0.26609497587114855,
#      'wmean': 0.27395670598704475},
#     'spearman': {'mean': 0.3367983145339083, 'wmean': 0.345843512081492}}}},
#  'STS162_cc_en_300_fasttext_sentence': {'STS162': {'answer-answer': {'pearson': [0.3489387982476427,
#      1.1011981314753832e-08],
#     'spearman': [0.4000999456948449, 3.500001868869484e-11],
#     'nsamples': 254},
#    'headlines': {'pearson': [0.6401576283205536, 4.117441227683796e-30],
#     'spearman': [0.6458783907801084, 8.67049008312231e-31],
#     'nsamples': 249},
#    'plagiarism': {'pearson': [0.566508899062466, 6.36018110348505e-21],
#     'spearman': [0.580781868974906, 3.8407620252615156e-22],
#     'nsamples': 230},
#    'postediting': {'pearson': [0.5887341575324284, 3.736025413459128e-24],
#     'spearman': [0.7292372771506441, 9.307228992240356e-42],
#     'nsamples': 244},
#    'question-question': {'pearson': [0.30097856413038576,
#      9.501635853723448e-06],
#     'spearman': [0.3344035750923563, 7.473758041967051e-07],
#     'nsamples': 209},
#    'all': {'pearson': {'mean': 0.4890636094586953,
#      'wmean': 0.49315548510307705},
#     'spearman': {'mean': 0.538080211538572, 'wmean': 0.542877890551455}}}},
#  'STS162_cc_en_300_fasttext_word': {'STS162': {'answer-answer': {'pearson': [0.3603717373295795,
#      3.3190225191758626e-09],
#     'spearman': [0.3770480267775135, 5.290565259287277e-10],
#     'nsamples': 254},
#    'headlines': {'pearson': [0.5480804829777879, 6.33698708617134e-21],
#     'spearman': [0.5444451323168672, 1.2833014349853117e-20],
#     'nsamples': 249},
#    'plagiarism': {'pearson': [0.6431740251760772, 3.016433554005771e-28],
#     'spearman': [0.6489936858725174, 6.863813748491504e-29],
#     'nsamples': 230},
#    'postediting': {'pearson': [0.740355557939472, 1.2466569078097058e-43],
#     'spearman': [0.790012845258126, 2.464893509685889e-53],
#     'nsamples': 244},
#    'question-question': {'pearson': [0.08615934376826677, 0.21481680710414694],
#     'spearman': [0.0868219577462059, 0.2112978929850528],
#     'nsamples': 209},
#    'all': {'pearson': {'mean': 0.4756282294382366,
#      'wmean': 0.4844776950408762},
#     'spearman': {'mean': 0.489464329594246, 'wmean': 0.4987474771593651}}}},
#  'STSCZ_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_mean_pooled_torch_all': {'STSCZ': {'headlines': {'pearson': [0.5125391564169962,
#      7.78994290633095e-40],
#     'spearman': [0.5566681996597297, 4.2403864449027674e-48],
#     'nsamples': 575},
#    'headlines2013-2015CZ_Lemma': {'pearson': [0.5167208035265121,
#      1.444077918028924e-40],
#     'spearman': [0.5629857433174792, 2.1911203934133332e-49],
#     'nsamples': 575},
#    'headlines2013-2015CZ_POSTag': {'pearson': [0.2517572533014806,
#      9.20156501253324e-10],
#     'spearman': [0.3146208887132803, 1.1189398957422662e-14],
#     'nsamples': 575},
#    'headlines2013-2015CZ_Stem': {'pearson': [0.49729705576546285,
#      2.987074366347959e-37],
#     'spearman': [0.5576539742725513, 2.6818768187955295e-48],
#     'nsamples': 575},
#    'images': {'pearson': [0.5151341479034207, 8.691788400825761e-59],
#     'spearman': [0.5796676963996854, 1.856253429442304e-77],
#     'nsamples': 850},
#    'imagesCZ2014-2015shuffled': {'pearson': [0.5151341479034207,
#      8.691788400825761e-59],
#     'spearman': [0.5796676963996854, 1.856253429442304e-77],
#     'nsamples': 850},
#    'imagesCZ2014-2015shuffled_Lemma': {'pearson': [0.5829819924080402,
#      1.564675722772472e-78],
#     'spearman': [0.6433637065049739, 1.7504517558897638e-100],
#     'nsamples': 850},
#    'imagesCZ2014-2015shuffled_POSTag': {'pearson': [0.40898305843998134,
#      1.3116519333726825e-35],
#     'spearman': [0.45214546186241705, 4.64230030734386e-44],
#     'nsamples': 850},
#    'imagesCZ2014-2015shuffled_Stem': {'pearson': [0.5997914463768859,
#      3.5562942033305096e-84],
#     'spearman': [0.6649743152309233, 1.3306970086487442e-109],
#     'nsamples': 850},
#    'all': {'pearson': {'mean': 0.48892656244913346,
#      'wmean': 0.49637431736763304},
#     'spearman': {'mean': 0.545749742484525, 'wmean': 0.5537717722697375}}}},
#  'STSCZ2_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_mean_pooled_torch_all': {'STSCZ2': {'headlines': {'pearson': [0.5373962151229553,
#      2.4383861237528887e-44],
#     'spearman': [0.545934972798684, 5.641292571756747e-46],
#     'nsamples': 575},
#    'headlines2013-2015CZ_Lemma': {'pearson': [0.5712144670660695,
#      4.193587511132753e-51],
#     'spearman': [0.5805305905511879, 4.1499390046457424e-53],
#     'nsamples': 575},
#    'headlines2013-2015CZ_POSTag': {'pearson': [0.2864644682129161,
#      2.532606723187987e-12],
#     'spearman': [0.3163042209186031, 7.939872867353916e-15],
#     'nsamples': 575},
#    'headlines2013-2015CZ_Stem': {'pearson': [0.5538488560579653,
#      1.558837462357503e-47],
#     'spearman': [0.5620640682644243, 3.389350177575842e-49],
#     'nsamples': 575},
#    'images': {'pearson': [0.5812975521934144, 5.519731388515483e-78],
#     'spearman': [0.6066048496797043, 1.4681787976389586e-86],
#     'nsamples': 850},
#    'imagesCZ2014-2015shuffled': {'pearson': [0.5812975521934146,
#      5.519731388514228e-78],
#     'spearman': [0.6066048496797043, 1.4681787976389586e-86],
#     'nsamples': 850},
#    'imagesCZ2014-2015shuffled_Lemma': {'pearson': [0.592106116799881,
#      1.4873580332657153e-81],
#     'spearman': [0.6083225101535554, 3.6021196498727563e-87],
#     'nsamples': 850},
#    'imagesCZ2014-2015shuffled_POSTag': {'pearson': [0.4511146843189074,
#      7.639938983537043e-44],
#     'spearman': [0.47125912619517135, 3.2943796183918465e-48],
#     'nsamples': 850},
#    'imagesCZ2014-2015shuffled_Stem': {'pearson': [0.6078138271687633,
#      5.46592297385187e-87],
#     'spearman': [0.6359881497473486, 1.5459040724569876e-97],
#     'nsamples': 850},
#    'all': {'pearson': {'mean': 0.5291726376815874,
#      'wmean': 0.5362162712194914},
#     'spearman': {'mean': 0.5481792597764872, 'wmean': 0.5560674851669586}}}},
#  'STSCZ_wiki_cs_300_fasttext_sentence': {'STSCZ': {'headlines': {'pearson': [0.6458306696096886,
#      3.587471181759894e-69],
#     'spearman': [0.6407838171352014, 8.640990226803496e-68],
#     'nsamples': 575},
#    'headlines2013-2015CZ_Lemma': {'pearson': [0.612050388203227,
#      2.1514748062402092e-60],
#     'spearman': [0.6181317050819604, 6.777963186032025e-62],
#     'nsamples': 575},
#    'headlines2013-2015CZ_POSTag': {'pearson': [0.3868785145953727,
#      5.714762759102055e-22],
#     'spearman': [0.41057500953931547, 8.618212494184426e-25],
#     'nsamples': 575},
#    'headlines2013-2015CZ_Stem': {'pearson': [0.6306228536559314,
#      4.377368749861743e-65],
#     'spearman': [0.6313618452104776, 2.804821185695657e-65],
#     'nsamples': 575},
#    'images': {'pearson': [0.7018580923853577, 4.5467488544723494e-127],
#     'spearman': [0.7091848845708458, 7.286236004064457e-131],
#     'nsamples': 850},
#    'imagesCZ2014-2015shuffled': {'pearson': [0.7018580923853578,
#      4.546748854471315e-127],
#     'spearman': [0.7091848845708458, 7.286236004064457e-131],
#     'nsamples': 850},
#    'imagesCZ2014-2015shuffled_Lemma': {'pearson': [0.735999712847127,
#      7.936366299283808e-146],
#     'spearman': [0.7415265221680057, 3.8530774602972414e-149],
#     'nsamples': 850},
#    'imagesCZ2014-2015shuffled_POSTag': {'pearson': [0.45349860383880175,
#      2.4076090432006873e-44],
#     'spearman': [0.4917289446750187, 5.932883171056722e-53],
#     'nsamples': 850},
#    'imagesCZ2014-2015shuffled_Stem': {'pearson': [0.7577233822197231,
#      2.316471265275101e-159],
#     'spearman': [0.7636159369930806, 2.7783739214591352e-163],
#     'nsamples': 850},
#    'all': {'pearson': {'mean': 0.6251467010822874,
#      'wmean': 0.6346018467346318},
#     'spearman': {'mean': 0.6351215055494168, 'wmean': 0.645182460120172}}}},
#  'STSCZ_wiki_cs_300_fasttext_word': {'STSCZ': {'headlines': {'pearson': [0.6286271983412663,
#      1.4475576019259406e-64],
#     'spearman': [0.6145092474484171, 5.364427220120675e-61],
#     'nsamples': 575},
#    'headlines2013-2015CZ_Lemma': {'pearson': [0.6280712234124126,
#      2.0168292310796724e-64],
#     'spearman': [0.6182545296990112, 6.315839602746647e-62],
#     'nsamples': 575},
#    'headlines2013-2015CZ_POSTag': {'pearson': [0.2755796463719494,
#      1.7628597442195736e-11],
#     'spearman': [0.2951501241780452, 5.063394326043467e-13],
#     'nsamples': 575},
#    'headlines2013-2015CZ_Stem': {'pearson': [0.6716863548568717,
#      1.1097406785991446e-76],
#     'spearman': [0.6556696563401583, 6.086625995132441e-72],
#     'nsamples': 575},
#    'images': {'pearson': [0.7296737182595723, 3.903729994608591e-142],
#     'spearman': [0.7338931190817919, 1.382923042414908e-144],
#     'nsamples': 850},
#    'imagesCZ2014-2015shuffled': {'pearson': [0.7296737182595725,
#      3.903729994608591e-142],
#     'spearman': [0.7338931190817919, 1.382923042414908e-144],
#     'nsamples': 850},
#    'imagesCZ2014-2015shuffled_Lemma': {'pearson': [0.7802867430497888,
#      5.00990447806585e-175],
#     'spearman': [0.7844706105819272, 3.88561320803869e-178],
#     'nsamples': 850},
#    'imagesCZ2014-2015shuffled_POSTag': {'pearson': [0.25065664033570695,
#      1.2090909704956186e-13],
#     'spearman': [0.29213306049049287, 3.47120042438679e-18],
#     'nsamples': 850},
#    'imagesCZ2014-2015shuffled_Stem': {'pearson': [0.7909716516639285,
#      4.128210674722358e-183],
#     'spearman': [0.7963959543990607, 2.128642950321615e-187],
#     'nsamples': 850},
#    'all': {'pearson': {'mean': 0.6094696549501187,
#      'wmean': 0.6192904800073621},
#     'spearman': {'mean': 0.6138188245889662, 'wmean': 0.6252257297324494}}}},
#  'STSCZ2_wiki_cs_300_fasttext_sentence': {'STSCZ2': {'headlines': {'pearson': [0.6458306696175045,
#      3.587471163915819e-69],
#     'spearman': [0.6407837867996465, 8.641153929550116e-68],
#     'nsamples': 575},
#    'headlines2013-2015CZ_Lemma': {'pearson': [0.6120503889054463,
#      2.1514739565731116e-60],
#     'spearman': [0.6181544233544137, 6.690024327727067e-62],
#     'nsamples': 575},
#    'headlines2013-2015CZ_POSTag': {'pearson': [0.3868785144176036,
#      5.714763026518505e-22],
#     'spearman': [0.41038312114653325, 9.103095197254672e-25],
#     'nsamples': 575},
#    'headlines2013-2015CZ_Stem': {'pearson': [0.6306228522020187,
#      4.3773725780115575e-65],
#     'spearman': [0.6313921752646786, 2.7539759127873423e-65],
#     'nsamples': 575},
#    'images': {'pearson': [0.7018580923878125, 4.546748841363884e-127],
#     'spearman': [0.7091848845708458, 7.286236004064457e-131],
#     'nsamples': 850},
#    'imagesCZ2014-2015shuffled': {'pearson': [0.7018580923878122,
#      4.5467488413654345e-127],
#     'spearman': [0.7091848845708458, 7.286236004064457e-131],
#     'nsamples': 850},
#    'imagesCZ2014-2015shuffled_Lemma': {'pearson': [0.7359997150144314,
#      7.936342852046774e-146],
#     'spearman': [0.7415273196145958, 3.8487834629323504e-149],
#     'nsamples': 850},
#    'imagesCZ2014-2015shuffled_POSTag': {'pearson': [0.45349860410064413,
#      2.407608736621139e-44],
#     'spearman': [0.4916190156637625, 6.303959698974724e-53],
#     'nsamples': 850},
#    'imagesCZ2014-2015shuffled_Stem': {'pearson': [0.7577233817099545,
#      2.316473048568603e-159],
#     'spearman': [0.7636134899941573, 2.788963075961417e-163],
#     'nsamples': 850},
#    'all': {'pearson': {'mean': 0.625146701193692, 'wmean': 0.6346018469034407},
#     'spearman': {'mean': 0.6350936778866089, 'wmean': 0.6451557895461233}}}},
#  'STSCZ2_wiki_cs_300_fasttext_word': {'STSCZ2': {'headlines': {'pearson': [0.60420279620433,
#      1.6707134277662287e-58],
#     'spearman': [0.6000934740648913, 1.5555146586825057e-57],
#     'nsamples': 575},
#    'headlines2013-2015CZ_Lemma': {'pearson': [0.6113611444434196,
#      3.168638989449942e-60],
#     'spearman': [0.6066767435352322, 4.292535202737262e-59],
#     'nsamples': 575},
#    'headlines2013-2015CZ_POSTag': {'pearson': [0.3908428108187229,
#      1.9985047758088178e-22],
#     'spearman': [0.3923237445488398, 1.3447810335327034e-22],
#     'nsamples': 575},
#    'headlines2013-2015CZ_Stem': {'pearson': [0.6108134445641521,
#      4.307106317054289e-60],
#     'spearman': [0.6094717055010657, 9.113227599234875e-60],
#     'nsamples': 575},
#    'images': {'pearson': [0.6772680683392207, 3.860869842382178e-115],
#     'spearman': [0.6839821259051817, 2.7978146625360314e-118],
#     'nsamples': 850},
#    'imagesCZ2014-2015shuffled': {'pearson': [0.6772901914415662,
#      3.7711746976929466e-115],
#     'spearman': [0.6839990298264992, 2.7466709864076103e-118],
#     'nsamples': 850},
#    'imagesCZ2014-2015shuffled_Lemma': {'pearson': [0.6750581923847843,
#      3.998647005989418e-114],
#     'spearman': [0.6830525847607746, 7.701496660613658e-118],
#     'nsamples': 850},
#    'imagesCZ2014-2015shuffled_POSTag': {'pearson': [0.4833751116265437,
#      5.603073733291127e-51],
#     'spearman': [0.49793198446976517, 1.8658605219501352e-54],
#     'nsamples': 850},
#    'imagesCZ2014-2015shuffled_Stem': {'pearson': [0.7113914392947454,
#      4.9686619923375874e-132],
#     'spearman': [0.7196827416897724, 1.635395105461824e-136],
#     'nsamples': 850},
#    'all': {'pearson': {'mean': 0.6046225776797205, 'wmean': 0.613072849670449},
#     'spearman': {'mean': 0.6085793482557801, 'wmean': 0.618057474130223}}}},
#  'STS16_wiki_cs_300_fasttext_sentence': {'STS16': {'answer-answer': {'pearson': [0.23995709280797442,
#      0.00011246310711919195],
#     'spearman': [0.2719313954499254, 1.1046214842047455e-05],
#     'nsamples': 254},
#    'headlines': {'pearson': [0.5991475800587382, 1.1840756619927356e-25],
#     'spearman': [0.6446634747087941, 1.2104216786371427e-30],
#     'nsamples': 249},
#    'plagiarism': {'pearson': [0.4886277422714877, 3.321580335825171e-15],
#     'spearman': [0.5187306378200451, 3.045298624050369e-17],
#     'nsamples': 230},
#    'postediting': {'pearson': [0.5348062727605822, 1.8759821365809316e-19],
#     'spearman': [0.7374128515808515, 3.987937219184984e-43],
#     'nsamples': 244},
#    'question-question': {'pearson': [0.18455880540218667, 0.00746949566148706],
#     'spearman': [0.20476508016435058, 0.002938701693513246],
#     'nsamples': 209},
#    'all': {'pearson': {'mean': 0.4094194986601939,
#      'wmean': 0.4144913580210224},
#     'spearman': {'mean': 0.4755006879447933, 'wmean': 0.4819767823654791}}}},
#  'STS16_wiki_cs_300_fasttext_word': {'STS16': {'answer-answer': {'pearson': [0.2099749872211533,
#      0.0007583532209409944],
#     'spearman': [0.2605533619486473, 2.6118389179583894e-05],
#     'nsamples': 254},
#    'headlines': {'pearson': [0.6120752842758558, 5.4686442419782505e-27],
#     'spearman': [0.6405073921520866, 3.746905552141949e-30],
#     'nsamples': 249},
#    'plagiarism': {'pearson': [0.5045992871412172, 2.9188982065753e-16],
#     'spearman': [0.5193969449712086, 2.7303188819245816e-17],
#     'nsamples': 230},
#    'postediting': {'pearson': [0.5499744224242898, 1.0869205703329944e-20],
#     'spearman': [0.7471426062291399, 8.025427879417118e-45],
#     'nsamples': 244},
#    'question-question': {'pearson': [0.21050625631782952,
#      0.002218127569281186],
#     'spearman': [0.23436131446152753, 0.0006366620769744242],
#     'nsamples': 209},
#    'all': {'pearson': {'mean': 0.41742604747606915,
#      'wmean': 0.4215748694968753},
#     'spearman': {'mean': 0.480392323952522, 'wmean': 0.48601391447434505}}}},
#  'STS162_wiki_cs_300_fasttext_sentence': {'STS162': {'answer-answer': {'pearson': [0.23995708982819816,
#      0.0001124631298695971],
#     'spearman': [0.2719313954499254, 1.1046214842047455e-05],
#     'nsamples': 254},
#    'headlines': {'pearson': [0.5991475806915812, 1.1840754877743174e-25],
#     'spearman': [0.6446634747087941, 1.2104216786371427e-30],
#     'nsamples': 249},
#    'plagiarism': {'pearson': [0.48862774500418377, 3.321578989492972e-15],
#     'spearman': [0.5187306378200451, 3.045298624050369e-17],
#     'nsamples': 230},
#    'postediting': {'pearson': [0.5348062734239757, 1.8759819087250393e-19],
#     'spearman': [0.7374128515808515, 3.987937219184984e-43],
#     'nsamples': 244},
#    'question-question': {'pearson': [0.18455880077678855,
#      0.007469497181510661],
#     'spearman': [0.20476508016435058, 0.002938701693513246],
#     'nsamples': 209},
#    'all': {'pearson': {'mean': 0.4094194979449455, 'wmean': 0.414491357367055},
#     'spearman': {'mean': 0.4755006879447933, 'wmean': 0.4819767823654791}}}},
#  'STS162_wiki_cs_300_fasttext_word': {'STS162': {'answer-answer': {'pearson': [0.32601016305496777,
#      1.0603495661903907e-07],
#     'spearman': [0.3565669717979974, 4.973316461156873e-09],
#     'nsamples': 254},
#    'headlines': {'pearson': [0.6269840730630858, 1.3164719638344547e-28],
#     'spearman': [0.6370108112663807, 9.565863215816966e-30],
#     'nsamples': 249},
#    'plagiarism': {'pearson': [0.6623034175641477, 2.0514890279924012e-30],
#     'spearman': [0.6864922499812324, 2.149251654294826e-33],
#     'nsamples': 230},
#    'postediting': {'pearson': [0.766695343904831, 1.7742513748154504e-48],
#     'spearman': [0.8256500719837734, 4.320332385032603e-62],
#     'nsamples': 244},
#    'question-question': {'pearson': [0.4290110963614181,
#      9.106210221564432e-11],
#     'spearman': [0.43785584245234965, 3.361346402191228e-11],
#     'nsamples': 209},
#    'all': {'pearson': {'mean': 0.56220081878969, 'wmean': 0.5632313530360366},
#     'spearman': {'mean': 0.5887151894963466, 'wmean': 0.5902591981233434}}}},
#  'STSCZ_elmo_139': {'STSCZ': {'headlines': {'pearson': [0.5147392972800048,
#      3.218800784076569e-40],
#     'spearman': [0.510899959567052, 1.49863590015424e-39],
#     'nsamples': 575},
#    'headlines2013-2015CZ_Lemma': {'pearson': [0.5311890238284899,
#      3.5248293381898782e-43],
#     'spearman': [0.5271051406162605, 1.9830854644388062e-42],
#     'nsamples': 575},
#    'headlines2013-2015CZ_POSTag': {'pearson': [0.1385821411229395,
#      0.0008624221189713498],
#     'spearman': [0.23191813234545391, 1.8445455983267526e-08],
#     'nsamples': 575},
#    'headlines2013-2015CZ_Stem': {'pearson': [0.5119110928299921,
#      1.0013694707212308e-39],
#     'spearman': [0.5106890709388854, 1.6298311219833357e-39],
#     'nsamples': 575},
#    'images': {'pearson': [0.6239431237201327, 6.779461294938793e-93],
#     'spearman': [0.6288396172249616, 9.30743830031751e-95],
#     'nsamples': 850},
#    'imagesCZ2014-2015shuffled': {'pearson': [0.6239431237201327,
#      6.779461294938793e-93],
#     'spearman': [0.6288396172249616, 9.30743830031751e-95],
#     'nsamples': 850},
#    'imagesCZ2014-2015shuffled_Lemma': {'pearson': [0.6804584567497891,
#      1.2740548368548437e-116],
#     'spearman': [0.6917255877107253, 5.229995440413782e-122],
#     'nsamples': 850},
#    'imagesCZ2014-2015shuffled_POSTag': {'pearson': [0.2600290534664051,
#      1.3310293522698567e-14],
#     'spearman': [0.3065667596093388, 5.916574919818481e-20],
#     'nsamples': 850},
#    'imagesCZ2014-2015shuffled_Stem': {'pearson': [0.6236893057858786,
#      8.449499844281885e-93],
#     'spearman': [0.6366849469352678, 8.209162599041034e-98],
#     'nsamples': 850},
#    'all': {'pearson': {'mean': 0.5009427353893072,
#      'wmean': 0.5138467172650851},
#     'spearman': {'mean': 0.5192520924636563, 'wmean': 0.5316962021211247}}}},
#  'STSCZ2_elmo_139': {'STSCZ2': {'headlines': {'pearson': [0.27255224235255404,
#      2.9788995283906296e-11],
#     'spearman': [0.28305565593236776, 4.6928600008687685e-12],
#     'nsamples': 575},
#    'headlines2013-2015CZ_Lemma': {'pearson': [0.2840609945925119,
#      3.915754931545367e-12],
#     'spearman': [0.278292326664657, 1.0956297140176624e-11],
#     'nsamples': 575},
#    'headlines2013-2015CZ_POSTag': {'pearson': [0.2329903804685388,
#      1.5791748168036417e-08],
#     'spearman': [0.2590260466174676, 2.8700177513725345e-10],
#     'nsamples': 575},
#    'headlines2013-2015CZ_Stem': {'pearson': [0.1703655048219196,
#      4.0189339480149935e-05],
#     'spearman': [0.1767846846786471, 2.0120556603020266e-05],
#     'nsamples': 575},
#    'images': {'pearson': [0.42321391691747406, 2.9212182211320895e-38],
#     'spearman': [0.42737035817447455, 4.640919313824928e-39],
#     'nsamples': 850},
#    'imagesCZ2014-2015shuffled': {'pearson': [0.4232190622846947,
#      2.914619268636632e-38],
#     'spearman': [0.4273675506366168, 4.646730252733158e-39],
#     'nsamples': 850},
#    'imagesCZ2014-2015shuffled_Lemma': {'pearson': [0.4202086138310282,
#      1.0872574107652364e-37],
#     'spearman': [0.4303735237049103, 1.2087940897535205e-39],
#     'nsamples': 850},
#    'imagesCZ2014-2015shuffled_POSTag': {'pearson': [0.30262663318267763,
#      1.8397141127193628e-19],
#     'spearman': [0.3180284779814953, 1.9756877171941047e-21],
#     'nsamples': 850},
#    'imagesCZ2014-2015shuffled_Stem': {'pearson': [0.36643309026823806,
#      2.088664583648101e-28],
#     'spearman': [0.39780398134790557, 1.2982228593714966e-33],
#     'nsamples': 850},
#    'all': {'pearson': {'mean': 0.32174115985773744,
#      'wmean': 0.33546997928197286},
#     'spearman': {'mean': 0.3331225117487269, 'wmean': 0.3472013081766637}}}}}

# %%
res_by_task = {}
for res in results:
    for task in results[res]:
        task_results = res_by_task.get(task, {})
        for dataset in results[res][task]:
            dataset_results = task_results.get(dataset, {})
            dataset_results[res] = results[res][task][dataset]
            task_results[dataset] = dataset_results
        res_by_task[task] = task_results
res_by_task
# Out:
# {'STSCZ': {'headlines': {'STSCZ_bert-base-multilingual-cased_torch': {'pearson': [0.45181167547936035,
#      2.854290863573569e-30],
#     'spearman': [0.509163722179652, 2.9853923460035995e-39],
#     'nsamples': 575},
#    'STSCZ_multi_cased_L-12_H-768_A-12_torch': {'pearson': [0.5101076658989366,
#      2.0534831136245208e-39],
#     'spearman': [0.5523454236645796, 3.105297653554739e-47],
#     'nsamples': 575},
#    'STSCZ_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_torch': {'pearson': [0.5250992742990885,
#      4.59294727664545e-42],
#     'spearman': [0.5596413291539634, 1.0599526893408327e-48],
#     'nsamples': 575},
#    'STSCZ_multi_cased_L-12_H-768_A-12_mean_pooled_torch': {'pearson': [0.5020967154907711,
#      4.738714900955174e-38],
#     'spearman': [0.5593170350255514, 1.2338383169105442e-48],
#     'nsamples': 575},
#    'STSCZ_bert-base-multilingual-cased_torch_headlines': {'pearson': [0.45181167547936035,
#      2.854290863573569e-30],
#     'spearman': [0.509163722179652, 2.9853923460035995e-39],
#     'nsamples': 575},
#    'STSCZ_bert-base-multilingual-cased_torch_all': {'pearson': [0.45181167547936035,
#      2.854290863573569e-30],
#     'spearman': [0.509163722179652, 2.9853923460035995e-39],
#     'nsamples': 575},
#    'STSCZ_multi_cased_L-12_H-768_A-12_mean_pooled_torch_all': {'pearson': [0.5020967154907711,
#      4.738714900955174e-38],
#     'spearman': [0.5593170350255514, 1.2338383169105442e-48],
#     'nsamples': 575},
#    'STSCZ_cc_cs_300_fasttext_sentence': {'pearson': [0.5820461373692433,
#      1.9311198812527916e-53],
#     'spearman': [0.5769693605652192, 2.4655284689135243e-52],
#     'nsamples': 575},
#    'STSCZ_cc_cs_300_fasttext_word': {'pearson': [0.45243410576300863,
#      2.3274827666070004e-30],
#     'spearman': [0.4626670241236353, 7.649139808893686e-32],
#     'nsamples': 575},
#    'STSCZ_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_mean_pooled_torch_all': {'pearson': [0.5125391564169962,
#      7.78994290633095e-40],
#     'spearman': [0.5566681996597297, 4.2403864449027674e-48],
#     'nsamples': 575},
#    'STSCZ_wiki_cs_300_fasttext_sentence': {'pearson': [0.6458306696096886,
#      3.587471181759894e-69],
#     'spearman': [0.6407838171352014, 8.640990226803496e-68],
#     'nsamples': 575},
#    'STSCZ_wiki_cs_300_fasttext_word': {'pearson': [0.6286271983412663,
#      1.4475576019259406e-64],
#     'spearman': [0.6145092474484171, 5.364427220120675e-61],
#     'nsamples': 575},
#    'STSCZ_elmo_139': {'pearson': [0.5147392972800048, 3.218800784076569e-40],
#     'spearman': [0.510899959567052, 1.49863590015424e-39],
#     'nsamples': 575}},
#   'images': {'STSCZ_bert-base-multilingual-cased_torch': {'pearson': [0.43734476852886184,
#      5.049647454736709e-41],
#     'spearman': [0.539174813744424, 2.845041547860588e-65],
#     'nsamples': 850},
#    'STSCZ_multi_cased_L-12_H-768_A-12_torch': {'pearson': [0.5300776517070618,
#      9.322986813324278e-63],
#     'spearman': [0.5925229440467971, 1.076577551080529e-81],
#     'nsamples': 850},
#    'STSCZ_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_torch': {'pearson': [0.5180317559416066,
#      1.5302798780388756e-59],
#     'spearman': [0.5788123364431161, 3.498461796319507e-77],
#     'nsamples': 850},
#    'STSCZ_multi_cased_L-12_H-768_A-12_mean_pooled_torch': {'pearson': [0.5589500586797128,
#      5.161686863097684e-71],
#     'spearman': [0.6097894674102017, 1.077548093424233e-87],
#     'nsamples': 850},
#    'STSCZ_bert-base-multilingual-cased_torch_headlines': {'pearson': [0.016953513009774122,
#      0.6216002154410325],
#     'spearman': [0.2976376987095722, 7.54796561832515e-19],
#     'nsamples': 850},
#    'STSCZ_bert-base-multilingual-cased_torch_all': {'pearson': [0.43734476852886184,
#      5.049647454736709e-41],
#     'spearman': [0.539174813744424, 2.845041547860588e-65],
#     'nsamples': 850},
#    'STSCZ_multi_cased_L-12_H-768_A-12_mean_pooled_torch_all': {'pearson': [0.5589500586797128,
#      5.161686863097684e-71],
#     'spearman': [0.6097894674102017, 1.077548093424233e-87],
#     'nsamples': 850},
#    'STSCZ_cc_cs_300_fasttext_sentence': {'pearson': [0.704812580513345,
#      1.3848618673576658e-128],
#     'spearman': [0.7081043087726708, 2.6893604314281973e-130],
#     'nsamples': 850},
#    'STSCZ_cc_cs_300_fasttext_word': {'pearson': [0.5523616913911996,
#      4.659975317289405e-69],
#     'spearman': [0.5695330701307794, 3.0073856401921574e-74],
#     'nsamples': 850},
#    'STSCZ_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_mean_pooled_torch_all': {'pearson': [0.5151341479034207,
#      8.691788400825761e-59],
#     'spearman': [0.5796676963996854, 1.856253429442304e-77],
#     'nsamples': 850},
#    'STSCZ_wiki_cs_300_fasttext_sentence': {'pearson': [0.7018580923853577,
#      4.5467488544723494e-127],
#     'spearman': [0.7091848845708458, 7.286236004064457e-131],
#     'nsamples': 850},
#    'STSCZ_wiki_cs_300_fasttext_word': {'pearson': [0.7296737182595723,
#      3.903729994608591e-142],
#     'spearman': [0.7338931190817919, 1.382923042414908e-144],
#     'nsamples': 850},
#    'STSCZ_elmo_139': {'pearson': [0.6239431237201327, 6.779461294938793e-93],
#     'spearman': [0.6288396172249616, 9.30743830031751e-95],
#     'nsamples': 850}},
#   'all': {'STSCZ_bert-base-multilingual-cased_torch': {'pearson': {'mean': 0.4445782220041111,
#      'wmean': 0.44318229238608053},
#     'spearman': {'mean': 0.524169267962038, 'wmean': 0.5270650750428493}},
#    'STSCZ_multi_cased_L-12_H-768_A-12_torch': {'pearson': {'mean': 0.5200926588029993,
#      'wmean': 0.5220195872581692},
#     'spearman': {'mean': 0.5724341838556883, 'wmean': 0.576310962138183}},
#    'STSCZ_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_torch': {'pearson': {'mean': 0.5215655151203475,
#      'wmean': 0.5208835615946257},
#     'spearman': {'mean': 0.5692268327985397, 'wmean': 0.5710766668352124}},
#    'STSCZ_multi_cased_L-12_H-768_A-12_mean_pooled_torch': {'pearson': {'mean': 0.5305233870852419,
#      'wmean': 0.5360092359894381},
#     'spearman': {'mean': 0.5845532512178766, 'wmean': 0.5894233982023603}},
#    'STSCZ_bert-base-multilingual-cased_torch_headlines': {'pearson': {'mean': 0.23438259424456723,
#      'wmean': 0.19242259611153698},
#     'spearman': {'mean': 0.4034007104446121, 'wmean': 0.38299030467118333}},
#    'STSCZ_bert-base-multilingual-cased_torch_all': {'pearson': {'mean': 0.418532144301011,
#      'wmean': 0.42491212894763813},
#     'spearman': {'mean': 0.4948314463221034, 'wmean': 0.5022395218890819}},
#    'STSCZ_multi_cased_L-12_H-768_A-12_mean_pooled_torch_all': {'pearson': {'mean': 0.5071994164598018,
#      'wmean': 0.5181532058253263},
#     'spearman': {'mean': 0.5565623776550255, 'wmean': 0.5665169517917784}},
#    'STSCZ_cc_cs_300_fasttext_sentence': {'pearson': {'mean': 0.6036036852694605,
#      'wmean': 0.6165630767987659},
#     'spearman': {'mean': 0.6102613311791916, 'wmean': 0.6241954193208734}},
#    'STSCZ_cc_cs_300_fasttext_word': {'pearson': {'mean': 0.45619247075362385,
#      'wmean': 0.46774489199796515},
#     'spearman': {'mean': 0.4740800720006779, 'wmean': 0.4863351366622194}},
#    'STSCZ_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_mean_pooled_torch_all': {'pearson': {'mean': 0.48892656244913346,
#      'wmean': 0.49637431736763304},
#     'spearman': {'mean': 0.545749742484525, 'wmean': 0.5537717722697375}},
#    'STSCZ_wiki_cs_300_fasttext_sentence': {'pearson': {'mean': 0.6251467010822874,
#      'wmean': 0.6346018467346318},
#     'spearman': {'mean': 0.6351215055494168, 'wmean': 0.645182460120172}},
#    'STSCZ_wiki_cs_300_fasttext_word': {'pearson': {'mean': 0.6094696549501187,
#      'wmean': 0.6192904800073621},
#     'spearman': {'mean': 0.6138188245889662, 'wmean': 0.6252257297324494}},
#    'STSCZ_elmo_139': {'pearson': {'mean': 0.5009427353893072,
#      'wmean': 0.5138467172650851},
#     'spearman': {'mean': 0.5192520924636563, 'wmean': 0.5316962021211247}}},
#   'headlines2013-2015CZ_Lemma': {'STSCZ_bert-base-multilingual-cased_torch_all': {'pearson': [0.4150248298334991,
#      2.397838092073334e-25],
#     'spearman': [0.4703661077927978, 5.420967380805618e-33],
#     'nsamples': 575},
#    'STSCZ_multi_cased_L-12_H-768_A-12_mean_pooled_torch_all': {'pearson': [0.4829875732788488,
#      6.098424442828543e-35],
#     'spearman': [0.5440374515295321, 1.3150499898806454e-45],
#     'nsamples': 575},
#    'STSCZ_cc_cs_300_fasttext_sentence': {'pearson': [0.587485564515748,
#      1.1992911458213011e-54],
#     'spearman': [0.5845739257518789, 5.34297855637833e-54],
#     'nsamples': 575},
#    'STSCZ_cc_cs_300_fasttext_word': {'pearson': [0.43930747947377846,
#      1.5756052978792167e-28],
#     'spearman': [0.44202836394592754, 6.676272507672774e-29],
#     'nsamples': 575},
#    'STSCZ_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_mean_pooled_torch_all': {'pearson': [0.5167208035265121,
#      1.444077918028924e-40],
#     'spearman': [0.5629857433174792, 2.1911203934133332e-49],
#     'nsamples': 575},
#    'STSCZ_wiki_cs_300_fasttext_sentence': {'pearson': [0.612050388203227,
#      2.1514748062402092e-60],
#     'spearman': [0.6181317050819604, 6.777963186032025e-62],
#     'nsamples': 575},
#    'STSCZ_wiki_cs_300_fasttext_word': {'pearson': [0.6280712234124126,
#      2.0168292310796724e-64],
#     'spearman': [0.6182545296990112, 6.315839602746647e-62],
#     'nsamples': 575},
#    'STSCZ_elmo_139': {'pearson': [0.5311890238284899, 3.5248293381898782e-43],
#     'spearman': [0.5271051406162605, 1.9830854644388062e-42],
#     'nsamples': 575}},
#   'headlines2013-2015CZ_POSTag': {'STSCZ_bert-base-multilingual-cased_torch_all': {'pearson': [0.24801205708553467,
#      1.6536787475919304e-09],
#     'spearman': [0.3215429541505239, 2.691886726587671e-15],
#     'nsamples': 575},
#    'STSCZ_multi_cased_L-12_H-768_A-12_mean_pooled_torch_all': {'pearson': [0.2794474827397236,
#      8.933337395835672e-12],
#     'spearman': [0.33097565989096955, 3.637367809442198e-16],
#     'nsamples': 575},
#    'STSCZ_cc_cs_300_fasttext_sentence': {'pearson': [0.36263788030530675,
#      2.6002107537234417e-19],
#     'spearman': [0.38619654319028396, 6.837057428838524e-22],
#     'nsamples': 575},
#    'STSCZ_cc_cs_300_fasttext_word': {'pearson': [0.23938439723774907,
#      6.155990654999399e-09],
#     'spearman': [0.27689362131245493, 1.4010409884995993e-11],
#     'nsamples': 575},
#    'STSCZ_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_mean_pooled_torch_all': {'pearson': [0.2517572533014806,
#      9.20156501253324e-10],
#     'spearman': [0.3146208887132803, 1.1189398957422662e-14],
#     'nsamples': 575},
#    'STSCZ_wiki_cs_300_fasttext_sentence': {'pearson': [0.3868785145953727,
#      5.714762759102055e-22],
#     'spearman': [0.41057500953931547, 8.618212494184426e-25],
#     'nsamples': 575},
#    'STSCZ_wiki_cs_300_fasttext_word': {'pearson': [0.2755796463719494,
#      1.7628597442195736e-11],
#     'spearman': [0.2951501241780452, 5.063394326043467e-13],
#     'nsamples': 575},
#    'STSCZ_elmo_139': {'pearson': [0.1385821411229395, 0.0008624221189713498],
#     'spearman': [0.23191813234545391, 1.8445455983267526e-08],
#     'nsamples': 575}},
#   'headlines2013-2015CZ_Stem': {'STSCZ_bert-base-multilingual-cased_torch_all': {'pearson': [0.4073203804950766,
#      2.1703777979810177e-24],
#     'spearman': [0.5018061103883155, 5.301940251759242e-38],
#     'nsamples': 575},
#    'STSCZ_multi_cased_L-12_H-768_A-12_mean_pooled_torch_all': {'pearson': [0.5033665476237332,
#      2.897243878712131e-38],
#     'spearman': [0.5548195074622949, 9.971349100510309e-48],
#     'nsamples': 575},
#    'STSCZ_cc_cs_300_fasttext_sentence': {'pearson': [0.5735760151895442,
#      1.3198189808421834e-51],
#     'spearman': [0.5614208503802359, 4.591749203002682e-49],
#     'nsamples': 575},
#    'STSCZ_cc_cs_300_fasttext_word': {'pearson': [0.41848623090201237,
#      8.746681245770348e-26],
#     'spearman': [0.42283792031852685, 2.4207190230962004e-26],
#     'nsamples': 575},
#    'STSCZ_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_mean_pooled_torch_all': {'pearson': [0.49729705576546285,
#      2.987074366347959e-37],
#     'spearman': [0.5576539742725513, 2.6818768187955295e-48],
#     'nsamples': 575},
#    'STSCZ_wiki_cs_300_fasttext_sentence': {'pearson': [0.6306228536559314,
#      4.377368749861743e-65],
#     'spearman': [0.6313618452104776, 2.804821185695657e-65],
#     'nsamples': 575},
#    'STSCZ_wiki_cs_300_fasttext_word': {'pearson': [0.6716863548568717,
#      1.1097406785991446e-76],
#     'spearman': [0.6556696563401583, 6.086625995132441e-72],
#     'nsamples': 575},
#    'STSCZ_elmo_139': {'pearson': [0.5119110928299921, 1.0013694707212308e-39],
#     'spearman': [0.5106890709388854, 1.6298311219833357e-39],
#     'nsamples': 575}},
#   'imagesCZ2014-2015shuffled': {'STSCZ_bert-base-multilingual-cased_torch_all': {'pearson': [0.4373447685288619,
#      5.049647454736709e-41],
#     'spearman': [0.539174813744424, 2.845041547860588e-65],
#     'nsamples': 850},
#    'STSCZ_multi_cased_L-12_H-768_A-12_mean_pooled_torch_all': {'pearson': [0.558950058679713,
#      5.161686863096951e-71],
#     'spearman': [0.6097894674102017, 1.077548093424233e-87],
#     'nsamples': 850},
#    'STSCZ_cc_cs_300_fasttext_sentence': {'pearson': [0.7048125805133452,
#      1.3848618673576658e-128],
#     'spearman': [0.7081043087726708, 2.6893604314281973e-130],
#     'nsamples': 850},
#    'STSCZ_cc_cs_300_fasttext_word': {'pearson': [0.5523616913911996,
#      4.659975317289405e-69],
#     'spearman': [0.5695330701307794, 3.0073856401921574e-74],
#     'nsamples': 850},
#    'STSCZ_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_mean_pooled_torch_all': {'pearson': [0.5151341479034207,
#      8.691788400825761e-59],
#     'spearman': [0.5796676963996854, 1.856253429442304e-77],
#     'nsamples': 850},
#    'STSCZ_wiki_cs_300_fasttext_sentence': {'pearson': [0.7018580923853578,
#      4.546748854471315e-127],
#     'spearman': [0.7091848845708458, 7.286236004064457e-131],
#     'nsamples': 850},
#    'STSCZ_wiki_cs_300_fasttext_word': {'pearson': [0.7296737182595725,
#      3.903729994608591e-142],
#     'spearman': [0.7338931190817919, 1.382923042414908e-144],
#     'nsamples': 850},
#    'STSCZ_elmo_139': {'pearson': [0.6239431237201327, 6.779461294938793e-93],
#     'spearman': [0.6288396172249616, 9.30743830031751e-95],
#     'nsamples': 850}},
#   'imagesCZ2014-2015shuffled_Lemma': {'STSCZ_bert-base-multilingual-cased_torch_all': {'pearson': [0.48246330212387195,
#      9.135343935005096e-51],
#     'spearman': [0.552713600961128, 3.6730690900003224e-69],
#     'nsamples': 850},
#    'STSCZ_multi_cased_L-12_H-768_A-12_mean_pooled_torch_all': {'pearson': [0.6342237892143996,
#      7.621792209406906e-97],
#     'spearman': [0.6718201002450108, 1.1846413289124497e-112],
#     'nsamples': 850},
#    'STSCZ_cc_cs_300_fasttext_sentence': {'pearson': [0.7393735872345127,
#      7.704023662501198e-148],
#     'spearman': [0.7443437789863141, 7.306868277557645e-151],
#     'nsamples': 850},
#    'STSCZ_cc_cs_300_fasttext_word': {'pearson': [0.6368556939138795,
#      7.027997924638165e-98],
#     'spearman': [0.6466839561186869, 7.766512106239325e-102],
#     'nsamples': 850},
#    'STSCZ_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_mean_pooled_torch_all': {'pearson': [0.5829819924080402,
#      1.564675722772472e-78],
#     'spearman': [0.6433637065049739, 1.7504517558897638e-100],
#     'nsamples': 850},
#    'STSCZ_wiki_cs_300_fasttext_sentence': {'pearson': [0.735999712847127,
#      7.936366299283808e-146],
#     'spearman': [0.7415265221680057, 3.8530774602972414e-149],
#     'nsamples': 850},
#    'STSCZ_wiki_cs_300_fasttext_word': {'pearson': [0.7802867430497888,
#      5.00990447806585e-175],
#     'spearman': [0.7844706105819272, 3.88561320803869e-178],
#     'nsamples': 850},
#    'STSCZ_elmo_139': {'pearson': [0.6804584567497891, 1.2740548368548437e-116],
#     'spearman': [0.6917255877107253, 5.229995440413782e-122],
#     'nsamples': 850}},
#   'imagesCZ2014-2015shuffled_POSTag': {'STSCZ_bert-base-multilingual-cased_torch_all': {'pearson': [0.36082666389871754,
#      1.5547674376319544e-27],
#     'spearman': [0.4141248800287106, 1.4934946611193519e-36],
#     'nsamples': 850},
#    'STSCZ_multi_cased_L-12_H-768_A-12_mean_pooled_torch_all': {'pearson': [0.4314614024130017,
#      7.400400081866647e-40],
#     'spearman': [0.4675910136479867, 2.1603259054104817e-47],
#     'nsamples': 850},
#    'STSCZ_cc_cs_300_fasttext_sentence': {'pearson': [0.4423134703370569,
#      5.0179840622483297e-42],
#     'spearman': [0.4804254743436288, 2.7094865799245444e-50],
#     'nsamples': 850},
#    'STSCZ_cc_cs_300_fasttext_word': {'pearson': [0.17169138733392075,
#      4.761225170002821e-07],
#     'spearman': [0.2304541957896072, 1.0411711069945414e-11],
#     'nsamples': 850},
#    'STSCZ_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_mean_pooled_torch_all': {'pearson': [0.40898305843998134,
#      1.3116519333726825e-35],
#     'spearman': [0.45214546186241705, 4.64230030734386e-44],
#     'nsamples': 850},
#    'STSCZ_wiki_cs_300_fasttext_sentence': {'pearson': [0.45349860383880175,
#      2.4076090432006873e-44],
#     'spearman': [0.4917289446750187, 5.932883171056722e-53],
#     'nsamples': 850},
#    'STSCZ_wiki_cs_300_fasttext_word': {'pearson': [0.25065664033570695,
#      1.2090909704956186e-13],
#     'spearman': [0.29213306049049287, 3.47120042438679e-18],
#     'nsamples': 850},
#    'STSCZ_elmo_139': {'pearson': [0.2600290534664051, 1.3310293522698567e-14],
#     'spearman': [0.3065667596093388, 5.916574919818481e-20],
#     'nsamples': 850}},
#   'imagesCZ2014-2015shuffled_Stem': {'STSCZ_bert-base-multilingual-cased_torch_all': {'pearson': [0.5266408527353151,
#      7.94517592272987e-62],
#     'spearman': [0.6054160139089552, 3.863218562393235e-86],
#     'nsamples': 850},
#    'STSCZ_multi_cased_L-12_H-768_A-12_mean_pooled_torch_all': {'pearson': [0.6133111200183127,
#      5.793347872366065e-89],
#     'spearman': [0.6609216962734804, 7.799229763547072e-108],
#     'nsamples': 850},
#    'STSCZ_cc_cs_300_fasttext_sentence': {'pearson': [0.7353753514470425,
#      1.8566456468222726e-145],
#     'spearman': [0.742213429849822, 1.4723375793843887e-149],
#     'nsamples': 850},
#    'STSCZ_cc_cs_300_fasttext_word': {'pearson': [0.6428495593758667,
#      2.8258709682104704e-100],
#     'spearman': [0.6460894261357044, 1.360579221641065e-101],
#     'nsamples': 850},
#    'STSCZ_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_mean_pooled_torch_all': {'pearson': [0.5997914463768859,
#      3.5562942033305096e-84],
#     'spearman': [0.6649743152309233, 1.3306970086487442e-109],
#     'nsamples': 850},
#    'STSCZ_wiki_cs_300_fasttext_sentence': {'pearson': [0.7577233822197231,
#      2.316471265275101e-159],
#     'spearman': [0.7636159369930806, 2.7783739214591352e-163],
#     'nsamples': 850},
#    'STSCZ_wiki_cs_300_fasttext_word': {'pearson': [0.7909716516639285,
#      4.128210674722358e-183],
#     'spearman': [0.7963959543990607, 2.128642950321615e-187],
#     'nsamples': 850},
#    'STSCZ_elmo_139': {'pearson': [0.6236893057858786, 8.449499844281885e-93],
#     'spearman': [0.6366849469352678, 8.209162599041034e-98],
#     'nsamples': 850}}},
#  'STSCZ2': {'headlines': {'STSCZ2_bert-base-multilingual-cased_torch': {'pearson': [0.38382098407064996,
#      1.272624384364285e-21],
#     'spearman': [0.4257876270230112, 1.0026060356177619e-26],
#     'nsamples': 575},
#    'STSCZ2_multi_cased_L-12_H-768_A-12_torch': {'pearson': [0.5544278878699856,
#      1.1943206070235641e-47],
#     'spearman': [0.5624157871569156, 2.8700587859568032e-49],
#     'nsamples': 575},
#    'STSCZ2_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_torch': {'pearson': [0.5340470627349253,
#      1.0375334885774865e-43],
#     'spearman': [0.541701348093774, 3.7004423685046276e-45],
#     'nsamples': 575},
#    'STSCZ2_multi_cased_L-12_H-768_A-12_mean_pooled_torch': {'pearson': [0.558530011585776,
#      1.7826338167991827e-48],
#     'spearman': [0.563151152736174, 2.0258318063795265e-49],
#     'nsamples': 575},
#    'STSCZ2_bert-base-multilingual-cased_torch_all': {'pearson': [0.38382098407064996,
#      1.272624384364285e-21],
#     'spearman': [0.4257876270230112, 1.0026060356177619e-26],
#     'nsamples': 575},
#    'STSCZ2_multi_cased_L-12_H-768_A-12_mean_pooled_torch_all': {'pearson': [0.558530011585776,
#      1.7826338167991827e-48],
#     'spearman': [0.563151152736174, 2.0258318063795265e-49],
#     'nsamples': 575},
#    'STSCZ2_cc_cs_300_fasttext_sentence': {'pearson': [0.5820461378683905,
#      1.931119393427596e-53],
#     'spearman': [0.5769693059362351, 2.4655954499659657e-52],
#     'nsamples': 575},
#    'STSCZ2_cc_cs_300_fasttext_word': {'pearson': [0.5767938496545317,
#      2.6903203175692284e-52],
#     'spearman': [0.5662250131539256, 4.678368863918498e-50],
#     'nsamples': 575},
#    'STSCZ2_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_mean_pooled_torch_all': {'pearson': [0.5373962151229553,
#      2.4383861237528887e-44],
#     'spearman': [0.545934972798684, 5.641292571756747e-46],
#     'nsamples': 575},
#    'STSCZ2_wiki_cs_300_fasttext_sentence': {'pearson': [0.6458306696175045,
#      3.587471163915819e-69],
#     'spearman': [0.6407837867996465, 8.641153929550116e-68],
#     'nsamples': 575},
#    'STSCZ2_wiki_cs_300_fasttext_word': {'pearson': [0.60420279620433,
#      1.6707134277662287e-58],
#     'spearman': [0.6000934740648913, 1.5555146586825057e-57],
#     'nsamples': 575},
#    'STSCZ2_elmo_139': {'pearson': [0.27255224235255404,
#      2.9788995283906296e-11],
#     'spearman': [0.28305565593236776, 4.6928600008687685e-12],
#     'nsamples': 575}},
#   'images': {'STSCZ2_bert-base-multilingual-cased_torch': {'pearson': [0.3982399674501556,
#      1.088782977184562e-33],
#     'spearman': [0.4543518361367437, 1.5890018878238387e-44],
#     'nsamples': 850},
#    'STSCZ2_multi_cased_L-12_H-768_A-12_torch': {'pearson': [0.6128901535718398,
#      8.232390899028563e-89],
#     'spearman': [0.635210520451141, 3.1269343430443696e-97],
#     'nsamples': 850},
#    'STSCZ2_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_torch': {'pearson': [0.5726332037719152,
#      3.2230052479298675e-75],
#     'spearman': [0.6011994950572622, 1.156065681677813e-84],
#     'nsamples': 850},
#    'STSCZ2_multi_cased_L-12_H-768_A-12_mean_pooled_torch': {'pearson': [0.6273688052337666,
#      3.4021270359198095e-94],
#     'spearman': [0.6455169235005342, 2.3317744424249662e-101],
#     'nsamples': 850},
#    'STSCZ2_bert-base-multilingual-cased_torch_all': {'pearson': [0.3982399674501556,
#      1.088782977184562e-33],
#     'spearman': [0.4543518361367437, 1.5890018878238387e-44],
#     'nsamples': 850},
#    'STSCZ2_multi_cased_L-12_H-768_A-12_mean_pooled_torch_all': {'pearson': [0.6273688052337666,
#      3.4021270359198095e-94],
#     'spearman': [0.6455169235005342, 2.3317744424249662e-101],
#     'nsamples': 850},
#    'STSCZ2_cc_cs_300_fasttext_sentence': {'pearson': [0.7048125806765313,
#      1.384861598637031e-128],
#     'spearman': [0.7081043087726708, 2.6893604314281973e-130],
#     'nsamples': 850},
#    'STSCZ2_cc_cs_300_fasttext_word': {'pearson': [0.5548804656126964,
#      8.431523860026883e-70],
#     'spearman': [0.5844975628031199, 5.001224394665181e-79],
#     'nsamples': 850},
#    'STSCZ2_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_mean_pooled_torch_all': {'pearson': [0.5812975521934144,
#      5.519731388515483e-78],
#     'spearman': [0.6066048496797043, 1.4681787976389586e-86],
#     'nsamples': 850},
#    'STSCZ2_wiki_cs_300_fasttext_sentence': {'pearson': [0.7018580923878125,
#      4.546748841363884e-127],
#     'spearman': [0.7091848845708458, 7.286236004064457e-131],
#     'nsamples': 850},
#    'STSCZ2_wiki_cs_300_fasttext_word': {'pearson': [0.6772680683392207,
#      3.860869842382178e-115],
#     'spearman': [0.6839821259051817, 2.7978146625360314e-118],
#     'nsamples': 850},
#    'STSCZ2_elmo_139': {'pearson': [0.42321391691747406,
#      2.9212182211320895e-38],
#     'spearman': [0.42737035817447455, 4.640919313824928e-39],
#     'nsamples': 850}},
#   'all': {'STSCZ2_bert-base-multilingual-cased_torch': {'pearson': {'mean': 0.3910304757604028,
#      'wmean': 0.39242178117421467},
#     'spearman': {'mean': 0.44006973157987744, 'wmean': 0.4428259271961148}},
#    'STSCZ2_multi_cased_L-12_H-768_A-12_torch': {'pearson': {'mean': 0.5836590207209127,
#      'wmean': 0.5893001165342495},
#     'spearman': {'mean': 0.5988131538040283, 'wmean': 0.605837207016629}},
#    'STSCZ2_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_torch': {'pearson': {'mean': 0.5533401332534202,
#      'wmean': 0.5570633573885684},
#     'spearman': {'mean': 0.5714504215755181, 'wmean': 0.5771914708439249}},
#    'STSCZ2_multi_cased_L-12_H-768_A-12_mean_pooled_torch': {'pearson': {'mean': 0.5929494084097713,
#      'wmean': 0.5995917481477353},
#     'spearman': {'mean': 0.6043340381183542, 'wmean': 0.6122816124903538}},
#    'STSCZ2_bert-base-multilingual-cased_torch_all': {'pearson': {'mean': 0.3739173267830893,
#      'wmean': 0.37787270995938155},
#     'spearman': {'mean': 0.4192751202917358, 'wmean': 0.4252524871304601}},
#    'STSCZ2_multi_cased_L-12_H-768_A-12_mean_pooled_torch_all': {'pearson': {'mean': 0.5478348654743409,
#      'wmean': 0.556184221301426},
#     'spearman': {'mean': 0.5638031176482585, 'wmean': 0.5731609041769595}},
#    'STSCZ2_cc_cs_300_fasttext_sentence': {'pearson': {'mean': 0.6036036852774079,
#      'wmean': 0.6165630768759564},
#     'spearman': {'mean': 0.6103128682131267, 'wmean': 0.6242524128351089}},
#    'STSCZ2_cc_cs_300_fasttext_word': {'pearson': {'mean': 0.555295608849674,
#      'wmean': 0.5564759056272152},
#     'spearman': {'mean': 0.5691656082258402, 'wmean': 0.5724726637829888}},
#    'STSCZ2_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_mean_pooled_torch_all': {'pearson': {'mean': 0.5291726376815874,
#      'wmean': 0.5362162712194914},
#     'spearman': {'mean': 0.5481792597764872, 'wmean': 0.5560674851669586}},
#    'STSCZ2_wiki_cs_300_fasttext_sentence': {'pearson': {'mean': 0.625146701193692,
#      'wmean': 0.6346018469034407},
#     'spearman': {'mean': 0.6350936778866089, 'wmean': 0.6451557895461233}},
#    'STSCZ2_wiki_cs_300_fasttext_word': {'pearson': {'mean': 0.6046225776797205,
#      'wmean': 0.613072849670449},
#     'spearman': {'mean': 0.6085793482557801, 'wmean': 0.618057474130223}},
#    'STSCZ2_elmo_139': {'pearson': {'mean': 0.32174115985773744,
#      'wmean': 0.33546997928197286},
#     'spearman': {'mean': 0.3331225117487269, 'wmean': 0.3472013081766637}}},
#   'headlines2013-2015CZ_Lemma': {'STSCZ2_bert-base-multilingual-cased_torch_all': {'pearson': [0.37420771967025546,
#      1.4938262952177982e-20],
#     'spearman': [0.40877152913396725, 1.4395697398347397e-24],
#     'nsamples': 575},
#    'STSCZ2_multi_cased_L-12_H-768_A-12_mean_pooled_torch_all': {'pearson': [0.5677451062309433,
#      2.253462932704996e-50],
#     'spearman': [0.5775390247654023, 1.856768354571934e-52],
#     'nsamples': 575},
#    'STSCZ2_cc_cs_300_fasttext_sentence': {'pearson': [0.5874855657237583,
#      1.1992903986512135e-54],
#     'spearman': [0.5845812407435088, 5.323061605156563e-54],
#     'nsamples': 575},
#    'STSCZ2_cc_cs_300_fasttext_word': {'pearson': [0.620097854441282,
#      2.1803935972729474e-62],
#     'spearman': [0.619538975718204, 3.012327944916386e-62],
#     'nsamples': 575},
#    'STSCZ2_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_mean_pooled_torch_all': {'pearson': [0.5712144670660695,
#      4.193587511132753e-51],
#     'spearman': [0.5805305905511879, 4.1499390046457424e-53],
#     'nsamples': 575},
#    'STSCZ2_wiki_cs_300_fasttext_sentence': {'pearson': [0.6120503889054463,
#      2.1514739565731116e-60],
#     'spearman': [0.6181544233544137, 6.690024327727067e-62],
#     'nsamples': 575},
#    'STSCZ2_wiki_cs_300_fasttext_word': {'pearson': [0.6113611444434196,
#      3.168638989449942e-60],
#     'spearman': [0.6066767435352322, 4.292535202737262e-59],
#     'nsamples': 575},
#    'STSCZ2_elmo_139': {'pearson': [0.2840609945925119, 3.915754931545367e-12],
#     'spearman': [0.278292326664657, 1.0956297140176624e-11],
#     'nsamples': 575}},
#   'headlines2013-2015CZ_POSTag': {'STSCZ2_bert-base-multilingual-cased_torch_all': {'pearson': [0.24717603885372336,
#      1.8824264666906744e-09],
#     'spearman': [0.2812520375355312, 6.481817053923247e-12],
#     'nsamples': 575},
#    'STSCZ2_multi_cased_L-12_H-768_A-12_mean_pooled_torch_all': {'pearson': [0.31613694740319875,
#      8.216017919732669e-15],
#     'spearman': [0.3340121509463883, 1.881333777401849e-16],
#     'nsamples': 575},
#    'STSCZ2_cc_cs_300_fasttext_sentence': {'pearson': [0.3626378777881063,
#      2.6002123373050687e-19],
#     'spearman': [0.3862466529911947, 6.747667061647054e-22],
#     'nsamples': 575},
#    'STSCZ2_cc_cs_300_fasttext_word': {'pearson': [0.4048563616752499,
#      4.33801867824397e-24],
#     'spearman': [0.4242567089902576, 1.5859346416108124e-26],
#     'nsamples': 575},
#    'STSCZ2_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_mean_pooled_torch_all': {'pearson': [0.2864644682129161,
#      2.532606723187987e-12],
#     'spearman': [0.3163042209186031, 7.939872867353916e-15],
#     'nsamples': 575},
#    'STSCZ2_wiki_cs_300_fasttext_sentence': {'pearson': [0.3868785144176036,
#      5.714763026518505e-22],
#     'spearman': [0.41038312114653325, 9.103095197254672e-25],
#     'nsamples': 575},
#    'STSCZ2_wiki_cs_300_fasttext_word': {'pearson': [0.3908428108187229,
#      1.9985047758088178e-22],
#     'spearman': [0.3923237445488398, 1.3447810335327034e-22],
#     'nsamples': 575},
#    'STSCZ2_elmo_139': {'pearson': [0.2329903804685388, 1.5791748168036417e-08],
#     'spearman': [0.2590260466174676, 2.8700177513725345e-10],
#     'nsamples': 575}},
#   'headlines2013-2015CZ_Stem': {'STSCZ2_bert-base-multilingual-cased_torch_all': {'pearson': [0.3962545288842209,
#      4.652956897964154e-23],
#     'spearman': [0.41891927731572953, 7.703530735021434e-26],
#     'nsamples': 575},
#    'STSCZ2_multi_cased_L-12_H-768_A-12_mean_pooled_torch_all': {'pearson': [0.5500609215232368,
#      8.790217089249806e-47],
#     'spearman': [0.5576246811887364, 2.7186974099362865e-48],
#     'nsamples': 575},
#    'STSCZ2_cc_cs_300_fasttext_sentence': {'pearson': [0.5735760143821316,
#      1.3198195046275271e-51],
#     'spearman': [0.5614396649125397, 4.55119260887321e-49],
#     'nsamples': 575},
#    'STSCZ2_cc_cs_300_fasttext_word': {'pearson': [0.5913218463807428,
#      1.636467714491527e-55],
#     'spearman': [0.5878736844979819, 9.816007703252722e-55],
#     'nsamples': 575},
#    'STSCZ2_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_mean_pooled_torch_all': {'pearson': [0.5538488560579653,
#      1.558837462357503e-47],
#     'spearman': [0.5620640682644243, 3.389350177575842e-49],
#     'nsamples': 575},
#    'STSCZ2_wiki_cs_300_fasttext_sentence': {'pearson': [0.6306228522020187,
#      4.3773725780115575e-65],
#     'spearman': [0.6313921752646786, 2.7539759127873423e-65],
#     'nsamples': 575},
#    'STSCZ2_wiki_cs_300_fasttext_word': {'pearson': [0.6108134445641521,
#      4.307106317054289e-60],
#     'spearman': [0.6094717055010657, 9.113227599234875e-60],
#     'nsamples': 575},
#    'STSCZ2_elmo_139': {'pearson': [0.1703655048219196, 4.0189339480149935e-05],
#     'spearman': [0.1767846846786471, 2.0120556603020266e-05],
#     'nsamples': 575}},
#   'imagesCZ2014-2015shuffled': {'STSCZ2_bert-base-multilingual-cased_torch_all': {'pearson': [0.39823996745015566,
#      1.0887829771845003e-33],
#     'spearman': [0.4543518361367437, 1.5890018878238387e-44],
#     'nsamples': 850},
#    'STSCZ2_multi_cased_L-12_H-768_A-12_mean_pooled_torch_all': {'pearson': [0.6273688052337667,
#      3.4021270359198095e-94],
#     'spearman': [0.6455169235005342, 2.3317744424249662e-101],
#     'nsamples': 850},
#    'STSCZ2_cc_cs_300_fasttext_sentence': {'pearson': [0.7048125806765313,
#      1.384861598637031e-128],
#     'spearman': [0.7081043087726708, 2.6893604314281973e-130],
#     'nsamples': 850},
#    'STSCZ2_cc_cs_300_fasttext_word': {'pearson': [0.5548659451588897,
#      8.515390503799146e-70],
#     'spearman': [0.5844968976025093, 5.003735297977067e-79],
#     'nsamples': 850},
#    'STSCZ2_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_mean_pooled_torch_all': {'pearson': [0.5812975521934146,
#      5.519731388514228e-78],
#     'spearman': [0.6066048496797043, 1.4681787976389586e-86],
#     'nsamples': 850},
#    'STSCZ2_wiki_cs_300_fasttext_sentence': {'pearson': [0.7018580923878122,
#      4.5467488413654345e-127],
#     'spearman': [0.7091848845708458, 7.286236004064457e-131],
#     'nsamples': 850},
#    'STSCZ2_wiki_cs_300_fasttext_word': {'pearson': [0.6772901914415662,
#      3.7711746976929466e-115],
#     'spearman': [0.6839990298264992, 2.7466709864076103e-118],
#     'nsamples': 850},
#    'STSCZ2_elmo_139': {'pearson': [0.4232190622846947, 2.914619268636632e-38],
#     'spearman': [0.4273675506366168, 4.646730252733158e-39],
#     'nsamples': 850}},
#   'imagesCZ2014-2015shuffled_Lemma': {'STSCZ2_bert-base-multilingual-cased_torch_all': {'pearson': [0.3919903739226422,
#      1.3224031526731955e-32],
#     'spearman': [0.43818568579934736, 3.425491335068501e-41],
#     'nsamples': 850},
#    'STSCZ2_multi_cased_L-12_H-768_A-12_mean_pooled_torch_all': {'pearson': [0.6195819994859347,
#      2.898911951647063e-91],
#     'spearman': [0.635206888091879, 3.137225589731125e-97],
#     'nsamples': 850},
#    'STSCZ2_cc_cs_300_fasttext_sentence': {'pearson': [0.7393735882155084,
#      7.704013199517808e-148],
#     'spearman': [0.7443441885904576, 7.302629298374185e-151],
#     'nsamples': 850},
#    'STSCZ2_cc_cs_300_fasttext_word': {'pearson': [0.6074012081481969,
#      7.661724106364479e-87],
#     'spearman': [0.6275360863325707, 2.9368373907941145e-94],
#     'nsamples': 850},
#    'STSCZ2_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_mean_pooled_torch_all': {'pearson': [0.592106116799881,
#      1.4873580332657153e-81],
#     'spearman': [0.6083225101535554, 3.6021196498727563e-87],
#     'nsamples': 850},
#    'STSCZ2_wiki_cs_300_fasttext_sentence': {'pearson': [0.7359997150144314,
#      7.936342852046774e-146],
#     'spearman': [0.7415273196145958, 3.8487834629323504e-149],
#     'nsamples': 850},
#    'STSCZ2_wiki_cs_300_fasttext_word': {'pearson': [0.6750581923847843,
#      3.998647005989418e-114],
#     'spearman': [0.6830525847607746, 7.701496660613658e-118],
#     'nsamples': 850},
#    'STSCZ2_elmo_139': {'pearson': [0.4202086138310282, 1.0872574107652364e-37],
#     'spearman': [0.4303735237049103, 1.2087940897535205e-39],
#     'nsamples': 850}},
#   'imagesCZ2014-2015shuffled_POSTag': {'STSCZ2_bert-base-multilingual-cased_torch_all': {'pearson': [0.32399976126609514,
#      3.167770357374969e-22],
#     'spearman': [0.3858731918134056, 1.447016556735035e-31],
#     'nsamples': 850},
#    'STSCZ2_multi_cased_L-12_H-768_A-12_mean_pooled_torch_all': {'pearson': [0.4558206945539104,
#      7.749172160365418e-45],
#     'spearman': [0.4817060592450098, 1.3694590407236705e-50],
#     'nsamples': 850},
#    'STSCZ2_cc_cs_300_fasttext_sentence': {'pearson': [0.4423134693402556,
#      5.0179864058840023e-42],
#     'spearman': [0.48081309756277546, 2.204551748562595e-50],
#     'nsamples': 850},
#    'STSCZ2_cc_cs_300_fasttext_word': {'pearson': [0.48461036950239644,
#      2.882668780105476e-51],
#     'spearman': [0.5096284296100534, 2.2518755727202835e-57],
#     'nsamples': 850},
#    'STSCZ2_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_mean_pooled_torch_all': {'pearson': [0.4511146843189074,
#      7.639938983537043e-44],
#     'spearman': [0.47125912619517135, 3.2943796183918465e-48],
#     'nsamples': 850},
#    'STSCZ2_wiki_cs_300_fasttext_sentence': {'pearson': [0.45349860410064413,
#      2.407608736621139e-44],
#     'spearman': [0.4916190156637625, 6.303959698974724e-53],
#     'nsamples': 850},
#    'STSCZ2_wiki_cs_300_fasttext_word': {'pearson': [0.4833751116265437,
#      5.603073733291127e-51],
#     'spearman': [0.49793198446976517, 1.8658605219501352e-54],
#     'nsamples': 850},
#    'STSCZ2_elmo_139': {'pearson': [0.30262663318267763,
#      1.8397141127193628e-19],
#     'spearman': [0.3180284779814953, 1.9756877171941047e-21],
#     'nsamples': 850}},
#   'imagesCZ2014-2015shuffled_Stem': {'STSCZ2_bert-base-multilingual-cased_torch_all': {'pearson': [0.45132659947990533,
#      6.897157487274878e-44],
#     'spearman': [0.505983061731143, 1.8804546301508516e-56],
#     'nsamples': 850},
#    'STSCZ2_multi_cased_L-12_H-768_A-12_mean_pooled_torch_all': {'pearson': [0.607900498018535,
#      5.091309025872096e-87],
#     'spearman': [0.6339542548596686, 9.716456709198145e-97],
#     'nsamples': 850},
#    'STSCZ2_cc_cs_300_fasttext_sentence': {'pearson': [0.7353753528254581,
#      1.85664216807523e-145],
#     'spearman': [0.7422130456360874, 1.473131314342989e-149],
#     'nsamples': 850},
#    'STSCZ2_cc_cs_300_fasttext_word': {'pearson': [0.6028325790730802,
#      3.1183208471869164e-85],
#     'spearman': [0.6184371153239391, 7.694236018979995e-91],
#     'nsamples': 850},
#    'STSCZ2_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_mean_pooled_torch_all': {'pearson': [0.6078138271687633,
#      5.46592297385187e-87],
#     'spearman': [0.6359881497473486, 1.5459040724569876e-97],
#     'nsamples': 850},
#    'STSCZ2_wiki_cs_300_fasttext_sentence': {'pearson': [0.7577233817099545,
#      2.316473048568603e-159],
#     'spearman': [0.7636134899941573, 2.788963075961417e-163],
#     'nsamples': 850},
#    'STSCZ2_wiki_cs_300_fasttext_word': {'pearson': [0.7113914392947454,
#      4.9686619923375874e-132],
#     'spearman': [0.7196827416897724, 1.635395105461824e-136],
#     'nsamples': 850},
#    'STSCZ2_elmo_139': {'pearson': [0.36643309026823806, 2.088664583648101e-28],
#     'spearman': [0.39780398134790557, 1.2982228593714966e-33],
#     'nsamples': 850}}},
#  'STS16': {'answer-answer': {'STS16_bert-base-cased_mean_pooled_torch': {'pearson': [0.32110346404764606,
#      1.6814153533209378e-07],
#     'spearman': [0.3751744218750229, 6.537125413890069e-10],
#     'nsamples': 254},
#    'STS16_bert-base-cased_torch': {'pearson': [0.3531108035612372,
#      7.148159624073278e-09],
#     'spearman': [0.3948697595833895, 6.602986415547235e-11],
#     'nsamples': 254},
#    'STS16_cc_en_300_fasttext_sentence': {'pearson': [0.3489388038056709,
#      1.1011975021318023e-08],
#     'spearman': [0.4000999456948449, 3.500001868869484e-11],
#     'nsamples': 254},
#    'STS16_cc_en_300_fasttext_word': {'pearson': [0.18434807394519095,
#      0.003189607186792924],
#     'spearman': [0.25070476391131463, 5.3317975010263185e-05],
#     'nsamples': 254},
#    'STS16_wiki_cs_300_fasttext_sentence': {'pearson': [0.23995709280797442,
#      0.00011246310711919195],
#     'spearman': [0.2719313954499254, 1.1046214842047455e-05],
#     'nsamples': 254},
#    'STS16_wiki_cs_300_fasttext_word': {'pearson': [0.2099749872211533,
#      0.0007583532209409944],
#     'spearman': [0.2605533619486473, 2.6118389179583894e-05],
#     'nsamples': 254}},
#   'headlines': {'STS16_bert-base-cased_mean_pooled_torch': {'pearson': [0.5421631916919518,
#      1.9897402815149126e-20],
#     'spearman': [0.6168922308032694, 1.6764839523992787e-27],
#     'nsamples': 249},
#    'STS16_bert-base-cased_torch': {'pearson': [0.5892013636320054,
#      1.149333186897537e-24],
#     'spearman': [0.6284451736039791, 9.037828181712479e-29],
#     'nsamples': 249},
#    'STS16_cc_en_300_fasttext_sentence': {'pearson': [0.6401576283447556,
#      4.117441200833762e-30],
#     'spearman': [0.6458778887368579, 8.67168824588698e-31],
#     'nsamples': 249},
#    'STS16_cc_en_300_fasttext_word': {'pearson': [0.4406466314596257,
#      2.9867596389026083e-13],
#     'spearman': [0.440220184351843, 3.166659005556519e-13],
#     'nsamples': 249},
#    'STS16_wiki_cs_300_fasttext_sentence': {'pearson': [0.5991475800587382,
#      1.1840756619927356e-25],
#     'spearman': [0.6446634747087941, 1.2104216786371427e-30],
#     'nsamples': 249},
#    'STS16_wiki_cs_300_fasttext_word': {'pearson': [0.6120752842758558,
#      5.4686442419782505e-27],
#     'spearman': [0.6405073921520866, 3.746905552141949e-30],
#     'nsamples': 249}},
#   'plagiarism': {'STS16_bert-base-cased_mean_pooled_torch': {'pearson': [0.4900225542310833,
#      2.6995446608184965e-15],
#     'spearman': [0.5088572683951347, 1.4935642762647775e-16],
#     'nsamples': 230},
#    'STS16_bert-base-cased_torch': {'pearson': [0.4357427632627837,
#      4.473836994859913e-12],
#     'spearman': [0.5561956360797917, 4.4494555238689656e-20],
#     'nsamples': 230},
#    'STS16_cc_en_300_fasttext_sentence': {'pearson': [0.5665088977043184,
#      6.360182761365652e-21],
#     'spearman': [0.580781868974906, 3.8407620252615156e-22],
#     'nsamples': 230},
#    'STS16_cc_en_300_fasttext_word': {'pearson': [0.28751150543021686,
#      9.402574508260559e-06],
#     'spearman': [0.3629615524141609, 1.4354400734699763e-08],
#     'nsamples': 230},
#    'STS16_wiki_cs_300_fasttext_sentence': {'pearson': [0.4886277422714877,
#      3.321580335825171e-15],
#     'spearman': [0.5187306378200451, 3.045298624050369e-17],
#     'nsamples': 230},
#    'STS16_wiki_cs_300_fasttext_word': {'pearson': [0.5045992871412172,
#      2.9188982065753e-16],
#     'spearman': [0.5193969449712086, 2.7303188819245816e-17],
#     'nsamples': 230}},
#   'postediting': {'STS16_bert-base-cased_mean_pooled_torch': {'pearson': [0.3969384066508668,
#      1.236012143298513e-10],
#     'spearman': [0.7322140978055455, 2.995860983837213e-42],
#     'nsamples': 244},
#    'STS16_bert-base-cased_torch': {'pearson': [0.4218221282547021,
#      6.0297624278997545e-12],
#     'spearman': [0.7468032838634672, 9.224173490233604e-45],
#     'nsamples': 244},
#    'STS16_cc_en_300_fasttext_sentence': {'pearson': [0.5887341559442562,
#      3.736026717110978e-24],
#     'spearman': [0.7292372771506441, 9.307228992240356e-42],
#     'nsamples': 244},
#    'STS16_cc_en_300_fasttext_word': {'pearson': [0.4252609518666171,
#      3.893884338763317e-12],
#     'spearman': [0.6200986368552872, 2.564532364877301e-27],
#     'nsamples': 244},
#    'STS16_wiki_cs_300_fasttext_sentence': {'pearson': [0.5348062727605822,
#      1.8759821365809316e-19],
#     'spearman': [0.7374128515808515, 3.987937219184984e-43],
#     'nsamples': 244},
#    'STS16_wiki_cs_300_fasttext_word': {'pearson': [0.5499744224242898,
#      1.0869205703329944e-20],
#     'spearman': [0.7471426062291399, 8.025427879417118e-45],
#     'nsamples': 244}},
#   'question-question': {'STS16_bert-base-cased_mean_pooled_torch': {'pearson': [0.24207225186486922,
#      0.0004135599851528423],
#     'spearman': [0.30169321607902844, 9.027432895757852e-06],
#     'nsamples': 209},
#    'STS16_bert-base-cased_torch': {'pearson': [0.24391960688286882,
#      0.00037217708397526073],
#     'spearman': [0.2798099966097731, 4.0753309555780803e-05],
#     'nsamples': 209},
#    'STS16_cc_en_300_fasttext_sentence': {'pearson': [0.30097857472393397,
#      9.501628652486875e-06],
#     'spearman': [0.3344035750923563, 7.473758041967051e-07],
#     'nsamples': 209},
#    'STS16_cc_en_300_fasttext_word': {'pearson': [-0.007292283345907742,
#      0.9165405046070281],
#     'spearman': [0.010006435136935696, 0.8856604843739284],
#     'nsamples': 209},
#    'STS16_wiki_cs_300_fasttext_sentence': {'pearson': [0.18455880540218667,
#      0.00746949566148706],
#     'spearman': [0.20476508016435058, 0.002938701693513246],
#     'nsamples': 209},
#    'STS16_wiki_cs_300_fasttext_word': {'pearson': [0.21050625631782952,
#      0.002218127569281186],
#     'spearman': [0.23436131446152753, 0.0006366620769744242],
#     'nsamples': 209}},
#   'all': {'STS16_bert-base-cased_mean_pooled_torch': {'pearson': {'mean': 0.3984599736972834,
#      'wmean': 0.40194787009706273},
#     'spearman': {'mean': 0.5069662469916002, 'wmean': 0.5123539311823111}},
#    'STS16_bert-base-cased_torch': {'pearson': {'mean': 0.4087593331187194,
#      'wmean': 0.4135968940404981},
#     'spearman': {'mean': 0.5212247699480801, 'wmean': 0.5273229797757608}},
#    'STS16_cc_en_300_fasttext_sentence': {'pearson': {'mean': 0.489063612104587,
#      'wmean': 0.4931554875751927},
#     'spearman': {'mean': 0.5380801111299218, 'wmean': 0.5428777851477707}},
#    'STS16_cc_en_300_fasttext_word': {'pearson': {'mean': 0.26609497587114855,
#      'wmean': 0.27395670598704475},
#     'spearman': {'mean': 0.3367983145339083, 'wmean': 0.345843512081492}},
#    'STS16_wiki_cs_300_fasttext_sentence': {'pearson': {'mean': 0.4094194986601939,
#      'wmean': 0.4144913580210224},
#     'spearman': {'mean': 0.4755006879447933, 'wmean': 0.4819767823654791}},
#    'STS16_wiki_cs_300_fasttext_word': {'pearson': {'mean': 0.41742604747606915,
#      'wmean': 0.4215748694968753},
#     'spearman': {'mean': 0.480392323952522, 'wmean': 0.48601391447434505}}}},
#  'STS162': {'answer-answer': {'STS162_bert-base-cased_torch': {'pearson': [0.3760310146895078,
#      5.935410067050635e-10],
#     'spearman': [0.40001297415205916, 3.5374629184793124e-11],
#     'nsamples': 254},
#    'STS162_bert-base-cased_mean_pooled_torch': {'pearson': [0.5550939755708896,
#      6.249200759095932e-22],
#     'spearman': [0.569130625791919, 3.331910569319697e-23],
#     'nsamples': 254},
#    'STS162_cc_en_300_fasttext_sentence': {'pearson': [0.3489387982476427,
#      1.1011981314753832e-08],
#     'spearman': [0.4000999456948449, 3.500001868869484e-11],
#     'nsamples': 254},
#    'STS162_cc_en_300_fasttext_word': {'pearson': [0.3603717373295795,
#      3.3190225191758626e-09],
#     'spearman': [0.3770480267775135, 5.290565259287277e-10],
#     'nsamples': 254},
#    'STS162_wiki_cs_300_fasttext_sentence': {'pearson': [0.23995708982819816,
#      0.0001124631298695971],
#     'spearman': [0.2719313954499254, 1.1046214842047455e-05],
#     'nsamples': 254},
#    'STS162_wiki_cs_300_fasttext_word': {'pearson': [0.32601016305496777,
#      1.0603495661903907e-07],
#     'spearman': [0.3565669717979974, 4.973316461156873e-09],
#     'nsamples': 254}},
#   'headlines': {'STS162_bert-base-cased_torch': {'pearson': [0.5036459855635268,
#      2.0219645721518128e-17],
#     'spearman': [0.5056978395823368, 1.428961297341267e-17],
#     'nsamples': 249},
#    'STS162_bert-base-cased_mean_pooled_torch': {'pearson': [0.6334819915268047,
#      2.4335892711056615e-29],
#     'spearman': [0.6396281950965452, 4.748092819529793e-30],
#     'nsamples': 249},
#    'STS162_cc_en_300_fasttext_sentence': {'pearson': [0.6401576283205536,
#      4.117441227683796e-30],
#     'spearman': [0.6458783907801084, 8.67049008312231e-31],
#     'nsamples': 249},
#    'STS162_cc_en_300_fasttext_word': {'pearson': [0.5480804829777879,
#      6.33698708617134e-21],
#     'spearman': [0.5444451323168672, 1.2833014349853117e-20],
#     'nsamples': 249},
#    'STS162_wiki_cs_300_fasttext_sentence': {'pearson': [0.5991475806915812,
#      1.1840754877743174e-25],
#     'spearman': [0.6446634747087941, 1.2104216786371427e-30],
#     'nsamples': 249},
#    'STS162_wiki_cs_300_fasttext_word': {'pearson': [0.6269840730630858,
#      1.3164719638344547e-28],
#     'spearman': [0.6370108112663807, 9.565863215816966e-30],
#     'nsamples': 249}},
#   'plagiarism': {'STS162_bert-base-cased_torch': {'pearson': [0.6131590669704027,
#      3.852471282985387e-25],
#     'spearman': [0.6668246664170382, 5.974643730124522e-31],
#     'nsamples': 230},
#    'STS162_bert-base-cased_mean_pooled_torch': {'pearson': [0.7655284968786941,
#      1.4831953871553005e-45],
#     'spearman': [0.7828603033522973, 6.970649011429045e-49],
#     'nsamples': 230},
#    'STS162_cc_en_300_fasttext_sentence': {'pearson': [0.566508899062466,
#      6.36018110348505e-21],
#     'spearman': [0.580781868974906, 3.8407620252615156e-22],
#     'nsamples': 230},
#    'STS162_cc_en_300_fasttext_word': {'pearson': [0.6431740251760772,
#      3.016433554005771e-28],
#     'spearman': [0.6489936858725174, 6.863813748491504e-29],
#     'nsamples': 230},
#    'STS162_wiki_cs_300_fasttext_sentence': {'pearson': [0.48862774500418377,
#      3.321578989492972e-15],
#     'spearman': [0.5187306378200451, 3.045298624050369e-17],
#     'nsamples': 230},
#    'STS162_wiki_cs_300_fasttext_word': {'pearson': [0.6623034175641477,
#      2.0514890279924012e-30],
#     'spearman': [0.6864922499812324, 2.149251654294826e-33],
#     'nsamples': 230}},
#   'postediting': {'STS162_bert-base-cased_torch': {'pearson': [0.7019757556504326,
#      1.5532772728688603e-37],
#     'spearman': [0.7637626994830876, 6.603689616359677e-48],
#     'nsamples': 244},
#    'STS162_bert-base-cased_mean_pooled_torch': {'pearson': [0.8022864710063166,
#      3.7962941045441648e-56],
#     'spearman': [0.8300453439104866, 2.6173818814507954e-63],
#     'nsamples': 244},
#    'STS162_cc_en_300_fasttext_sentence': {'pearson': [0.5887341575324284,
#      3.736025413459128e-24],
#     'spearman': [0.7292372771506441, 9.307228992240356e-42],
#     'nsamples': 244},
#    'STS162_cc_en_300_fasttext_word': {'pearson': [0.740355557939472,
#      1.2466569078097058e-43],
#     'spearman': [0.790012845258126, 2.464893509685889e-53],
#     'nsamples': 244},
#    'STS162_wiki_cs_300_fasttext_sentence': {'pearson': [0.5348062734239757,
#      1.8759819087250393e-19],
#     'spearman': [0.7374128515808515, 3.987937219184984e-43],
#     'nsamples': 244},
#    'STS162_wiki_cs_300_fasttext_word': {'pearson': [0.766695343904831,
#      1.7742513748154504e-48],
#     'spearman': [0.8256500719837734, 4.320332385032603e-62],
#     'nsamples': 244}},
#   'question-question': {'STS162_bert-base-cased_torch': {'pearson': [0.06937425637682093,
#      0.318221115521911],
#     'spearman': [0.116497183169029, 0.09299546063963784],
#     'nsamples': 209},
#    'STS162_bert-base-cased_mean_pooled_torch': {'pearson': [0.45670528209797157,
#      3.642326627461808e-12],
#     'spearman': [0.43585629590739194, 4.221429214501767e-11],
#     'nsamples': 209},
#    'STS162_cc_en_300_fasttext_sentence': {'pearson': [0.30097856413038576,
#      9.501635853723448e-06],
#     'spearman': [0.3344035750923563, 7.473758041967051e-07],
#     'nsamples': 209},
#    'STS162_cc_en_300_fasttext_word': {'pearson': [0.08615934376826677,
#      0.21481680710414694],
#     'spearman': [0.0868219577462059, 0.2112978929850528],
#     'nsamples': 209},
#    'STS162_wiki_cs_300_fasttext_sentence': {'pearson': [0.18455880077678855,
#      0.007469497181510661],
#     'spearman': [0.20476508016435058, 0.002938701693513246],
#     'nsamples': 209},
#    'STS162_wiki_cs_300_fasttext_word': {'pearson': [0.4290110963614181,
#      9.106210221564432e-11],
#     'spearman': [0.43785584245234965, 3.361346402191228e-11],
#     'nsamples': 209}},
#   'all': {'STS162_bert-base-cased_torch': {'pearson': {'mean': 0.4528372158501381,
#      'wmean': 0.4618276707429232},
#     'spearman': {'mean': 0.4905590725607102, 'wmean': 0.49881765659590555}},
#    'STS162_bert-base-cased_mean_pooled_torch': {'pearson': {'mean': 0.6426192434161353,
#      'wmean': 0.6458783666537076},
#     'spearman': {'mean': 0.651504152811728, 'wmean': 0.6555729334401511}},
#    'STS162_cc_en_300_fasttext_sentence': {'pearson': {'mean': 0.4890636094586953,
#      'wmean': 0.49315548510307705},
#     'spearman': {'mean': 0.538080211538572, 'wmean': 0.542877890551455}},
#    'STS162_cc_en_300_fasttext_word': {'pearson': {'mean': 0.4756282294382366,
#      'wmean': 0.4844776950408762},
#     'spearman': {'mean': 0.489464329594246, 'wmean': 0.4987474771593651}},
#    'STS162_wiki_cs_300_fasttext_sentence': {'pearson': {'mean': 0.4094194979449455,
#      'wmean': 0.414491357367055},
#     'spearman': {'mean': 0.4755006879447933, 'wmean': 0.4819767823654791}},
#    'STS162_wiki_cs_300_fasttext_word': {'pearson': {'mean': 0.56220081878969,
#      'wmean': 0.5632313530360366},
#     'spearman': {'mean': 0.5887151894963466, 'wmean': 0.5902591981233434}}}}}

# %%
PEARSON='pearson'
SPEARMAN='spearman'
ALL_DATASETS='all'
MEAN='wmean'

pearson_results = {}
spearman_results = {}
all_results = {}
for task in res_by_task:
    pearson_results[task] = {}
    spearman_results[task] = {}
    gen = (dataset for dataset in res_by_task[task] if dataset != ALL_DATASETS)
    for dataset in gen:
        pearson_results[task][dataset] = {}
        spearman_results[task][dataset] = {}
        for res in res_by_task[task][dataset]:
            pearson_results[task][dataset][res] = res_by_task[task][dataset][res][PEARSON][0]
            spearman_results[task][dataset][res] = res_by_task[task][dataset][res][SPEARMAN][0]
    all_results[task] = {}
    all_results[task][PEARSON] = {}
    all_results[task][SPEARMAN] = {}
    for res in res_by_task[task][ALL_DATASETS]:
        all_results[task][PEARSON][res] = res_by_task[task][ALL_DATASETS][res][PEARSON][MEAN]
        all_results[task][SPEARMAN][res] = res_by_task[task][ALL_DATASETS][res][SPEARMAN][MEAN]
    
pearson_results
# Out:
# {'STSCZ': {'headlines': {'STSCZ_bert-base-multilingual-cased_torch': 0.45181167547936035,
#    'STSCZ_multi_cased_L-12_H-768_A-12_torch': 0.5101076658989366,
#    'STSCZ_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_torch': 0.5250992742990885,
#    'STSCZ_multi_cased_L-12_H-768_A-12_mean_pooled_torch': 0.5020967154907711,
#    'STSCZ_bert-base-multilingual-cased_torch_headlines': 0.45181167547936035,
#    'STSCZ_bert-base-multilingual-cased_torch_all': 0.45181167547936035,
#    'STSCZ_multi_cased_L-12_H-768_A-12_mean_pooled_torch_all': 0.5020967154907711,
#    'STSCZ_cc_cs_300_fasttext_sentence': 0.5820461373692433,
#    'STSCZ_cc_cs_300_fasttext_word': 0.45243410576300863,
#    'STSCZ_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_mean_pooled_torch_all': 0.5125391564169962,
#    'STSCZ_wiki_cs_300_fasttext_sentence': 0.6458306696096886,
#    'STSCZ_wiki_cs_300_fasttext_word': 0.6286271983412663,
#    'STSCZ_elmo_139': 0.5147392972800048},
#   'images': {'STSCZ_bert-base-multilingual-cased_torch': 0.43734476852886184,
#    'STSCZ_multi_cased_L-12_H-768_A-12_torch': 0.5300776517070618,
#    'STSCZ_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_torch': 0.5180317559416066,
#    'STSCZ_multi_cased_L-12_H-768_A-12_mean_pooled_torch': 0.5589500586797128,
#    'STSCZ_bert-base-multilingual-cased_torch_headlines': 0.016953513009774122,
#    'STSCZ_bert-base-multilingual-cased_torch_all': 0.43734476852886184,
#    'STSCZ_multi_cased_L-12_H-768_A-12_mean_pooled_torch_all': 0.5589500586797128,
#    'STSCZ_cc_cs_300_fasttext_sentence': 0.704812580513345,
#    'STSCZ_cc_cs_300_fasttext_word': 0.5523616913911996,
#    'STSCZ_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_mean_pooled_torch_all': 0.5151341479034207,
#    'STSCZ_wiki_cs_300_fasttext_sentence': 0.7018580923853577,
#    'STSCZ_wiki_cs_300_fasttext_word': 0.7296737182595723,
#    'STSCZ_elmo_139': 0.6239431237201327},
#   'headlines2013-2015CZ_Lemma': {'STSCZ_bert-base-multilingual-cased_torch_all': 0.4150248298334991,
#    'STSCZ_multi_cased_L-12_H-768_A-12_mean_pooled_torch_all': 0.4829875732788488,
#    'STSCZ_cc_cs_300_fasttext_sentence': 0.587485564515748,
#    'STSCZ_cc_cs_300_fasttext_word': 0.43930747947377846,
#    'STSCZ_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_mean_pooled_torch_all': 0.5167208035265121,
#    'STSCZ_wiki_cs_300_fasttext_sentence': 0.612050388203227,
#    'STSCZ_wiki_cs_300_fasttext_word': 0.6280712234124126,
#    'STSCZ_elmo_139': 0.5311890238284899},
#   'headlines2013-2015CZ_POSTag': {'STSCZ_bert-base-multilingual-cased_torch_all': 0.24801205708553467,
#    'STSCZ_multi_cased_L-12_H-768_A-12_mean_pooled_torch_all': 0.2794474827397236,
#    'STSCZ_cc_cs_300_fasttext_sentence': 0.36263788030530675,
#    'STSCZ_cc_cs_300_fasttext_word': 0.23938439723774907,
#    'STSCZ_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_mean_pooled_torch_all': 0.2517572533014806,
#    'STSCZ_wiki_cs_300_fasttext_sentence': 0.3868785145953727,
#    'STSCZ_wiki_cs_300_fasttext_word': 0.2755796463719494,
#    'STSCZ_elmo_139': 0.1385821411229395},
#   'headlines2013-2015CZ_Stem': {'STSCZ_bert-base-multilingual-cased_torch_all': 0.4073203804950766,
#    'STSCZ_multi_cased_L-12_H-768_A-12_mean_pooled_torch_all': 0.5033665476237332,
#    'STSCZ_cc_cs_300_fasttext_sentence': 0.5735760151895442,
#    'STSCZ_cc_cs_300_fasttext_word': 0.41848623090201237,
#    'STSCZ_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_mean_pooled_torch_all': 0.49729705576546285,
#    'STSCZ_wiki_cs_300_fasttext_sentence': 0.6306228536559314,
#    'STSCZ_wiki_cs_300_fasttext_word': 0.6716863548568717,
#    'STSCZ_elmo_139': 0.5119110928299921},
#   'imagesCZ2014-2015shuffled': {'STSCZ_bert-base-multilingual-cased_torch_all': 0.4373447685288619,
#    'STSCZ_multi_cased_L-12_H-768_A-12_mean_pooled_torch_all': 0.558950058679713,
#    'STSCZ_cc_cs_300_fasttext_sentence': 0.7048125805133452,
#    'STSCZ_cc_cs_300_fasttext_word': 0.5523616913911996,
#    'STSCZ_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_mean_pooled_torch_all': 0.5151341479034207,
#    'STSCZ_wiki_cs_300_fasttext_sentence': 0.7018580923853578,
#    'STSCZ_wiki_cs_300_fasttext_word': 0.7296737182595725,
#    'STSCZ_elmo_139': 0.6239431237201327},
#   'imagesCZ2014-2015shuffled_Lemma': {'STSCZ_bert-base-multilingual-cased_torch_all': 0.48246330212387195,
#    'STSCZ_multi_cased_L-12_H-768_A-12_mean_pooled_torch_all': 0.6342237892143996,
#    'STSCZ_cc_cs_300_fasttext_sentence': 0.7393735872345127,
#    'STSCZ_cc_cs_300_fasttext_word': 0.6368556939138795,
#    'STSCZ_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_mean_pooled_torch_all': 0.5829819924080402,
#    'STSCZ_wiki_cs_300_fasttext_sentence': 0.735999712847127,
#    'STSCZ_wiki_cs_300_fasttext_word': 0.7802867430497888,
#    'STSCZ_elmo_139': 0.6804584567497891},
#   'imagesCZ2014-2015shuffled_POSTag': {'STSCZ_bert-base-multilingual-cased_torch_all': 0.36082666389871754,
#    'STSCZ_multi_cased_L-12_H-768_A-12_mean_pooled_torch_all': 0.4314614024130017,
#    'STSCZ_cc_cs_300_fasttext_sentence': 0.4423134703370569,
#    'STSCZ_cc_cs_300_fasttext_word': 0.17169138733392075,
#    'STSCZ_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_mean_pooled_torch_all': 0.40898305843998134,
#    'STSCZ_wiki_cs_300_fasttext_sentence': 0.45349860383880175,
#    'STSCZ_wiki_cs_300_fasttext_word': 0.25065664033570695,
#    'STSCZ_elmo_139': 0.2600290534664051},
#   'imagesCZ2014-2015shuffled_Stem': {'STSCZ_bert-base-multilingual-cased_torch_all': 0.5266408527353151,
#    'STSCZ_multi_cased_L-12_H-768_A-12_mean_pooled_torch_all': 0.6133111200183127,
#    'STSCZ_cc_cs_300_fasttext_sentence': 0.7353753514470425,
#    'STSCZ_cc_cs_300_fasttext_word': 0.6428495593758667,
#    'STSCZ_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_mean_pooled_torch_all': 0.5997914463768859,
#    'STSCZ_wiki_cs_300_fasttext_sentence': 0.7577233822197231,
#    'STSCZ_wiki_cs_300_fasttext_word': 0.7909716516639285,
#    'STSCZ_elmo_139': 0.6236893057858786}},
#  'STSCZ2': {'headlines': {'STSCZ2_bert-base-multilingual-cased_torch': 0.38382098407064996,
#    'STSCZ2_multi_cased_L-12_H-768_A-12_torch': 0.5544278878699856,
#    'STSCZ2_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_torch': 0.5340470627349253,
#    'STSCZ2_multi_cased_L-12_H-768_A-12_mean_pooled_torch': 0.558530011585776,
#    'STSCZ2_bert-base-multilingual-cased_torch_all': 0.38382098407064996,
#    'STSCZ2_multi_cased_L-12_H-768_A-12_mean_pooled_torch_all': 0.558530011585776,
#    'STSCZ2_cc_cs_300_fasttext_sentence': 0.5820461378683905,
#    'STSCZ2_cc_cs_300_fasttext_word': 0.5767938496545317,
#    'STSCZ2_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_mean_pooled_torch_all': 0.5373962151229553,
#    'STSCZ2_wiki_cs_300_fasttext_sentence': 0.6458306696175045,
#    'STSCZ2_wiki_cs_300_fasttext_word': 0.60420279620433,
#    'STSCZ2_elmo_139': 0.27255224235255404},
#   'images': {'STSCZ2_bert-base-multilingual-cased_torch': 0.3982399674501556,
#    'STSCZ2_multi_cased_L-12_H-768_A-12_torch': 0.6128901535718398,
#    'STSCZ2_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_torch': 0.5726332037719152,
#    'STSCZ2_multi_cased_L-12_H-768_A-12_mean_pooled_torch': 0.6273688052337666,
#    'STSCZ2_bert-base-multilingual-cased_torch_all': 0.3982399674501556,
#    'STSCZ2_multi_cased_L-12_H-768_A-12_mean_pooled_torch_all': 0.6273688052337666,
#    'STSCZ2_cc_cs_300_fasttext_sentence': 0.7048125806765313,
#    'STSCZ2_cc_cs_300_fasttext_word': 0.5548804656126964,
#    'STSCZ2_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_mean_pooled_torch_all': 0.5812975521934144,
#    'STSCZ2_wiki_cs_300_fasttext_sentence': 0.7018580923878125,
#    'STSCZ2_wiki_cs_300_fasttext_word': 0.6772680683392207,
#    'STSCZ2_elmo_139': 0.42321391691747406},
#   'headlines2013-2015CZ_Lemma': {'STSCZ2_bert-base-multilingual-cased_torch_all': 0.37420771967025546,
#    'STSCZ2_multi_cased_L-12_H-768_A-12_mean_pooled_torch_all': 0.5677451062309433,
#    'STSCZ2_cc_cs_300_fasttext_sentence': 0.5874855657237583,
#    'STSCZ2_cc_cs_300_fasttext_word': 0.620097854441282,
#    'STSCZ2_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_mean_pooled_torch_all': 0.5712144670660695,
#    'STSCZ2_wiki_cs_300_fasttext_sentence': 0.6120503889054463,
#    'STSCZ2_wiki_cs_300_fasttext_word': 0.6113611444434196,
#    'STSCZ2_elmo_139': 0.2840609945925119},
#   'headlines2013-2015CZ_POSTag': {'STSCZ2_bert-base-multilingual-cased_torch_all': 0.24717603885372336,
#    'STSCZ2_multi_cased_L-12_H-768_A-12_mean_pooled_torch_all': 0.31613694740319875,
#    'STSCZ2_cc_cs_300_fasttext_sentence': 0.3626378777881063,
#    'STSCZ2_cc_cs_300_fasttext_word': 0.4048563616752499,
#    'STSCZ2_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_mean_pooled_torch_all': 0.2864644682129161,
#    'STSCZ2_wiki_cs_300_fasttext_sentence': 0.3868785144176036,
#    'STSCZ2_wiki_cs_300_fasttext_word': 0.3908428108187229,
#    'STSCZ2_elmo_139': 0.2329903804685388},
#   'headlines2013-2015CZ_Stem': {'STSCZ2_bert-base-multilingual-cased_torch_all': 0.3962545288842209,
#    'STSCZ2_multi_cased_L-12_H-768_A-12_mean_pooled_torch_all': 0.5500609215232368,
#    'STSCZ2_cc_cs_300_fasttext_sentence': 0.5735760143821316,
#    'STSCZ2_cc_cs_300_fasttext_word': 0.5913218463807428,
#    'STSCZ2_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_mean_pooled_torch_all': 0.5538488560579653,
#    'STSCZ2_wiki_cs_300_fasttext_sentence': 0.6306228522020187,
#    'STSCZ2_wiki_cs_300_fasttext_word': 0.6108134445641521,
#    'STSCZ2_elmo_139': 0.1703655048219196},
#   'imagesCZ2014-2015shuffled': {'STSCZ2_bert-base-multilingual-cased_torch_all': 0.39823996745015566,
#    'STSCZ2_multi_cased_L-12_H-768_A-12_mean_pooled_torch_all': 0.6273688052337667,
#    'STSCZ2_cc_cs_300_fasttext_sentence': 0.7048125806765313,
#    'STSCZ2_cc_cs_300_fasttext_word': 0.5548659451588897,
#    'STSCZ2_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_mean_pooled_torch_all': 0.5812975521934146,
#    'STSCZ2_wiki_cs_300_fasttext_sentence': 0.7018580923878122,
#    'STSCZ2_wiki_cs_300_fasttext_word': 0.6772901914415662,
#    'STSCZ2_elmo_139': 0.4232190622846947},
#   'imagesCZ2014-2015shuffled_Lemma': {'STSCZ2_bert-base-multilingual-cased_torch_all': 0.3919903739226422,
#    'STSCZ2_multi_cased_L-12_H-768_A-12_mean_pooled_torch_all': 0.6195819994859347,
#    'STSCZ2_cc_cs_300_fasttext_sentence': 0.7393735882155084,
#    'STSCZ2_cc_cs_300_fasttext_word': 0.6074012081481969,
#    'STSCZ2_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_mean_pooled_torch_all': 0.592106116799881,
#    'STSCZ2_wiki_cs_300_fasttext_sentence': 0.7359997150144314,
#    'STSCZ2_wiki_cs_300_fasttext_word': 0.6750581923847843,
#    'STSCZ2_elmo_139': 0.4202086138310282},
#   'imagesCZ2014-2015shuffled_POSTag': {'STSCZ2_bert-base-multilingual-cased_torch_all': 0.32399976126609514,
#    'STSCZ2_multi_cased_L-12_H-768_A-12_mean_pooled_torch_all': 0.4558206945539104,
#    'STSCZ2_cc_cs_300_fasttext_sentence': 0.4423134693402556,
#    'STSCZ2_cc_cs_300_fasttext_word': 0.48461036950239644,
#    'STSCZ2_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_mean_pooled_torch_all': 0.4511146843189074,
#    'STSCZ2_wiki_cs_300_fasttext_sentence': 0.45349860410064413,
#    'STSCZ2_wiki_cs_300_fasttext_word': 0.4833751116265437,
#    'STSCZ2_elmo_139': 0.30262663318267763},
#   'imagesCZ2014-2015shuffled_Stem': {'STSCZ2_bert-base-multilingual-cased_torch_all': 0.45132659947990533,
#    'STSCZ2_multi_cased_L-12_H-768_A-12_mean_pooled_torch_all': 0.607900498018535,
#    'STSCZ2_cc_cs_300_fasttext_sentence': 0.7353753528254581,
#    'STSCZ2_cc_cs_300_fasttext_word': 0.6028325790730802,
#    'STSCZ2_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_mean_pooled_torch_all': 0.6078138271687633,
#    'STSCZ2_wiki_cs_300_fasttext_sentence': 0.7577233817099545,
#    'STSCZ2_wiki_cs_300_fasttext_word': 0.7113914392947454,
#    'STSCZ2_elmo_139': 0.36643309026823806}},
#  'STS16': {'answer-answer': {'STS16_bert-base-cased_mean_pooled_torch': 0.32110346404764606,
#    'STS16_bert-base-cased_torch': 0.3531108035612372,
#    'STS16_cc_en_300_fasttext_sentence': 0.3489388038056709,
#    'STS16_cc_en_300_fasttext_word': 0.18434807394519095,
#    'STS16_wiki_cs_300_fasttext_sentence': 0.23995709280797442,
#    'STS16_wiki_cs_300_fasttext_word': 0.2099749872211533},
#   'headlines': {'STS16_bert-base-cased_mean_pooled_torch': 0.5421631916919518,
#    'STS16_bert-base-cased_torch': 0.5892013636320054,
#    'STS16_cc_en_300_fasttext_sentence': 0.6401576283447556,
#    'STS16_cc_en_300_fasttext_word': 0.4406466314596257,
#    'STS16_wiki_cs_300_fasttext_sentence': 0.5991475800587382,
#    'STS16_wiki_cs_300_fasttext_word': 0.6120752842758558},
#   'plagiarism': {'STS16_bert-base-cased_mean_pooled_torch': 0.4900225542310833,
#    'STS16_bert-base-cased_torch': 0.4357427632627837,
#    'STS16_cc_en_300_fasttext_sentence': 0.5665088977043184,
#    'STS16_cc_en_300_fasttext_word': 0.28751150543021686,
#    'STS16_wiki_cs_300_fasttext_sentence': 0.4886277422714877,
#    'STS16_wiki_cs_300_fasttext_word': 0.5045992871412172},
#   'postediting': {'STS16_bert-base-cased_mean_pooled_torch': 0.3969384066508668,
#    'STS16_bert-base-cased_torch': 0.4218221282547021,
#    'STS16_cc_en_300_fasttext_sentence': 0.5887341559442562,
#    'STS16_cc_en_300_fasttext_word': 0.4252609518666171,
#    'STS16_wiki_cs_300_fasttext_sentence': 0.5348062727605822,
#    'STS16_wiki_cs_300_fasttext_word': 0.5499744224242898},
#   'question-question': {'STS16_bert-base-cased_mean_pooled_torch': 0.24207225186486922,
#    'STS16_bert-base-cased_torch': 0.24391960688286882,
#    'STS16_cc_en_300_fasttext_sentence': 0.30097857472393397,
#    'STS16_cc_en_300_fasttext_word': -0.007292283345907742,
#    'STS16_wiki_cs_300_fasttext_sentence': 0.18455880540218667,
#    'STS16_wiki_cs_300_fasttext_word': 0.21050625631782952}},
#  'STS162': {'answer-answer': {'STS162_bert-base-cased_torch': 0.3760310146895078,
#    'STS162_bert-base-cased_mean_pooled_torch': 0.5550939755708896,
#    'STS162_cc_en_300_fasttext_sentence': 0.3489387982476427,
#    'STS162_cc_en_300_fasttext_word': 0.3603717373295795,
#    'STS162_wiki_cs_300_fasttext_sentence': 0.23995708982819816,
#    'STS162_wiki_cs_300_fasttext_word': 0.32601016305496777},
#   'headlines': {'STS162_bert-base-cased_torch': 0.5036459855635268,
#    'STS162_bert-base-cased_mean_pooled_torch': 0.6334819915268047,
#    'STS162_cc_en_300_fasttext_sentence': 0.6401576283205536,
#    'STS162_cc_en_300_fasttext_word': 0.5480804829777879,
#    'STS162_wiki_cs_300_fasttext_sentence': 0.5991475806915812,
#    'STS162_wiki_cs_300_fasttext_word': 0.6269840730630858},
#   'plagiarism': {'STS162_bert-base-cased_torch': 0.6131590669704027,
#    'STS162_bert-base-cased_mean_pooled_torch': 0.7655284968786941,
#    'STS162_cc_en_300_fasttext_sentence': 0.566508899062466,
#    'STS162_cc_en_300_fasttext_word': 0.6431740251760772,
#    'STS162_wiki_cs_300_fasttext_sentence': 0.48862774500418377,
#    'STS162_wiki_cs_300_fasttext_word': 0.6623034175641477},
#   'postediting': {'STS162_bert-base-cased_torch': 0.7019757556504326,
#    'STS162_bert-base-cased_mean_pooled_torch': 0.8022864710063166,
#    'STS162_cc_en_300_fasttext_sentence': 0.5887341575324284,
#    'STS162_cc_en_300_fasttext_word': 0.740355557939472,
#    'STS162_wiki_cs_300_fasttext_sentence': 0.5348062734239757,
#    'STS162_wiki_cs_300_fasttext_word': 0.766695343904831},
#   'question-question': {'STS162_bert-base-cased_torch': 0.06937425637682093,
#    'STS162_bert-base-cased_mean_pooled_torch': 0.45670528209797157,
#    'STS162_cc_en_300_fasttext_sentence': 0.30097856413038576,
#    'STS162_cc_en_300_fasttext_word': 0.08615934376826677,
#    'STS162_wiki_cs_300_fasttext_sentence': 0.18455880077678855,
#    'STS162_wiki_cs_300_fasttext_word': 0.4290110963614181}}}

# %%
for task in pearson_results:
    display(task)
    df = pd.DataFrame(pearson_results[task])
    df = df.sort_values('headlines', ascending=False)
    display(df)
# Out:
# 'STSCZ'
#                                                     headlines    images  \
# STSCZ_wiki_cs_300_fasttext_sentence                  0.645831  0.701858
# STSCZ_wiki_cs_300_fasttext_word                      0.628627  0.729674
# STSCZ_cc_cs_300_fasttext_sentence                    0.582046  0.704813
# STSCZ_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_torch     0.525099  0.518032
# STSCZ_elmo_139                                       0.514739  0.623943
# STSCZ_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_mean...   0.512539  0.515134
# STSCZ_multi_cased_L-12_H-768_A-12_torch              0.510108  0.530078
# STSCZ_multi_cased_L-12_H-768_A-12_mean_pooled_t...   0.502097  0.558950
# STSCZ_multi_cased_L-12_H-768_A-12_mean_pooled_t...   0.502097  0.558950
# STSCZ_cc_cs_300_fasttext_word                        0.452434  0.552362
# STSCZ_bert-base-multilingual-cased_torch             0.451812  0.437345
# STSCZ_bert-base-multilingual-cased_torch_headlines   0.451812  0.016954
# STSCZ_bert-base-multilingual-cased_torch_all         0.451812  0.437345
#
#                                                     headlines2013-2015CZ_Lemma  \
# STSCZ_wiki_cs_300_fasttext_sentence                                   0.612050
# STSCZ_wiki_cs_300_fasttext_word                                       0.628071
# STSCZ_cc_cs_300_fasttext_sentence                                     0.587486
# STSCZ_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_torch                           NaN
# STSCZ_elmo_139                                                        0.531189
# STSCZ_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_mean...                    0.516721
# STSCZ_multi_cased_L-12_H-768_A-12_torch                                    NaN
# STSCZ_multi_cased_L-12_H-768_A-12_mean_pooled_t...                         NaN
# STSCZ_multi_cased_L-12_H-768_A-12_mean_pooled_t...                    0.482988
# STSCZ_cc_cs_300_fasttext_word                                         0.439307
# STSCZ_bert-base-multilingual-cased_torch                                   NaN
# STSCZ_bert-base-multilingual-cased_torch_headlines                         NaN
# STSCZ_bert-base-multilingual-cased_torch_all                          0.415025
#
#                                                     headlines2013-2015CZ_POSTag  \
# STSCZ_wiki_cs_300_fasttext_sentence                                    0.386879
# STSCZ_wiki_cs_300_fasttext_word                                        0.275580
# STSCZ_cc_cs_300_fasttext_sentence                                      0.362638
# STSCZ_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_torch                            NaN
# STSCZ_elmo_139                                                         0.138582
# STSCZ_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_mean...                     0.251757
# STSCZ_multi_cased_L-12_H-768_A-12_torch                                     NaN
# STSCZ_multi_cased_L-12_H-768_A-12_mean_pooled_t...                          NaN
# STSCZ_multi_cased_L-12_H-768_A-12_mean_pooled_t...                     0.279447
# STSCZ_cc_cs_300_fasttext_word                                          0.239384
# STSCZ_bert-base-multilingual-cased_torch                                    NaN
# STSCZ_bert-base-multilingual-cased_torch_headlines                          NaN
# STSCZ_bert-base-multilingual-cased_torch_all                           0.248012
#
#                                                     headlines2013-2015CZ_Stem  \
# STSCZ_wiki_cs_300_fasttext_sentence                                  0.630623
# STSCZ_wiki_cs_300_fasttext_word                                      0.671686
# STSCZ_cc_cs_300_fasttext_sentence                                    0.573576
# STSCZ_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_torch                          NaN
# STSCZ_elmo_139                                                       0.511911
# STSCZ_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_mean...                   0.497297
# STSCZ_multi_cased_L-12_H-768_A-12_torch                                   NaN
# STSCZ_multi_cased_L-12_H-768_A-12_mean_pooled_t...                        NaN
# STSCZ_multi_cased_L-12_H-768_A-12_mean_pooled_t...                   0.503367
# STSCZ_cc_cs_300_fasttext_word                                        0.418486
# STSCZ_bert-base-multilingual-cased_torch                                  NaN
# STSCZ_bert-base-multilingual-cased_torch_headlines                        NaN
# STSCZ_bert-base-multilingual-cased_torch_all                         0.407320
#
#                                                     imagesCZ2014-2015shuffled  \
# STSCZ_wiki_cs_300_fasttext_sentence                                  0.701858
# STSCZ_wiki_cs_300_fasttext_word                                      0.729674
# STSCZ_cc_cs_300_fasttext_sentence                                    0.704813
# STSCZ_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_torch                          NaN
# STSCZ_elmo_139                                                       0.623943
# STSCZ_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_mean...                   0.515134
# STSCZ_multi_cased_L-12_H-768_A-12_torch                                   NaN
# STSCZ_multi_cased_L-12_H-768_A-12_mean_pooled_t...                        NaN
# STSCZ_multi_cased_L-12_H-768_A-12_mean_pooled_t...                   0.558950
# STSCZ_cc_cs_300_fasttext_word                                        0.552362
# STSCZ_bert-base-multilingual-cased_torch                                  NaN
# STSCZ_bert-base-multilingual-cased_torch_headlines                        NaN
# STSCZ_bert-base-multilingual-cased_torch_all                         0.437345
#
#                                                     imagesCZ2014-2015shuffled_Lemma  \
# STSCZ_wiki_cs_300_fasttext_sentence                                        0.736000
# STSCZ_wiki_cs_300_fasttext_word                                            0.780287
# STSCZ_cc_cs_300_fasttext_sentence                                          0.739374
# STSCZ_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_torch                                NaN
# STSCZ_elmo_139                                                             0.680458
# STSCZ_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_mean...                         0.582982
# STSCZ_multi_cased_L-12_H-768_A-12_torch                                         NaN
# STSCZ_multi_cased_L-12_H-768_A-12_mean_pooled_t...                              NaN
# STSCZ_multi_cased_L-12_H-768_A-12_mean_pooled_t...                         0.634224
# STSCZ_cc_cs_300_fasttext_word                                              0.636856
# STSCZ_bert-base-multilingual-cased_torch                                        NaN
# STSCZ_bert-base-multilingual-cased_torch_headlines                              NaN
# STSCZ_bert-base-multilingual-cased_torch_all                               0.482463
#
#                                                     imagesCZ2014-2015shuffled_POSTag  \
# STSCZ_wiki_cs_300_fasttext_sentence                                         0.453499
# STSCZ_wiki_cs_300_fasttext_word                                             0.250657
# STSCZ_cc_cs_300_fasttext_sentence                                           0.442313
# STSCZ_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_torch                                 NaN
# STSCZ_elmo_139                                                              0.260029
# STSCZ_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_mean...                          0.408983
# STSCZ_multi_cased_L-12_H-768_A-12_torch                                          NaN
# STSCZ_multi_cased_L-12_H-768_A-12_mean_pooled_t...                               NaN
# STSCZ_multi_cased_L-12_H-768_A-12_mean_pooled_t...                          0.431461
# STSCZ_cc_cs_300_fasttext_word                                               0.171691
# STSCZ_bert-base-multilingual-cased_torch                                         NaN
# STSCZ_bert-base-multilingual-cased_torch_headlines                               NaN
# STSCZ_bert-base-multilingual-cased_torch_all                                0.360827
#
#                                                     imagesCZ2014-2015shuffled_Stem
# STSCZ_wiki_cs_300_fasttext_sentence                                       0.757723
# STSCZ_wiki_cs_300_fasttext_word                                           0.790972
# STSCZ_cc_cs_300_fasttext_sentence                                         0.735375
# STSCZ_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_torch                               NaN
# STSCZ_elmo_139                                                            0.623689
# STSCZ_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_mean...                        0.599791
# STSCZ_multi_cased_L-12_H-768_A-12_torch                                        NaN
# STSCZ_multi_cased_L-12_H-768_A-12_mean_pooled_t...                             NaN
# STSCZ_multi_cased_L-12_H-768_A-12_mean_pooled_t...                        0.613311
# STSCZ_cc_cs_300_fasttext_word                                             0.642850
# STSCZ_bert-base-multilingual-cased_torch                                       NaN
# STSCZ_bert-base-multilingual-cased_torch_headlines                             NaN
# STSCZ_bert-base-multilingual-cased_torch_all                              0.526641
# 'STSCZ2'
#                                                     headlines    images  \
# STSCZ2_wiki_cs_300_fasttext_sentence                 0.645831  0.701858
# STSCZ2_wiki_cs_300_fasttext_word                     0.604203  0.677268
# STSCZ2_cc_cs_300_fasttext_sentence                   0.582046  0.704813
# STSCZ2_cc_cs_300_fasttext_word                       0.576794  0.554880
# STSCZ2_multi_cased_L-12_H-768_A-12_mean_pooled_...   0.558530  0.627369
# STSCZ2_multi_cased_L-12_H-768_A-12_mean_pooled_...   0.558530  0.627369
# STSCZ2_multi_cased_L-12_H-768_A-12_torch             0.554428  0.612890
# STSCZ2_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_mea...   0.537396  0.581298
# STSCZ2_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_torch    0.534047  0.572633
# STSCZ2_bert-base-multilingual-cased_torch            0.383821  0.398240
# STSCZ2_bert-base-multilingual-cased_torch_all        0.383821  0.398240
# STSCZ2_elmo_139                                      0.272552  0.423214
#
#                                                     headlines2013-2015CZ_Lemma  \
# STSCZ2_wiki_cs_300_fasttext_sentence                                  0.612050
# STSCZ2_wiki_cs_300_fasttext_word                                      0.611361
# STSCZ2_cc_cs_300_fasttext_sentence                                    0.587486
# STSCZ2_cc_cs_300_fasttext_word                                        0.620098
# STSCZ2_multi_cased_L-12_H-768_A-12_mean_pooled_...                         NaN
# STSCZ2_multi_cased_L-12_H-768_A-12_mean_pooled_...                    0.567745
# STSCZ2_multi_cased_L-12_H-768_A-12_torch                                   NaN
# STSCZ2_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_mea...                    0.571214
# STSCZ2_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_torch                          NaN
# STSCZ2_bert-base-multilingual-cased_torch                                  NaN
# STSCZ2_bert-base-multilingual-cased_torch_all                         0.374208
# STSCZ2_elmo_139                                                       0.284061
#
#                                                     headlines2013-2015CZ_POSTag  \
# STSCZ2_wiki_cs_300_fasttext_sentence                                   0.386879
# STSCZ2_wiki_cs_300_fasttext_word                                       0.390843
# STSCZ2_cc_cs_300_fasttext_sentence                                     0.362638
# STSCZ2_cc_cs_300_fasttext_word                                         0.404856
# STSCZ2_multi_cased_L-12_H-768_A-12_mean_pooled_...                          NaN
# STSCZ2_multi_cased_L-12_H-768_A-12_mean_pooled_...                     0.316137
# STSCZ2_multi_cased_L-12_H-768_A-12_torch                                    NaN
# STSCZ2_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_mea...                     0.286464
# STSCZ2_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_torch                           NaN
# STSCZ2_bert-base-multilingual-cased_torch                                   NaN
# STSCZ2_bert-base-multilingual-cased_torch_all                          0.247176
# STSCZ2_elmo_139                                                        0.232990
#
#                                                     headlines2013-2015CZ_Stem  \
# STSCZ2_wiki_cs_300_fasttext_sentence                                 0.630623
# STSCZ2_wiki_cs_300_fasttext_word                                     0.610813
# STSCZ2_cc_cs_300_fasttext_sentence                                   0.573576
# STSCZ2_cc_cs_300_fasttext_word                                       0.591322
# STSCZ2_multi_cased_L-12_H-768_A-12_mean_pooled_...                        NaN
# STSCZ2_multi_cased_L-12_H-768_A-12_mean_pooled_...                   0.550061
# STSCZ2_multi_cased_L-12_H-768_A-12_torch                                  NaN
# STSCZ2_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_mea...                   0.553849
# STSCZ2_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_torch                         NaN
# STSCZ2_bert-base-multilingual-cased_torch                                 NaN
# STSCZ2_bert-base-multilingual-cased_torch_all                        0.396255
# STSCZ2_elmo_139                                                      0.170366
#
#                                                     imagesCZ2014-2015shuffled  \
# STSCZ2_wiki_cs_300_fasttext_sentence                                 0.701858
# STSCZ2_wiki_cs_300_fasttext_word                                     0.677290
# STSCZ2_cc_cs_300_fasttext_sentence                                   0.704813
# STSCZ2_cc_cs_300_fasttext_word                                       0.554866
# STSCZ2_multi_cased_L-12_H-768_A-12_mean_pooled_...                        NaN
# STSCZ2_multi_cased_L-12_H-768_A-12_mean_pooled_...                   0.627369
# STSCZ2_multi_cased_L-12_H-768_A-12_torch                                  NaN
# STSCZ2_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_mea...                   0.581298
# STSCZ2_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_torch                         NaN
# STSCZ2_bert-base-multilingual-cased_torch                                 NaN
# STSCZ2_bert-base-multilingual-cased_torch_all                        0.398240
# STSCZ2_elmo_139                                                      0.423219
#
#                                                     imagesCZ2014-2015shuffled_Lemma  \
# STSCZ2_wiki_cs_300_fasttext_sentence                                       0.736000
# STSCZ2_wiki_cs_300_fasttext_word                                           0.675058
# STSCZ2_cc_cs_300_fasttext_sentence                                         0.739374
# STSCZ2_cc_cs_300_fasttext_word                                             0.607401
# STSCZ2_multi_cased_L-12_H-768_A-12_mean_pooled_...                              NaN
# STSCZ2_multi_cased_L-12_H-768_A-12_mean_pooled_...                         0.619582
# STSCZ2_multi_cased_L-12_H-768_A-12_torch                                        NaN
# STSCZ2_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_mea...                         0.592106
# STSCZ2_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_torch                               NaN
# STSCZ2_bert-base-multilingual-cased_torch                                       NaN
# STSCZ2_bert-base-multilingual-cased_torch_all                              0.391990
# STSCZ2_elmo_139                                                            0.420209
#
#                                                     imagesCZ2014-2015shuffled_POSTag  \
# STSCZ2_wiki_cs_300_fasttext_sentence                                        0.453499
# STSCZ2_wiki_cs_300_fasttext_word                                            0.483375
# STSCZ2_cc_cs_300_fasttext_sentence                                          0.442313
# STSCZ2_cc_cs_300_fasttext_word                                              0.484610
# STSCZ2_multi_cased_L-12_H-768_A-12_mean_pooled_...                               NaN
# STSCZ2_multi_cased_L-12_H-768_A-12_mean_pooled_...                          0.455821
# STSCZ2_multi_cased_L-12_H-768_A-12_torch                                         NaN
# STSCZ2_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_mea...                          0.451115
# STSCZ2_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_torch                                NaN
# STSCZ2_bert-base-multilingual-cased_torch                                        NaN
# STSCZ2_bert-base-multilingual-cased_torch_all                               0.324000
# STSCZ2_elmo_139                                                             0.302627
#
#                                                     imagesCZ2014-2015shuffled_Stem
# STSCZ2_wiki_cs_300_fasttext_sentence                                      0.757723
# STSCZ2_wiki_cs_300_fasttext_word                                          0.711391
# STSCZ2_cc_cs_300_fasttext_sentence                                        0.735375
# STSCZ2_cc_cs_300_fasttext_word                                            0.602833
# STSCZ2_multi_cased_L-12_H-768_A-12_mean_pooled_...                             NaN
# STSCZ2_multi_cased_L-12_H-768_A-12_mean_pooled_...                        0.607900
# STSCZ2_multi_cased_L-12_H-768_A-12_torch                                       NaN
# STSCZ2_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_mea...                        0.607814
# STSCZ2_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_torch                              NaN
# STSCZ2_bert-base-multilingual-cased_torch                                      NaN
# STSCZ2_bert-base-multilingual-cased_torch_all                             0.451327
# STSCZ2_elmo_139                                                           0.366433
# 'STS16'
#                                          answer-answer  headlines  plagiarism  \
# STS16_cc_en_300_fasttext_sentence             0.348939   0.640158    0.566509
# STS16_wiki_cs_300_fasttext_word               0.209975   0.612075    0.504599
# STS16_wiki_cs_300_fasttext_sentence           0.239957   0.599148    0.488628
# STS16_bert-base-cased_torch                   0.353111   0.589201    0.435743
# STS16_bert-base-cased_mean_pooled_torch       0.321103   0.542163    0.490023
# STS16_cc_en_300_fasttext_word                 0.184348   0.440647    0.287512
#
#                                          postediting  question-question
# STS16_cc_en_300_fasttext_sentence           0.588734           0.300979
# STS16_wiki_cs_300_fasttext_word             0.549974           0.210506
# STS16_wiki_cs_300_fasttext_sentence         0.534806           0.184559
# STS16_bert-base-cased_torch                 0.421822           0.243920
# STS16_bert-base-cased_mean_pooled_torch     0.396938           0.242072
# STS16_cc_en_300_fasttext_word               0.425261          -0.007292
# 'STS162'
#                                           answer-answer  headlines  \
# STS162_cc_en_300_fasttext_sentence             0.348939   0.640158
# STS162_bert-base-cased_mean_pooled_torch       0.555094   0.633482
# STS162_wiki_cs_300_fasttext_word               0.326010   0.626984
# STS162_wiki_cs_300_fasttext_sentence           0.239957   0.599148
# STS162_cc_en_300_fasttext_word                 0.360372   0.548080
# STS162_bert-base-cased_torch                   0.376031   0.503646
#
#                                           plagiarism  postediting  \
# STS162_cc_en_300_fasttext_sentence          0.566509     0.588734
# STS162_bert-base-cased_mean_pooled_torch    0.765528     0.802286
# STS162_wiki_cs_300_fasttext_word            0.662303     0.766695
# STS162_wiki_cs_300_fasttext_sentence        0.488628     0.534806
# STS162_cc_en_300_fasttext_word              0.643174     0.740356
# STS162_bert-base-cased_torch                0.613159     0.701976
#
#                                           question-question
# STS162_cc_en_300_fasttext_sentence                 0.300979
# STS162_bert-base-cased_mean_pooled_torch           0.456705
# STS162_wiki_cs_300_fasttext_word                   0.429011
# STS162_wiki_cs_300_fasttext_sentence               0.184559
# STS162_cc_en_300_fasttext_word                     0.086159
# STS162_bert-base-cased_torch                       0.069374

# %%
for task in pearson_results:
    display(task)
    df = pd.DataFrame(all_results[task])
    df = df.sort_values(PEARSON, ascending=False)
    display(df)
# Out:
# 'STSCZ'
#                                                      pearson  spearman
# STSCZ_wiki_cs_300_fasttext_sentence                 0.634602  0.645182
# STSCZ_wiki_cs_300_fasttext_word                     0.619290  0.625226
# STSCZ_cc_cs_300_fasttext_sentence                   0.616563  0.624195
# STSCZ_multi_cased_L-12_H-768_A-12_mean_pooled_t...  0.536009  0.589423
# STSCZ_multi_cased_L-12_H-768_A-12_torch             0.522020  0.576311
# STSCZ_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_torch    0.520884  0.571077
# STSCZ_multi_cased_L-12_H-768_A-12_mean_pooled_t...  0.518153  0.566517
# STSCZ_elmo_139                                      0.513847  0.531696
# STSCZ_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_mean...  0.496374  0.553772
# STSCZ_cc_cs_300_fasttext_word                       0.467745  0.486335
# STSCZ_bert-base-multilingual-cased_torch            0.443182  0.527065
# STSCZ_bert-base-multilingual-cased_torch_all        0.424912  0.502240
# STSCZ_bert-base-multilingual-cased_torch_headlines  0.192423  0.382990
# 'STSCZ2'
#                                                      pearson  spearman
# STSCZ2_wiki_cs_300_fasttext_sentence                0.634602  0.645156
# STSCZ2_cc_cs_300_fasttext_sentence                  0.616563  0.624252
# STSCZ2_wiki_cs_300_fasttext_word                    0.613073  0.618057
# STSCZ2_multi_cased_L-12_H-768_A-12_mean_pooled_...  0.599592  0.612282
# STSCZ2_multi_cased_L-12_H-768_A-12_torch            0.589300  0.605837
# STSCZ2_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_torch   0.557063  0.577191
# STSCZ2_cc_cs_300_fasttext_word                      0.556476  0.572473
# STSCZ2_multi_cased_L-12_H-768_A-12_mean_pooled_...  0.556184  0.573161
# STSCZ2_bg_cs_pl_ru_cased_L-12_H-768_A-12_v1_mea...  0.536216  0.556067
# STSCZ2_bert-base-multilingual-cased_torch           0.392422  0.442826
# STSCZ2_bert-base-multilingual-cased_torch_all       0.377873  0.425252
# STSCZ2_elmo_139                                     0.335470  0.347201
# 'STS16'
#                                           pearson  spearman
# STS16_cc_en_300_fasttext_sentence        0.493155  0.542878
# STS16_wiki_cs_300_fasttext_word          0.421575  0.486014
# STS16_wiki_cs_300_fasttext_sentence      0.414491  0.481977
# STS16_bert-base-cased_torch              0.413597  0.527323
# STS16_bert-base-cased_mean_pooled_torch  0.401948  0.512354
# STS16_cc_en_300_fasttext_word            0.273957  0.345844
# 'STS162'
#                                            pearson  spearman
# STS162_bert-base-cased_mean_pooled_torch  0.645878  0.655573
# STS162_wiki_cs_300_fasttext_word          0.563231  0.590259
# STS162_cc_en_300_fasttext_sentence        0.493155  0.542878
# STS162_cc_en_300_fasttext_word            0.484478  0.498747
# STS162_bert-base-cased_torch              0.461828  0.498818
# STS162_wiki_cs_300_fasttext_sentence      0.414491  0.481977
